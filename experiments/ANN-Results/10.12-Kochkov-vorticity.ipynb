# %%
import matplotlib.pyplot as plt
from helpers.cm26 import DatasetCM26, operator_Kochkov, operator_coarsen, operator_gaussian
from helpers.computational_tools import select_NA, select_Pacific, select_Cem, select_Equator, StateFunctions, compare
from helpers.ann_tools import ANN, import_ANN, minibatch, export_ANN
import torch
import torch.optim as optim
import numpy as np
from time import time
import json
# %load_ext autoreload
# %autoreload 3
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ds = DatasetCM26()

# %%
ann_Txy = ANN([27, 20, 1])
ann_Txx_Tyy = ANN([27, 20, 2])
log_dict = {}
# ann_Txy = import_ANN('trained_models/ANN_CM26_Kochkov/Txy_epoch_2000.nc')
# ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26_Kochkov/Txx_Tyy_epoch_2000.nc')

# %%
num_epochs=1000

all_parameters = list(ann_Txy.parameters()) + list(ann_Txx_Tyy.parameters())
optimizer = optim.Adam(all_parameters, lr=1e-3)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
        milestones=[int(num_epochs/2), int(num_epochs*3/4), int(num_epochs*7/8)], gamma=0.1)  

t_s = time()

for epoch in range(num_epochs):
    t_e = time()
    
    training_dataset = ds.sample_epoch(time=np.random.randint(6950), operator=operator_Kochkov) # Approximately 19 years for training
    testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035), operator=operator_Kochkov) # Approximately 3 years for testing
    print(f'---------- Epoch {epoch} ------------\n')
    
    for factor in [2,4,6,10,20]:
        ############# Training step ################
        def tensor(x, torch_type=torch.float32):
            return torch.tensor(x.values).type(torch_type)
        
        batch = training_dataset[factor]
        # Momentum subgrid forcing
        SGSx = tensor(batch.data.SGSx)
        SGSy = tensor(batch.data.SGSy)
        SGS_norm = float(1. / np.sqrt((SGSx**2 + SGSy**2).mean()))
        SGSx = SGSx * SGS_norm
        SGSy = SGSy * SGS_norm
        
        # Vorticity subgrid forcing
        SGS_RV = batch.state.relative_vorticity_torch(SGSx, SGSy)
        SGS_RV_norm = 1. / torch.sqrt((SGS_RV**2).mean())
        SGS_RV = SGS_RV * SGS_RV_norm
        
        # order of loops is such that the last iteration
        # is standard model without augmentation
        for rotation in [90, 0]:
            for reflect_x in [True, False]:
                for reflect_y in [True, False]:
                    
                    optimizer.zero_grad()
                    prediction = batch.state.Apply_ANN(ann_Txy, ann_Txx_Tyy,
                        rotation=rotation, reflect_x=reflect_x, reflect_y=reflect_y)
                    ANNx = prediction['ZB20u'] * SGS_norm
                    ANNy = prediction['ZB20v'] * SGS_norm
                    ANN_RV = batch.state.relative_vorticity_torch(ANNx, ANNy) * SGS_RV_norm
                    
                    MSE_RV_train = ((ANN_RV - SGS_RV)**2).mean()
        
                    MSE_RV_train.backward()
                    optimizer.step()
                
        MSE_train = ((ANNx.detach()-SGSx)**2 + (ANNy.detach()-SGSy)**2).mean()
        
        ############ Testing step ##################
        with torch.no_grad():
            batch = testing_dataset[factor]
            
            # Momentum subgrid forcing
            SGSx = tensor(batch.data.SGSx)
            SGSy = tensor(batch.data.SGSy)
            SGS_norm = float(1. / np.sqrt((SGSx**2 + SGSy**2).mean()))
            SGSx = SGSx * SGS_norm
            SGSy = SGSy * SGS_norm

            # Vorticity subgrid forcing
            SGS_RV = batch.state.relative_vorticity_torch(SGSx, SGSy)
            SGS_RV_norm = 1. / torch.sqrt((SGS_RV**2).mean())
            SGS_RV = SGS_RV * SGS_RV_norm
            
            # prediction
            prediction = batch.state.Apply_ANN(ann_Txy, ann_Txx_Tyy,
                rotation=rotation, reflect_x=reflect_x, reflect_y=reflect_y)
            ANNx = prediction['ZB20u'] * SGS_norm
            ANNy = prediction['ZB20v'] * SGS_norm
            ANN_RV = batch.state.relative_vorticity_torch(ANNx, ANNy) * SGS_RV_norm
            
            MSE_RV_test = ((ANN_RV - SGS_RV)**2).mean()
            MSE_test = ((ANNx-SGSx)**2 + (ANNy-SGSy)**2).mean()
        
        print(f'Factor: {factor}. '+'MSE train/test: [%.6f, %.6f], MSE-RV train/test: [%.6f, %.6f]' % (float(MSE_train.data), float(MSE_test.data), float(MSE_RV_train.data), float(MSE_RV_test.data)))
        ########### Saving history of losses ############
        log_dict[f'epoch-{epoch+1}-factor-{factor}'] = dict(MSE_train=float(MSE_train.data),MSE_test=float(MSE_test.data), MSE_RV_train=float(MSE_RV_train.data), MSE_RV_test=float(MSE_RV_test.data))
        ######## Freeing memory ############
        del training_dataset[factor].data
        del training_dataset[factor].param
        del testing_dataset[factor].data
        del testing_dataset[factor].param
    t = time()
    print('Epoch time/Remaining time in seconds: [%d/%d]' % (t-t_e, (t-t_s)*(num_epochs/(epoch+1)-1)))
    scheduler.step()
    
    if (epoch+1) % 50 == 0:
        export_ANN(ann_Txy, input_norms=torch.ones(27), output_norms=torch.ones(1), 
           filename=f'trained_models/ANN_CM26_Kochkov_vorticity/Txy_epoch_{epoch+1}.nc')
        export_ANN(ann_Txx_Tyy, input_norms=torch.ones(27), output_norms=torch.ones(2), 
           filename=f'trained_models/ANN_CM26_Kochkov_vorticity/Txx_Tyy_epoch_{epoch+1}.nc')
        with open(f'trained_models/ANN_CM26_Kochkov_vorticity/log_dict_epoch_{epoch+1}', 'w') as file:
            json.dump(log_dict, file)
# Out:
# ---------- Epoch 0 ------------
#
# Factor: 2. MSE train/test: [68.404526, 59.494827], MSE-RV train/test: [25.272274, 24.709126]
# Factor: 4. MSE train/test: [27.087132, 28.762114], MSE-RV train/test: [7.119515, 9.706103]
# Factor: 6. MSE train/test: [17.373983, 19.586475], MSE-RV train/test: [5.062565, 6.251055]
# Factor: 10. MSE train/test: [8.917799, 9.101432], MSE-RV train/test: [3.259121, 3.393558]
# Factor: 20. MSE train/test: [3.404039, 2.885223], MSE-RV train/test: [1.725383, 1.729884]
# Epoch time/Remaining time in seconds: [23/23677]
# ---------- Epoch 1 ------------
#
# Factor: 2. MSE train/test: [34.675865, 33.103409], MSE-RV train/test: [10.908404, 10.236644]
# Factor: 4. MSE train/test: [14.511780, 14.903557], MSE-RV train/test: [3.945120, 3.888195]
# Factor: 6. MSE train/test: [9.051028, 8.856112], MSE-RV train/test: [2.768940, 2.728858]
# Factor: 10. MSE train/test: [4.814860, 4.593243], MSE-RV train/test: [2.052456, 1.940453]
# Factor: 20. MSE train/test: [1.887865, 1.923174], MSE-RV train/test: [1.241882, 1.331210]
# Epoch time/Remaining time in seconds: [24/23904]
# ---------- Epoch 2 ------------
#
# Factor: 2. MSE train/test: [15.007629, 12.661164], MSE-RV train/test: [4.450788, 4.123879]
# Factor: 4. MSE train/test: [7.131016, 6.252481], MSE-RV train/test: [1.907622, 1.899531]
# Factor: 6. MSE train/test: [5.040043, 4.374372], MSE-RV train/test: [1.673558, 1.552402]
# Factor: 10. MSE train/test: [2.982778, 2.656822], MSE-RV train/test: [1.448469, 1.366698]
# Factor: 20. MSE train/test: [1.450913, 1.480976], MSE-RV train/test: [1.099815, 1.136966]
# Epoch time/Remaining time in seconds: [23/23714]
# ---------- Epoch 3 ------------
#
# Factor: 2. MSE train/test: [7.291159, 7.098838], MSE-RV train/test: [2.235334, 2.108627]
# Factor: 4. MSE train/test: [4.564108, 4.036337], MSE-RV train/test: [1.417740, 1.389028]
# Factor: 6. MSE train/test: [3.422193, 2.866977], MSE-RV train/test: [1.228349, 1.220992]
# Factor: 10. MSE train/test: [2.280133, 1.957563], MSE-RV train/test: [1.163173, 1.138435]
# Factor: 20. MSE train/test: [1.219669, 1.255469], MSE-RV train/test: [1.054839, 1.046610]
# Epoch time/Remaining time in seconds: [22/23438]
# ---------- Epoch 4 ------------
#
# Factor: 2. MSE train/test: [4.728504, 5.398684], MSE-RV train/test: [1.516830, 1.430609]
# Factor: 4. MSE train/test: [3.172020, 3.247180], MSE-RV train/test: [1.166100, 1.146133]
# Factor: 6. MSE train/test: [2.504109, 2.700186], MSE-RV train/test: [1.114107, 1.113699]
# Factor: 10. MSE train/test: [1.801973, 1.892256], MSE-RV train/test: [1.103669, 1.090253]
# Factor: 20. MSE train/test: [1.162016, 1.249797], MSE-RV train/test: [1.016795, 1.021034]
# Epoch time/Remaining time in seconds: [22/23288]
# ---------- Epoch 5 ------------
#
# Factor: 2. MSE train/test: [4.947688, 3.986445], MSE-RV train/test: [1.334453, 1.940677]
# Factor: 4. MSE train/test: [3.150977, 2.969157], MSE-RV train/test: [1.049425, 1.111111]
# Factor: 6. MSE train/test: [2.682959, 2.459892], MSE-RV train/test: [1.073402, 1.026181]
# Factor: 10. MSE train/test: [1.806630, 1.773571], MSE-RV train/test: [1.071996, 1.046462]
# Factor: 20. MSE train/test: [1.222212, 1.148440], MSE-RV train/test: [1.033417, 1.025043]
# Epoch time/Remaining time in seconds: [22/23074]
# ---------- Epoch 6 ------------
#
# Factor: 2. MSE train/test: [3.965449, 3.862172], MSE-RV train/test: [1.165383, 1.311502]
# Factor: 4. MSE train/test: [2.920356, 2.972445], MSE-RV train/test: [0.986082, 1.013718]
# Factor: 6. MSE train/test: [2.434628, 2.484195], MSE-RV train/test: [0.983018, 1.004777]
# Factor: 10. MSE train/test: [1.841323, 1.690076], MSE-RV train/test: [1.019620, 1.010038]
# Factor: 20. MSE train/test: [1.184841, 1.131387], MSE-RV train/test: [1.016423, 1.012650]
# Epoch time/Remaining time in seconds: [23/23025]
# ---------- Epoch 7 ------------
#
# Factor: 2. MSE train/test: [3.606683, 4.166738], MSE-RV train/test: [1.105904, 1.019524]
# Factor: 4. MSE train/test: [2.525690, 2.674701], MSE-RV train/test: [0.961895, 0.950440]
# Factor: 6. MSE train/test: [2.197035, 2.208357], MSE-RV train/test: [0.973590, 0.974518]
# Factor: 10. MSE train/test: [1.643708, 1.656303], MSE-RV train/test: [1.003358, 1.012262]
# Factor: 20. MSE train/test: [1.104633, 1.118158], MSE-RV train/test: [1.010287, 1.014758]
# Epoch time/Remaining time in seconds: [23/23027]
# ---------- Epoch 8 ------------
#
# Factor: 2. MSE train/test: [4.093813, 3.729702], MSE-RV train/test: [1.014288, 1.059212]
# Factor: 4. MSE train/test: [2.715627, 2.668736], MSE-RV train/test: [0.915071, 0.925129]
# Factor: 6. MSE train/test: [2.245408, 2.240421], MSE-RV train/test: [0.925233, 0.972891]
# Factor: 10. MSE train/test: [1.644476, 1.605375], MSE-RV train/test: [0.991252, 0.999990]
# Factor: 20. MSE train/test: [1.154658, 1.167521], MSE-RV train/test: [0.999905, 1.011307]
# Epoch time/Remaining time in seconds: [23/23034]
# ---------- Epoch 9 ------------
#
# Factor: 2. MSE train/test: [3.696632, 3.332285], MSE-RV train/test: [0.959322, 1.038501]
# Factor: 4. MSE train/test: [2.487949, 2.502550], MSE-RV train/test: [0.912883, 0.916326]
# Factor: 6. MSE train/test: [2.136463, 2.112372], MSE-RV train/test: [0.944706, 0.948005]
# Factor: 10. MSE train/test: [1.537851, 1.545046], MSE-RV train/test: [0.998206, 0.999128]
# Factor: 20. MSE train/test: [1.069144, 1.170305], MSE-RV train/test: [1.005607, 1.015557]
# Epoch time/Remaining time in seconds: [26/23334]
# ---------- Epoch 10 ------------
#
# Factor: 2. MSE train/test: [3.730861, 3.455379], MSE-RV train/test: [1.044051, 0.940793]
# Factor: 4. MSE train/test: [2.596930, 2.593880], MSE-RV train/test: [0.869404, 0.894897]
# Factor: 6. MSE train/test: [2.183296, 2.046091], MSE-RV train/test: [0.869097, 0.939339]
# Factor: 10. MSE train/test: [1.602510, 1.499892], MSE-RV train/test: [0.984539, 0.999232]
# Factor: 20. MSE train/test: [1.058586, 1.079250], MSE-RV train/test: [1.003776, 1.004465]
# Epoch time/Remaining time in seconds: [26/23588]
# ---------- Epoch 11 ------------
#
# Factor: 2. MSE train/test: [3.233078, 3.747186], MSE-RV train/test: [0.916437, 0.921817]
# Factor: 4. MSE train/test: [2.482819, 2.662388], MSE-RV train/test: [0.860550, 0.892477]
# Factor: 6. MSE train/test: [2.074419, 2.102542], MSE-RV train/test: [0.891106, 0.910553]
# Factor: 10. MSE train/test: [1.567462, 1.549692], MSE-RV train/test: [0.960757, 0.976790]
# Factor: 20. MSE train/test: [1.131738, 1.088047], MSE-RV train/test: [1.002576, 1.001271]
# Epoch time/Remaining time in seconds: [27/23873]
# ---------- Epoch 12 ------------
#
# Factor: 2. MSE train/test: [3.925221, 3.614837], MSE-RV train/test: [0.900130, 0.991917]
# Factor: 4. MSE train/test: [2.585756, 2.419610], MSE-RV train/test: [0.873049, 0.883723]
# Factor: 6. MSE train/test: [2.091221, 2.057564], MSE-RV train/test: [0.902535, 0.920705]
# Factor: 10. MSE train/test: [1.593787, 1.479791], MSE-RV train/test: [0.958191, 0.972680]
# Factor: 20. MSE train/test: [1.125758, 1.124930], MSE-RV train/test: [1.012711, 1.000135]
# Epoch time/Remaining time in seconds: [27/24067]
# ---------- Epoch 13 ------------
#
# Factor: 2. MSE train/test: [3.360207, 4.038997], MSE-RV train/test: [0.889204, 0.866759]
# Factor: 4. MSE train/test: [2.540704, 2.509238], MSE-RV train/test: [0.861852, 0.833592]
# Factor: 6. MSE train/test: [2.016785, 2.001632], MSE-RV train/test: [0.889586, 0.875068]
# Factor: 10. MSE train/test: [1.507216, 1.487590], MSE-RV train/test: [0.960259, 0.976654]
# Factor: 20. MSE train/test: [1.136851, 1.118790], MSE-RV train/test: [1.004175, 0.996513]
# Epoch time/Remaining time in seconds: [27/24243]
# ---------- Epoch 14 ------------
#
# Factor: 2. MSE train/test: [3.120920, 3.727969], MSE-RV train/test: [0.912854, 0.902313]
# Factor: 4. MSE train/test: [2.406366, 2.423681], MSE-RV train/test: [0.862765, 0.840467]
# Factor: 6. MSE train/test: [1.955822, 1.971716], MSE-RV train/test: [0.931644, 0.907196]
# Factor: 10. MSE train/test: [1.368705, 1.497717], MSE-RV train/test: [0.990420, 0.991888]
# Factor: 20. MSE train/test: [1.069967, 1.130610], MSE-RV train/test: [1.000049, 0.992479]
# Epoch time/Remaining time in seconds: [23/24143]
# ---------- Epoch 15 ------------
#
# Factor: 2. MSE train/test: [3.353056, 3.528184], MSE-RV train/test: [1.000860, 0.849474]
# Factor: 4. MSE train/test: [2.248522, 2.183805], MSE-RV train/test: [0.885851, 0.845298]
# Factor: 6. MSE train/test: [1.947551, 1.896712], MSE-RV train/test: [0.916151, 0.908049]
# Factor: 10. MSE train/test: [1.491939, 1.407722], MSE-RV train/test: [0.961790, 0.962803]
# Factor: 20. MSE train/test: [1.092390, 1.110065], MSE-RV train/test: [0.998382, 0.997165]
# Epoch time/Remaining time in seconds: [23/24076]
# ---------- Epoch 16 ------------
#
# Factor: 2. MSE train/test: [3.254136, 3.031574], MSE-RV train/test: [0.981156, 0.844850]
# Factor: 4. MSE train/test: [2.423980, 2.244463], MSE-RV train/test: [0.884462, 0.852405]
# Factor: 6. MSE train/test: [1.995934, 1.880032], MSE-RV train/test: [0.895615, 0.892927]
# Factor: 10. MSE train/test: [1.407935, 1.375977], MSE-RV train/test: [0.960774, 0.978267]
# Factor: 20. MSE train/test: [1.077175, 1.082500], MSE-RV train/test: [1.000240, 1.006734]
# Epoch time/Remaining time in seconds: [23/23978]
# ---------- Epoch 17 ------------
#
# Factor: 2. MSE train/test: [3.193513, 3.114868], MSE-RV train/test: [0.830248, 0.845896]
# Factor: 4. MSE train/test: [2.450186, 2.299453], MSE-RV train/test: [0.858986, 0.870639]
# Factor: 6. MSE train/test: [1.986489, 1.969943], MSE-RV train/test: [0.869422, 0.900470]
# Factor: 10. MSE train/test: [1.444904, 1.428478], MSE-RV train/test: [0.963159, 0.970720]
# Factor: 20. MSE train/test: [1.117331, 1.052075], MSE-RV train/test: [0.994811, 0.983751]
# Epoch time/Remaining time in seconds: [23/23878]
# ---------- Epoch 18 ------------
#
# Factor: 2. MSE train/test: [3.114846, 3.506420], MSE-RV train/test: [0.852321, 0.873112]
# Factor: 4. MSE train/test: [2.135482, 2.416332], MSE-RV train/test: [0.876206, 0.871496]
# Factor: 6. MSE train/test: [1.835740, 1.952930], MSE-RV train/test: [0.905458, 0.899357]
# Factor: 10. MSE train/test: [1.369191, 1.392228], MSE-RV train/test: [0.964494, 0.953283]
# Factor: 20. MSE train/test: [1.093410, 1.134167], MSE-RV train/test: [0.992807, 1.006233]
# Epoch time/Remaining time in seconds: [23/23807]
# ---------- Epoch 19 ------------
#
# Factor: 2. MSE train/test: [3.397715, 3.149469], MSE-RV train/test: [0.891497, 0.855468]
# Factor: 4. MSE train/test: [2.497741, 2.325623], MSE-RV train/test: [0.882065, 0.839217]
# Factor: 6. MSE train/test: [1.930356, 1.969838], MSE-RV train/test: [0.909527, 0.878134]
# Factor: 10. MSE train/test: [1.432989, 1.409335], MSE-RV train/test: [0.963322, 0.956120]
# Factor: 20. MSE train/test: [1.087533, 1.037244], MSE-RV train/test: [1.011882, 0.989712]
# Epoch time/Remaining time in seconds: [23/23737]
# ---------- Epoch 20 ------------
#
# Factor: 2. MSE train/test: [3.386292, 3.458296], MSE-RV train/test: [0.831133, 0.818655]
# Factor: 4. MSE train/test: [2.245704, 2.409147], MSE-RV train/test: [0.843058, 0.834310]
# Factor: 6. MSE train/test: [1.842484, 1.921950], MSE-RV train/test: [0.891704, 0.869345]
# Factor: 10. MSE train/test: [1.437936, 1.411605], MSE-RV train/test: [0.959041, 0.962929]
# Factor: 20. MSE train/test: [1.090348, 1.121955], MSE-RV train/test: [1.001678, 1.005236]
# Epoch time/Remaining time in seconds: [23/23659]
# ---------- Epoch 21 ------------
#
# Factor: 2. MSE train/test: [3.587199, 3.613128], MSE-RV train/test: [0.794392, 0.882567]
# Factor: 4. MSE train/test: [2.208952, 2.378342], MSE-RV train/test: [0.840454, 0.854086]
# Factor: 6. MSE train/test: [1.814291, 1.848542], MSE-RV train/test: [0.890268, 0.899832]
# Factor: 10. MSE train/test: [1.383281, 1.410981], MSE-RV train/test: [0.962535, 0.962934]
# Factor: 20. MSE train/test: [1.110932, 1.097290], MSE-RV train/test: [1.001273, 1.011375]
# Epoch time/Remaining time in seconds: [23/23600]
# ---------- Epoch 22 ------------
#
# Factor: 2. MSE train/test: [3.668849, 3.844780], MSE-RV train/test: [0.831701, 0.804362]
# Factor: 4. MSE train/test: [2.298512, 2.372828], MSE-RV train/test: [0.852552, 0.839437]
# Factor: 6. MSE train/test: [1.864070, 1.958705], MSE-RV train/test: [0.890834, 0.870988]
# Factor: 10. MSE train/test: [1.401929, 1.402519], MSE-RV train/test: [0.975735, 0.981046]
# Factor: 20. MSE train/test: [1.093440, 1.048204], MSE-RV train/test: [0.996349, 0.995566]
# Epoch time/Remaining time in seconds: [23/23569]
# ---------- Epoch 23 ------------
#
# Factor: 2. MSE train/test: [3.397205, 3.511685], MSE-RV train/test: [0.813685, 0.847275]
# Factor: 4. MSE train/test: [2.459166, 2.281903], MSE-RV train/test: [0.841221, 0.834784]
# Factor: 6. MSE train/test: [1.986973, 1.852448], MSE-RV train/test: [0.880169, 0.879807]
# Factor: 10. MSE train/test: [1.428617, 1.351961], MSE-RV train/test: [0.949067, 0.953554]
# Factor: 20. MSE train/test: [1.088335, 1.093610], MSE-RV train/test: [0.995722, 0.996259]
# Epoch time/Remaining time in seconds: [23/23514]
# ---------- Epoch 24 ------------
#
# Factor: 2. MSE train/test: [3.346745, 3.712440], MSE-RV train/test: [0.825125, 0.809944]
# Factor: 4. MSE train/test: [2.504395, 2.313964], MSE-RV train/test: [0.844370, 0.825778]
# Factor: 6. MSE train/test: [1.999370, 1.983075], MSE-RV train/test: [0.888114, 0.864216]
# Factor: 10. MSE train/test: [1.473777, 1.380522], MSE-RV train/test: [0.962967, 0.965475]
# Factor: 20. MSE train/test: [1.093827, 1.078985], MSE-RV train/test: [0.995284, 1.001953]
# Epoch time/Remaining time in seconds: [23/23456]
# ---------- Epoch 25 ------------
#
# Factor: 2. MSE train/test: [3.350955, 4.195464], MSE-RV train/test: [0.822021, 0.828992]
# Factor: 4. MSE train/test: [2.166762, 2.640317], MSE-RV train/test: [0.853958, 0.818693]
# Factor: 6. MSE train/test: [1.794122, 1.961975], MSE-RV train/test: [0.902746, 0.867209]
# Factor: 10. MSE train/test: [1.357176, 1.337207], MSE-RV train/test: [0.966718, 0.933654]
# Factor: 20. MSE train/test: [1.080238, 1.107424], MSE-RV train/test: [1.001806, 0.996947]
# Epoch time/Remaining time in seconds: [24/23431]
# ---------- Epoch 26 ------------
#
# Factor: 2. MSE train/test: [3.831578, 2.942687], MSE-RV train/test: [0.803174, 0.916213]
# Factor: 4. MSE train/test: [2.330145, 2.333309], MSE-RV train/test: [0.831869, 0.851085]
# Factor: 6. MSE train/test: [1.826939, 1.856229], MSE-RV train/test: [0.873016, 0.891960]
# Factor: 10. MSE train/test: [1.365614, 1.395826], MSE-RV train/test: [0.941439, 0.956302]
# Factor: 20. MSE train/test: [1.067522, 1.098569], MSE-RV train/test: [0.999545, 1.009231]
# Epoch time/Remaining time in seconds: [27/23538]
# ---------- Epoch 27 ------------
#
# Factor: 2. MSE train/test: [3.401498, 3.553040], MSE-RV train/test: [0.810900, 0.808626]
# Factor: 4. MSE train/test: [2.414876, 2.232203], MSE-RV train/test: [0.825026, 0.857235]
# Factor: 6. MSE train/test: [1.953226, 1.827938], MSE-RV train/test: [0.874723, 0.888476]
# Factor: 10. MSE train/test: [1.440856, 1.425832], MSE-RV train/test: [0.967814, 0.960599]
# Factor: 20. MSE train/test: [1.096780, 1.083986], MSE-RV train/test: [1.000691, 1.002098]
# Epoch time/Remaining time in seconds: [27/23621]
# ---------- Epoch 28 ------------
#
# Factor: 2. MSE train/test: [3.966743, 4.208418], MSE-RV train/test: [0.801334, 0.787097]
# Factor: 4. MSE train/test: [2.309144, 2.392246], MSE-RV train/test: [0.804130, 0.797437]
# Factor: 6. MSE train/test: [1.827894, 1.904016], MSE-RV train/test: [0.898562, 0.844187]
# Factor: 10. MSE train/test: [1.370801, 1.423169], MSE-RV train/test: [0.983995, 0.958082]
# Factor: 20. MSE train/test: [1.080629, 1.120341], MSE-RV train/test: [1.001889, 0.993643]
# Epoch time/Remaining time in seconds: [27/23692]
# ---------- Epoch 29 ------------
#
# Factor: 2. MSE train/test: [3.556275, 3.055094], MSE-RV train/test: [0.801186, 0.821368]
# Factor: 4. MSE train/test: [2.479244, 2.255015], MSE-RV train/test: [0.816519, 0.850777]
# Factor: 6. MSE train/test: [1.940422, 1.821512], MSE-RV train/test: [0.865265, 0.903116]
# Factor: 10. MSE train/test: [1.406995, 1.403607], MSE-RV train/test: [0.956448, 0.959869]
# Factor: 20. MSE train/test: [1.093812, 1.094982], MSE-RV train/test: [0.997178, 0.989065]
# Epoch time/Remaining time in seconds: [23/23641]
# ---------- Epoch 30 ------------
#
# Factor: 2. MSE train/test: [3.905794, 3.370132], MSE-RV train/test: [0.794757, 0.803800]
# Factor: 4. MSE train/test: [2.452667, 2.399028], MSE-RV train/test: [0.816359, 0.825777]
# Factor: 6. MSE train/test: [1.911359, 1.911831], MSE-RV train/test: [0.889034, 0.865044]
# Factor: 10. MSE train/test: [1.377447, 1.401466], MSE-RV train/test: [0.977645, 0.961844]
# Factor: 20. MSE train/test: [1.064994, 1.097145], MSE-RV train/test: [1.000783, 0.997759]
# Epoch time/Remaining time in seconds: [22/23568]
# ---------- Epoch 31 ------------
#
# Factor: 2. MSE train/test: [3.465609, 3.894749], MSE-RV train/test: [0.805970, 0.808653]
# Factor: 4. MSE train/test: [2.026686, 2.420474], MSE-RV train/test: [0.863569, 0.827139]
# Factor: 6. MSE train/test: [1.671305, 1.972508], MSE-RV train/test: [0.912212, 0.873057]
# Factor: 10. MSE train/test: [1.394024, 1.449380], MSE-RV train/test: [0.946617, 0.953807]
# Factor: 20. MSE train/test: [1.106814, 1.069150], MSE-RV train/test: [0.997635, 0.997197]
# Epoch time/Remaining time in seconds: [23/23521]
# ---------- Epoch 32 ------------
#
# Factor: 2. MSE train/test: [3.501111, 3.556908], MSE-RV train/test: [0.786903, 0.798199]
# Factor: 4. MSE train/test: [2.393374, 2.387839], MSE-RV train/test: [0.816212, 0.828066]
# Factor: 6. MSE train/test: [1.937889, 1.953896], MSE-RV train/test: [0.854110, 0.879083]
# Factor: 10. MSE train/test: [1.458511, 1.428216], MSE-RV train/test: [0.946745, 0.960987]
# Factor: 20. MSE train/test: [1.138936, 1.117599], MSE-RV train/test: [0.993822, 1.007053]
# Epoch time/Remaining time in seconds: [23/23477]
# ---------- Epoch 33 ------------
#
# Factor: 2. MSE train/test: [2.954351, 3.249132], MSE-RV train/test: [0.813111, 0.811240]
# Factor: 4. MSE train/test: [2.179114, 2.372408], MSE-RV train/test: [0.861241, 0.810636]
# Factor: 6. MSE train/test: [1.808959, 1.859394], MSE-RV train/test: [0.884158, 0.870153]
# Factor: 10. MSE train/test: [1.373594, 1.403363], MSE-RV train/test: [0.956120, 0.929597]
# Factor: 20. MSE train/test: [1.073156, 1.089168], MSE-RV train/test: [0.995629, 0.989975]
# Epoch time/Remaining time in seconds: [22/23416]
# ---------- Epoch 34 ------------
#
# Factor: 2. MSE train/test: [3.233102, 3.538708], MSE-RV train/test: [0.850730, 0.780912]
# Factor: 4. MSE train/test: [2.123072, 2.422016], MSE-RV train/test: [0.830740, 0.812230]
# Factor: 6. MSE train/test: [1.752659, 1.871172], MSE-RV train/test: [0.868240, 0.854420]
# Factor: 10. MSE train/test: [1.373704, 1.388921], MSE-RV train/test: [0.968549, 0.942795]
# Factor: 20. MSE train/test: [1.093311, 1.081463], MSE-RV train/test: [1.003676, 1.000787]
# Epoch time/Remaining time in seconds: [23/23374]
# ---------- Epoch 35 ------------
#
# Factor: 2. MSE train/test: [3.732934, 3.521314], MSE-RV train/test: [0.805446, 0.759463]
# Factor: 4. MSE train/test: [2.407335, 2.390368], MSE-RV train/test: [0.828184, 0.796452]
# Factor: 6. MSE train/test: [1.889331, 1.922546], MSE-RV train/test: [0.875874, 0.859777]
# Factor: 10. MSE train/test: [1.409487, 1.473224], MSE-RV train/test: [0.954695, 0.958985]
# Factor: 20. MSE train/test: [1.126739, 1.131752], MSE-RV train/test: [0.998954, 1.004865]
# Epoch time/Remaining time in seconds: [23/23330]
# ---------- Epoch 36 ------------
#
# Factor: 2. MSE train/test: [3.798822, 3.153567], MSE-RV train/test: [0.813430, 0.795225]
# Factor: 4. MSE train/test: [2.553343, 2.097137], MSE-RV train/test: [0.790598, 0.832470]
# Factor: 6. MSE train/test: [2.004408, 1.785413], MSE-RV train/test: [0.857983, 0.888128]
# Factor: 10. MSE train/test: [1.456338, 1.392162], MSE-RV train/test: [0.955522, 0.960460]
# Factor: 20. MSE train/test: [1.148113, 1.079631], MSE-RV train/test: [1.007668, 1.004635]
# Epoch time/Remaining time in seconds: [23/23287]
# ---------- Epoch 37 ------------
#
# Factor: 2. MSE train/test: [3.331122, 3.528430], MSE-RV train/test: [0.774064, 0.788964]
# Factor: 4. MSE train/test: [2.113568, 2.266845], MSE-RV train/test: [0.809922, 0.821201]
# Factor: 6. MSE train/test: [1.724992, 1.829075], MSE-RV train/test: [0.856458, 0.857073]
# Factor: 10. MSE train/test: [1.421192, 1.410932], MSE-RV train/test: [0.955036, 0.937321]
# Factor: 20. MSE train/test: [1.101559, 1.105308], MSE-RV train/test: [0.994195, 0.998181]
# Epoch time/Remaining time in seconds: [24/23261]
# ---------- Epoch 38 ------------
#
# Factor: 2. MSE train/test: [3.683964, 2.789688], MSE-RV train/test: [0.787224, 0.821899]
# Factor: 4. MSE train/test: [2.307026, 2.160155], MSE-RV train/test: [0.815318, 0.832270]
# Factor: 6. MSE train/test: [1.938919, 1.864053], MSE-RV train/test: [0.865784, 0.891998]
# Factor: 10. MSE train/test: [1.359137, 1.398037], MSE-RV train/test: [0.953831, 0.930319]
# Factor: 20. MSE train/test: [1.033942, 1.084938], MSE-RV train/test: [0.983756, 0.995146]
# Epoch time/Remaining time in seconds: [23/23209]
# ---------- Epoch 39 ------------
#
# Factor: 2. MSE train/test: [3.588030, 3.508766], MSE-RV train/test: [0.803711, 0.773254]
# Factor: 4. MSE train/test: [2.175176, 2.262687], MSE-RV train/test: [0.846531, 0.789443]
# Factor: 6. MSE train/test: [1.761733, 1.778136], MSE-RV train/test: [0.893928, 0.838700]
# Factor: 10. MSE train/test: [1.367003, 1.392337], MSE-RV train/test: [0.945087, 0.936261]
# Factor: 20. MSE train/test: [1.134009, 1.091886], MSE-RV train/test: [1.003807, 1.009203]
# Epoch time/Remaining time in seconds: [22/23155]
# ---------- Epoch 40 ------------
#
# Factor: 2. MSE train/test: [3.482398, 3.618629], MSE-RV train/test: [0.801400, 0.789753]
# Factor: 4. MSE train/test: [2.324671, 2.171155], MSE-RV train/test: [0.818741, 0.826253]
# Factor: 6. MSE train/test: [1.838339, 1.755409], MSE-RV train/test: [0.875362, 0.854867]
# Factor: 10. MSE train/test: [1.401875, 1.404633], MSE-RV train/test: [0.934696, 0.970604]
# Factor: 20. MSE train/test: [1.083655, 1.130034], MSE-RV train/test: [0.997510, 0.989996]
# Epoch time/Remaining time in seconds: [23/23116]
# ---------- Epoch 41 ------------
#
# Factor: 2. MSE train/test: [3.475397, 3.140773], MSE-RV train/test: [0.790970, 0.844656]
# Factor: 4. MSE train/test: [2.179815, 2.256358], MSE-RV train/test: [0.827043, 0.837293]
# Factor: 6. MSE train/test: [1.782900, 1.768037], MSE-RV train/test: [0.871557, 0.877506]
# Factor: 10. MSE train/test: [1.373753, 1.475453], MSE-RV train/test: [0.945200, 0.954862]
# Factor: 20. MSE train/test: [1.146363, 1.134603], MSE-RV train/test: [0.999876, 0.989246]
# Epoch time/Remaining time in seconds: [24/23099]
# ---------- Epoch 42 ------------
#
# Factor: 2. MSE train/test: [3.671343, 3.341443], MSE-RV train/test: [0.759868, 0.802624]
# Factor: 4. MSE train/test: [2.350748, 2.140591], MSE-RV train/test: [0.784460, 0.822481]
# Factor: 6. MSE train/test: [1.893013, 1.761515], MSE-RV train/test: [0.834686, 0.887486]
# Factor: 10. MSE train/test: [1.407090, 1.310835], MSE-RV train/test: [0.936874, 0.950941]
# Factor: 20. MSE train/test: [1.117069, 1.113478], MSE-RV train/test: [1.002264, 1.005720]
# Epoch time/Remaining time in seconds: [24/23085]
# ---------- Epoch 43 ------------
#
# Factor: 2. MSE train/test: [3.422277, 3.573091], MSE-RV train/test: [0.760867, 0.801568]
# Factor: 4. MSE train/test: [2.283530, 2.321808], MSE-RV train/test: [0.780159, 0.827434]
# Factor: 6. MSE train/test: [1.886752, 1.825220], MSE-RV train/test: [0.823332, 0.869328]
# Factor: 10. MSE train/test: [1.522621, 1.453208], MSE-RV train/test: [0.932404, 0.932844]
# Factor: 20. MSE train/test: [1.134553, 1.148372], MSE-RV train/test: [0.989711, 1.004546]
# Epoch time/Remaining time in seconds: [25/23091]
# ---------- Epoch 44 ------------
#
# Factor: 2. MSE train/test: [3.460565, 3.120784], MSE-RV train/test: [0.771799, 0.799357]
# Factor: 4. MSE train/test: [2.330709, 2.022730], MSE-RV train/test: [0.779436, 0.838977]
# Factor: 6. MSE train/test: [1.813776, 1.686503], MSE-RV train/test: [0.834802, 0.890500]
# Factor: 10. MSE train/test: [1.393875, 1.330261], MSE-RV train/test: [0.956565, 0.969060]
# Factor: 20. MSE train/test: [1.089355, 1.087511], MSE-RV train/test: [0.994121, 0.988182]
# Epoch time/Remaining time in seconds: [27/23131]
# ---------- Epoch 45 ------------
#
# Factor: 2. MSE train/test: [3.353669, 3.367401], MSE-RV train/test: [0.798900, 0.786027]
# Factor: 4. MSE train/test: [2.134373, 2.053647], MSE-RV train/test: [0.837222, 0.828165]
# Factor: 6. MSE train/test: [1.778162, 1.732547], MSE-RV train/test: [0.883515, 0.881061]
# Factor: 10. MSE train/test: [1.377236, 1.399561], MSE-RV train/test: [0.935030, 0.954058]
# Factor: 20. MSE train/test: [1.103189, 1.106685], MSE-RV train/test: [0.998819, 1.001295]
# Epoch time/Remaining time in seconds: [22/23069]
# ---------- Epoch 46 ------------
#
# Factor: 2. MSE train/test: [3.804710, 2.968243], MSE-RV train/test: [0.777149, 0.762526]
# Factor: 4. MSE train/test: [2.102967, 2.044253], MSE-RV train/test: [0.789457, 0.798159]
# Factor: 6. MSE train/test: [1.737621, 1.714491], MSE-RV train/test: [0.852336, 0.848673]
# Factor: 10. MSE train/test: [1.407859, 1.396242], MSE-RV train/test: [0.958433, 0.938697]
# Factor: 20. MSE train/test: [1.058514, 1.054950], MSE-RV train/test: [0.998582, 0.999052]
# Epoch time/Remaining time in seconds: [22/23004]
# ---------- Epoch 47 ------------
#
# Factor: 2. MSE train/test: [3.019681, 3.306180], MSE-RV train/test: [0.830876, 0.766067]
# Factor: 4. MSE train/test: [1.978246, 2.157388], MSE-RV train/test: [0.846301, 0.814664]
# Factor: 6. MSE train/test: [1.700593, 1.788311], MSE-RV train/test: [0.866133, 0.865199]
# Factor: 10. MSE train/test: [1.395063, 1.385856], MSE-RV train/test: [0.948037, 0.932032]
# Factor: 20. MSE train/test: [1.063727, 1.136067], MSE-RV train/test: [0.992290, 0.995198]
# Epoch time/Remaining time in seconds: [22/22942]
# ---------- Epoch 48 ------------
#
# Factor: 2. MSE train/test: [3.418191, 2.744554], MSE-RV train/test: [0.796641, 0.813567]
# Factor: 4. MSE train/test: [2.188751, 1.968804], MSE-RV train/test: [0.832496, 0.864841]
# Factor: 6. MSE train/test: [1.811043, 1.606115], MSE-RV train/test: [0.876629, 0.905249]
# Factor: 10. MSE train/test: [1.468831, 1.280926], MSE-RV train/test: [0.936167, 0.954105]
# Factor: 20. MSE train/test: [1.061715, 1.096681], MSE-RV train/test: [1.003096, 1.015059]
# Epoch time/Remaining time in seconds: [22/22888]
# ---------- Epoch 49 ------------
#
# Factor: 2. MSE train/test: [3.239007, 2.356934], MSE-RV train/test: [0.782587, 0.842766]
# Factor: 4. MSE train/test: [1.999565, 1.951752], MSE-RV train/test: [0.826026, 0.865534]
# Factor: 6. MSE train/test: [1.672956, 1.581577], MSE-RV train/test: [0.864312, 0.892107]
# Factor: 10. MSE train/test: [1.324033, 1.351857], MSE-RV train/test: [0.935555, 0.975629]
# Factor: 20. MSE train/test: [1.068188, 1.060938], MSE-RV train/test: [0.991651, 0.997351]
# Epoch time/Remaining time in seconds: [22/22831]
# ---------- Epoch 50 ------------
#
# Factor: 2. MSE train/test: [3.272834, 3.171782], MSE-RV train/test: [0.785239, 0.784535]
# Factor: 4. MSE train/test: [2.278801, 1.930480], MSE-RV train/test: [0.797963, 0.824822]
# Factor: 6. MSE train/test: [1.816276, 1.687168], MSE-RV train/test: [0.830688, 0.848443]
# Factor: 10. MSE train/test: [1.367894, 1.374218], MSE-RV train/test: [0.929015, 0.942008]
# Factor: 20. MSE train/test: [1.053927, 1.085685], MSE-RV train/test: [1.003069, 0.994571]
# Epoch time/Remaining time in seconds: [21/22775]
# ---------- Epoch 51 ------------
#
# Factor: 2. MSE train/test: [3.183177, 3.222717], MSE-RV train/test: [0.764144, 0.757466]
# Factor: 4. MSE train/test: [2.057306, 1.990099], MSE-RV train/test: [0.782972, 0.806933]
# Factor: 6. MSE train/test: [1.698105, 1.669301], MSE-RV train/test: [0.852629, 0.863350]
# Factor: 10. MSE train/test: [1.333235, 1.297801], MSE-RV train/test: [0.922217, 0.952091]
# Factor: 20. MSE train/test: [1.125758, 1.057606], MSE-RV train/test: [1.003477, 1.001734]
# Epoch time/Remaining time in seconds: [21/22714]
# ---------- Epoch 52 ------------
#
# Factor: 2. MSE train/test: [2.814002, 2.892327], MSE-RV train/test: [0.805270, 0.756661]
# Factor: 4. MSE train/test: [2.064887, 2.001228], MSE-RV train/test: [0.783488, 0.816374]
# Factor: 6. MSE train/test: [1.811639, 1.709422], MSE-RV train/test: [0.838605, 0.886242]
# Factor: 10. MSE train/test: [1.363499, 1.340785], MSE-RV train/test: [0.942567, 0.955421]
# Factor: 20. MSE train/test: [1.117735, 1.070445], MSE-RV train/test: [0.990376, 0.990967]
# Epoch time/Remaining time in seconds: [22/22663]
# ---------- Epoch 53 ------------
#
# Factor: 2. MSE train/test: [2.966960, 2.969273], MSE-RV train/test: [0.763974, 0.766307]
# Factor: 4. MSE train/test: [2.025544, 2.014793], MSE-RV train/test: [0.787691, 0.797710]
# Factor: 6. MSE train/test: [1.677971, 1.652552], MSE-RV train/test: [0.852995, 0.851358]
# Factor: 10. MSE train/test: [1.355139, 1.355606], MSE-RV train/test: [0.926749, 0.943747]
# Factor: 20. MSE train/test: [1.134799, 1.062438], MSE-RV train/test: [0.996859, 0.982197]
# Epoch time/Remaining time in seconds: [22/22607]
# ---------- Epoch 54 ------------
#
# Factor: 2. MSE train/test: [3.018743, 2.437869], MSE-RV train/test: [0.785899, 0.820669]
# Factor: 4. MSE train/test: [2.090038, 1.942520], MSE-RV train/test: [0.809113, 0.854144]
# Factor: 6. MSE train/test: [1.664229, 1.754277], MSE-RV train/test: [0.859280, 0.890634]
# Factor: 10. MSE train/test: [1.323106, 1.346746], MSE-RV train/test: [0.957831, 0.952341]
# Factor: 20. MSE train/test: [1.109147, 1.071724], MSE-RV train/test: [0.997925, 0.989133]
# Epoch time/Remaining time in seconds: [22/22553]
# ---------- Epoch 55 ------------
#
# Factor: 2. MSE train/test: [2.846509, 1.610065], MSE-RV train/test: [0.753814, 0.797656]
# Factor: 4. MSE train/test: [1.905061, 1.829023], MSE-RV train/test: [0.833122, 0.841125]
# Factor: 6. MSE train/test: [1.642576, 1.555368], MSE-RV train/test: [0.881464, 0.923984]
# Factor: 10. MSE train/test: [1.376658, 1.337742], MSE-RV train/test: [0.932181, 0.968708]
# Factor: 20. MSE train/test: [1.086896, 1.078924], MSE-RV train/test: [0.991510, 0.993848]
# Epoch time/Remaining time in seconds: [23/22515]
# ---------- Epoch 56 ------------
#
# Factor: 2. MSE train/test: [3.087386, 2.774033], MSE-RV train/test: [0.774618, 0.766714]
# Factor: 4. MSE train/test: [2.019440, 1.983599], MSE-RV train/test: [0.827872, 0.804859]
# Factor: 6. MSE train/test: [1.732946, 1.711931], MSE-RV train/test: [0.871347, 0.856897]
# Factor: 10. MSE train/test: [1.378943, 1.326069], MSE-RV train/test: [0.950304, 0.954442]
# Factor: 20. MSE train/test: [1.095714, 1.072510], MSE-RV train/test: [1.007849, 1.003403]
# Epoch time/Remaining time in seconds: [23/22487]
# ---------- Epoch 57 ------------
#
# Factor: 2. MSE train/test: [3.341572, 2.854566], MSE-RV train/test: [0.751770, 0.750341]
# Factor: 4. MSE train/test: [2.009056, 2.029638], MSE-RV train/test: [0.801150, 0.789567]
# Factor: 6. MSE train/test: [1.729497, 1.779588], MSE-RV train/test: [0.846252, 0.843195]
# Factor: 10. MSE train/test: [1.408861, 1.376141], MSE-RV train/test: [0.970487, 0.912277]
# Factor: 20. MSE train/test: [1.079914, 1.180623], MSE-RV train/test: [1.006202, 1.009204]
# Epoch time/Remaining time in seconds: [23/22463]
# ---------- Epoch 58 ------------
#
# Factor: 2. MSE train/test: [3.229035, 3.189187], MSE-RV train/test: [0.770644, 0.751805]
# Factor: 4. MSE train/test: [2.029858, 2.046555], MSE-RV train/test: [0.837603, 0.795491]
# Factor: 6. MSE train/test: [1.825083, 1.672476], MSE-RV train/test: [0.881309, 0.845129]
# Factor: 10. MSE train/test: [1.385288, 1.389242], MSE-RV train/test: [0.954664, 0.947105]
# Factor: 20. MSE train/test: [1.102740, 1.102997], MSE-RV train/test: [1.001105, 0.988905]
# Epoch time/Remaining time in seconds: [25/22461]
# ---------- Epoch 59 ------------
#
# Factor: 2. MSE train/test: [2.736172, 3.468348], MSE-RV train/test: [0.780058, 0.771463]
# Factor: 4. MSE train/test: [2.107883, 2.304232], MSE-RV train/test: [0.789686, 0.792159]
# Factor: 6. MSE train/test: [1.828411, 1.789733], MSE-RV train/test: [0.825346, 0.839105]
# Factor: 10. MSE train/test: [1.397015, 1.326808], MSE-RV train/test: [0.929431, 0.917889]
# Factor: 20. MSE train/test: [1.064248, 1.088857], MSE-RV train/test: [1.012834, 1.005802]
# Epoch time/Remaining time in seconds: [26/22481]
# ---------- Epoch 60 ------------
#
# Factor: 2. MSE train/test: [3.006472, 3.072493], MSE-RV train/test: [0.796131, 0.778387]
# Factor: 4. MSE train/test: [1.947340, 2.042377], MSE-RV train/test: [0.831600, 0.795238]
# Factor: 6. MSE train/test: [1.557383, 1.662429], MSE-RV train/test: [0.864495, 0.867699]
# Factor: 10. MSE train/test: [1.315303, 1.335361], MSE-RV train/test: [0.950993, 0.952510]
# Factor: 20. MSE train/test: [1.082776, 1.100046], MSE-RV train/test: [0.989558, 1.003382]
# Epoch time/Remaining time in seconds: [25/22485]
# ---------- Epoch 61 ------------
#
# Factor: 2. MSE train/test: [2.941419, 3.253074], MSE-RV train/test: [0.783766, 0.751659]
# Factor: 4. MSE train/test: [1.987572, 2.131975], MSE-RV train/test: [0.831674, 0.787179]
# Factor: 6. MSE train/test: [1.745510, 1.735334], MSE-RV train/test: [0.891380, 0.836453]
# Factor: 10. MSE train/test: [1.351247, 1.380510], MSE-RV train/test: [0.953846, 0.934088]
# Factor: 20. MSE train/test: [1.035209, 1.113218], MSE-RV train/test: [0.997947, 0.990755]
# Epoch time/Remaining time in seconds: [22/22435]
# ---------- Epoch 62 ------------
#
# Factor: 2. MSE train/test: [3.214549, 3.044131], MSE-RV train/test: [0.767617, 0.752867]
# Factor: 4. MSE train/test: [2.136456, 1.990743], MSE-RV train/test: [0.799062, 0.811211]
# Factor: 6. MSE train/test: [1.748053, 1.667267], MSE-RV train/test: [0.844151, 0.844151]
# Factor: 10. MSE train/test: [1.354952, 1.339610], MSE-RV train/test: [0.970510, 0.949373]
# Factor: 20. MSE train/test: [1.106818, 1.079761], MSE-RV train/test: [1.013296, 0.996302]
# Epoch time/Remaining time in seconds: [22/22392]
# ---------- Epoch 63 ------------
#
# Factor: 2. MSE train/test: [2.834886, 3.237368], MSE-RV train/test: [0.751774, 0.766077]
# Factor: 4. MSE train/test: [2.055370, 2.100320], MSE-RV train/test: [0.791417, 0.813542]
# Factor: 6. MSE train/test: [1.732717, 1.756191], MSE-RV train/test: [0.851040, 0.862980]
# Factor: 10. MSE train/test: [1.368287, 1.394892], MSE-RV train/test: [0.937880, 0.921009]
# Factor: 20. MSE train/test: [1.076894, 1.088036], MSE-RV train/test: [0.991219, 0.994495]
# Epoch time/Remaining time in seconds: [22/22351]
# ---------- Epoch 64 ------------
#
# Factor: 2. MSE train/test: [3.069459, 2.941217], MSE-RV train/test: [0.752817, 0.769356]
# Factor: 4. MSE train/test: [2.049012, 1.961367], MSE-RV train/test: [0.818260, 0.804261]
# Factor: 6. MSE train/test: [1.714521, 1.672737], MSE-RV train/test: [0.856987, 0.877984]
# Factor: 10. MSE train/test: [1.358028, 1.293261], MSE-RV train/test: [0.939629, 0.950558]
# Factor: 20. MSE train/test: [1.110569, 1.062355], MSE-RV train/test: [0.999636, 0.993247]
# Epoch time/Remaining time in seconds: [22/22311]
# ---------- Epoch 65 ------------
#
# Factor: 2. MSE train/test: [3.179182, 2.814992], MSE-RV train/test: [0.766742, 0.773232]
# Factor: 4. MSE train/test: [2.079389, 2.015669], MSE-RV train/test: [0.812996, 0.781489]
# Factor: 6. MSE train/test: [1.762118, 1.718067], MSE-RV train/test: [0.861856, 0.839873]
# Factor: 10. MSE train/test: [1.438935, 1.317920], MSE-RV train/test: [0.960646, 0.931569]
# Factor: 20. MSE train/test: [1.096775, 1.064447], MSE-RV train/test: [0.993763, 0.990576]
# Epoch time/Remaining time in seconds: [22/22270]
# ---------- Epoch 66 ------------
#
# Factor: 2. MSE train/test: [2.901639, 3.160729], MSE-RV train/test: [0.761606, 0.781228]
# Factor: 4. MSE train/test: [2.048761, 2.341541], MSE-RV train/test: [0.805408, 0.818507]
# Factor: 6. MSE train/test: [1.695233, 1.845629], MSE-RV train/test: [0.851749, 0.870159]
# Factor: 10. MSE train/test: [1.357085, 1.450534], MSE-RV train/test: [0.938305, 0.935302]
# Factor: 20. MSE train/test: [1.137886, 1.127134], MSE-RV train/test: [0.995467, 1.006108]
# Epoch time/Remaining time in seconds: [23/22239]
# ---------- Epoch 67 ------------
#
# Factor: 2. MSE train/test: [3.065753, 2.654145], MSE-RV train/test: [0.710090, 0.814901]
# Factor: 4. MSE train/test: [2.022289, 1.963355], MSE-RV train/test: [0.739985, 0.828639]
# Factor: 6. MSE train/test: [1.783146, 1.731955], MSE-RV train/test: [0.832094, 0.873000]
# Factor: 10. MSE train/test: [1.418332, 1.456706], MSE-RV train/test: [0.977875, 0.964662]
# Factor: 20. MSE train/test: [1.129269, 1.134735], MSE-RV train/test: [0.998412, 1.004365]
# Epoch time/Remaining time in seconds: [22/22202]
# ---------- Epoch 68 ------------
#
# Factor: 2. MSE train/test: [2.912941, 2.898031], MSE-RV train/test: [0.774878, 0.778721]
# Factor: 4. MSE train/test: [1.928727, 2.036973], MSE-RV train/test: [0.836213, 0.810139]
# Factor: 6. MSE train/test: [1.671986, 1.638613], MSE-RV train/test: [0.888417, 0.857151]
# Factor: 10. MSE train/test: [1.324363, 1.335831], MSE-RV train/test: [0.953609, 0.956009]
# Factor: 20. MSE train/test: [1.098740, 1.098428], MSE-RV train/test: [0.995494, 1.002711]
# Epoch time/Remaining time in seconds: [23/22171]
# ---------- Epoch 69 ------------
#
# Factor: 2. MSE train/test: [2.717747, 3.101418], MSE-RV train/test: [0.775314, 0.748603]
# Factor: 4. MSE train/test: [2.057424, 2.169453], MSE-RV train/test: [0.787521, 0.774618]
# Factor: 6. MSE train/test: [1.783857, 1.790629], MSE-RV train/test: [0.836659, 0.841688]
# Factor: 10. MSE train/test: [1.422751, 1.435171], MSE-RV train/test: [0.917931, 0.945673]
# Factor: 20. MSE train/test: [1.098483, 1.102982], MSE-RV train/test: [1.000756, 1.002478]
# Epoch time/Remaining time in seconds: [22/22135]
# ---------- Epoch 70 ------------
#
# Factor: 2. MSE train/test: [2.538342, 2.599877], MSE-RV train/test: [0.802533, 0.781798]
# Factor: 4. MSE train/test: [1.950413, 1.970805], MSE-RV train/test: [0.854676, 0.810819]
# Factor: 6. MSE train/test: [1.750754, 1.758946], MSE-RV train/test: [0.885945, 0.868181]
# Factor: 10. MSE train/test: [1.374649, 1.394593], MSE-RV train/test: [0.947678, 0.929424]
# Factor: 20. MSE train/test: [1.069358, 1.093871], MSE-RV train/test: [1.000173, 0.996946]
# Epoch time/Remaining time in seconds: [22/22094]
# ---------- Epoch 71 ------------
#
# Factor: 2. MSE train/test: [2.722469, 2.813900], MSE-RV train/test: [0.753455, 0.749264]
# Factor: 4. MSE train/test: [1.969388, 2.078917], MSE-RV train/test: [0.805097, 0.774642]
# Factor: 6. MSE train/test: [1.692591, 1.774541], MSE-RV train/test: [0.863149, 0.826018]
# Factor: 10. MSE train/test: [1.305896, 1.308177], MSE-RV train/test: [0.921957, 0.921658]
# Factor: 20. MSE train/test: [1.095078, 1.083484], MSE-RV train/test: [1.001252, 1.011389]
# Epoch time/Remaining time in seconds: [22/22057]
# ---------- Epoch 72 ------------
#
# Factor: 2. MSE train/test: [2.630451, 2.957128], MSE-RV train/test: [0.798267, 0.754610]
# Factor: 4. MSE train/test: [1.967367, 2.043006], MSE-RV train/test: [0.845650, 0.796160]
# Factor: 6. MSE train/test: [1.648339, 1.746350], MSE-RV train/test: [0.895152, 0.856283]
# Factor: 10. MSE train/test: [1.343723, 1.392605], MSE-RV train/test: [0.948295, 0.927446]
# Factor: 20. MSE train/test: [1.116071, 1.145369], MSE-RV train/test: [0.999750, 0.996652]
# Epoch time/Remaining time in seconds: [23/22029]
# ---------- Epoch 73 ------------
#
# Factor: 2. MSE train/test: [3.008122, 2.793518], MSE-RV train/test: [0.745249, 0.788973]
# Factor: 4. MSE train/test: [1.967655, 2.001045], MSE-RV train/test: [0.792997, 0.815335]
# Factor: 6. MSE train/test: [1.734673, 1.748518], MSE-RV train/test: [0.852628, 0.869731]
# Factor: 10. MSE train/test: [1.352989, 1.387006], MSE-RV train/test: [0.943798, 0.945822]
# Factor: 20. MSE train/test: [1.071261, 1.062024], MSE-RV train/test: [1.001343, 0.984822]
# Epoch time/Remaining time in seconds: [22/21995]
# ---------- Epoch 74 ------------
#
# Factor: 2. MSE train/test: [2.791772, 3.049666], MSE-RV train/test: [0.761924, 0.761001]
# Factor: 4. MSE train/test: [1.910914, 2.052345], MSE-RV train/test: [0.803515, 0.796579]
# Factor: 6. MSE train/test: [1.689404, 1.669302], MSE-RV train/test: [0.869143, 0.846951]
# Factor: 10. MSE train/test: [1.383727, 1.368711], MSE-RV train/test: [0.936678, 0.942820]
# Factor: 20. MSE train/test: [1.096261, 1.080691], MSE-RV train/test: [1.001261, 0.995079]
# Epoch time/Remaining time in seconds: [23/21974]
# ---------- Epoch 75 ------------
#
# Factor: 2. MSE train/test: [2.490315, 2.740686], MSE-RV train/test: [0.764357, 0.720069]
# Factor: 4. MSE train/test: [1.854490, 2.011989], MSE-RV train/test: [0.802435, 0.748441]
# Factor: 6. MSE train/test: [1.664839, 1.711398], MSE-RV train/test: [0.856527, 0.825554]
# Factor: 10. MSE train/test: [1.333912, 1.317537], MSE-RV train/test: [0.932760, 0.911638]
# Factor: 20. MSE train/test: [1.079901, 1.130142], MSE-RV train/test: [1.007909, 0.999033]
# Epoch time/Remaining time in seconds: [25/21976]
# ---------- Epoch 76 ------------
#
# Factor: 2. MSE train/test: [3.361212, 2.836618], MSE-RV train/test: [0.757143, 0.764367]
# Factor: 4. MSE train/test: [2.014368, 1.977942], MSE-RV train/test: [0.810085, 0.807756]
# Factor: 6. MSE train/test: [1.690499, 1.676051], MSE-RV train/test: [0.871108, 0.861516]
# Factor: 10. MSE train/test: [1.369539, 1.350529], MSE-RV train/test: [0.946077, 0.945232]
# Factor: 20. MSE train/test: [1.072432, 1.070901], MSE-RV train/test: [1.000449, 0.988962]
# Epoch time/Remaining time in seconds: [26/21985]
# ---------- Epoch 77 ------------
#
# Factor: 2. MSE train/test: [2.780648, 2.870445], MSE-RV train/test: [0.740649, 0.791764]
# Factor: 4. MSE train/test: [2.115908, 1.977481], MSE-RV train/test: [0.756359, 0.811410]
# Factor: 6. MSE train/test: [1.776108, 1.659229], MSE-RV train/test: [0.847251, 0.862203]
# Factor: 10. MSE train/test: [1.477456, 1.231927], MSE-RV train/test: [0.910501, 0.936166]
# Factor: 20. MSE train/test: [1.121602, 1.084610], MSE-RV train/test: [0.993397, 0.994762]
# Epoch time/Remaining time in seconds: [25/21979]
# ---------- Epoch 78 ------------
#
# Factor: 2. MSE train/test: [3.294112, 2.704510], MSE-RV train/test: [0.759455, 0.789169]
# Factor: 4. MSE train/test: [2.175891, 2.045980], MSE-RV train/test: [0.797348, 0.821635]
# Factor: 6. MSE train/test: [1.730549, 1.692895], MSE-RV train/test: [0.854115, 0.877052]
# Factor: 10. MSE train/test: [1.412225, 1.439491], MSE-RV train/test: [0.935510, 0.955777]
# Factor: 20. MSE train/test: [1.076482, 1.117364], MSE-RV train/test: [0.989297, 0.988885]
# Epoch time/Remaining time in seconds: [22/21938]
# ---------- Epoch 79 ------------
#
# Factor: 2. MSE train/test: [2.908498, 2.847178], MSE-RV train/test: [0.764991, 0.768446]
# Factor: 4. MSE train/test: [1.990950, 2.127367], MSE-RV train/test: [0.826574, 0.804713]
# Factor: 6. MSE train/test: [1.733239, 1.775466], MSE-RV train/test: [0.872492, 0.847163]
# Factor: 10. MSE train/test: [1.390423, 1.379095], MSE-RV train/test: [0.945847, 0.937958]
# Factor: 20. MSE train/test: [1.112681, 1.086961], MSE-RV train/test: [0.989021, 1.000430]
# Epoch time/Remaining time in seconds: [27/21955]
# ---------- Epoch 80 ------------
#
# Factor: 2. MSE train/test: [2.895099, 2.463663], MSE-RV train/test: [0.761551, 0.779914]
# Factor: 4. MSE train/test: [2.006383, 1.853880], MSE-RV train/test: [0.823770, 0.823254]
# Factor: 6. MSE train/test: [1.699137, 1.686742], MSE-RV train/test: [0.891994, 0.873553]
# Factor: 10. MSE train/test: [1.325638, 1.391157], MSE-RV train/test: [0.944292, 0.945646]
# Factor: 20. MSE train/test: [1.097971, 1.116045], MSE-RV train/test: [0.991444, 0.997987]
# Epoch time/Remaining time in seconds: [23/21927]
# ---------- Epoch 81 ------------
#
# Factor: 2. MSE train/test: [2.677891, 2.734734], MSE-RV train/test: [0.797043, 0.756572]
# Factor: 4. MSE train/test: [1.991140, 1.925130], MSE-RV train/test: [0.798164, 0.818660]
# Factor: 6. MSE train/test: [1.676589, 1.686816], MSE-RV train/test: [0.861600, 0.870830]
# Factor: 10. MSE train/test: [1.410875, 1.342648], MSE-RV train/test: [0.936811, 0.931509]
# Factor: 20. MSE train/test: [1.181035, 1.116880], MSE-RV train/test: [0.996728, 1.010198]
# Epoch time/Remaining time in seconds: [23/21897]
# ---------- Epoch 82 ------------
#
# Factor: 2. MSE train/test: [3.014919, 3.098202], MSE-RV train/test: [0.788160, 0.766789]
# Factor: 4. MSE train/test: [2.122907, 2.180608], MSE-RV train/test: [0.830757, 0.794726]
# Factor: 6. MSE train/test: [1.797804, 1.795915], MSE-RV train/test: [0.878867, 0.847576]
# Factor: 10. MSE train/test: [1.367026, 1.437296], MSE-RV train/test: [0.948572, 0.934756]
# Factor: 20. MSE train/test: [1.085272, 1.067434], MSE-RV train/test: [1.005514, 0.996815]
# Epoch time/Remaining time in seconds: [23/21868]
# ---------- Epoch 83 ------------
#
# Factor: 2. MSE train/test: [2.838706, 3.064854], MSE-RV train/test: [0.740184, 0.752907]
# Factor: 4. MSE train/test: [2.064458, 2.094755], MSE-RV train/test: [0.786444, 0.798907]
# Factor: 6. MSE train/test: [1.754087, 1.802660], MSE-RV train/test: [0.854014, 0.840837]
# Factor: 10. MSE train/test: [1.434597, 1.398118], MSE-RV train/test: [0.937218, 0.938047]
# Factor: 20. MSE train/test: [1.142714, 1.091049], MSE-RV train/test: [1.003942, 0.991847]
# Epoch time/Remaining time in seconds: [23/21835]
# ---------- Epoch 84 ------------
#
# Factor: 2. MSE train/test: [2.666196, 3.229273], MSE-RV train/test: [0.738741, 0.777063]
# Factor: 4. MSE train/test: [2.080561, 2.232037], MSE-RV train/test: [0.795116, 0.788861]
# Factor: 6. MSE train/test: [1.729407, 1.735236], MSE-RV train/test: [0.846990, 0.825322]
# Factor: 10. MSE train/test: [1.425461, 1.274018], MSE-RV train/test: [0.918778, 0.929105]
# Factor: 20. MSE train/test: [1.098700, 1.105729], MSE-RV train/test: [0.996973, 0.996213]
# Epoch time/Remaining time in seconds: [22/21800]
# ---------- Epoch 85 ------------
#
# Factor: 2. MSE train/test: [2.861522, 2.873196], MSE-RV train/test: [0.729511, 0.772974]
# Factor: 4. MSE train/test: [1.991006, 1.929302], MSE-RV train/test: [0.786756, 0.820529]
# Factor: 6. MSE train/test: [1.641860, 1.685040], MSE-RV train/test: [0.862365, 0.881233]
# Factor: 10. MSE train/test: [1.364167, 1.425713], MSE-RV train/test: [0.956385, 0.943873]
# Factor: 20. MSE train/test: [1.091821, 1.093447], MSE-RV train/test: [0.987309, 0.997371]
# Epoch time/Remaining time in seconds: [23/21775]
# ---------- Epoch 86 ------------
#
# Factor: 2. MSE train/test: [2.965088, 2.567500], MSE-RV train/test: [0.736656, 0.756642]
# Factor: 4. MSE train/test: [2.026095, 1.968986], MSE-RV train/test: [0.777001, 0.810834]
# Factor: 6. MSE train/test: [1.799312, 1.791688], MSE-RV train/test: [0.825166, 0.855002]
# Factor: 10. MSE train/test: [1.394209, 1.382495], MSE-RV train/test: [0.967724, 0.951168]
# Factor: 20. MSE train/test: [1.109291, 1.107193], MSE-RV train/test: [1.007515, 0.994392]
# Epoch time/Remaining time in seconds: [23/21743]
# ---------- Epoch 87 ------------
#
# Factor: 2. MSE train/test: [2.838006, 2.847949], MSE-RV train/test: [0.791396, 0.746128]
# Factor: 4. MSE train/test: [1.959413, 1.991727], MSE-RV train/test: [0.810247, 0.813303]
# Factor: 6. MSE train/test: [1.703085, 1.685923], MSE-RV train/test: [0.850651, 0.866610]
# Factor: 10. MSE train/test: [1.435956, 1.429581], MSE-RV train/test: [0.932302, 0.942546]
# Factor: 20. MSE train/test: [1.074795, 1.096261], MSE-RV train/test: [0.996867, 0.991299]
# Epoch time/Remaining time in seconds: [22/21706]
# ---------- Epoch 88 ------------
#
# Factor: 2. MSE train/test: [2.644606, 2.622307], MSE-RV train/test: [0.753094, 0.748222]
# Factor: 4. MSE train/test: [1.883291, 1.953823], MSE-RV train/test: [0.804316, 0.813250]
# Factor: 6. MSE train/test: [1.676778, 1.683884], MSE-RV train/test: [0.866781, 0.846044]
# Factor: 10. MSE train/test: [1.380200, 1.348937], MSE-RV train/test: [0.944582, 0.943477]
# Factor: 20. MSE train/test: [1.078403, 1.122288], MSE-RV train/test: [0.999386, 0.986290]
# Epoch time/Remaining time in seconds: [22/21668]
# ---------- Epoch 89 ------------
#
# Factor: 2. MSE train/test: [2.476712, 2.753325], MSE-RV train/test: [0.737115, 0.744935]
# Factor: 4. MSE train/test: [2.043376, 2.051797], MSE-RV train/test: [0.768465, 0.783852]
# Factor: 6. MSE train/test: [1.800546, 1.760446], MSE-RV train/test: [0.805600, 0.826138]
# Factor: 10. MSE train/test: [1.479788, 1.445454], MSE-RV train/test: [0.945369, 0.932308]
# Factor: 20. MSE train/test: [1.160249, 1.091319], MSE-RV train/test: [0.988554, 1.010605]
# Epoch time/Remaining time in seconds: [23/21646]
# ---------- Epoch 90 ------------
#
# Factor: 2. MSE train/test: [2.539457, 2.569998], MSE-RV train/test: [0.808386, 0.748722]
# Factor: 4. MSE train/test: [2.143391, 1.997525], MSE-RV train/test: [0.848723, 0.788189]
# ...
# Epoch time/Remaining time in seconds: [27/760]
# ---------- Epoch 970 ------------
#
# Factor: 2. MSE train/test: [2.910913, 2.763445], MSE-RV train/test: [0.690179, 0.649506]
# Factor: 4. MSE train/test: [1.977667, 2.090630], MSE-RV train/test: [0.755548, 0.775974]
# Factor: 6. MSE train/test: [1.701423, 1.711397], MSE-RV train/test: [0.790582, 0.842403]
# Factor: 10. MSE train/test: [1.368921, 1.438309], MSE-RV train/test: [0.953064, 0.928530]
# Factor: 20. MSE train/test: [1.121565, 1.164318], MSE-RV train/test: [1.006466, 0.984247]
# Epoch time/Remaining time in seconds: [26/735]
# ---------- Epoch 971 ------------
#
# Factor: 2. MSE train/test: [3.074131, 2.342276], MSE-RV train/test: [0.708750, 0.691157]
# Factor: 4. MSE train/test: [2.195716, 1.907982], MSE-RV train/test: [0.751926, 0.744943]
# Factor: 6. MSE train/test: [1.759772, 1.663552], MSE-RV train/test: [0.834413, 0.802766]
# Factor: 10. MSE train/test: [1.313612, 1.342562], MSE-RV train/test: [0.946805, 0.912562]
# Factor: 20. MSE train/test: [1.133952, 1.116129], MSE-RV train/test: [0.999154, 0.997854]
# Epoch time/Remaining time in seconds: [27/710]
# ---------- Epoch 972 ------------
#
# Factor: 2. MSE train/test: [2.453872, 2.746364], MSE-RV train/test: [0.716171, 0.719570]
# Factor: 4. MSE train/test: [2.015788, 2.088648], MSE-RV train/test: [0.757192, 0.754251]
# Factor: 6. MSE train/test: [1.674419, 1.724980], MSE-RV train/test: [0.819039, 0.826582]
# Factor: 10. MSE train/test: [1.318018, 1.365874], MSE-RV train/test: [0.916759, 0.923937]
# Factor: 20. MSE train/test: [1.116619, 1.138576], MSE-RV train/test: [1.001988, 0.995545]
# Epoch time/Remaining time in seconds: [27/684]
# ---------- Epoch 973 ------------
#
# Factor: 2. MSE train/test: [2.578309, 2.830739], MSE-RV train/test: [0.720712, 0.753615]
# Factor: 4. MSE train/test: [1.999432, 2.056178], MSE-RV train/test: [0.781471, 0.798022]
# Factor: 6. MSE train/test: [1.760552, 1.765956], MSE-RV train/test: [0.833686, 0.820143]
# Factor: 10. MSE train/test: [1.387589, 1.432786], MSE-RV train/test: [0.914241, 0.928832]
# Factor: 20. MSE train/test: [1.167690, 1.067964], MSE-RV train/test: [0.986834, 0.988169]
# Epoch time/Remaining time in seconds: [27/659]
# ---------- Epoch 974 ------------
#
# Factor: 2. MSE train/test: [2.685714, 2.524940], MSE-RV train/test: [0.731438, 0.719796]
# Factor: 4. MSE train/test: [2.059800, 1.892229], MSE-RV train/test: [0.816530, 0.780092]
# Factor: 6. MSE train/test: [1.634879, 1.669448], MSE-RV train/test: [0.899520, 0.836352]
# Factor: 10. MSE train/test: [1.356216, 1.376638], MSE-RV train/test: [0.922879, 0.946341]
# Factor: 20. MSE train/test: [1.074041, 1.125212], MSE-RV train/test: [1.003021, 0.993984]
# Epoch time/Remaining time in seconds: [27/634]
# ---------- Epoch 975 ------------
#
# Factor: 2. MSE train/test: [2.976461, 2.361503], MSE-RV train/test: [0.745440, 0.740273]
# Factor: 4. MSE train/test: [2.109803, 1.871203], MSE-RV train/test: [0.790167, 0.776870]
# Factor: 6. MSE train/test: [1.758906, 1.686531], MSE-RV train/test: [0.835005, 0.848074]
# Factor: 10. MSE train/test: [1.479760, 1.415406], MSE-RV train/test: [0.929154, 0.930158]
# Factor: 20. MSE train/test: [1.091982, 1.160932], MSE-RV train/test: [0.994107, 0.999783]
# Epoch time/Remaining time in seconds: [27/608]
# ---------- Epoch 976 ------------
#
# Factor: 2. MSE train/test: [2.874627, 1.702236], MSE-RV train/test: [0.745096, 0.776183]
# Factor: 4. MSE train/test: [1.945750, 1.971237], MSE-RV train/test: [0.777174, 0.828023]
# Factor: 6. MSE train/test: [1.638362, 1.743310], MSE-RV train/test: [0.845974, 0.854960]
# Factor: 10. MSE train/test: [1.337946, 1.412102], MSE-RV train/test: [0.929593, 0.931660]
# Factor: 20. MSE train/test: [1.107156, 1.107015], MSE-RV train/test: [1.004796, 0.981636]
# Epoch time/Remaining time in seconds: [27/583]
# ---------- Epoch 977 ------------
#
# Factor: 2. MSE train/test: [2.349608, 2.990684], MSE-RV train/test: [0.714750, 0.708413]
# Factor: 4. MSE train/test: [1.857864, 2.048989], MSE-RV train/test: [0.776733, 0.752721]
# Factor: 6. MSE train/test: [1.736999, 1.760103], MSE-RV train/test: [0.835668, 0.818070]
# Factor: 10. MSE train/test: [1.391828, 1.327448], MSE-RV train/test: [0.925875, 0.913723]
# Factor: 20. MSE train/test: [1.170258, 1.090127], MSE-RV train/test: [0.988397, 1.000168]
# Epoch time/Remaining time in seconds: [26/558]
# ---------- Epoch 978 ------------
#
# Factor: 2. MSE train/test: [2.925363, 2.723097], MSE-RV train/test: [0.726851, 0.722775]
# Factor: 4. MSE train/test: [2.144775, 1.880232], MSE-RV train/test: [0.760961, 0.782899]
# Factor: 6. MSE train/test: [1.722619, 1.620343], MSE-RV train/test: [0.813893, 0.843567]
# Factor: 10. MSE train/test: [1.409309, 1.343680], MSE-RV train/test: [0.909698, 0.928551]
# Factor: 20. MSE train/test: [1.134899, 1.109419], MSE-RV train/test: [0.994604, 0.998998]
# Epoch time/Remaining time in seconds: [26/532]
# ---------- Epoch 979 ------------
#
# Factor: 2. MSE train/test: [2.968749, 1.995319], MSE-RV train/test: [0.729196, 0.743901]
# Factor: 4. MSE train/test: [2.000118, 1.953472], MSE-RV train/test: [0.790564, 0.794870]
# Factor: 6. MSE train/test: [1.623969, 1.724521], MSE-RV train/test: [0.858793, 0.868629]
# Factor: 10. MSE train/test: [1.364146, 1.390992], MSE-RV train/test: [0.936495, 0.934173]
# Factor: 20. MSE train/test: [1.091413, 1.120635], MSE-RV train/test: [0.996015, 0.977193]
# Epoch time/Remaining time in seconds: [25/507]
# ---------- Epoch 980 ------------
#
# Factor: 2. MSE train/test: [2.884855, 2.746145], MSE-RV train/test: [0.724302, 0.721605]
# Factor: 4. MSE train/test: [1.956967, 2.058439], MSE-RV train/test: [0.790683, 0.776992]
# Factor: 6. MSE train/test: [1.688284, 1.788564], MSE-RV train/test: [0.867137, 0.815273]
# Factor: 10. MSE train/test: [1.346262, 1.340437], MSE-RV train/test: [0.948125, 0.924134]
# Factor: 20. MSE train/test: [1.099084, 1.173573], MSE-RV train/test: [0.997338, 0.993475]
# Epoch time/Remaining time in seconds: [27/482]
# ---------- Epoch 981 ------------
#
# Factor: 2. MSE train/test: [2.889603, 2.869861], MSE-RV train/test: [0.722368, 0.744575]
# Factor: 4. MSE train/test: [2.029912, 1.952495], MSE-RV train/test: [0.805194, 0.790436]
# Factor: 6. MSE train/test: [1.663994, 1.680201], MSE-RV train/test: [0.861008, 0.843135]
# Factor: 10. MSE train/test: [1.291956, 1.283344], MSE-RV train/test: [0.954866, 0.920684]
# Factor: 20. MSE train/test: [1.176126, 1.119373], MSE-RV train/test: [0.998754, 1.002448]
# Epoch time/Remaining time in seconds: [28/456]
# ---------- Epoch 982 ------------
#
# Factor: 2. MSE train/test: [3.059371, 3.196001], MSE-RV train/test: [0.717709, 0.717599]
# Factor: 4. MSE train/test: [2.023890, 1.997455], MSE-RV train/test: [0.790262, 0.787453]
# Factor: 6. MSE train/test: [1.675035, 1.731806], MSE-RV train/test: [0.861352, 0.847940]
# Factor: 10. MSE train/test: [1.267858, 1.360241], MSE-RV train/test: [0.937366, 0.942246]
# Factor: 20. MSE train/test: [1.143630, 1.127680], MSE-RV train/test: [0.988378, 0.996862]
# Epoch time/Remaining time in seconds: [28/431]
# ---------- Epoch 983 ------------
#
# Factor: 2. MSE train/test: [2.427954, 2.062936], MSE-RV train/test: [0.720084, 0.747225]
# Factor: 4. MSE train/test: [1.913012, 1.877042], MSE-RV train/test: [0.804276, 0.767685]
# Factor: 6. MSE train/test: [1.686221, 1.736140], MSE-RV train/test: [0.874321, 0.823566]
# Factor: 10. MSE train/test: [1.361091, 1.380379], MSE-RV train/test: [0.945614, 0.922609]
# Factor: 20. MSE train/test: [1.171362, 1.144452], MSE-RV train/test: [0.983758, 1.014426]
# Epoch time/Remaining time in seconds: [27/406]
# ---------- Epoch 984 ------------
#
# Factor: 2. MSE train/test: [2.475434, 2.957044], MSE-RV train/test: [0.693462, 0.731935]
# Factor: 4. MSE train/test: [2.049959, 2.165963], MSE-RV train/test: [0.748124, 0.783250]
# Factor: 6. MSE train/test: [1.783350, 1.767244], MSE-RV train/test: [0.788527, 0.839248]
# Factor: 10. MSE train/test: [1.499817, 1.459036], MSE-RV train/test: [0.919048, 0.917620]
# Factor: 20. MSE train/test: [1.183377, 1.173388], MSE-RV train/test: [1.002617, 1.002593]
# Epoch time/Remaining time in seconds: [27/380]
# ---------- Epoch 985 ------------
#
# Factor: 2. MSE train/test: [2.900969, 2.948500], MSE-RV train/test: [0.716936, 0.728287]
# Factor: 4. MSE train/test: [2.052224, 1.986293], MSE-RV train/test: [0.752329, 0.786635]
# Factor: 6. MSE train/test: [1.667801, 1.632685], MSE-RV train/test: [0.806926, 0.842426]
# Factor: 10. MSE train/test: [1.339270, 1.336846], MSE-RV train/test: [0.910183, 0.922157]
# Factor: 20. MSE train/test: [1.171597, 1.125149], MSE-RV train/test: [0.986403, 0.995524]
# Epoch time/Remaining time in seconds: [27/355]
# ---------- Epoch 986 ------------
#
# Factor: 2. MSE train/test: [2.614933, 3.187035], MSE-RV train/test: [0.727571, 0.714819]
# Factor: 4. MSE train/test: [1.993291, 2.028670], MSE-RV train/test: [0.779488, 0.773615]
# Factor: 6. MSE train/test: [1.651062, 1.725591], MSE-RV train/test: [0.835598, 0.834925]
# Factor: 10. MSE train/test: [1.337229, 1.393881], MSE-RV train/test: [0.947932, 0.948385]
# Factor: 20. MSE train/test: [1.122997, 1.139494], MSE-RV train/test: [0.994726, 0.993310]
# Epoch time/Remaining time in seconds: [27/330]
# ---------- Epoch 987 ------------
#
# Factor: 2. MSE train/test: [2.516923, 2.823040], MSE-RV train/test: [0.704355, 0.727513]
# Factor: 4. MSE train/test: [2.056350, 1.916374], MSE-RV train/test: [0.754497, 0.769248]
# Factor: 6. MSE train/test: [1.771984, 1.633779], MSE-RV train/test: [0.804591, 0.832823]
# Factor: 10. MSE train/test: [1.414573, 1.366738], MSE-RV train/test: [0.906200, 0.938893]
# Factor: 20. MSE train/test: [1.161429, 1.102765], MSE-RV train/test: [1.003824, 0.990635]
# Epoch time/Remaining time in seconds: [27/304]
# ---------- Epoch 988 ------------
#
# Factor: 2. MSE train/test: [2.162195, 2.965994], MSE-RV train/test: [0.765313, 0.727302]
# Factor: 4. MSE train/test: [1.847549, 2.047924], MSE-RV train/test: [0.795338, 0.755532]
# Factor: 6. MSE train/test: [1.701969, 1.644848], MSE-RV train/test: [0.850457, 0.809403]
# Factor: 10. MSE train/test: [1.394911, 1.304501], MSE-RV train/test: [0.919147, 0.932050]
# Factor: 20. MSE train/test: [1.141246, 1.130978], MSE-RV train/test: [0.995839, 1.003896]
# Epoch time/Remaining time in seconds: [27/279]
# ---------- Epoch 989 ------------
#
# Factor: 2. MSE train/test: [2.278020, 2.435925], MSE-RV train/test: [0.737404, 0.752666]
# Factor: 4. MSE train/test: [1.938870, 2.024184], MSE-RV train/test: [0.803116, 0.797375]
# Factor: 6. MSE train/test: [1.671242, 1.770522], MSE-RV train/test: [0.864068, 0.842182]
# Factor: 10. MSE train/test: [1.343009, 1.335774], MSE-RV train/test: [0.946827, 0.940264]
# Factor: 20. MSE train/test: [1.111260, 1.171129], MSE-RV train/test: [0.995048, 1.008217]
# Epoch time/Remaining time in seconds: [27/253]
# ---------- Epoch 990 ------------
#
# Factor: 2. MSE train/test: [2.911393, 2.876202], MSE-RV train/test: [0.719118, 0.711575]
# Factor: 4. MSE train/test: [2.000623, 1.970521], MSE-RV train/test: [0.759167, 0.791152]
# Factor: 6. MSE train/test: [1.691497, 1.648412], MSE-RV train/test: [0.816781, 0.847617]
# Factor: 10. MSE train/test: [1.395867, 1.259705], MSE-RV train/test: [0.941817, 0.932736]
# Factor: 20. MSE train/test: [1.098016, 1.126430], MSE-RV train/test: [0.988350, 0.996645]
# Epoch time/Remaining time in seconds: [27/228]
# ---------- Epoch 991 ------------
#
# Factor: 2. MSE train/test: [3.262271, 2.991802], MSE-RV train/test: [0.705481, 0.704157]
# Factor: 4. MSE train/test: [2.091973, 1.988593], MSE-RV train/test: [0.746366, 0.758204]
# Factor: 6. MSE train/test: [1.728083, 1.650259], MSE-RV train/test: [0.817863, 0.833866]
# Factor: 10. MSE train/test: [1.279783, 1.323390], MSE-RV train/test: [0.902831, 0.951356]
# Factor: 20. MSE train/test: [1.093528, 1.099346], MSE-RV train/test: [0.979806, 0.996180]
# Epoch time/Remaining time in seconds: [27/203]
# ---------- Epoch 992 ------------
#
# Factor: 2. MSE train/test: [2.708804, 2.643780], MSE-RV train/test: [0.748071, 0.706040]
# Factor: 4. MSE train/test: [1.873973, 1.969053], MSE-RV train/test: [0.810903, 0.757704]
# Factor: 6. MSE train/test: [1.655313, 1.701676], MSE-RV train/test: [0.861974, 0.826006]
# Factor: 10. MSE train/test: [1.362289, 1.385404], MSE-RV train/test: [0.911335, 0.954710]
# Factor: 20. MSE train/test: [1.169270, 1.129208], MSE-RV train/test: [0.999628, 1.003547]
# Epoch time/Remaining time in seconds: [27/177]
# ---------- Epoch 993 ------------
#
# Factor: 2. MSE train/test: [2.736310, 2.436493], MSE-RV train/test: [0.765102, 0.739572]
# Factor: 4. MSE train/test: [1.921342, 1.993374], MSE-RV train/test: [0.799196, 0.797385]
# Factor: 6. MSE train/test: [1.672369, 1.716538], MSE-RV train/test: [0.843523, 0.851257]
# Factor: 10. MSE train/test: [1.372683, 1.389002], MSE-RV train/test: [0.945280, 0.950762]
# Factor: 20. MSE train/test: [1.150910, 1.191573], MSE-RV train/test: [0.995516, 0.985307]
# Epoch time/Remaining time in seconds: [27/152]
# ---------- Epoch 994 ------------
#
# Factor: 2. MSE train/test: [3.438424, 2.864219], MSE-RV train/test: [0.712805, 0.740511]
# Factor: 4. MSE train/test: [1.992463, 1.924979], MSE-RV train/test: [0.762867, 0.804184]
# Factor: 6. MSE train/test: [1.607394, 1.685925], MSE-RV train/test: [0.834381, 0.875244]
# Factor: 10. MSE train/test: [1.352571, 1.345108], MSE-RV train/test: [0.923809, 0.931810]
# Factor: 20. MSE train/test: [1.105281, 1.075873], MSE-RV train/test: [1.004100, 0.991420]
# Epoch time/Remaining time in seconds: [27/127]
# ---------- Epoch 995 ------------
#
# Factor: 2. MSE train/test: [2.290549, 2.901852], MSE-RV train/test: [0.749602, 0.742190]
# Factor: 4. MSE train/test: [1.879618, 2.031293], MSE-RV train/test: [0.785612, 0.774097]
# Factor: 6. MSE train/test: [1.717496, 1.671319], MSE-RV train/test: [0.840438, 0.841539]
# Factor: 10. MSE train/test: [1.437167, 1.310677], MSE-RV train/test: [0.920820, 0.928412]
# Factor: 20. MSE train/test: [1.130738, 1.142512], MSE-RV train/test: [0.998531, 1.005377]
# Epoch time/Remaining time in seconds: [27/101]
# ---------- Epoch 996 ------------
#
# Factor: 2. MSE train/test: [2.776807, 2.279115], MSE-RV train/test: [0.749128, 0.724550]
# Factor: 4. MSE train/test: [1.920498, 1.891634], MSE-RV train/test: [0.802981, 0.777375]
# Factor: 6. MSE train/test: [1.625112, 1.653905], MSE-RV train/test: [0.860042, 0.832002]
# Factor: 10. MSE train/test: [1.313852, 1.352316], MSE-RV train/test: [0.936458, 0.928428]
# Factor: 20. MSE train/test: [1.080953, 1.084245], MSE-RV train/test: [0.989266, 1.006601]
# Epoch time/Remaining time in seconds: [27/76]
# ---------- Epoch 997 ------------
#
# Factor: 2. MSE train/test: [2.776270, 2.824438], MSE-RV train/test: [0.746755, 0.734337]
# Factor: 4. MSE train/test: [2.043849, 1.974499], MSE-RV train/test: [0.789348, 0.781418]
# Factor: 6. MSE train/test: [1.737595, 1.695294], MSE-RV train/test: [0.839976, 0.845303]
# Factor: 10. MSE train/test: [1.347247, 1.308129], MSE-RV train/test: [0.916083, 0.931674]
# Factor: 20. MSE train/test: [1.151045, 1.113878], MSE-RV train/test: [1.010370, 0.999238]
# Epoch time/Remaining time in seconds: [27/50]
# ---------- Epoch 998 ------------
#
# Factor: 2. MSE train/test: [2.717464, 2.805468], MSE-RV train/test: [0.738116, 0.723563]
# Factor: 4. MSE train/test: [2.005973, 1.994785], MSE-RV train/test: [0.806155, 0.757619]
# Factor: 6. MSE train/test: [1.698910, 1.720456], MSE-RV train/test: [0.858397, 0.801217]
# Factor: 10. MSE train/test: [1.312629, 1.296754], MSE-RV train/test: [0.945297, 0.913173]
# Factor: 20. MSE train/test: [1.080151, 1.179765], MSE-RV train/test: [0.997358, 0.998430]
# Epoch time/Remaining time in seconds: [27/25]
# ---------- Epoch 999 ------------
#
# Factor: 2. MSE train/test: [2.790213, 2.824535], MSE-RV train/test: [0.728235, 0.719900]
# Factor: 4. MSE train/test: [2.022102, 1.933505], MSE-RV train/test: [0.774023, 0.778008]
# Factor: 6. MSE train/test: [1.723178, 1.635029], MSE-RV train/test: [0.837610, 0.830970]
# Factor: 10. MSE train/test: [1.418647, 1.295274], MSE-RV train/test: [0.930188, 0.930827]
# Factor: 20. MSE train/test: [1.145820, 1.110272], MSE-RV train/test: [1.002228, 0.988252]
# Epoch time/Remaining time in seconds: [27/0]

# %% [markdown]
# # Energy cospectrum

# %%
time_id = np.random.randint(6950,8035)

# %%
plt.figure(figsize=(6,10))
for row, (operator, title) in enumerate(zip([operator_coarsen, operator_Kochkov, operator_gaussian], ['operator_coarsen', 'operator_Kochkov', 'operator_Gaussian'])):
    dataset = ds.sample_epoch(time=time_id, operator=operator, factors=[2])[2]
    plt.subplot(3,1,row+1)
    kw_sp = dict(region='Pacific')
    dataset.state.transfer(dataset.data.SGSx, dataset.data.SGSy, **kw_sp).plot(color='k', label='SGS')
    # Standard ANN
    ann_Txy = import_ANN('trained_models/ANN_CM26/Txy_epoch_2000.nc')
    ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26/Txx_Tyy_epoch_2000.nc')
    dataset.state.transfer_ANN(ann_Txy, ann_Txx_Tyy, kw_sp=kw_sp).plot(label='Standard ANN')
    # Kochkov ANN
    ann_Txy = import_ANN('trained_models/ANN_CM26_Kochkov/Txy_epoch_2000.nc')
    ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26_Kochkov/Txx_Tyy_epoch_2000.nc')
    dataset.state.transfer_ANN(ann_Txy, ann_Txx_Tyy, kw_sp=kw_sp).plot(label='Kochkov ANN')

    # Kochkov ANN augmented
    ann_Txy = import_ANN('trained_models/ANN_CM26_Kochkov_augmented/Txy_epoch_100.nc')
    ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26_Kochkov_augmented/Txx_Tyy_epoch_100.nc')
    dataset.state.transfer_ANN(ann_Txy, ann_Txx_Tyy, kw_sp=kw_sp).plot(label='Kochkov ANN aug.')

    # Kochkov ANN vorticity
    ann_Txy = import_ANN('trained_models/ANN_CM26_Kochkov_vorticity/Txy_epoch_100.nc')
    ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26_Kochkov_vorticity/Txx_Tyy_epoch_100.nc')
    dataset.state.transfer_ANN(ann_Txy, ann_Txx_Tyy, kw_sp=kw_sp).plot(label='Kochkov ANN vorticity')

    
    plt.xscale('log')
    plt.axhline(y=0, color='gray', alpha=0.5, lw=3, zorder=-1)
    plt.legend()
    plt.title(title)
