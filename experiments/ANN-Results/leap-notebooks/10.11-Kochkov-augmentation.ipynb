# %%
import matplotlib.pyplot as plt
from helpers.cm26 import DatasetCM26, operator_Kochkov
from helpers.computational_tools import select_NA, select_Pacific, select_Cem, select_Equator, StateFunctions, compare
from helpers.ann_tools import ANN, import_ANN, minibatch, export_ANN
import torch
import torch.optim as optim
import numpy as np
from time import time
import json
# %load_ext autoreload
# %autoreload 3

# %%
ds = DatasetCM26()

# %%
# ann_Txy = ANN([27, 20, 1])
# ann_Txx_Tyy = ANN([27, 20, 2])
log_dict = {}
ann_Txy = import_ANN('trained_models/ANN_CM26_Kochkov/Txy_epoch_2000.nc')
ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26_Kochkov/Txx_Tyy_epoch_2000.nc')

# %%
num_epochs=100

all_parameters = list(ann_Txy.parameters()) + list(ann_Txx_Tyy.parameters())
optimizer = optim.Adam(all_parameters, lr=1e-3)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
        milestones=[int(num_epochs/2), int(num_epochs*3/4), int(num_epochs*7/8)], gamma=0.1)  

t_s = time()

for epoch in range(num_epochs):
    t_e = time()
    
    training_dataset = ds.sample_epoch(time=np.random.randint(6950), operator=operator_Kochkov) # Approximately 19 years for training
    testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035), operator=operator_Kochkov) # Approximately 3 years for testing
    print(f'---------- Epoch {epoch} ------------\n')
    
    for factor in [2,4,6,10,20]:
        ############# Training step ################
        
        batch = training_dataset[factor]
        SGSx = torch.tensor(batch.data.SGSx.values).type(torch.float32)
        SGSy = torch.tensor(batch.data.SGSy.values).type(torch.float32)
        
        SGS_norm = 1. / torch.sqrt((SGSx**2 + SGSy**2).mean())
        SGSx = SGS_norm * SGSx
        SGSy = SGS_norm * SGSy
        
        # order of loops is such that the last iteration
        # is standard model without augmentation
        for rotation in [90, 0]:
            for reflect_x in [True, False]:
                for reflect_y in [True, False]:
                    
                    optimizer.zero_grad()
                    prediction = batch.state.Apply_ANN(ann_Txy, ann_Txx_Tyy,
                        rotation=rotation, reflect_x=reflect_x, reflect_y=reflect_y)
                    ANNx = prediction['ZB20u'] * SGS_norm
                    ANNy = prediction['ZB20v'] * SGS_norm
                    MSE_train = ((ANNx-SGSx)**2 + (ANNy-SGSy)**2).mean()
        
                    MSE_train.backward()
                    optimizer.step()
        
        ############ Testing step ##################
        with torch.no_grad():
            batch = testing_dataset[factor]
            prediction = batch.state.Apply_ANN(ann_Txy, ann_Txx_Tyy)
            ANNx = prediction['ZB20u']
            ANNy = prediction['ZB20v']
            SGSx = torch.tensor(batch.data.SGSx.values).type(torch.float32)
            SGSy = torch.tensor(batch.data.SGSy.values).type(torch.float32)

            SGS_norm = 1. / torch.sqrt((SGSx**2 + SGSy**2).mean())

            MSE_test = ((ANNx*SGS_norm-SGSx*SGS_norm)**2 + (ANNy*SGS_norm-SGSy*SGS_norm)**2).mean()
        
        print(f'Factor: {factor}. '+'MSE train/test: [%.6f, %.6f]' % (float(MSE_train.data), float(MSE_test.data)))
        ########### Saving history of losses ############
        log_dict[f'epoch-{epoch+1}-factor-{factor}'] = dict(MSE_train=float(MSE_train.data),MSE_test=float(MSE_test.data))
        ######## Freeing memory ############
        del training_dataset[factor].data
        del training_dataset[factor].param
        del testing_dataset[factor].data
        del testing_dataset[factor].param
    t = time()
    print('Epoch time/Remaining time in seconds: [%d/%d]' % (t-t_e, (t-t_s)*(num_epochs/(epoch+1)-1)))
    scheduler.step()
    
    if (epoch+1) % 50 == 0:
        export_ANN(ann_Txy, input_norms=torch.ones(27), output_norms=torch.ones(1), 
           filename=f'trained_models/ANN_CM26_Kochkov_augmented/Txy_epoch_{epoch+1}.nc')
        export_ANN(ann_Txx_Tyy, input_norms=torch.ones(27), output_norms=torch.ones(2), 
           filename=f'trained_models/ANN_CM26_Kochkov_augmented/Txx_Tyy_epoch_{epoch+1}.nc')
        with open(f'trained_models/ANN_CM26_Kochkov_augmented/log_dict_epoch_{epoch+1}', 'w') as file:
            json.dump(log_dict, file)
# Out:
# ---------- Epoch 0 ------------
#
# Factor: 2. MSE train/test: [0.584559, 0.597894]
# Factor: 4. MSE train/test: [0.572371, 0.607747]
# Factor: 6. MSE train/test: [0.647255, 0.647357]
# Factor: 10. MSE train/test: [0.814737, 0.798697]
# Factor: 20. MSE train/test: [0.973381, 0.982239]
# Epoch time/Remaining time in seconds: [27/2676]
# ---------- Epoch 1 ------------
#
# Factor: 2. MSE train/test: [0.661409, 0.636738]
# Factor: 4. MSE train/test: [0.635682, 0.593563]
# Factor: 6. MSE train/test: [0.710839, 0.657809]
# Factor: 10. MSE train/test: [0.815673, 0.824961]
# Factor: 20. MSE train/test: [0.960262, 0.973040]
# Epoch time/Remaining time in seconds: [26/2599]
# ---------- Epoch 2 ------------
#
# Factor: 2. MSE train/test: [0.707960, 0.672557]
# Factor: 4. MSE train/test: [0.660206, 0.635050]
# Factor: 6. MSE train/test: [0.676754, 0.708666]
# Factor: 10. MSE train/test: [0.809021, 0.796882]
# Factor: 20. MSE train/test: [0.974526, 0.972888]
# Epoch time/Remaining time in seconds: [27/2590]
# ---------- Epoch 3 ------------
#
# Factor: 2. MSE train/test: [0.634933, 0.638900]
# Factor: 4. MSE train/test: [0.624989, 0.607657]
# Factor: 6. MSE train/test: [0.673612, 0.683491]
# Factor: 10. MSE train/test: [0.814991, 0.811037]
# Factor: 20. MSE train/test: [0.980579, 0.961340]
# Epoch time/Remaining time in seconds: [27/2571]
# ---------- Epoch 4 ------------
#
# Factor: 2. MSE train/test: [0.672388, 0.607132]
# Factor: 4. MSE train/test: [0.633995, 0.657775]
# Factor: 6. MSE train/test: [0.682691, 0.701124]
# Factor: 10. MSE train/test: [0.799726, 0.804009]
# Factor: 20. MSE train/test: [0.967468, 0.969419]
# Epoch time/Remaining time in seconds: [24/2510]
# ---------- Epoch 5 ------------
#
# Factor: 2. MSE train/test: [0.720551, 0.651505]
# Factor: 4. MSE train/test: [0.674599, 0.594757]
# Factor: 6. MSE train/test: [0.722689, 0.658658]
# Factor: 10. MSE train/test: [0.824798, 0.826404]
# Factor: 20. MSE train/test: [0.944825, 0.974907]
# Epoch time/Remaining time in seconds: [26/2484]
# ---------- Epoch 6 ------------
#
# Factor: 2. MSE train/test: [0.704198, 0.667650]
# Factor: 4. MSE train/test: [0.682566, 0.640552]
# Factor: 6. MSE train/test: [0.717824, 0.689882]
# Factor: 10. MSE train/test: [0.789518, 0.806770]
# Factor: 20. MSE train/test: [0.976323, 0.967126]
# Epoch time/Remaining time in seconds: [26/2453]
# ---------- Epoch 7 ------------
#
# Factor: 2. MSE train/test: [0.666309, 0.704398]
# Factor: 4. MSE train/test: [0.639262, 0.642969]
# Factor: 6. MSE train/test: [0.680759, 0.686879]
# Factor: 10. MSE train/test: [0.808626, 0.827875]
# Factor: 20. MSE train/test: [0.976763, 0.965293]
# Epoch time/Remaining time in seconds: [27/2434]
# ---------- Epoch 8 ------------
#
# Factor: 2. MSE train/test: [0.668237, 0.631246]
# Factor: 4. MSE train/test: [0.651994, 0.618351]
# Factor: 6. MSE train/test: [0.682877, 0.678725]
# Factor: 10. MSE train/test: [0.814150, 0.828522]
# Factor: 20. MSE train/test: [0.972003, 0.951789]
# Epoch time/Remaining time in seconds: [26/2411]
# ---------- Epoch 9 ------------
#
# Factor: 2. MSE train/test: [0.644703, 0.722076]
# Factor: 4. MSE train/test: [0.591404, 0.658942]
# Factor: 6. MSE train/test: [0.684934, 0.689887]
# Factor: 10. MSE train/test: [0.830505, 0.830414]
# Factor: 20. MSE train/test: [0.987380, 0.970959]
# Epoch time/Remaining time in seconds: [27/2390]
# ---------- Epoch 10 ------------
#
# Factor: 2. MSE train/test: [0.739317, 0.724975]
# Factor: 4. MSE train/test: [0.651404, 0.669968]
# Factor: 6. MSE train/test: [0.678128, 0.711993]
# Factor: 10. MSE train/test: [0.789093, 0.785350]
# Factor: 20. MSE train/test: [0.962466, 0.941368]
# Epoch time/Remaining time in seconds: [26/2365]
# ---------- Epoch 11 ------------
#
# Factor: 2. MSE train/test: [0.564637, 0.724789]
# Factor: 4. MSE train/test: [0.573257, 0.630959]
# Factor: 6. MSE train/test: [0.639726, 0.694874]
# Factor: 10. MSE train/test: [0.793515, 0.816479]
# Factor: 20. MSE train/test: [0.985722, 0.972678]
# Epoch time/Remaining time in seconds: [26/2341]
# ---------- Epoch 12 ------------
#
# Factor: 2. MSE train/test: [0.704503, 0.609486]
# Factor: 4. MSE train/test: [0.646278, 0.674837]
# Factor: 6. MSE train/test: [0.679741, 0.703562]
# Factor: 10. MSE train/test: [0.804746, 0.792395]
# Factor: 20. MSE train/test: [0.968123, 0.991361]
# Epoch time/Remaining time in seconds: [26/2316]
# ---------- Epoch 13 ------------
#
# Factor: 2. MSE train/test: [0.612248, 0.664967]
# Factor: 4. MSE train/test: [0.583232, 0.621650]
# Factor: 6. MSE train/test: [0.649459, 0.697924]
# Factor: 10. MSE train/test: [0.778849, 0.821524]
# Factor: 20. MSE train/test: [0.958927, 0.985462]
# Epoch time/Remaining time in seconds: [26/2291]
# ---------- Epoch 14 ------------
#
# Factor: 2. MSE train/test: [0.662210, 0.669796]
# Factor: 4. MSE train/test: [0.641490, 0.642859]
# Factor: 6. MSE train/test: [0.681977, 0.685475]
# Factor: 10. MSE train/test: [0.806985, 0.812771]
# Factor: 20. MSE train/test: [0.977473, 0.950497]
# Epoch time/Remaining time in seconds: [27/2267]
# ---------- Epoch 15 ------------
#
# Factor: 2. MSE train/test: [0.704135, 0.657184]
# Factor: 4. MSE train/test: [0.671318, 0.628783]
# Factor: 6. MSE train/test: [0.706060, 0.695458]
# Factor: 10. MSE train/test: [0.832387, 0.803337]
# Factor: 20. MSE train/test: [0.984669, 0.969148]
# Epoch time/Remaining time in seconds: [22/2216]
# ---------- Epoch 16 ------------
#
# Factor: 2. MSE train/test: [0.661129, 0.652309]
# Factor: 4. MSE train/test: [0.636258, 0.636490]
# Factor: 6. MSE train/test: [0.693757, 0.660030]
# Factor: 10. MSE train/test: [0.810192, 0.821312]
# Factor: 20. MSE train/test: [0.977544, 0.994226]
# Epoch time/Remaining time in seconds: [22/2169]
# ---------- Epoch 17 ------------
#
# Factor: 2. MSE train/test: [0.593175, 0.689684]
# Factor: 4. MSE train/test: [0.574425, 0.655434]
# Factor: 6. MSE train/test: [0.659541, 0.683834]
# Factor: 10. MSE train/test: [0.834493, 0.810888]
# Factor: 20. MSE train/test: [0.960269, 0.976444]
# Epoch time/Remaining time in seconds: [22/2126]
# ---------- Epoch 18 ------------
#
# Factor: 2. MSE train/test: [0.665085, 0.682146]
# Factor: 4. MSE train/test: [0.653982, 0.628445]
# Factor: 6. MSE train/test: [0.703806, 0.652237]
# Factor: 10. MSE train/test: [0.786449, 0.808386]
# Factor: 20. MSE train/test: [0.976032, 0.960189]
# Epoch time/Remaining time in seconds: [22/2084]
# ---------- Epoch 19 ------------
#
# Factor: 2. MSE train/test: [0.711745, 0.739051]
# Factor: 4. MSE train/test: [0.644915, 0.655056]
# Factor: 6. MSE train/test: [0.677950, 0.671269]
# Factor: 10. MSE train/test: [0.805678, 0.794033]
# Factor: 20. MSE train/test: [0.983648, 0.973977]
# Epoch time/Remaining time in seconds: [22/2044]
# ---------- Epoch 20 ------------
#
# Factor: 2. MSE train/test: [0.654954, 0.653123]
# Factor: 4. MSE train/test: [0.631319, 0.616213]
# Factor: 6. MSE train/test: [0.687352, 0.689906]
# Factor: 10. MSE train/test: [0.833696, 0.810841]
# Factor: 20. MSE train/test: [0.982057, 0.990888]
# Epoch time/Remaining time in seconds: [22/2007]
# ---------- Epoch 21 ------------
#
# Factor: 2. MSE train/test: [0.828604, 0.710098]
# Factor: 4. MSE train/test: [0.705147, 0.678532]
# Factor: 6. MSE train/test: [0.709970, 0.697296]
# Factor: 10. MSE train/test: [0.821122, 0.840882]
# Factor: 20. MSE train/test: [0.968786, 0.984922]
# Epoch time/Remaining time in seconds: [22/1972]
# ---------- Epoch 22 ------------
#
# Factor: 2. MSE train/test: [0.693026, 0.644918]
# Factor: 4. MSE train/test: [0.635469, 0.604018]
# Factor: 6. MSE train/test: [0.697457, 0.655434]
# Factor: 10. MSE train/test: [0.825881, 0.785360]
# Factor: 20. MSE train/test: [0.973306, 0.980764]
# Epoch time/Remaining time in seconds: [24/1943]
# ---------- Epoch 23 ------------
#
# Factor: 2. MSE train/test: [0.686779, 0.708204]
# Factor: 4. MSE train/test: [0.655211, 0.645193]
# Factor: 6. MSE train/test: [0.695661, 0.672405]
# Factor: 10. MSE train/test: [0.795912, 0.808769]
# Factor: 20. MSE train/test: [0.956311, 0.980069]
# Epoch time/Remaining time in seconds: [24/1915]
# ---------- Epoch 24 ------------
#
# Factor: 2. MSE train/test: [0.605593, 0.732439]
# Factor: 4. MSE train/test: [0.566438, 0.651027]
# Factor: 6. MSE train/test: [0.644970, 0.678607]
# Factor: 10. MSE train/test: [0.786693, 0.798142]
# Factor: 20. MSE train/test: [0.980853, 0.969885]
# Epoch time/Remaining time in seconds: [24/1888]
# ---------- Epoch 25 ------------
#
# Factor: 2. MSE train/test: [0.650890, 0.668866]
# Factor: 4. MSE train/test: [0.622402, 0.656736]
# Factor: 6. MSE train/test: [0.671049, 0.708276]
# Factor: 10. MSE train/test: [0.808093, 0.820599]
# Factor: 20. MSE train/test: [0.976103, 0.992318]
# Epoch time/Remaining time in seconds: [26/1865]
# ---------- Epoch 26 ------------
#
# Factor: 2. MSE train/test: [0.714183, 0.681464]
# Factor: 4. MSE train/test: [0.634694, 0.627580]
# Factor: 6. MSE train/test: [0.674276, 0.659581]
# Factor: 10. MSE train/test: [0.797214, 0.812891]
# Factor: 20. MSE train/test: [0.973088, 0.961137]
# Epoch time/Remaining time in seconds: [22/1833]
# ---------- Epoch 27 ------------
#
# Factor: 2. MSE train/test: [0.680901, 0.691733]
# Factor: 4. MSE train/test: [0.641969, 0.625303]
# Factor: 6. MSE train/test: [0.712955, 0.682605]
# Factor: 10. MSE train/test: [0.828103, 0.789888]
# Factor: 20. MSE train/test: [0.966277, 0.957533]
# Epoch time/Remaining time in seconds: [22/1801]
# ---------- Epoch 28 ------------
#
# Factor: 2. MSE train/test: [0.681381, 0.676769]
# Factor: 4. MSE train/test: [0.654754, 0.652522]
# Factor: 6. MSE train/test: [0.704227, 0.704007]
# Factor: 10. MSE train/test: [0.818648, 0.822885]
# Factor: 20. MSE train/test: [0.977639, 0.986509]
# Epoch time/Remaining time in seconds: [22/1770]
# ---------- Epoch 29 ------------
#
# Factor: 2. MSE train/test: [0.536226, 0.628816]
# Factor: 4. MSE train/test: [0.522441, 0.622628]
# Factor: 6. MSE train/test: [0.644284, 0.661303]
# Factor: 10. MSE train/test: [0.826656, 0.792966]
# Factor: 20. MSE train/test: [0.973925, 0.974011]
# Epoch time/Remaining time in seconds: [22/1739]
# ---------- Epoch 30 ------------
#
# Factor: 2. MSE train/test: [0.637322, 0.669337]
# Factor: 4. MSE train/test: [0.614996, 0.649805]
# Factor: 6. MSE train/test: [0.686996, 0.690516]
# Factor: 10. MSE train/test: [0.815664, 0.819238]
# Factor: 20. MSE train/test: [0.975023, 0.987863]
# Epoch time/Remaining time in seconds: [22/1709]
# ---------- Epoch 31 ------------
#
# Factor: 2. MSE train/test: [0.688058, 0.585164]
# Factor: 4. MSE train/test: [0.636523, 0.642864]
# Factor: 6. MSE train/test: [0.672270, 0.690211]
# Factor: 10. MSE train/test: [0.809195, 0.798659]
# Factor: 20. MSE train/test: [0.987043, 0.973144]
# Epoch time/Remaining time in seconds: [22/1680]
# ---------- Epoch 32 ------------
#
# Factor: 2. MSE train/test: [0.673640, 0.666987]
# Factor: 4. MSE train/test: [0.663520, 0.606128]
# Factor: 6. MSE train/test: [0.689782, 0.669454]
# Factor: 10. MSE train/test: [0.786691, 0.800720]
# Factor: 20. MSE train/test: [0.992979, 0.980388]
# Epoch time/Remaining time in seconds: [22/1651]
# ---------- Epoch 33 ------------
#
# Factor: 2. MSE train/test: [0.661738, 0.646516]
# Factor: 4. MSE train/test: [0.645152, 0.645536]
# Factor: 6. MSE train/test: [0.697650, 0.713407]
# Factor: 10. MSE train/test: [0.790572, 0.838133]
# Factor: 20. MSE train/test: [0.994587, 0.938713]
# Epoch time/Remaining time in seconds: [22/1623]
# ---------- Epoch 34 ------------
#
# Factor: 2. MSE train/test: [0.697302, 0.689947]
# Factor: 4. MSE train/test: [0.670355, 0.689633]
# Factor: 6. MSE train/test: [0.695455, 0.720837]
# Factor: 10. MSE train/test: [0.808364, 0.804278]
# Factor: 20. MSE train/test: [0.976227, 0.969295]
# Epoch time/Remaining time in seconds: [24/1597]
# ---------- Epoch 35 ------------
#
# Factor: 2. MSE train/test: [0.542535, 0.634050]
# Factor: 4. MSE train/test: [0.548664, 0.595441]
# Factor: 6. MSE train/test: [0.652492, 0.646563]
# Factor: 10. MSE train/test: [0.806207, 0.779155]
# Factor: 20. MSE train/test: [0.950488, 0.977350]
# Epoch time/Remaining time in seconds: [24/1573]
# ---------- Epoch 36 ------------
#
# Factor: 2. MSE train/test: [0.643910, 0.599105]
# Factor: 4. MSE train/test: [0.596829, 0.594687]
# Factor: 6. MSE train/test: [0.659117, 0.675898]
# Factor: 10. MSE train/test: [0.824093, 0.815313]
# Factor: 20. MSE train/test: [0.976967, 0.969662]
# Epoch time/Remaining time in seconds: [25/1550]
# ---------- Epoch 37 ------------
#
# Factor: 2. MSE train/test: [0.707067, 0.706930]
# Factor: 4. MSE train/test: [0.735385, 0.660918]
# Factor: 6. MSE train/test: [0.739958, 0.694684]
# Factor: 10. MSE train/test: [0.820979, 0.820646]
# Factor: 20. MSE train/test: [0.962602, 0.981494]
# Epoch time/Remaining time in seconds: [27/1530]
# ---------- Epoch 38 ------------
#
# Factor: 2. MSE train/test: [0.670457, 0.718180]
# Factor: 4. MSE train/test: [0.669152, 0.642152]
# Factor: 6. MSE train/test: [0.707163, 0.662404]
# Factor: 10. MSE train/test: [0.826525, 0.797981]
# Factor: 20. MSE train/test: [0.965627, 0.985645]
# Epoch time/Remaining time in seconds: [23/1502]
# ---------- Epoch 39 ------------
#
# Factor: 2. MSE train/test: [0.620196, 0.655048]
# Factor: 4. MSE train/test: [0.583429, 0.609741]
# Factor: 6. MSE train/test: [0.648763, 0.677901]
# Factor: 10. MSE train/test: [0.786719, 0.813147]
# Factor: 20. MSE train/test: [0.986034, 0.969205]
# Epoch time/Remaining time in seconds: [23/1476]
# ---------- Epoch 40 ------------
#
# Factor: 2. MSE train/test: [0.659713, 0.658427]
# Factor: 4. MSE train/test: [0.598244, 0.615866]
# Factor: 6. MSE train/test: [0.686547, 0.679612]
# Factor: 10. MSE train/test: [0.847459, 0.802618]
# Factor: 20. MSE train/test: [0.989195, 0.977184]
# Epoch time/Remaining time in seconds: [22/1448]
# ---------- Epoch 41 ------------
#
# Factor: 2. MSE train/test: [0.567318, 0.670724]
# Factor: 4. MSE train/test: [0.548067, 0.619259]
# Factor: 6. MSE train/test: [0.641538, 0.686936]
# Factor: 10. MSE train/test: [0.793379, 0.800976]
# Factor: 20. MSE train/test: [0.977782, 0.967149]
# Epoch time/Remaining time in seconds: [23/1423]
# ---------- Epoch 42 ------------
#
# Factor: 2. MSE train/test: [0.655884, 0.523590]
# Factor: 4. MSE train/test: [0.612500, 0.494790]
# Factor: 6. MSE train/test: [0.683031, 0.628951]
# Factor: 10. MSE train/test: [0.841155, 0.792622]
# Factor: 20. MSE train/test: [0.981154, 0.961990]
# Epoch time/Remaining time in seconds: [23/1396]
# ---------- Epoch 43 ------------
#
# Factor: 2. MSE train/test: [0.700675, 0.655809]
# Factor: 4. MSE train/test: [0.650996, 0.591924]
# Factor: 6. MSE train/test: [0.685786, 0.664718]
# Factor: 10. MSE train/test: [0.791438, 0.818869]
# Factor: 20. MSE train/test: [0.965454, 0.984170]
# Epoch time/Remaining time in seconds: [22/1369]
# ---------- Epoch 44 ------------
#
# Factor: 2. MSE train/test: [0.664966, 0.645482]
# Factor: 4. MSE train/test: [0.632183, 0.605158]
# Factor: 6. MSE train/test: [0.693961, 0.641790]
# Factor: 10. MSE train/test: [0.828202, 0.802212]
# Factor: 20. MSE train/test: [0.970034, 0.967837]
# Epoch time/Remaining time in seconds: [22/1343]
# ---------- Epoch 45 ------------
#
# Factor: 2. MSE train/test: [0.569415, 0.682127]
# Factor: 4. MSE train/test: [0.556591, 0.622012]
# Factor: 6. MSE train/test: [0.638893, 0.700482]
# Factor: 10. MSE train/test: [0.780899, 0.829279]
# Factor: 20. MSE train/test: [0.968290, 0.979213]
# Epoch time/Remaining time in seconds: [22/1316]
# ---------- Epoch 46 ------------
#
# Factor: 2. MSE train/test: [0.631952, 0.686206]
# Factor: 4. MSE train/test: [0.653826, 0.658527]
# Factor: 6. MSE train/test: [0.678892, 0.687527]
# Factor: 10. MSE train/test: [0.802235, 0.813225]
# Factor: 20. MSE train/test: [0.982978, 0.975871]
# Epoch time/Remaining time in seconds: [23/1290]
# ---------- Epoch 47 ------------
#
# Factor: 2. MSE train/test: [0.710997, 0.673644]
# Factor: 4. MSE train/test: [0.660201, 0.657436]
# Factor: 6. MSE train/test: [0.677619, 0.718809]
# Factor: 10. MSE train/test: [0.783218, 0.804083]
# Factor: 20. MSE train/test: [0.983383, 0.988337]
# Epoch time/Remaining time in seconds: [24/1266]
# ---------- Epoch 48 ------------
#
# Factor: 2. MSE train/test: [0.676370, 0.695073]
# Factor: 4. MSE train/test: [0.618190, 0.644912]
# Factor: 6. MSE train/test: [0.645227, 0.687717]
# Factor: 10. MSE train/test: [0.788501, 0.807407]
# Factor: 20. MSE train/test: [0.979329, 0.980562]
# Epoch time/Remaining time in seconds: [24/1242]
# ---------- Epoch 49 ------------
#
# Factor: 2. MSE train/test: [0.679179, 0.681461]
# Factor: 4. MSE train/test: [0.632777, 0.649897]
# Factor: 6. MSE train/test: [0.673162, 0.676311]
# Factor: 10. MSE train/test: [0.789186, 0.797368]
# Factor: 20. MSE train/test: [0.968217, 0.986064]
# Epoch time/Remaining time in seconds: [23/1217]
# ---------- Epoch 50 ------------
#
# Factor: 2. MSE train/test: [0.632247, 0.674756]
# Factor: 4. MSE train/test: [0.606099, 0.641216]
# Factor: 6. MSE train/test: [0.682858, 0.709138]
# Factor: 10. MSE train/test: [0.825093, 0.814389]
# Factor: 20. MSE train/test: [0.980586, 0.973498]
# Epoch time/Remaining time in seconds: [22/1191]
# ---------- Epoch 51 ------------
#
# Factor: 2. MSE train/test: [0.650402, 0.623574]
# Factor: 4. MSE train/test: [0.631796, 0.596935]
# Factor: 6. MSE train/test: [0.668760, 0.664690]
# Factor: 10. MSE train/test: [0.836994, 0.806757]
# Factor: 20. MSE train/test: [0.976888, 0.970764]
# Epoch time/Remaining time in seconds: [22/1165]
# ---------- Epoch 52 ------------
#
# Factor: 2. MSE train/test: [0.665835, 0.683636]
# Factor: 4. MSE train/test: [0.638010, 0.659348]
# Factor: 6. MSE train/test: [0.699091, 0.696759]
# Factor: 10. MSE train/test: [0.809442, 0.816770]
# Factor: 20. MSE train/test: [0.979237, 0.971170]
# Epoch time/Remaining time in seconds: [23/1140]
# ---------- Epoch 53 ------------
#
# Factor: 2. MSE train/test: [0.592448, 0.611738]
# Factor: 4. MSE train/test: [0.556309, 0.586915]
# Factor: 6. MSE train/test: [0.643114, 0.657133]
# Factor: 10. MSE train/test: [0.796085, 0.795368]
# Factor: 20. MSE train/test: [0.988706, 0.992687]
# Epoch time/Remaining time in seconds: [23/1115]
# ---------- Epoch 54 ------------
#
# Factor: 2. MSE train/test: [0.676041, 0.670378]
# Factor: 4. MSE train/test: [0.596388, 0.626178]
# Factor: 6. MSE train/test: [0.638872, 0.701988]
# Factor: 10. MSE train/test: [0.798397, 0.798976]
# Factor: 20. MSE train/test: [0.977311, 0.972801]
# Epoch time/Remaining time in seconds: [22/1089]
# ---------- Epoch 55 ------------
#
# Factor: 2. MSE train/test: [0.642526, 0.671727]
# Factor: 4. MSE train/test: [0.642701, 0.640070]
# Factor: 6. MSE train/test: [0.692461, 0.664458]
# Factor: 10. MSE train/test: [0.813537, 0.784507]
# Factor: 20. MSE train/test: [0.992529, 0.981399]
# Epoch time/Remaining time in seconds: [22/1064]
# ---------- Epoch 56 ------------
#
# Factor: 2. MSE train/test: [0.703108, 0.623712]
# Factor: 4. MSE train/test: [0.642226, 0.544414]
# Factor: 6. MSE train/test: [0.690658, 0.654835]
# Factor: 10. MSE train/test: [0.819127, 0.803210]
# Factor: 20. MSE train/test: [0.969100, 0.959387]
# Epoch time/Remaining time in seconds: [23/1039]
# ---------- Epoch 57 ------------
#
# Factor: 2. MSE train/test: [0.672606, 0.674554]
# Factor: 4. MSE train/test: [0.626857, 0.620052]
# Factor: 6. MSE train/test: [0.688926, 0.683786]
# Factor: 10. MSE train/test: [0.811503, 0.828415]
# Factor: 20. MSE train/test: [0.979440, 0.974926]
# Epoch time/Remaining time in seconds: [23/1014]
# ---------- Epoch 58 ------------
#
# Factor: 2. MSE train/test: [0.605746, 0.606706]
# Factor: 4. MSE train/test: [0.574782, 0.596182]
# Factor: 6. MSE train/test: [0.646395, 0.679891]
# Factor: 10. MSE train/test: [0.812555, 0.815857]
# Factor: 20. MSE train/test: [0.986075, 0.959135]
# Epoch time/Remaining time in seconds: [26/991]
# ---------- Epoch 59 ------------
#
# Factor: 2. MSE train/test: [0.684384, 0.656296]
# Factor: 4. MSE train/test: [0.617874, 0.641565]
# Factor: 6. MSE train/test: [0.660917, 0.678285]
# Factor: 10. MSE train/test: [0.791639, 0.803682]
# Factor: 20. MSE train/test: [0.973547, 0.992774]
# Epoch time/Remaining time in seconds: [25/967]
# ---------- Epoch 60 ------------
#
# Factor: 2. MSE train/test: [0.625417, 0.684821]
# Factor: 4. MSE train/test: [0.567022, 0.658851]
# Factor: 6. MSE train/test: [0.665009, 0.691970]
# Factor: 10. MSE train/test: [0.794032, 0.792080]
# Factor: 20. MSE train/test: [0.973911, 0.976223]
# Epoch time/Remaining time in seconds: [25/944]
# ---------- Epoch 61 ------------
#
# Factor: 2. MSE train/test: [0.652312, 0.679984]
# Factor: 4. MSE train/test: [0.596407, 0.618459]
# Factor: 6. MSE train/test: [0.645934, 0.650841]
# Factor: 10. MSE train/test: [0.807402, 0.792463]
# Factor: 20. MSE train/test: [0.985762, 0.981711]
# Epoch time/Remaining time in seconds: [25/920]
# ---------- Epoch 62 ------------
#
# Factor: 2. MSE train/test: [0.656589, 0.604245]
# Factor: 4. MSE train/test: [0.613121, 0.588853]
# Factor: 6. MSE train/test: [0.676685, 0.666776]
# Factor: 10. MSE train/test: [0.800315, 0.802657]
# Factor: 20. MSE train/test: [0.978793, 0.960864]
# Epoch time/Remaining time in seconds: [24/896]
# ---------- Epoch 63 ------------
#
# Factor: 2. MSE train/test: [0.609771, 0.630798]
# Factor: 4. MSE train/test: [0.582194, 0.623528]
# Factor: 6. MSE train/test: [0.657285, 0.687732]
# Factor: 10. MSE train/test: [0.809845, 0.829749]
# Factor: 20. MSE train/test: [0.982536, 0.946134]
# Epoch time/Remaining time in seconds: [23/872]
# ---------- Epoch 64 ------------
#
# Factor: 2. MSE train/test: [0.654374, 0.613932]
# Factor: 4. MSE train/test: [0.607367, 0.591750]
# Factor: 6. MSE train/test: [0.655156, 0.645651]
# Factor: 10. MSE train/test: [0.808698, 0.781931]
# Factor: 20. MSE train/test: [0.977675, 0.961662]
# Epoch time/Remaining time in seconds: [23/847]
# ---------- Epoch 65 ------------
#
# Factor: 2. MSE train/test: [0.614269, 0.666028]
# Factor: 4. MSE train/test: [0.583814, 0.624148]
# Factor: 6. MSE train/test: [0.648746, 0.683392]
# Factor: 10. MSE train/test: [0.818970, 0.802402]
# Factor: 20. MSE train/test: [0.977691, 0.978984]
# Epoch time/Remaining time in seconds: [23/822]
# ---------- Epoch 66 ------------
#
# Factor: 2. MSE train/test: [0.642499, 0.631969]
# Factor: 4. MSE train/test: [0.596280, 0.614240]
# Factor: 6. MSE train/test: [0.636225, 0.662239]
# Factor: 10. MSE train/test: [0.803624, 0.780251]
# Factor: 20. MSE train/test: [0.978266, 0.983450]
# Epoch time/Remaining time in seconds: [23/798]
# ---------- Epoch 67 ------------
#
# Factor: 2. MSE train/test: [0.655275, 0.636455]
# Factor: 4. MSE train/test: [0.650309, 0.641136]
# Factor: 6. MSE train/test: [0.703677, 0.662184]
# Factor: 10. MSE train/test: [0.822427, 0.800236]
# Factor: 20. MSE train/test: [0.967705, 0.975660]
# Epoch time/Remaining time in seconds: [23/774]
# ---------- Epoch 68 ------------
#
# Factor: 2. MSE train/test: [0.654440, 0.718990]
# Factor: 4. MSE train/test: [0.617702, 0.623415]
# Factor: 6. MSE train/test: [0.656357, 0.699188]
# Factor: 10. MSE train/test: [0.826710, 0.825264]
# Factor: 20. MSE train/test: [0.971349, 0.974447]
# Epoch time/Remaining time in seconds: [23/749]
# ---------- Epoch 69 ------------
#
# Factor: 2. MSE train/test: [0.672399, 0.642440]
# Factor: 4. MSE train/test: [0.594620, 0.611637]
# Factor: 6. MSE train/test: [0.660439, 0.661386]
# Factor: 10. MSE train/test: [0.799113, 0.826061]
# Factor: 20. MSE train/test: [0.988544, 0.968362]
# Epoch time/Remaining time in seconds: [22/724]
# ---------- Epoch 70 ------------
#
# Factor: 2. MSE train/test: [0.658816, 0.636670]
# Factor: 4. MSE train/test: [0.597152, 0.630416]
# Factor: 6. MSE train/test: [0.668989, 0.677213]
# Factor: 10. MSE train/test: [0.797077, 0.824086]
# Factor: 20. MSE train/test: [0.974302, 0.940288]
# Epoch time/Remaining time in seconds: [23/700]
# ---------- Epoch 71 ------------
#
# Factor: 2. MSE train/test: [0.653021, 0.645871]
# Factor: 4. MSE train/test: [0.614960, 0.626740]
# Factor: 6. MSE train/test: [0.664090, 0.670299]
# Factor: 10. MSE train/test: [0.775985, 0.829744]
# Factor: 20. MSE train/test: [0.969254, 0.969974]
# Epoch time/Remaining time in seconds: [24/676]
# ---------- Epoch 72 ------------
#
# Factor: 2. MSE train/test: [0.672031, 0.669329]
# Factor: 4. MSE train/test: [0.659157, 0.643314]
# Factor: 6. MSE train/test: [0.717157, 0.667147]
# Factor: 10. MSE train/test: [0.834013, 0.808738]
# Factor: 20. MSE train/test: [0.966615, 0.986362]
# Epoch time/Remaining time in seconds: [25/652]
# ---------- Epoch 73 ------------
#
# Factor: 2. MSE train/test: [0.655797, 0.652811]
# Factor: 4. MSE train/test: [0.632930, 0.635694]
# Factor: 6. MSE train/test: [0.682558, 0.693716]
# Factor: 10. MSE train/test: [0.805074, 0.819358]
# Factor: 20. MSE train/test: [0.982926, 0.971603]
# Epoch time/Remaining time in seconds: [25/628]
# ---------- Epoch 74 ------------
#
# Factor: 2. MSE train/test: [0.686158, 0.714198]
# Factor: 4. MSE train/test: [0.642664, 0.663641]
# Factor: 6. MSE train/test: [0.704894, 0.702643]
# Factor: 10. MSE train/test: [0.839774, 0.806545]
# Factor: 20. MSE train/test: [0.971619, 0.967657]
# Epoch time/Remaining time in seconds: [23/604]
# ---------- Epoch 75 ------------
#
# Factor: 2. MSE train/test: [0.676773, 0.629090]
# Factor: 4. MSE train/test: [0.646664, 0.624530]
# Factor: 6. MSE train/test: [0.686929, 0.687423]
# Factor: 10. MSE train/test: [0.806695, 0.836879]
# Factor: 20. MSE train/test: [0.983989, 0.989284]
# Epoch time/Remaining time in seconds: [23/579]
# ---------- Epoch 76 ------------
#
# Factor: 2. MSE train/test: [0.633657, 0.541419]
# Factor: 4. MSE train/test: [0.632863, 0.533473]
# Factor: 6. MSE train/test: [0.709596, 0.648266]
# Factor: 10. MSE train/test: [0.806279, 0.808815]
# Factor: 20. MSE train/test: [0.986244, 0.961014]
# Epoch time/Remaining time in seconds: [23/555]
# ---------- Epoch 77 ------------
#
# Factor: 2. MSE train/test: [0.613741, 0.665725]
# Factor: 4. MSE train/test: [0.607357, 0.625066]
# Factor: 6. MSE train/test: [0.671776, 0.699296]
# Factor: 10. MSE train/test: [0.787322, 0.830323]
# Factor: 20. MSE train/test: [0.974262, 0.975105]
# Epoch time/Remaining time in seconds: [23/530]
# ---------- Epoch 78 ------------
#
# Factor: 2. MSE train/test: [0.664671, 0.666434]
# Factor: 4. MSE train/test: [0.631364, 0.635393]
# Factor: 6. MSE train/test: [0.690261, 0.690050]
# Factor: 10. MSE train/test: [0.806923, 0.794106]
# Factor: 20. MSE train/test: [0.955449, 0.952453]
# Epoch time/Remaining time in seconds: [23/506]
# ---------- Epoch 79 ------------
#
# Factor: 2. MSE train/test: [0.649416, 0.676051]
# Factor: 4. MSE train/test: [0.579876, 0.644365]
# Factor: 6. MSE train/test: [0.650245, 0.697312]
# Factor: 10. MSE train/test: [0.802479, 0.823420]
# Factor: 20. MSE train/test: [0.966925, 0.982477]
# Epoch time/Remaining time in seconds: [23/482]
# ---------- Epoch 80 ------------
#
# Factor: 2. MSE train/test: [0.678827, 0.602292]
# Factor: 4. MSE train/test: [0.615339, 0.564754]
# Factor: 6. MSE train/test: [0.672876, 0.644793]
# Factor: 10. MSE train/test: [0.823513, 0.796874]
# Factor: 20. MSE train/test: [0.956877, 0.985485]
# Epoch time/Remaining time in seconds: [23/457]
# ---------- Epoch 81 ------------
#
# Factor: 2. MSE train/test: [0.641564, 0.671782]
# Factor: 4. MSE train/test: [0.604688, 0.655661]
# Factor: 6. MSE train/test: [0.660991, 0.692279]
# Factor: 10. MSE train/test: [0.803335, 0.823072]
# Factor: 20. MSE train/test: [0.958629, 0.958318]
# Epoch time/Remaining time in seconds: [23/433]
# ---------- Epoch 82 ------------
#
# Factor: 2. MSE train/test: [0.701637, 0.706679]
# Factor: 4. MSE train/test: [0.634838, 0.678072]
# Factor: 6. MSE train/test: [0.653240, 0.713097]
# Factor: 10. MSE train/test: [0.815965, 0.795512]
# Factor: 20. MSE train/test: [0.990277, 0.955899]
# Epoch time/Remaining time in seconds: [23/409]
# ---------- Epoch 83 ------------
#
# Factor: 2. MSE train/test: [0.667586, 0.551463]
# Factor: 4. MSE train/test: [0.657751, 0.552112]
# Factor: 6. MSE train/test: [0.690137, 0.640749]
# Factor: 10. MSE train/test: [0.827052, 0.772437]
# Factor: 20. MSE train/test: [0.965591, 0.976104]
# Epoch time/Remaining time in seconds: [24/385]
# ---------- Epoch 84 ------------
#
# Factor: 2. MSE train/test: [0.643542, 0.649746]
# Factor: 4. MSE train/test: [0.632524, 0.637859]
# Factor: 6. MSE train/test: [0.696628, 0.686834]
# Factor: 10. MSE train/test: [0.829677, 0.808663]
# Factor: 20. MSE train/test: [0.958151, 0.979833]
# Epoch time/Remaining time in seconds: [25/361]
# ---------- Epoch 85 ------------
#
# Factor: 2. MSE train/test: [0.603845, 0.615913]
# Factor: 4. MSE train/test: [0.577559, 0.600872]
# Factor: 6. MSE train/test: [0.658282, 0.678365]
# Factor: 10. MSE train/test: [0.814083, 0.840255]
# Factor: 20. MSE train/test: [0.984106, 0.965932]
# Epoch time/Remaining time in seconds: [24/337]
# ---------- Epoch 86 ------------
#
# Factor: 2. MSE train/test: [0.622804, 0.679705]
# Factor: 4. MSE train/test: [0.587300, 0.640264]
# Factor: 6. MSE train/test: [0.668191, 0.698009]
# Factor: 10. MSE train/test: [0.781001, 0.826040]
# Factor: 20. MSE train/test: [0.982320, 0.955549]
# Epoch time/Remaining time in seconds: [23/313]
# ---------- Epoch 87 ------------
#
# Factor: 2. MSE train/test: [0.625215, 0.668396]
# Factor: 4. MSE train/test: [0.593854, 0.633371]
# Factor: 6. MSE train/test: [0.671426, 0.676959]
# Factor: 10. MSE train/test: [0.799937, 0.800793]
# Factor: 20. MSE train/test: [0.969553, 0.996506]
# Epoch time/Remaining time in seconds: [22/288]
# ---------- Epoch 88 ------------
#
# Factor: 2. MSE train/test: [0.647288, 0.725144]
# Factor: 4. MSE train/test: [0.647385, 0.615534]
# Factor: 6. MSE train/test: [0.707935, 0.646406]
# Factor: 10. MSE train/test: [0.801771, 0.783774]
# Factor: 20. MSE train/test: [0.968307, 0.977900]
# Epoch time/Remaining time in seconds: [22/264]
# ---------- Epoch 89 ------------
#
# Factor: 2. MSE train/test: [0.652593, 0.644808]
# Factor: 4. MSE train/test: [0.631447, 0.634038]
# Factor: 6. MSE train/test: [0.707993, 0.665848]
# Factor: 10. MSE train/test: [0.823123, 0.800961]
# Factor: 20. MSE train/test: [0.973086, 0.976960]
# Epoch time/Remaining time in seconds: [23/240]
# ---------- Epoch 90 ------------
#
# Factor: 2. MSE train/test: [0.685134, 0.557659]
# Factor: 4. MSE train/test: [0.630870, 0.556068]
# Factor: 6. MSE train/test: [0.687638, 0.639982]
# Factor: 10. MSE train/test: [0.826880, 0.785192]
# Factor: 20. MSE train/test: [0.990810, 0.977307]
# Epoch time/Remaining time in seconds: [24/216]
# ---------- Epoch 91 ------------
#
# Factor: 2. MSE train/test: [0.658241, 0.621913]
# Factor: 4. MSE train/test: [0.663750, 0.606218]
# Factor: 6. MSE train/test: [0.729200, 0.658010]
# Factor: 10. MSE train/test: [0.829147, 0.800592]
# Factor: 20. MSE train/test: [0.985933, 0.969228]
# Epoch time/Remaining time in seconds: [23/192]
# ---------- Epoch 92 ------------
#
# Factor: 2. MSE train/test: [0.547734, 0.670145]
# Factor: 4. MSE train/test: [0.518307, 0.571491]
# Factor: 6. MSE train/test: [0.617181, 0.672120]
# Factor: 10. MSE train/test: [0.765136, 0.809724]
# Factor: 20. MSE train/test: [0.965484, 0.954675]
# Epoch time/Remaining time in seconds: [23/168]
# ---------- Epoch 93 ------------
#
# Factor: 2. MSE train/test: [0.663321, 0.605239]
# Factor: 4. MSE train/test: [0.619386, 0.563458]
# Factor: 6. MSE train/test: [0.681690, 0.624683]
# Factor: 10. MSE train/test: [0.802943, 0.789259]
# Factor: 20. MSE train/test: [0.986501, 0.967958]
# Epoch time/Remaining time in seconds: [25/144]
# ---------- Epoch 94 ------------
#
# Factor: 2. MSE train/test: [0.730555, 0.672719]
# Factor: 4. MSE train/test: [0.635010, 0.662413]
# Factor: 6. MSE train/test: [0.669583, 0.711528]
# Factor: 10. MSE train/test: [0.801624, 0.806299]
# Factor: 20. MSE train/test: [0.965181, 0.976322]
# Epoch time/Remaining time in seconds: [23/120]
# ---------- Epoch 95 ------------
#
# Factor: 2. MSE train/test: [0.576056, 0.672913]
# Factor: 4. MSE train/test: [0.562160, 0.642009]
# Factor: 6. MSE train/test: [0.634694, 0.669034]
# Factor: 10. MSE train/test: [0.815012, 0.784707]
# Factor: 20. MSE train/test: [0.977343, 0.984000]
# Epoch time/Remaining time in seconds: [24/96]
# ---------- Epoch 96 ------------
#
# Factor: 2. MSE train/test: [0.668957, 0.594011]
# Factor: 4. MSE train/test: [0.624238, 0.574453]
# Factor: 6. MSE train/test: [0.684599, 0.633149]
# Factor: 10. MSE train/test: [0.789625, 0.792268]
# Factor: 20. MSE train/test: [0.980901, 0.985323]
# Epoch time/Remaining time in seconds: [28/72]
# ---------- Epoch 97 ------------
#
# Factor: 2. MSE train/test: [0.699236, 0.652879]
# Factor: 4. MSE train/test: [0.628334, 0.614147]
# Factor: 6. MSE train/test: [0.676093, 0.652824]
# Factor: 10. MSE train/test: [0.793571, 0.776408]
# Factor: 20. MSE train/test: [0.975006, 0.983712]
# Epoch time/Remaining time in seconds: [26/48]
# ---------- Epoch 98 ------------
#
# Factor: 2. MSE train/test: [0.670045, 0.676378]
# Factor: 4. MSE train/test: [0.606836, 0.633014]
# Factor: 6. MSE train/test: [0.655115, 0.675785]
# Factor: 10. MSE train/test: [0.805421, 0.803126]
# Factor: 20. MSE train/test: [0.975026, 0.976577]
# Epoch time/Remaining time in seconds: [23/24]
# ---------- Epoch 99 ------------
#
# Factor: 2. MSE train/test: [0.699258, 0.659165]
# Factor: 4. MSE train/test: [0.625900, 0.638016]
# Factor: 6. MSE train/test: [0.669324, 0.692572]
# Factor: 10. MSE train/test: [0.813515, 0.809356]
# Factor: 20. MSE train/test: [0.988516, 0.984523]
# Epoch time/Remaining time in seconds: [25/0]
