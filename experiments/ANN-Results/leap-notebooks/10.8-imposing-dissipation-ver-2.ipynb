# %%
import matplotlib.pyplot as plt
from helpers.cm26 import DatasetCM26, remesh
from helpers.computational_tools import select_NA, select_Pacific, StateFunctions, compare
from helpers.ann_tools import ANN, import_ANN, minibatch, export_ANN
import torch
import torch.optim as optim
import numpy as np
import xarray as xr
from time import time
import json
# %load_ext autoreload
# %autoreload 3

# %%
def sample_grid_harmonic(dataset, key, plain=False):
    '''
    Here for simplicity the dataset is coarsegrained
    snapshot of CM26.
    '''
    data = dataset.data
    ny, nx = data.u.shape
    
    u = np.zeros((ny,nx))
    v = np.zeros((ny,nx))
    
    # assign random phase (1 or -1)
    phase = -1 if np.random.randint(2)==0 else 1
    
    if key == 'vorticity':
        sign = -1
    elif key == 'divergence':
        sign = 1
    else:
        print('Error: key is wrongly specified')
    
    for j in range(ny):
        for i in range(nx):
            if plain:
                idx = i if np.random.randint(2)==0 else j
            else:
                idx = i+j
            u[j,i] = phase *        (-1)**(idx)
            v[j,i] = phase * sign * (-1)**(idx)
            
    data['u'] = xr.DataArray(u, dims=['yh', 'xq']) * dataset.param.wet_u
    data['v'] = xr.DataArray(v, dims=['yq', 'xh']) * dataset.param.wet_v
    return DatasetCM26(data, dataset.param, dataset.grid)

# %%
def sample_plane_wave(ny, nx):
        # Sampling frequency between -pi and pi, i.e. all
        # available frequencies
        freq_x = 0
        freq_y = 0
        while np.abs(freq_x)<2/3*np.pi and np.abs(freq_y)<2/3*np.pi:
            # i.e. if wave is inside the square of 2/3*pi,
            # keep sampling
            freq_x = np.random.rand() * np.pi * 2 - np.pi
            freq_y = np.random.rand() * np.pi * 2 - np.pi

        phase_u = np.random.rand()*2*np.pi
        phase_v = np.random.rand()*2*np.pi

        i = np.ones(ny).reshape(-1,1)@np.arange(nx).reshape(1,-1)
        j = np.arange(ny).reshape(-1,1)@np.ones(nx).reshape(1,-1)

        u = np.sin(freq_x * i + freq_y * j + phase_u)
        v = np.sin(freq_x * i + freq_y * j + phase_v)

        return u, v

# %%
u, v = sample_plane_wave(30,30)
plt.subplot(1,2,1)
plt.imshow(u)
plt.subplot(1,2,2)
plt.imshow(v)

# %%
def sample_two_thirds(dataset):
    '''
    Here for simplicity the dataset is coarsegrained
    snapshot of CM26.
    '''        
    
    data = dataset.data
    ny, nx = data.u.shape
    u,v = sample_plane_wave(ny,nx)

    data['u'] = xr.DataArray(u, dims=['yh', 'xq']) * dataset.param.wet_u
    data['v'] = xr.DataArray(v, dims=['yq', 'xh']) * dataset.param.wet_v
    return DatasetCM26(data, dataset.param, dataset.grid)

# %%
ds = DatasetCM26()

# %%
training_dataset = ds.sample_epoch(time=np.random.randint(6950))

# %%
plt.figure(figsize=(12,4))
for j,grid_harmonic in enumerate(['vorticity', 'divergence']):
    batch = sample_grid_harmonic(training_dataset[20],grid_harmonic)
#    batch = sample_two_thirds(training_dataset[20])
    smag = batch.state.Smagorinsky()
    Txx = smag['Txx']
    Tyy = smag['Tyy']
    Txy = smag['Txy']
    sh_xy, sh_xx, vort_xy = batch.state.velocity_gradients()
    dissipation =  Txx * sh_xx + batch.grid.interp(Txy * sh_xy,['X','Y'])
    plt.subplot(1,2,1+j)
    dissipation.plot()
    plt.title(f'Dissipation on \ngrid harmonic: {grid_harmonic}')
plt.tight_layout()

# %%
plt.figure(figsize=(8,4))
batch = sample_two_thirds(training_dataset[20])
smag = batch.state.Smagorinsky()
Txx = smag['Txx']
Tyy = smag['Tyy']
Txy = smag['Txy']
sh_xy, sh_xx, vort_xy = batch.state.velocity_gradients()
dissipation =  Txx * sh_xx + batch.grid.interp(Txy * sh_xy,['X','Y'])
dissipation.plot()
plt.title(f'Dissipation on plane wave')
plt.tight_layout()

# %%
training_dataset = ds.sample_epoch(time=np.random.randint(6950)) # Approximately 19 years for training

# %%
batch = training_dataset[10]
smag = batch.state.Smagorinsky()
smagx = torch.tensor(smag['smagx'].values).type(torch.float32)
smagy = torch.tensor(smag['smagy'].values).type(torch.float32)

u_wave, v_wave = sample_plane_wave(*smagx.shape)
u_wave = torch.tensor(u_wave).type(torch.float32)
v_wave = torch.tensor(v_wave).type(torch.float32)

Smag_fourier_x = (smagx * u_wave).mean()
Smag_fourier_y = (smagy * v_wave).mean()

print(Smag_fourier_x, Smag_fourier_y)
# Out:
# tensor(1.2854e-10) tensor(7.0379e-10)

# %%
1. / (np.abs(Smag_fourier_x) + np.abs(Smag_fourier_y) + 1e-30)
# Out:
# tensor(1.2014e+09)

# %% [markdown]
# So, the typical value of normalization constant is 1e+9

# %%
# ann_Txy = ANN([27, 20, 1])
# ann_Txx_Tyy = ANN([27, 20, 2])
log_dict = {}
ann_Txy = import_ANN('trained_models/ANN_CM26/Txy_epoch_2000.nc')
ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26/Txx_Tyy_epoch_2000.nc')

# %%
num_epochs=500

all_parameters = list(ann_Txy.parameters()) + list(ann_Txx_Tyy.parameters())
optimizer = optim.Adam(all_parameters, lr=1e-3)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
        milestones=[int(num_epochs/2), int(num_epochs*3/4), int(num_epochs*7/8)], gamma=0.1)  

t_s = time()

for epoch in range(num_epochs):
    t_e = time()
    
    training_dataset = ds.sample_epoch(time=np.random.randint(6950)) # Approximately 19 years for training
    testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035)) # Approximately 3 years for testing
    print(f'---------- Epoch {epoch} ------------\n')
    
    for factor in [2,4,6,10,20]:
        ############# Training step ################
        
        optimizer.zero_grad()
        
        batch = training_dataset[factor]
        prediction = batch.state.Apply_ANN(ann_Txy, ann_Txx_Tyy)
        ANNx = prediction['ZB20u']
        ANNy = prediction['ZB20v']
        SGSx = torch.tensor(batch.data.SGSx.values).type(torch.float32)
        SGSy = torch.tensor(batch.data.SGSy.values).type(torch.float32)
        
        SGS_norm = 1. / torch.sqrt((SGSx**2 + SGSy**2).mean())
        
        MSE_train = ((ANNx*SGS_norm-SGSx*SGS_norm)**2 + (ANNy*SGS_norm-SGSy*SGS_norm)**2).mean()
        
        u_wave, v_wave = sample_plane_wave(*ANNx.shape)
        u_wave = torch.tensor(u_wave).type(torch.float32)
        v_wave = torch.tensor(v_wave).type(torch.float32)
        
        # Regulatization.
        smag = batch.state.Smagorinsky()
        smagx = torch.tensor(smag['smagx'].values).type(torch.float32)
        smagy = torch.tensor(smag['smagy'].values).type(torch.float32)
        
        # These are fourier coefficients of error between ANN and Smag on
        # short waves
        Error_fourier_x = ((ANNx-smagx) * u_wave).mean()
        Error_fourier_y = ((ANNy-smagy) * v_wave).mean()
        Smag_fourier_x = (smagx * u_wave).mean()
        Smag_fourier_y = (smagy * v_wave).mean()
        
        SGS_norm = 1e+9 # This is typical value
        
        MSE_plane_waves = (Error_fourier_x * SGS_norm)**2 + (Error_fourier_y * SGS_norm)**2
        
        loss = MSE_train + MSE_plane_waves
        
        loss.backward()
        optimizer.step()
        
        ############ Testing step ##################
        with torch.no_grad():
            batch = testing_dataset[factor]
            prediction = batch.state.Apply_ANN(ann_Txy, ann_Txx_Tyy)
            ANNx = prediction['ZB20u']
            ANNy = prediction['ZB20v']
            SGSx = torch.tensor(batch.data.SGSx.values).type(torch.float32)
            SGSy = torch.tensor(batch.data.SGSy.values).type(torch.float32)

            SGS_norm = 1. / torch.sqrt((SGSx**2 + SGSy**2).mean())

            MSE_test = ((ANNx*SGS_norm-SGSx*SGS_norm)**2 + (ANNy*SGS_norm-SGSy*SGS_norm)**2).mean()
        
        print(f'Factor: {factor}.' + \
              ' MSE train/test: [%.6f, %.6f]' % (float(MSE_train.data), float(MSE_test.data)) + \
              ' MSE on plane waves: %.6f' % (float(MSE_plane_waves)))
        ########### Saving history of losses ############
        log_dict[f'epoch-{epoch+1}-factor-{factor}'] = \
            dict(MSE_train=float(MSE_train.data),
                 MSE_test=float(MSE_test.data),
                 MSE_plane_waves=float(MSE_plane_waves)
                )
        ######## Freeing memory ############
        del training_dataset[factor].data
        del training_dataset[factor].param
        del testing_dataset[factor].data
        del testing_dataset[factor].param
    t = time()
    print('Epoch time/Remaining time in seconds: [%d/%d]' % (t-t_e, (t-t_s)*(num_epochs/(epoch+1)-1)))
    scheduler.step()    
    
    if (epoch+1) % 50 == 0:
        export_ANN(ann_Txy, input_norms=torch.ones(27), output_norms=torch.ones(1), 
           filename=f'trained_models/ANN_CM26_grid_harmonic_ver2/Txy_epoch_{epoch+1}.nc')
        export_ANN(ann_Txx_Tyy, input_norms=torch.ones(27), output_norms=torch.ones(2), 
           filename=f'trained_models/ANN_CM26_grid_harmonic_ver2/Txx_Tyy_epoch_{epoch+1}.nc')
        with open(f'trained_models/ANN_CM26_grid_harmonic_ver2/log_dict_epoch_{epoch+1}', 'w') as file:
            json.dump(log_dict, file)
# Out:
# ---------- Epoch 0 ------------
#
# Factor: 2. MSE train/test: [0.577159, 0.567896] MSE on plane waves: 0.001151
# Factor: 4. MSE train/test: [0.554812, 0.531509] MSE on plane waves: 0.112979
# Factor: 6. MSE train/test: [0.573299, 0.569737] MSE on plane waves: 0.083091
# Factor: 10. MSE train/test: [0.636243, 0.694314] MSE on plane waves: 0.055128
# Factor: 20. MSE train/test: [0.889708, 0.822258] MSE on plane waves: 0.095500
# Epoch time/Remaining time in seconds: [15/7575]
# ---------- Epoch 1 ------------
#
# Factor: 2. MSE train/test: [0.649750, 0.613253] MSE on plane waves: 0.015293
# Factor: 4. MSE train/test: [0.561765, 0.563265] MSE on plane waves: 0.135903
# Factor: 6. MSE train/test: [0.580740, 0.570825] MSE on plane waves: 0.284188
# Factor: 10. MSE train/test: [0.670347, 0.667489] MSE on plane waves: 1.214757
# Factor: 20. MSE train/test: [0.889816, 0.908145] MSE on plane waves: 0.734787
# Epoch time/Remaining time in seconds: [15/7517]
# ---------- Epoch 2 ------------
#
# Factor: 2. MSE train/test: [0.622311, 0.648606] MSE on plane waves: 0.096164
# Factor: 4. MSE train/test: [0.589597, 0.568161] MSE on plane waves: 0.005989
# Factor: 6. MSE train/test: [0.609142, 0.589456] MSE on plane waves: 9.836644
# Factor: 10. MSE train/test: [0.689474, 0.711512] MSE on plane waves: 0.022608
# Factor: 20. MSE train/test: [0.893496, 0.919551] MSE on plane waves: 2.778531
# Epoch time/Remaining time in seconds: [15/7533]
# ---------- Epoch 3 ------------
#
# Factor: 2. MSE train/test: [0.637758, 0.687704] MSE on plane waves: 0.118864
# Factor: 4. MSE train/test: [0.611215, 0.649880] MSE on plane waves: 0.189251
# Factor: 6. MSE train/test: [0.625477, 0.665788] MSE on plane waves: 1.438369
# Factor: 10. MSE train/test: [0.738236, 0.743350] MSE on plane waves: 5.826555
# Factor: 20. MSE train/test: [0.931853, 0.927639] MSE on plane waves: 1.583457
# Epoch time/Remaining time in seconds: [15/7525]
# ---------- Epoch 4 ------------
#
# Factor: 2. MSE train/test: [0.736882, 0.666399] MSE on plane waves: 0.057903
# Factor: 4. MSE train/test: [0.648272, 0.616472] MSE on plane waves: 0.016303
# Factor: 6. MSE train/test: [0.675334, 0.652595] MSE on plane waves: 0.578314
# Factor: 10. MSE train/test: [0.732607, 0.750803] MSE on plane waves: 2.168133
# Factor: 20. MSE train/test: [0.924905, 0.954908] MSE on plane waves: 0.063627
# Epoch time/Remaining time in seconds: [15/7522]
# ---------- Epoch 5 ------------
#
# Factor: 2. MSE train/test: [0.759787, 0.758941] MSE on plane waves: 0.022802
# Factor: 4. MSE train/test: [0.687594, 0.660359] MSE on plane waves: 0.006961
# Factor: 6. MSE train/test: [0.716976, 0.687410] MSE on plane waves: 0.920749
# Factor: 10. MSE train/test: [0.767796, 0.762876] MSE on plane waves: 0.828793
# Factor: 20. MSE train/test: [0.946539, 0.953573] MSE on plane waves: 1.851965
# Epoch time/Remaining time in seconds: [14/7482]
# ---------- Epoch 6 ------------
#
# Factor: 2. MSE train/test: [0.660668, 0.775649] MSE on plane waves: 0.041360
# Factor: 4. MSE train/test: [0.649680, 0.682802] MSE on plane waves: 1.186707
# Factor: 6. MSE train/test: [0.685403, 0.685600] MSE on plane waves: 0.033659
# Factor: 10. MSE train/test: [0.770345, 0.791706] MSE on plane waves: 0.100253
# Factor: 20. MSE train/test: [0.936674, 0.966597] MSE on plane waves: 0.435054
# Epoch time/Remaining time in seconds: [15/7463]
# ---------- Epoch 7 ------------
#
# Factor: 2. MSE train/test: [0.751764, 0.737183] MSE on plane waves: 0.025890
# Factor: 4. MSE train/test: [0.707526, 0.662751] MSE on plane waves: 0.083505
# Factor: 6. MSE train/test: [0.714084, 0.685203] MSE on plane waves: 1.902890
# Factor: 10. MSE train/test: [0.780746, 0.768818] MSE on plane waves: 0.356055
# Factor: 20. MSE train/test: [0.918562, 0.964034] MSE on plane waves: 0.009208
# Epoch time/Remaining time in seconds: [15/7453]
# ---------- Epoch 8 ------------
#
# Factor: 2. MSE train/test: [0.583914, 0.770054] MSE on plane waves: 0.045932
# Factor: 4. MSE train/test: [0.579427, 0.717929] MSE on plane waves: 0.330514
# Factor: 6. MSE train/test: [0.654844, 0.748132] MSE on plane waves: 1.608829
# Factor: 10. MSE train/test: [0.775629, 0.826490] MSE on plane waves: 2.860959
# Factor: 20. MSE train/test: [0.923797, 0.971269] MSE on plane waves: 0.106158
# Epoch time/Remaining time in seconds: [15/7433]
# ---------- Epoch 9 ------------
#
# Factor: 2. MSE train/test: [0.812950, 0.763022] MSE on plane waves: 0.001366
# Factor: 4. MSE train/test: [0.732934, 0.723632] MSE on plane waves: 0.432580
# Factor: 6. MSE train/test: [0.756745, 0.720472] MSE on plane waves: 0.640310
# Factor: 10. MSE train/test: [0.820156, 0.813614] MSE on plane waves: 0.565930
# Factor: 20. MSE train/test: [0.972574, 0.922018] MSE on plane waves: 2.142087
# Epoch time/Remaining time in seconds: [15/7420]
# ---------- Epoch 10 ------------
#
# Factor: 2. MSE train/test: [0.682882, 0.745865] MSE on plane waves: 0.031407
# Factor: 4. MSE train/test: [0.648598, 0.700231] MSE on plane waves: 0.142237
# Factor: 6. MSE train/test: [0.668382, 0.705990] MSE on plane waves: 0.528032
# Factor: 10. MSE train/test: [0.782193, 0.777421] MSE on plane waves: 1.102506
# Factor: 20. MSE train/test: [0.952939, 0.941671] MSE on plane waves: 0.160157
# Epoch time/Remaining time in seconds: [14/7384]
# ---------- Epoch 11 ------------
#
# Factor: 2. MSE train/test: [0.732384, 0.702756] MSE on plane waves: 0.018895
# Factor: 4. MSE train/test: [0.695513, 0.630383] MSE on plane waves: 0.479337
# Factor: 6. MSE train/test: [0.701676, 0.659263] MSE on plane waves: 2.083928
# Factor: 10. MSE train/test: [0.777319, 0.756667] MSE on plane waves: 0.756480
# Factor: 20. MSE train/test: [0.957321, 0.954776] MSE on plane waves: 0.844350
# Epoch time/Remaining time in seconds: [15/7373]
# ---------- Epoch 12 ------------
#
# Factor: 2. MSE train/test: [0.762562, 0.747135] MSE on plane waves: 0.014188
# Factor: 4. MSE train/test: [0.675497, 0.656831] MSE on plane waves: 0.050248
# Factor: 6. MSE train/test: [0.696049, 0.682540] MSE on plane waves: 0.638435
# Factor: 10. MSE train/test: [0.786820, 0.782795] MSE on plane waves: 0.010860
# Factor: 20. MSE train/test: [0.928220, 0.930861] MSE on plane waves: 0.033566
# Epoch time/Remaining time in seconds: [15/7374]
# ---------- Epoch 13 ------------
#
# Factor: 2. MSE train/test: [0.713744, 0.756537] MSE on plane waves: 0.058858
# Factor: 4. MSE train/test: [0.667870, 0.674321] MSE on plane waves: 0.006446
# Factor: 6. MSE train/test: [0.688066, 0.668682] MSE on plane waves: 1.301583
# Factor: 10. MSE train/test: [0.783131, 0.709013] MSE on plane waves: 0.365785
# Factor: 20. MSE train/test: [0.948314, 0.906578] MSE on plane waves: 0.080453
# Epoch time/Remaining time in seconds: [15/7374]
# ---------- Epoch 14 ------------
#
# Factor: 2. MSE train/test: [0.735958, 0.676481] MSE on plane waves: 0.043317
# Factor: 4. MSE train/test: [0.663095, 0.643889] MSE on plane waves: 1.421839
# Factor: 6. MSE train/test: [0.673653, 0.668756] MSE on plane waves: 0.020017
# Factor: 10. MSE train/test: [0.760687, 0.781289] MSE on plane waves: 0.060633
# Factor: 20. MSE train/test: [0.950723, 0.885761] MSE on plane waves: 0.103678
# Epoch time/Remaining time in seconds: [15/7383]
# ---------- Epoch 15 ------------
#
# Factor: 2. MSE train/test: [0.767759, 0.727584] MSE on plane waves: 0.011929
# Factor: 4. MSE train/test: [0.672790, 0.640047] MSE on plane waves: 0.021104
# Factor: 6. MSE train/test: [0.701563, 0.652360] MSE on plane waves: 0.277551
# Factor: 10. MSE train/test: [0.775130, 0.740989] MSE on plane waves: 0.672486
# Factor: 20. MSE train/test: [0.927217, 0.927239] MSE on plane waves: 4.533201
# Epoch time/Remaining time in seconds: [15/7387]
# ---------- Epoch 16 ------------
#
# Factor: 2. MSE train/test: [0.572643, 0.724936] MSE on plane waves: 0.037565
# Factor: 4. MSE train/test: [0.539171, 0.690316] MSE on plane waves: 0.069705
# Factor: 6. MSE train/test: [0.637041, 0.678002] MSE on plane waves: 0.064013
# Factor: 10. MSE train/test: [0.760047, 0.759581] MSE on plane waves: 0.347071
# Factor: 20. MSE train/test: [0.940090, 0.969358] MSE on plane waves: 1.323641
# Epoch time/Remaining time in seconds: [16/7402]
# ---------- Epoch 17 ------------
#
# Factor: 2. MSE train/test: [0.773317, 0.662430] MSE on plane waves: 0.029565
# Factor: 4. MSE train/test: [0.727260, 0.641604] MSE on plane waves: 0.048241
# Factor: 6. MSE train/test: [0.743740, 0.692600] MSE on plane waves: 1.566252
# Factor: 10. MSE train/test: [0.771199, 0.796678] MSE on plane waves: 0.451218
# Factor: 20. MSE train/test: [0.988041, 0.954868] MSE on plane waves: 0.149310
# Epoch time/Remaining time in seconds: [17/7442]
# ---------- Epoch 18 ------------
#
# Factor: 2. MSE train/test: [0.779618, 0.768144] MSE on plane waves: 0.037227
# Factor: 4. MSE train/test: [0.707806, 0.708896] MSE on plane waves: 0.115505
# Factor: 6. MSE train/test: [0.705782, 0.706918] MSE on plane waves: 0.141078
# Factor: 10. MSE train/test: [0.752532, 0.792253] MSE on plane waves: 0.232338
# Factor: 20. MSE train/test: [0.934672, 0.960487] MSE on plane waves: 0.113216
# Epoch time/Remaining time in seconds: [15/7438]
# ---------- Epoch 19 ------------
#
# Factor: 2. MSE train/test: [0.717927, 0.691932] MSE on plane waves: 0.010818
# Factor: 4. MSE train/test: [0.666815, 0.570193] MSE on plane waves: 0.012678
# Factor: 6. MSE train/test: [0.670295, 0.698216] MSE on plane waves: 1.744429
# Factor: 10. MSE train/test: [0.737294, 0.784769] MSE on plane waves: 0.293870
# Factor: 20. MSE train/test: [0.914760, 0.932207] MSE on plane waves: 1.336163
# Epoch time/Remaining time in seconds: [15/7422]
# ---------- Epoch 20 ------------
#
# Factor: 2. MSE train/test: [0.674456, 0.782875] MSE on plane waves: 0.029580
# Factor: 4. MSE train/test: [0.605645, 0.652369] MSE on plane waves: 0.239698
# Factor: 6. MSE train/test: [0.627111, 0.645841] MSE on plane waves: 1.301148
# Factor: 10. MSE train/test: [0.742701, 0.743382] MSE on plane waves: 0.028278
# Factor: 20. MSE train/test: [0.962371, 0.973497] MSE on plane waves: 0.055411
# Epoch time/Remaining time in seconds: [15/7407]
# ---------- Epoch 21 ------------
#
# Factor: 2. MSE train/test: [0.674791, 0.689232] MSE on plane waves: 0.020898
# Factor: 4. MSE train/test: [0.645218, 0.642914] MSE on plane waves: 0.171959
# Factor: 6. MSE train/test: [0.684700, 0.646600] MSE on plane waves: 0.004452
# Factor: 10. MSE train/test: [0.766808, 0.756755] MSE on plane waves: 1.077510
# Factor: 20. MSE train/test: [0.952131, 0.972987] MSE on plane waves: 0.935288
# Epoch time/Remaining time in seconds: [16/7407]
# ---------- Epoch 22 ------------
#
# Factor: 2. MSE train/test: [0.626626, 0.672073] MSE on plane waves: 0.064248
# Factor: 4. MSE train/test: [0.589441, 0.613452] MSE on plane waves: 0.017489
# Factor: 6. MSE train/test: [0.637237, 0.635777] MSE on plane waves: 0.082896
# Factor: 10. MSE train/test: [0.724934, 0.724527] MSE on plane waves: 1.001906
# Factor: 20. MSE train/test: [0.975886, 0.948148] MSE on plane waves: 0.141947
# Epoch time/Remaining time in seconds: [16/7402]
# ---------- Epoch 23 ------------
#
# Factor: 2. MSE train/test: [0.719474, 0.631545] MSE on plane waves: 0.001133
# Factor: 4. MSE train/test: [0.625545, 0.563977] MSE on plane waves: 0.380050
# Factor: 6. MSE train/test: [0.641375, 0.644058] MSE on plane waves: 2.929455
# Factor: 10. MSE train/test: [0.724612, 0.751542] MSE on plane waves: 0.119298
# Factor: 20. MSE train/test: [0.931199, 0.927291] MSE on plane waves: 0.172103
# Epoch time/Remaining time in seconds: [15/7389]
# ---------- Epoch 24 ------------
#
# Factor: 2. MSE train/test: [0.718912, 0.722433] MSE on plane waves: 0.027003
# Factor: 4. MSE train/test: [0.620304, 0.612644] MSE on plane waves: 0.004013
# Factor: 6. MSE train/test: [0.638895, 0.611712] MSE on plane waves: 0.073237
# Factor: 10. MSE train/test: [0.702541, 0.705832] MSE on plane waves: 1.298025
# Factor: 20. MSE train/test: [0.950135, 0.941019] MSE on plane waves: 1.684246
# Epoch time/Remaining time in seconds: [15/7380]
# ---------- Epoch 25 ------------
#
# Factor: 2. MSE train/test: [0.725803, 0.566220] MSE on plane waves: 0.014837
# Factor: 4. MSE train/test: [0.629319, 0.575892] MSE on plane waves: 0.067350
# Factor: 6. MSE train/test: [0.629597, 0.605254] MSE on plane waves: 0.517131
# Factor: 10. MSE train/test: [0.741997, 0.655298] MSE on plane waves: 0.406493
# Factor: 20. MSE train/test: [0.919594, 0.889335] MSE on plane waves: 0.032421
# Epoch time/Remaining time in seconds: [16/7379]
# ---------- Epoch 26 ------------
#
# Factor: 2. MSE train/test: [0.737241, 0.753886] MSE on plane waves: 0.006887
# Factor: 4. MSE train/test: [0.666371, 0.648903] MSE on plane waves: 0.091218
# Factor: 6. MSE train/test: [0.656247, 0.634082] MSE on plane waves: 6.611829
# Factor: 10. MSE train/test: [0.740455, 0.730847] MSE on plane waves: 1.008256
# Factor: 20. MSE train/test: [0.961330, 0.903003] MSE on plane waves: 1.269790
# Epoch time/Remaining time in seconds: [15/7362]
# ---------- Epoch 27 ------------
#
# Factor: 2. MSE train/test: [0.764664, 0.739746] MSE on plane waves: 0.054988
# Factor: 4. MSE train/test: [0.688383, 0.703289] MSE on plane waves: 0.082121
# Factor: 6. MSE train/test: [0.707831, 0.715069] MSE on plane waves: 0.371204
# Factor: 10. MSE train/test: [0.797316, 0.818138] MSE on plane waves: 2.590336
# Factor: 20. MSE train/test: [0.954738, 0.997802] MSE on plane waves: 0.531877
# Epoch time/Remaining time in seconds: [15/7340]
# ---------- Epoch 28 ------------
#
# Factor: 2. MSE train/test: [0.817638, 0.746151] MSE on plane waves: 0.044038
# Factor: 4. MSE train/test: [0.759860, 0.710056] MSE on plane waves: 0.079985
# Factor: 6. MSE train/test: [0.777488, 0.759477] MSE on plane waves: 0.020564
# Factor: 10. MSE train/test: [0.893366, 0.842594] MSE on plane waves: 5.186786
# Factor: 20. MSE train/test: [1.020316, 0.962514] MSE on plane waves: 0.259926
# Epoch time/Remaining time in seconds: [15/7326]
# ---------- Epoch 29 ------------
#
# Factor: 2. MSE train/test: [0.865109, 0.893918] MSE on plane waves: 0.014417
# Factor: 4. MSE train/test: [0.790130, 0.787908] MSE on plane waves: 0.044276
# Factor: 6. MSE train/test: [0.822754, 0.827897] MSE on plane waves: 0.404461
# Factor: 10. MSE train/test: [0.934008, 0.966566] MSE on plane waves: 1.762960
# Factor: 20. MSE train/test: [0.995349, 1.029405] MSE on plane waves: 0.187387
# Epoch time/Remaining time in seconds: [15/7313]
# ---------- Epoch 30 ------------
#
# Factor: 2. MSE train/test: [0.841517, 0.681434] MSE on plane waves: 0.007522
# Factor: 4. MSE train/test: [0.830519, 0.738148] MSE on plane waves: 0.156282
# Factor: 6. MSE train/test: [0.867176, 0.832671] MSE on plane waves: 0.328908
# Factor: 10. MSE train/test: [0.906238, 0.920945] MSE on plane waves: 0.526389
# Factor: 20. MSE train/test: [1.090000, 1.060723] MSE on plane waves: 0.725491
# Epoch time/Remaining time in seconds: [15/7296]
# ---------- Epoch 31 ------------
#
# Factor: 2. MSE train/test: [0.907960, 0.837289] MSE on plane waves: 0.080227
# Factor: 4. MSE train/test: [0.827682, 0.873912] MSE on plane waves: 0.004214
# Factor: 6. MSE train/test: [0.820818, 0.879943] MSE on plane waves: 0.171199
# Factor: 10. MSE train/test: [0.874181, 0.928198] MSE on plane waves: 0.599501
# Factor: 20. MSE train/test: [0.989861, 0.978444] MSE on plane waves: 0.777369
# Epoch time/Remaining time in seconds: [15/7274]
# ---------- Epoch 32 ------------
#
# Factor: 2. MSE train/test: [0.906094, 0.884101] MSE on plane waves: 0.004586
# Factor: 4. MSE train/test: [0.834693, 0.818285] MSE on plane waves: 0.097652
# Factor: 6. MSE train/test: [0.837748, 0.836148] MSE on plane waves: 0.724690
# Factor: 10. MSE train/test: [0.924013, 0.908708] MSE on plane waves: 0.191143
# Factor: 20. MSE train/test: [0.979649, 1.015860] MSE on plane waves: 0.863688
# Epoch time/Remaining time in seconds: [15/7259]
# ---------- Epoch 33 ------------
#
# Factor: 2. MSE train/test: [0.856895, 0.906162] MSE on plane waves: 0.009397
# Factor: 4. MSE train/test: [0.777045, 0.849209] MSE on plane waves: 0.052360
# Factor: 6. MSE train/test: [0.788476, 0.824655] MSE on plane waves: 0.953427
# Factor: 10. MSE train/test: [0.880948, 0.908481] MSE on plane waves: 7.493720
# Factor: 20. MSE train/test: [0.988283, 1.004422] MSE on plane waves: 0.422530
# Epoch time/Remaining time in seconds: [15/7239]
# ---------- Epoch 34 ------------
#
# Factor: 2. MSE train/test: [0.806374, 0.836303] MSE on plane waves: 0.055876
# Factor: 4. MSE train/test: [0.739900, 0.791531] MSE on plane waves: 0.002922
# Factor: 6. MSE train/test: [0.770424, 0.808559] MSE on plane waves: 0.981536
# Factor: 10. MSE train/test: [0.889138, 0.874550] MSE on plane waves: 0.021774
# Factor: 20. MSE train/test: [0.990746, 0.977919] MSE on plane waves: 0.224124
# Epoch time/Remaining time in seconds: [16/7232]
# ---------- Epoch 35 ------------
#
# Factor: 2. MSE train/test: [0.801780, 0.880781] MSE on plane waves: 0.000343
# Factor: 4. MSE train/test: [0.775651, 0.801054] MSE on plane waves: 3.395744
# Factor: 6. MSE train/test: [0.827193, 0.835001] MSE on plane waves: 0.041681
# Factor: 10. MSE train/test: [0.900579, 0.928014] MSE on plane waves: 0.393528
# Factor: 20. MSE train/test: [1.033057, 0.963732] MSE on plane waves: 0.122265
# Epoch time/Remaining time in seconds: [15/7221]
# ---------- Epoch 36 ------------
#
# Factor: 2. MSE train/test: [0.746950, 0.820892] MSE on plane waves: 0.023215
# Factor: 4. MSE train/test: [0.720550, 0.794641] MSE on plane waves: 0.277316
# Factor: 6. MSE train/test: [0.776536, 0.814794] MSE on plane waves: 0.481761
# Factor: 10. MSE train/test: [0.850914, 0.863876] MSE on plane waves: 0.312420
# Factor: 20. MSE train/test: [0.975366, 0.984101] MSE on plane waves: 1.449223
# Epoch time/Remaining time in seconds: [17/7233]
# ---------- Epoch 37 ------------
#
# Factor: 2. MSE train/test: [0.729886, 0.706878] MSE on plane waves: 0.057825
# Factor: 4. MSE train/test: [0.736693, 0.695644] MSE on plane waves: 0.135614
# Factor: 6. MSE train/test: [0.768964, 0.732967] MSE on plane waves: 0.399417
# Factor: 10. MSE train/test: [0.848993, 0.838998] MSE on plane waves: 0.022362
# Factor: 20. MSE train/test: [1.021030, 0.975523] MSE on plane waves: 0.021971
# Epoch time/Remaining time in seconds: [15/7220]
# ---------- Epoch 38 ------------
#
# Factor: 2. MSE train/test: [0.712408, 0.662001] MSE on plane waves: 0.063196
# Factor: 4. MSE train/test: [0.699962, 0.637672] MSE on plane waves: 0.032392
# Factor: 6. MSE train/test: [0.738080, 0.703007] MSE on plane waves: 0.409607
# Factor: 10. MSE train/test: [0.820232, 0.804793] MSE on plane waves: 0.009853
# Factor: 20. MSE train/test: [0.969328, 0.935837] MSE on plane waves: 1.014030
# Epoch time/Remaining time in seconds: [15/7204]
# ---------- Epoch 39 ------------
#
# Factor: 2. MSE train/test: [0.746302, 0.777970] MSE on plane waves: 0.048897
# Factor: 4. MSE train/test: [0.698058, 0.684689] MSE on plane waves: 0.049381
# Factor: 6. MSE train/test: [0.718821, 0.698296] MSE on plane waves: 0.047454
# Factor: 10. MSE train/test: [0.776391, 0.770623] MSE on plane waves: 4.305321
# Factor: 20. MSE train/test: [0.921282, 0.971690] MSE on plane waves: 0.058116
# Epoch time/Remaining time in seconds: [15/7188]
# ---------- Epoch 40 ------------
#
# Factor: 2. MSE train/test: [0.700518, 0.755397] MSE on plane waves: 0.003488
# Factor: 4. MSE train/test: [0.647246, 0.687408] MSE on plane waves: 0.005566
# Factor: 6. MSE train/test: [0.706438, 0.698029] MSE on plane waves: 0.592855
# Factor: 10. MSE train/test: [0.776672, 0.767993] MSE on plane waves: 1.112707
# Factor: 20. MSE train/test: [0.974720, 0.902229] MSE on plane waves: 3.231732
# Epoch time/Remaining time in seconds: [15/7170]
# ---------- Epoch 41 ------------
#
# Factor: 2. MSE train/test: [0.747311, 0.729121] MSE on plane waves: 0.004792
# Factor: 4. MSE train/test: [0.682566, 0.663369] MSE on plane waves: 0.705570
# Factor: 6. MSE train/test: [0.674426, 0.680333] MSE on plane waves: 0.203528
# Factor: 10. MSE train/test: [0.742368, 0.773324] MSE on plane waves: 6.667489
# Factor: 20. MSE train/test: [1.006159, 0.943019] MSE on plane waves: 0.192457
# Epoch time/Remaining time in seconds: [15/7153]
# ---------- Epoch 42 ------------
#
# Factor: 2. MSE train/test: [0.720186, 0.692217] MSE on plane waves: 0.022703
# Factor: 4. MSE train/test: [0.714234, 0.676476] MSE on plane waves: 0.497311
# Factor: 6. MSE train/test: [0.742501, 0.718835] MSE on plane waves: 0.138146
# Factor: 10. MSE train/test: [0.823683, 0.807238] MSE on plane waves: 0.092080
# Factor: 20. MSE train/test: [0.955472, 0.996578] MSE on plane waves: 0.084205
# Epoch time/Remaining time in seconds: [15/7134]
# ---------- Epoch 43 ------------
#
# Factor: 2. MSE train/test: [0.700995, 0.815603] MSE on plane waves: 0.027638
# Factor: 4. MSE train/test: [0.685407, 0.767283] MSE on plane waves: 0.148070
# Factor: 6. MSE train/test: [0.750709, 0.794262] MSE on plane waves: 0.004065
# Factor: 10. MSE train/test: [0.810193, 0.837929] MSE on plane waves: 0.348297
# Factor: 20. MSE train/test: [0.960819, 0.899502] MSE on plane waves: 0.086245
# Epoch time/Remaining time in seconds: [15/7117]
# ---------- Epoch 44 ------------
#
# Factor: 2. MSE train/test: [0.824434, 0.726765] MSE on plane waves: 0.016122
# Factor: 4. MSE train/test: [0.765433, 0.680746] MSE on plane waves: 0.020338
# Factor: 6. MSE train/test: [0.751480, 0.719778] MSE on plane waves: 0.788246
# Factor: 10. MSE train/test: [0.798989, 0.817342] MSE on plane waves: 0.339785
# Factor: 20. MSE train/test: [0.971522, 0.983859] MSE on plane waves: 0.710490
# Epoch time/Remaining time in seconds: [15/7098]
# ---------- Epoch 45 ------------
#
# Factor: 2. MSE train/test: [0.846959, 0.831430] MSE on plane waves: 0.001098
# Factor: 4. MSE train/test: [0.731478, 0.743440] MSE on plane waves: 0.027740
# Factor: 6. MSE train/test: [0.711110, 0.754565] MSE on plane waves: 1.303178
# Factor: 10. MSE train/test: [0.796381, 0.806472] MSE on plane waves: 0.588174
# Factor: 20. MSE train/test: [0.996803, 0.991828] MSE on plane waves: 1.555182
# Epoch time/Remaining time in seconds: [15/7080]
# ---------- Epoch 46 ------------
#
# Factor: 2. MSE train/test: [0.652854, 0.677814] MSE on plane waves: 0.088294
# Factor: 4. MSE train/test: [0.643894, 0.647531] MSE on plane waves: 0.082006
# Factor: 6. MSE train/test: [0.685566, 0.689053] MSE on plane waves: 0.373426
# Factor: 10. MSE train/test: [0.779673, 0.809410] MSE on plane waves: 0.090100
# Factor: 20. MSE train/test: [1.043219, 0.977991] MSE on plane waves: 0.277456
# Epoch time/Remaining time in seconds: [15/7065]
# ---------- Epoch 47 ------------
#
# Factor: 2. MSE train/test: [0.728505, 0.695787] MSE on plane waves: 0.031990
# Factor: 4. MSE train/test: [0.679819, 0.646576] MSE on plane waves: 0.047388
# Factor: 6. MSE train/test: [0.714566, 0.669198] MSE on plane waves: 2.294028
# Factor: 10. MSE train/test: [0.766379, 0.769837] MSE on plane waves: 1.577700
# Factor: 20. MSE train/test: [0.972958, 0.995979] MSE on plane waves: 0.666794
# Epoch time/Remaining time in seconds: [15/7049]
# ---------- Epoch 48 ------------
#
# Factor: 2. MSE train/test: [0.617750, 0.684045] MSE on plane waves: 0.066723
# Factor: 4. MSE train/test: [0.600865, 0.648192] MSE on plane waves: 0.011520
# Factor: 6. MSE train/test: [0.656952, 0.690404] MSE on plane waves: 0.057178
# Factor: 10. MSE train/test: [0.802498, 0.814604] MSE on plane waves: 1.943801
# Factor: 20. MSE train/test: [0.978436, 0.918657] MSE on plane waves: 1.232012
# Epoch time/Remaining time in seconds: [15/7034]
# ---------- Epoch 49 ------------
#
# Factor: 2. MSE train/test: [0.732536, 0.689673] MSE on plane waves: 0.027884
# Factor: 4. MSE train/test: [0.687836, 0.677233] MSE on plane waves: 0.079275
# Factor: 6. MSE train/test: [0.699959, 0.701886] MSE on plane waves: 0.362114
# Factor: 10. MSE train/test: [0.750288, 0.750218] MSE on plane waves: 0.308015
# Factor: 20. MSE train/test: [1.009469, 0.964769] MSE on plane waves: 0.415203
# Epoch time/Remaining time in seconds: [15/7015]
# ---------- Epoch 50 ------------
#
# Factor: 2. MSE train/test: [0.723166, 0.714523] MSE on plane waves: 0.043856
# Factor: 4. MSE train/test: [0.686390, 0.656929] MSE on plane waves: 0.308360
# Factor: 6. MSE train/test: [0.703188, 0.667773] MSE on plane waves: 0.122882
# Factor: 10. MSE train/test: [0.744121, 0.737982] MSE on plane waves: 0.368509
# Factor: 20. MSE train/test: [0.941424, 0.965170] MSE on plane waves: 0.006844
# Epoch time/Remaining time in seconds: [15/6999]
# ---------- Epoch 51 ------------
#
# Factor: 2. MSE train/test: [0.733110, 0.717248] MSE on plane waves: 0.001369
# Factor: 4. MSE train/test: [0.678824, 0.648165] MSE on plane waves: 0.142816
# Factor: 6. MSE train/test: [0.656116, 0.673428] MSE on plane waves: 0.783959
# Factor: 10. MSE train/test: [0.706364, 0.736374] MSE on plane waves: 0.166735
# Factor: 20. MSE train/test: [0.974697, 0.941664] MSE on plane waves: 1.783353
# Epoch time/Remaining time in seconds: [15/6982]
# ---------- Epoch 52 ------------
#
# Factor: 2. MSE train/test: [0.713470, 0.696178] MSE on plane waves: 0.038680
# Factor: 4. MSE train/test: [0.671198, 0.664935] MSE on plane waves: 0.226233
# Factor: 6. MSE train/test: [0.690206, 0.686760] MSE on plane waves: 2.849853
# Factor: 10. MSE train/test: [0.774732, 0.752396] MSE on plane waves: 0.353894
# Factor: 20. MSE train/test: [0.943375, 0.924255] MSE on plane waves: 0.129596
# Epoch time/Remaining time in seconds: [15/6963]
# ---------- Epoch 53 ------------
#
# Factor: 2. MSE train/test: [0.704800, 0.701592] MSE on plane waves: 0.043504
# Factor: 4. MSE train/test: [0.638911, 0.669644] MSE on plane waves: 0.166538
# Factor: 6. MSE train/test: [0.646924, 0.681385] MSE on plane waves: 1.002970
# Factor: 10. MSE train/test: [0.715955, 0.778925] MSE on plane waves: 1.324477
# Factor: 20. MSE train/test: [0.945899, 0.999788] MSE on plane waves: 1.818999
# Epoch time/Remaining time in seconds: [15/6947]
# ---------- Epoch 54 ------------
#
# Factor: 2. MSE train/test: [0.687751, 0.663349] MSE on plane waves: 0.062672
# Factor: 4. MSE train/test: [0.673721, 0.651188] MSE on plane waves: 1.344402
# Factor: 6. MSE train/test: [0.680502, 0.694126] MSE on plane waves: 1.338212
# Factor: 10. MSE train/test: [0.779694, 0.807047] MSE on plane waves: 0.028828
# Factor: 20. MSE train/test: [0.972844, 0.956307] MSE on plane waves: 1.437451
# Epoch time/Remaining time in seconds: [15/6931]
# ---------- Epoch 55 ------------
#
# Factor: 2. MSE train/test: [0.702555, 0.726033] MSE on plane waves: 0.047009
# Factor: 4. MSE train/test: [0.663504, 0.696746] MSE on plane waves: 0.848494
# Factor: 6. MSE train/test: [0.693815, 0.705082] MSE on plane waves: 0.216171
# Factor: 10. MSE train/test: [0.786900, 0.766657] MSE on plane waves: 0.499190
# Factor: 20. MSE train/test: [0.973554, 0.952133] MSE on plane waves: 0.289237
# Epoch time/Remaining time in seconds: [16/6918]
# ---------- Epoch 56 ------------
#
# Factor: 2. MSE train/test: [0.720802, 0.668748] MSE on plane waves: 0.450722
# Factor: 4. MSE train/test: [0.696779, 0.660919] MSE on plane waves: 0.184299
# Factor: 6. MSE train/test: [0.743436, 0.711592] MSE on plane waves: 0.050660
# Factor: 10. MSE train/test: [0.808214, 0.783621] MSE on plane waves: 1.941912
# Factor: 20. MSE train/test: [0.977923, 1.008986] MSE on plane waves: 0.350471
# Epoch time/Remaining time in seconds: [15/6905]
# ---------- Epoch 57 ------------
#
# Factor: 2. MSE train/test: [0.701529, 0.758028] MSE on plane waves: 0.108501
# Factor: 4. MSE train/test: [0.698116, 0.714900] MSE on plane waves: 0.557834
# Factor: 6. MSE train/test: [0.761507, 0.714248] MSE on plane waves: 0.145584
# Factor: 10. MSE train/test: [0.809707, 0.793725] MSE on plane waves: 0.191618
# Factor: 20. MSE train/test: [0.928088, 0.976062] MSE on plane waves: 0.312718
# Epoch time/Remaining time in seconds: [16/6895]
# ---------- Epoch 58 ------------
#
# Factor: 2. MSE train/test: [0.742510, 0.746325] MSE on plane waves: 0.062735
# Factor: 4. MSE train/test: [0.705678, 0.679811] MSE on plane waves: 0.551225
# Factor: 6. MSE train/test: [0.739340, 0.704135] MSE on plane waves: 0.002401
# Factor: 10. MSE train/test: [0.800754, 0.839264] MSE on plane waves: 0.096296
# Factor: 20. MSE train/test: [0.990909, 0.981852] MSE on plane waves: 0.956875
# Epoch time/Remaining time in seconds: [15/6882]
# ---------- Epoch 59 ------------
#
# Factor: 2. MSE train/test: [0.735032, 0.668462] MSE on plane waves: 0.007658
# Factor: 4. MSE train/test: [0.685159, 0.659658] MSE on plane waves: 0.029742
# Factor: 6. MSE train/test: [0.694443, 0.707586] MSE on plane waves: 1.248564
# Factor: 10. MSE train/test: [0.752628, 0.786632] MSE on plane waves: 1.760680
# Factor: 20. MSE train/test: [0.930639, 0.942855] MSE on plane waves: 2.412323
# Epoch time/Remaining time in seconds: [15/6866]
# ---------- Epoch 60 ------------
#
# Factor: 2. MSE train/test: [0.719205, 0.703522] MSE on plane waves: 0.003037
# Factor: 4. MSE train/test: [0.721269, 0.700028] MSE on plane waves: 0.250246
# Factor: 6. MSE train/test: [0.722649, 0.739123] MSE on plane waves: 0.277083
# Factor: 10. MSE train/test: [0.787277, 0.804509] MSE on plane waves: 0.153054
# Factor: 20. MSE train/test: [0.975031, 0.914422] MSE on plane waves: 2.364762
# Epoch time/Remaining time in seconds: [16/6854]
# ---------- Epoch 61 ------------
#
# Factor: 2. MSE train/test: [0.681322, 0.737948] MSE on plane waves: 0.046601
# Factor: 4. MSE train/test: [0.642450, 0.706801] MSE on plane waves: 0.012089
# Factor: 6. MSE train/test: [0.685989, 0.738029] MSE on plane waves: 0.088463
# Factor: 10. MSE train/test: [0.807326, 0.812783] MSE on plane waves: 0.417089
# Factor: 20. MSE train/test: [0.964265, 0.964119] MSE on plane waves: 0.048972
# Epoch time/Remaining time in seconds: [15/6839]
# ---------- Epoch 62 ------------
#
# Factor: 2. MSE train/test: [0.740525, 0.616082] MSE on plane waves: 0.005260
# Factor: 4. MSE train/test: [0.696092, 0.629704] MSE on plane waves: 0.494477
# Factor: 6. MSE train/test: [0.705717, 0.688182] MSE on plane waves: 0.472035
# Factor: 10. MSE train/test: [0.809083, 0.739751] MSE on plane waves: 1.030559
# Factor: 20. MSE train/test: [0.953533, 0.966799] MSE on plane waves: 0.889494
# Epoch time/Remaining time in seconds: [15/6824]
# ---------- Epoch 63 ------------
#
# Factor: 2. MSE train/test: [0.782663, 0.719306] MSE on plane waves: 0.110011
# Factor: 4. MSE train/test: [0.717315, 0.678938] MSE on plane waves: 0.116189
# Factor: 6. MSE train/test: [0.715992, 0.691816] MSE on plane waves: 0.574560
# Factor: 10. MSE train/test: [0.767584, 0.773590] MSE on plane waves: 0.687471
# Factor: 20. MSE train/test: [0.967899, 0.901500] MSE on plane waves: 0.637882
# Epoch time/Remaining time in seconds: [15/6807]
# ---------- Epoch 64 ------------
#
# Factor: 2. MSE train/test: [0.702452, 0.714307] MSE on plane waves: 0.051291
# Factor: 4. MSE train/test: [0.651372, 0.661025] MSE on plane waves: 0.049943
# Factor: 6. MSE train/test: [0.681417, 0.674369] MSE on plane waves: 0.271383
# Factor: 10. MSE train/test: [0.748307, 0.753555] MSE on plane waves: 1.647973
# Factor: 20. MSE train/test: [0.948445, 0.936237] MSE on plane waves: 0.063651
# Epoch time/Remaining time in seconds: [15/6793]
# ---------- Epoch 65 ------------
#
# Factor: 2. MSE train/test: [0.703831, 0.635232] MSE on plane waves: 0.003295
# Factor: 4. MSE train/test: [0.646925, 0.579020] MSE on plane waves: 0.094496
# Factor: 6. MSE train/test: [0.682764, 0.654720] MSE on plane waves: 1.165455
# Factor: 10. MSE train/test: [0.739548, 0.745039] MSE on plane waves: 0.903198
# Factor: 20. MSE train/test: [0.929922, 0.909193] MSE on plane waves: 0.008192
# Epoch time/Remaining time in seconds: [15/6777]
# ---------- Epoch 66 ------------
#
# Factor: 2. MSE train/test: [0.680995, 0.688271] MSE on plane waves: 0.012858
# Factor: 4. MSE train/test: [0.666295, 0.649902] MSE on plane waves: 0.722453
# Factor: 6. MSE train/test: [0.701055, 0.689621] MSE on plane waves: 0.589509
# Factor: 10. MSE train/test: [0.763079, 0.762255] MSE on plane waves: 0.063103
# Factor: 20. MSE train/test: [0.960207, 0.873409] MSE on plane waves: 0.105659
# Epoch time/Remaining time in seconds: [15/6759]
# ---------- Epoch 67 ------------
#
# Factor: 2. MSE train/test: [0.626941, 0.687213] MSE on plane waves: 0.039685
# Factor: 4. MSE train/test: [0.609877, 0.611434] MSE on plane waves: 0.069988
# Factor: 6. MSE train/test: [0.663043, 0.643213] MSE on plane waves: 0.109032
# Factor: 10. MSE train/test: [0.778262, 0.726516] MSE on plane waves: 0.398191
# Factor: 20. MSE train/test: [0.969035, 0.960001] MSE on plane waves: 2.108606
# Epoch time/Remaining time in seconds: [15/6741]
# ---------- Epoch 68 ------------
#
# Factor: 2. MSE train/test: [0.654905, 0.671923] MSE on plane waves: 0.004241
# Factor: 4. MSE train/test: [0.599932, 0.607705] MSE on plane waves: 0.154642
# Factor: 6. MSE train/test: [0.632625, 0.634694] MSE on plane waves: 0.198121
# Factor: 10. MSE train/test: [0.745350, 0.731965] MSE on plane waves: 0.374117
# Factor: 20. MSE train/test: [0.964623, 0.924673] MSE on plane waves: 3.298781
# Epoch time/Remaining time in seconds: [15/6725]
# ---------- Epoch 69 ------------
#
# Factor: 2. MSE train/test: [0.705683, 0.707502] MSE on plane waves: 0.026567
# Factor: 4. MSE train/test: [0.628784, 0.655883] MSE on plane waves: 0.024439
# Factor: 6. MSE train/test: [0.642002, 0.671649] MSE on plane waves: 0.629142
# Factor: 10. MSE train/test: [0.739571, 0.730661] MSE on plane waves: 2.455473
# Factor: 20. MSE train/test: [0.920510, 0.951061] MSE on plane waves: 1.052118
# Epoch time/Remaining time in seconds: [15/6707]
# ---------- Epoch 70 ------------
#
# Factor: 2. MSE train/test: [0.720434, 0.765415] MSE on plane waves: 0.089370
# Factor: 4. MSE train/test: [0.683695, 0.684204] MSE on plane waves: 0.042606
# Factor: 6. MSE train/test: [0.732311, 0.747362] MSE on plane waves: 0.059658
# Factor: 10. MSE train/test: [0.812918, 0.825320] MSE on plane waves: 0.539484
# Factor: 20. MSE train/test: [0.936778, 0.970676] MSE on plane waves: 0.320247
# Epoch time/Remaining time in seconds: [15/6691]
# ---------- Epoch 71 ------------
#
# Factor: 2. MSE train/test: [0.775299, 0.792349] MSE on plane waves: 0.015048
# Factor: 4. MSE train/test: [0.771994, 0.708190] MSE on plane waves: 0.237602
# Factor: 6. MSE train/test: [0.772250, 0.749122] MSE on plane waves: 0.120110
# Factor: 10. MSE train/test: [0.816471, 0.830183] MSE on plane waves: 0.906751
# Factor: 20. MSE train/test: [0.984049, 0.960031] MSE on plane waves: 0.244759
# Epoch time/Remaining time in seconds: [15/6676]
# ---------- Epoch 72 ------------
#
# Factor: 2. MSE train/test: [0.819168, 0.682486] MSE on plane waves: 0.001392
# Factor: 4. MSE train/test: [0.745226, 0.652671] MSE on plane waves: 0.018574
# Factor: 6. MSE train/test: [0.735002, 0.723692] MSE on plane waves: 0.257899
# Factor: 10. MSE train/test: [0.776033, 0.781698] MSE on plane waves: 2.394789
# Factor: 20. MSE train/test: [0.963333, 0.978564] MSE on plane waves: 0.912035
# Epoch time/Remaining time in seconds: [15/6661]
# ---------- Epoch 73 ------------
#
# Factor: 2. MSE train/test: [0.704984, 0.670335] MSE on plane waves: 0.021309
# Factor: 4. MSE train/test: [0.670418, 0.615957] MSE on plane waves: 0.390783
# Factor: 6. MSE train/test: [0.705549, 0.695823] MSE on plane waves: 0.148281
# Factor: 10. MSE train/test: [0.772682, 0.795669] MSE on plane waves: 1.029869
# Factor: 20. MSE train/test: [1.000276, 0.972363] MSE on plane waves: 0.116392
# Epoch time/Remaining time in seconds: [15/6645]
# ---------- Epoch 74 ------------
#
# Factor: 2. MSE train/test: [0.644254, 0.759275] MSE on plane waves: 0.004790
# Factor: 4. MSE train/test: [0.648357, 0.723268] MSE on plane waves: 0.439324
# Factor: 6. MSE train/test: [0.680626, 0.766141] MSE on plane waves: 0.552755
# Factor: 10. MSE train/test: [0.794689, 0.821821] MSE on plane waves: 0.467378
# Factor: 20. MSE train/test: [0.963539, 0.998850] MSE on plane waves: 0.388889
# Epoch time/Remaining time in seconds: [15/6628]
# ---------- Epoch 75 ------------
#
# Factor: 2. MSE train/test: [0.717936, 0.691787] MSE on plane waves: 0.000482
# Factor: 4. MSE train/test: [0.674659, 0.684732] MSE on plane waves: 0.316954
# Factor: 6. MSE train/test: [0.720742, 0.711515] MSE on plane waves: 0.302972
# Factor: 10. MSE train/test: [0.827977, 0.815196] MSE on plane waves: 0.615346
# Factor: 20. MSE train/test: [0.958450, 0.973270] MSE on plane waves: 2.053190
# Epoch time/Remaining time in seconds: [15/6613]
# ---------- Epoch 76 ------------
#
# Factor: 2. MSE train/test: [0.709848, 0.623646] MSE on plane waves: 0.030873
# Factor: 4. MSE train/test: [0.669023, 0.602194] MSE on plane waves: 0.011449
# Factor: 6. MSE train/test: [0.690603, 0.677794] MSE on plane waves: 0.138897
# Factor: 10. MSE train/test: [0.792428, 0.763251] MSE on plane waves: 0.528903
# Factor: 20. MSE train/test: [0.968109, 0.943121] MSE on plane waves: 0.015579
# Epoch time/Remaining time in seconds: [16/6601]
# ---------- Epoch 77 ------------
#
# Factor: 2. MSE train/test: [0.735673, 0.761793] MSE on plane waves: 0.408812
# Factor: 4. MSE train/test: [0.660975, 0.658486] MSE on plane waves: 0.194624
# Factor: 6. MSE train/test: [0.683695, 0.652152] MSE on plane waves: 0.273680
# Factor: 10. MSE train/test: [0.749266, 0.751449] MSE on plane waves: 0.302584
# Factor: 20. MSE train/test: [0.925057, 0.979309] MSE on plane waves: 0.464831
# Epoch time/Remaining time in seconds: [15/6587]
# ---------- Epoch 78 ------------
#
# Factor: 2. MSE train/test: [0.656326, 0.703271] MSE on plane waves: 0.062092
# Factor: 4. MSE train/test: [0.652445, 0.663193] MSE on plane waves: 0.098215
# Factor: 6. MSE train/test: [0.679909, 0.670105] MSE on plane waves: 0.062603
# Factor: 10. MSE train/test: [0.740986, 0.765628] MSE on plane waves: 0.129272
# Factor: 20. MSE train/test: [0.911081, 0.935435] MSE on plane waves: 0.423900
# Epoch time/Remaining time in seconds: [15/6570]
# ---------- Epoch 79 ------------
#
# Factor: 2. MSE train/test: [0.563127, 0.659885] MSE on plane waves: 0.025164
# Factor: 4. MSE train/test: [0.570603, 0.648537] MSE on plane waves: 0.110312
# Factor: 6. MSE train/test: [0.635603, 0.659255] MSE on plane waves: 1.146392
# Factor: 10. MSE train/test: [0.739219, 0.750614] MSE on plane waves: 0.057492
# Factor: 20. MSE train/test: [0.946602, 0.880636] MSE on plane waves: 3.311340
# Epoch time/Remaining time in seconds: [14/6551]
# ---------- Epoch 80 ------------
#
# Factor: 2. MSE train/test: [0.675844, 0.631801] MSE on plane waves: 0.020248
# Factor: 4. MSE train/test: [0.642373, 0.587374] MSE on plane waves: 0.295954
# Factor: 6. MSE train/test: [0.656599, 0.620203] MSE on plane waves: 0.413383
# Factor: 10. MSE train/test: [0.749228, 0.718753] MSE on plane waves: 0.225805
# Factor: 20. MSE train/test: [0.972656, 0.960835] MSE on plane waves: 0.430812
# Epoch time/Remaining time in seconds: [15/6535]
# ---------- Epoch 81 ------------
#
# Factor: 2. MSE train/test: [0.594119, 0.696116] MSE on plane waves: 0.015459
# Factor: 4. MSE train/test: [0.575186, 0.656721] MSE on plane waves: 1.569644
# Factor: 6. MSE train/test: [0.648359, 0.669296] MSE on plane waves: 1.580953
# Factor: 10. MSE train/test: [0.710829, 0.782769] MSE on plane waves: 0.472859
# Factor: 20. MSE train/test: [0.961065, 0.940912] MSE on plane waves: 0.881850
# Epoch time/Remaining time in seconds: [15/6519]
# ---------- Epoch 82 ------------
#
# Factor: 2. MSE train/test: [0.699567, 0.672658] MSE on plane waves: 0.018805
# Factor: 4. MSE train/test: [0.647206, 0.638927] MSE on plane waves: 0.234434
# Factor: 6. MSE train/test: [0.662657, 0.676991] MSE on plane waves: 3.453322
# Factor: 10. MSE train/test: [0.749340, 0.751840] MSE on plane waves: 0.078537
# Factor: 20. MSE train/test: [0.944075, 0.978498] MSE on plane waves: 0.229703
# Epoch time/Remaining time in seconds: [15/6503]
# ---------- Epoch 83 ------------
#
# Factor: 2. MSE train/test: [0.723213, 0.607305] MSE on plane waves: 0.100055
# Factor: 4. MSE train/test: [0.668009, 0.581906] MSE on plane waves: 0.455278
# Factor: 6. MSE train/test: [0.694609, 0.640293] MSE on plane waves: 2.186009
# Factor: 10. MSE train/test: [0.767009, 0.789080] MSE on plane waves: 0.233467
# Factor: 20. MSE train/test: [0.961006, 0.933946] MSE on plane waves: 0.229704
# Epoch time/Remaining time in seconds: [15/6486]
# ---------- Epoch 84 ------------
#
# Factor: 2. MSE train/test: [0.589630, 0.732919] MSE on plane waves: 0.052757
# Factor: 4. MSE train/test: [0.601692, 0.651066] MSE on plane waves: 0.714131
# Factor: 6. MSE train/test: [0.668071, 0.703511] MSE on plane waves: 1.840734
# Factor: 10. MSE train/test: [0.753183, 0.795508] MSE on plane waves: 0.564425
# Factor: 20. MSE train/test: [0.998224, 0.960039] MSE on plane waves: 0.480589
# Epoch time/Remaining time in seconds: [15/6469]
# ---------- Epoch 85 ------------
#
# Factor: 2. MSE train/test: [0.675803, 0.695165] MSE on plane waves: 0.003235
# Factor: 4. MSE train/test: [0.669127, 0.655015] MSE on plane waves: 0.252030
# Factor: 6. MSE train/test: [0.723563, 0.683605] MSE on plane waves: 0.271160
# Factor: 10. MSE train/test: [0.793451, 0.799505] MSE on plane waves: 0.398239
# Factor: 20. MSE train/test: [0.923255, 0.997441] MSE on plane waves: 0.228697
# Epoch time/Remaining time in seconds: [15/6451]
# ---------- Epoch 86 ------------
#
# Factor: 2. MSE train/test: [0.696083, 0.715502] MSE on plane waves: 0.039515
# Factor: 4. MSE train/test: [0.661423, 0.677309] MSE on plane waves: 0.295179
# Factor: 6. MSE train/test: [0.688308, 0.715563] MSE on plane waves: 0.262035
# Factor: 10. MSE train/test: [0.761443, 0.792387] MSE on plane waves: 0.031099
# Factor: 20. MSE train/test: [0.934820, 0.957607] MSE on plane waves: 0.504537
# Epoch time/Remaining time in seconds: [15/6433]
# ---------- Epoch 87 ------------
#
# Factor: 2. MSE train/test: [0.703501, 0.776067] MSE on plane waves: 0.003700
# Factor: 4. MSE train/test: [0.677563, 0.670856] MSE on plane waves: 0.657618
# Factor: 6. MSE train/test: [0.699425, 0.700696] MSE on plane waves: 0.141270
# Factor: 10. MSE train/test: [0.819354, 0.804995] MSE on plane waves: 0.134198
# Factor: 20. MSE train/test: [0.936614, 0.921656] MSE on plane waves: 0.310422
# Epoch time/Remaining time in seconds: [15/6415]
# ---------- Epoch 88 ------------
#
# Factor: 2. MSE train/test: [0.673487, 0.746261] MSE on plane waves: 0.000200
# Factor: 4. MSE train/test: [0.641768, 0.694994] MSE on plane waves: 0.317285
# Factor: 6. MSE train/test: [0.699101, 0.698762] MSE on plane waves: 0.552680
# Factor: 10. MSE train/test: [0.768227, 0.758511] MSE on plane waves: 0.533931
# Factor: 20. MSE train/test: [0.940485, 0.948623] MSE on plane waves: 0.597293
# Epoch time/Remaining time in seconds: [15/6399]
# ---------- Epoch 89 ------------
#
# Factor: 2. MSE train/test: [0.700486, 0.676123] MSE on plane waves: 0.071524
# Factor: 4. MSE train/test: [0.663401, 0.648810] MSE on plane waves: 0.018563
# Factor: 6. MSE train/test: [0.672866, 0.687172] MSE on plane waves: 1.168566
# Factor: 10. MSE train/test: [0.763449, 0.772592] MSE on plane waves: 2.314216
# Factor: 20. MSE train/test: [0.964972, 0.954655] MSE on plane waves: 0.311695
# Epoch time/Remaining time in seconds: [15/6381]
# ---------- Epoch 90 ------------
#
# Factor: 2. MSE train/test: [0.716341, 0.656794] MSE on plane waves: 0.031535
# Factor: 4. MSE train/test: [0.679327, 0.584986] MSE on plane waves: 1.113351
# Factor: 6. MSE train/test: [0.707193, 0.663837] MSE on plane waves: 0.007984
# Factor: 10. MSE train/test: [0.742750, 0.763796] MSE on plane waves: 0.476191
# Factor: 20. MSE train/test: [0.946739, 0.922434] MSE on plane waves: 0.427834
# Epoch time/Remaining time in seconds: [15/6364]
# ---------- Epoch 91 ------------
#
# Factor: 2. MSE train/test: [0.794657, 0.787737] MSE on plane waves: 0.010751
# Factor: 4. MSE train/test: [0.685718, 0.702206] MSE on plane waves: 0.010807
# Factor: 6. MSE train/test: [0.704264, 0.710616] MSE on plane waves: 3.821450
# Factor: 10. MSE train/test: [0.797952, 0.772361] MSE on plane waves: 0.511063
# Factor: 20. MSE train/test: [0.991659, 0.903070] MSE on plane waves: 1.452868
# Epoch time/Remaining time in seconds: [15/6347]
# ---------- Epoch 92 ------------
#
# Factor: 2. MSE train/test: [0.769880, 0.664238] MSE on plane waves: 0.001671
# Factor: 4. MSE train/test: [0.751063, 0.667053] MSE on plane waves: 0.971109
# Factor: 6. MSE train/test: [0.791337, 0.743266] MSE on plane waves: 2.107218
# Factor: 10. MSE train/test: [0.895068, 0.844091] MSE on plane waves: 0.719624
# Factor: 20. MSE train/test: [1.022623, 1.013452] MSE on plane waves: 1.555356
# Epoch time/Remaining time in seconds: [15/6330]
# ---------- Epoch 93 ------------
#
# Factor: 2. MSE train/test: [0.779818, 0.818265] MSE on plane waves: 0.030096
# Factor: 4. MSE train/test: [0.752711, 0.775681] MSE on plane waves: 0.121654
# Factor: 6. MSE train/test: [0.806270, 0.793092] MSE on plane waves: 2.625340
# Factor: 10. MSE train/test: [0.861450, 0.858083] MSE on plane waves: 0.066163
# Factor: 20. MSE train/test: [1.024146, 1.034795] MSE on plane waves: 0.049888
# Epoch time/Remaining time in seconds: [15/6313]
# ---------- Epoch 94 ------------
#
# Factor: 2. MSE train/test: [0.797521, 0.831552] MSE on plane waves: 0.000914
# Factor: 4. MSE train/test: [0.771242, 0.795653] MSE on plane waves: 0.154489
# Factor: 6. MSE train/test: [0.800299, 0.804876] MSE on plane waves: 0.632105
# Factor: 10. MSE train/test: [0.857143, 0.862830] MSE on plane waves: 1.345290
# Factor: 20. MSE train/test: [1.034200, 0.986729] MSE on plane waves: 0.036878
# Epoch time/Remaining time in seconds: [15/6299]
# ---------- Epoch 95 ------------
#
# Factor: 2. MSE train/test: [0.837838, 0.840217] MSE on plane waves: 0.003673
# Factor: 4. MSE train/test: [0.712292, 0.784931] MSE on plane waves: 0.072258
# Factor: 6. MSE train/test: [0.710689, 0.774870] MSE on plane waves: 0.024317
# Factor: 10. MSE train/test: [0.823359, 0.848077] MSE on plane waves: 0.520797
# Factor: 20. MSE train/test: [1.028189, 1.001644] MSE on plane waves: 0.102083
# Epoch time/Remaining time in seconds: [15/6284]
# ---------- Epoch 96 ------------
#
# Factor: 2. MSE train/test: [0.760313, 0.808731] MSE on plane waves: 0.008833
# Factor: 4. MSE train/test: [0.715483, 0.715707] MSE on plane waves: 0.262519
# Factor: 6. MSE train/test: [0.739413, 0.692933] MSE on plane waves: 4.890072
# Factor: 10. MSE train/test: [0.788816, 0.801980] MSE on plane waves: 0.877245
# Factor: 20. MSE train/test: [0.944522, 0.982867] MSE on plane waves: 0.115800
# Epoch time/Remaining time in seconds: [15/6270]
# ---------- Epoch 97 ------------
#
# Factor: 2. MSE train/test: [0.696023, 0.724292] MSE on plane waves: 0.026364
# Factor: 4. MSE train/test: [0.697037, 0.698488] MSE on plane waves: 0.525558
# Factor: 6. MSE train/test: [0.726454, 0.744091] MSE on plane waves: 0.008821
# Factor: 10. MSE train/test: [0.826993, 0.841104] MSE on plane waves: 0.784048
# Factor: 20. MSE train/test: [0.944193, 0.966114] MSE on plane waves: 0.104673
# Epoch time/Remaining time in seconds: [16/6259]
# ---------- Epoch 98 ------------
#
# Factor: 2. MSE train/test: [0.777746, 0.819818] MSE on plane waves: 0.001393
# Factor: 4. MSE train/test: [0.732947, 0.724554] MSE on plane waves: 0.135985
# Factor: 6. MSE train/test: [0.765778, 0.730232] MSE on plane waves: 0.090608
# Factor: 10. MSE train/test: [0.830509, 0.834493] MSE on plane waves: 2.909065
# Factor: 20. MSE train/test: [0.971376, 0.924310] MSE on plane waves: 0.640100
# Epoch time/Remaining time in seconds: [15/6244]
# ---------- Epoch 99 ------------
#
# Factor: 2. MSE train/test: [0.771466, 0.806836] MSE on plane waves: 0.013972
# Factor: 4. MSE train/test: [0.741389, 0.733584] MSE on plane waves: 0.231536
# Factor: 6. MSE train/test: [0.777015, 0.758160] MSE on plane waves: 0.633348
# Factor: 10. MSE train/test: [0.855606, 0.884879] MSE on plane waves: 0.178758
# Factor: 20. MSE train/test: [0.989243, 1.030755] MSE on plane waves: 0.175750
# Epoch time/Remaining time in seconds: [15/6229]
# ---------- Epoch 100 ------------
#
# Factor: 2. MSE train/test: [0.790098, 0.766631] MSE on plane waves: 0.038429
# Factor: 4. MSE train/test: [0.753043, 0.743467] MSE on plane waves: 0.174125
# Factor: 6. MSE train/test: [0.798794, 0.762781] MSE on plane waves: 0.162793
# Factor: 10. MSE train/test: [0.855509, 0.853701] MSE on plane waves: 2.428059
# Factor: 20. MSE train/test: [1.016854, 0.985733] MSE on plane waves: 1.972085
# Epoch time/Remaining time in seconds: [15/6214]
# ---------- Epoch 101 ------------
#
# Factor: 2. MSE train/test: [0.786416, 0.780904] MSE on plane waves: 0.004399
# Factor: 4. MSE train/test: [0.733546, 0.723387] MSE on plane waves: 0.019495
# Factor: 6. MSE train/test: [0.788047, 0.735105] MSE on plane waves: 0.155681
# Factor: 10. MSE train/test: [0.872086, 0.828762] MSE on plane waves: 0.274954
# Factor: 20. MSE train/test: [0.978491, 0.975227] MSE on plane waves: 0.112757
# Epoch time/Remaining time in seconds: [15/6198]
# ---------- Epoch 102 ------------
#
# Factor: 2. MSE train/test: [0.782968, 0.738390] MSE on plane waves: 0.030137
# ...
# Epoch time/Remaining time in seconds: [15/6183]
# ---------- Epoch 103 ------------
#
# Factor: 2. MSE train/test: [0.784193, 0.823973] MSE on plane waves: 0.137824
# Factor: 4. MSE train/test: [0.834774, 0.845251] MSE on plane waves: 0.110568
# Factor: 6. MSE train/test: [0.880061, 0.910403] MSE on plane waves: 0.003092
# Factor: 10. MSE train/test: [0.944589, 1.028895] MSE on plane waves: 0.716941
# Factor: 20. MSE train/test: [1.012673, 1.090902] MSE on plane waves: 1.475019
# Epoch time/Remaining time in seconds: [15/6165]
# ---------- Epoch 104 ------------
#
# Factor: 2. MSE train/test: [0.934610, 1.017331] MSE on plane waves: 0.009937
# Factor: 4. MSE train/test: [0.933203, 1.007092] MSE on plane waves: 0.004555
# Factor: 6. MSE train/test: [0.980361, 1.078575] MSE on plane waves: 0.760468
# Factor: 10. MSE train/test: [1.014597, 1.130859] MSE on plane waves: 0.122396
# Factor: 20. MSE train/test: [1.091674, 1.013742] MSE on plane waves: 0.059584
# Epoch time/Remaining time in seconds: [15/6149]
# ---------- Epoch 105 ------------
#
# Factor: 2. MSE train/test: [1.052384, 0.895654] MSE on plane waves: 0.050381
# Factor: 4. MSE train/test: [0.944707, 0.960457] MSE on plane waves: 0.330360
# Factor: 6. MSE train/test: [0.988118, 0.966977] MSE on plane waves: 0.004201
# Factor: 10. MSE train/test: [1.058194, 1.007973] MSE on plane waves: 0.000383
# Factor: 20. MSE train/test: [1.003687, 1.088467] MSE on plane waves: 0.319605
# Epoch time/Remaining time in seconds: [15/6132]
# ---------- Epoch 106 ------------
#
# Factor: 2. MSE train/test: [0.774083, 0.898385] MSE on plane waves: 0.003813
# Factor: 4. MSE train/test: [0.772944, 0.848375] MSE on plane waves: 1.414626
# Factor: 6. MSE train/test: [0.846625, 0.855490] MSE on plane waves: 0.674148
# Factor: 10. MSE train/test: [0.923631, 0.887368] MSE on plane waves: 0.499234
# Factor: 20. MSE train/test: [1.006460, 1.002704] MSE on plane waves: 0.011233
# Epoch time/Remaining time in seconds: [15/6115]
# ---------- Epoch 107 ------------
#
# Factor: 2. MSE train/test: [0.835136, 0.802959] MSE on plane waves: 0.110317
# Factor: 4. MSE train/test: [0.841612, 0.810654] MSE on plane waves: 0.028511
# Factor: 6. MSE train/test: [0.864505, 0.803868] MSE on plane waves: 2.225123
# Factor: 10. MSE train/test: [0.869221, 0.867600] MSE on plane waves: 0.802828
# Factor: 20. MSE train/test: [1.008419, 0.978148] MSE on plane waves: 0.188752
# Epoch time/Remaining time in seconds: [15/6099]
# ---------- Epoch 108 ------------
#
# Factor: 2. MSE train/test: [0.833159, 0.790946] MSE on plane waves: 0.028714
# Factor: 4. MSE train/test: [0.735029, 0.739231] MSE on plane waves: 0.416268
# Factor: 6. MSE train/test: [0.738847, 0.748231] MSE on plane waves: 0.482481
# Factor: 10. MSE train/test: [0.793845, 0.846850] MSE on plane waves: 0.106703
# Factor: 20. MSE train/test: [0.973487, 1.019750] MSE on plane waves: 2.208894
# Epoch time/Remaining time in seconds: [15/6083]
# ---------- Epoch 109 ------------
#
# Factor: 2. MSE train/test: [0.794730, 0.764164] MSE on plane waves: 0.019790
# Factor: 4. MSE train/test: [0.731725, 0.737374] MSE on plane waves: 0.000601
# Factor: 6. MSE train/test: [0.747153, 0.735577] MSE on plane waves: 0.122591
# Factor: 10. MSE train/test: [0.794845, 0.840192] MSE on plane waves: 0.047012
# Factor: 20. MSE train/test: [0.967717, 0.988479] MSE on plane waves: 0.042837
# Epoch time/Remaining time in seconds: [15/6068]
# ---------- Epoch 110 ------------
#
# Factor: 2. MSE train/test: [0.774276, 0.815799] MSE on plane waves: 0.128529
# Factor: 4. MSE train/test: [0.705319, 0.720127] MSE on plane waves: 0.020580
# Factor: 6. MSE train/test: [0.720708, 0.720372] MSE on plane waves: 0.047582
# Factor: 10. MSE train/test: [0.820869, 0.797792] MSE on plane waves: 4.300390
# Factor: 20. MSE train/test: [0.966671, 1.008095] MSE on plane waves: 1.328614
# Epoch time/Remaining time in seconds: [15/6052]
# ---------- Epoch 111 ------------
#
# Factor: 2. MSE train/test: [0.752525, 0.756196] MSE on plane waves: 0.095706
# Factor: 4. MSE train/test: [0.716759, 0.733268] MSE on plane waves: 0.030391
# Factor: 6. MSE train/test: [0.760607, 0.751605] MSE on plane waves: 0.450308
# Factor: 10. MSE train/test: [0.898651, 0.868463] MSE on plane waves: 0.179440
# Factor: 20. MSE train/test: [0.993804, 1.016605] MSE on plane waves: 0.392710
# Epoch time/Remaining time in seconds: [15/6035]
# ---------- Epoch 112 ------------
#
# Factor: 2. MSE train/test: [0.890393, 0.812659] MSE on plane waves: 0.006123
# Factor: 4. MSE train/test: [0.838044, 0.791464] MSE on plane waves: 0.056905
# Factor: 6. MSE train/test: [0.840826, 0.803591] MSE on plane waves: 0.114972
# Factor: 10. MSE train/test: [0.882522, 0.865759] MSE on plane waves: 0.742785
# Factor: 20. MSE train/test: [1.009690, 1.026847] MSE on plane waves: 0.149550
# Epoch time/Remaining time in seconds: [15/6019]
# ---------- Epoch 113 ------------
#
# Factor: 2. MSE train/test: [0.928007, 0.905982] MSE on plane waves: 0.013884
# Factor: 4. MSE train/test: [0.852580, 0.838896] MSE on plane waves: 0.382249
# Factor: 6. MSE train/test: [0.809368, 0.829909] MSE on plane waves: 0.019404
# Factor: 10. MSE train/test: [0.861583, 0.927906] MSE on plane waves: 6.887324
# Factor: 20. MSE train/test: [1.043911, 1.043281] MSE on plane waves: 2.734877
# Epoch time/Remaining time in seconds: [15/6003]
# ---------- Epoch 114 ------------
#
# Factor: 2. MSE train/test: [0.918466, 0.889678] MSE on plane waves: 0.014982
# Factor: 4. MSE train/test: [0.878965, 0.895072] MSE on plane waves: 0.089339
# Factor: 6. MSE train/test: [0.931136, 0.928955] MSE on plane waves: 0.494108
# Factor: 10. MSE train/test: [0.986537, 0.991733] MSE on plane waves: 0.410992
# Factor: 20. MSE train/test: [1.030506, 1.012329] MSE on plane waves: 0.092834
# Epoch time/Remaining time in seconds: [15/5988]
# ---------- Epoch 115 ------------
#
# Factor: 2. MSE train/test: [0.891495, 0.925559] MSE on plane waves: 0.034221
# Factor: 4. MSE train/test: [0.900517, 1.014188] MSE on plane waves: 0.104744
# Factor: 6. MSE train/test: [0.941153, 1.064260] MSE on plane waves: 0.296686
# Factor: 10. MSE train/test: [1.057066, 1.078036] MSE on plane waves: 0.161121
# Factor: 20. MSE train/test: [1.077284, 1.092315] MSE on plane waves: 0.211923
# Epoch time/Remaining time in seconds: [15/5973]
# ---------- Epoch 116 ------------
#
# Factor: 2. MSE train/test: [0.936860, 0.975453] MSE on plane waves: 0.023712
# Factor: 4. MSE train/test: [1.056968, 0.939061] MSE on plane waves: 0.270755
# Factor: 6. MSE train/test: [1.017256, 0.926299] MSE on plane waves: 0.409700
# Factor: 10. MSE train/test: [1.039201, 0.951312] MSE on plane waves: 0.393402
# Factor: 20. MSE train/test: [1.026228, 1.087835] MSE on plane waves: 0.777336
# Epoch time/Remaining time in seconds: [15/5957]
# ---------- Epoch 117 ------------
#
# Factor: 2. MSE train/test: [0.892496, 0.923010] MSE on plane waves: 0.002977
# Factor: 4. MSE train/test: [0.875964, 0.883240] MSE on plane waves: 0.347126
# Factor: 6. MSE train/test: [0.888036, 0.874368] MSE on plane waves: 0.265183
# Factor: 10. MSE train/test: [1.005750, 0.978156] MSE on plane waves: 0.059457
# Factor: 20. MSE train/test: [1.008690, 1.030975] MSE on plane waves: 0.171424
# Epoch time/Remaining time in seconds: [15/5941]
# ---------- Epoch 118 ------------
#
# Factor: 2. MSE train/test: [0.954845, 0.862156] MSE on plane waves: 0.027938
# Factor: 4. MSE train/test: [0.869556, 0.880421] MSE on plane waves: 0.135760
# Factor: 6. MSE train/test: [0.852943, 0.938657] MSE on plane waves: 0.574632
# Factor: 10. MSE train/test: [0.948655, 0.989467] MSE on plane waves: 0.030409
# Factor: 20. MSE train/test: [1.038867, 1.031092] MSE on plane waves: 0.592565
# Epoch time/Remaining time in seconds: [15/5926]
# ---------- Epoch 119 ------------
#
# Factor: 2. MSE train/test: [0.864168, 0.834177] MSE on plane waves: 0.019694
# Factor: 4. MSE train/test: [0.802112, 0.794893] MSE on plane waves: 0.245492
# Factor: 6. MSE train/test: [0.795715, 0.821807] MSE on plane waves: 0.384623
# Factor: 10. MSE train/test: [0.933325, 0.914203] MSE on plane waves: 0.362899
# Factor: 20. MSE train/test: [0.995330, 1.009813] MSE on plane waves: 2.140314
# Epoch time/Remaining time in seconds: [15/5910]
# ---------- Epoch 120 ------------
#
# Factor: 2. MSE train/test: [0.670283, 0.823399] MSE on plane waves: 0.032506
# Factor: 4. MSE train/test: [0.673122, 0.783774] MSE on plane waves: 0.358717
# Factor: 6. MSE train/test: [0.729472, 0.780231] MSE on plane waves: 0.728884
# Factor: 10. MSE train/test: [0.880113, 0.881219] MSE on plane waves: 0.738003
# Factor: 20. MSE train/test: [1.001103, 0.992375] MSE on plane waves: 0.388492
# Epoch time/Remaining time in seconds: [15/5895]
# ---------- Epoch 121 ------------
#
# Factor: 2. MSE train/test: [0.766394, 0.724671] MSE on plane waves: 0.014590
# Factor: 4. MSE train/test: [0.754394, 0.657986] MSE on plane waves: 0.150067
# Factor: 6. MSE train/test: [0.778939, 0.753977] MSE on plane waves: 1.092111
# Factor: 10. MSE train/test: [0.840697, 0.825657] MSE on plane waves: 1.394651
# Factor: 20. MSE train/test: [0.963322, 0.974354] MSE on plane waves: 0.468689
# Epoch time/Remaining time in seconds: [15/5879]
# ---------- Epoch 122 ------------
#
# Factor: 2. MSE train/test: [0.673477, 0.740196] MSE on plane waves: 0.092023
# Factor: 4. MSE train/test: [0.640282, 0.739300] MSE on plane waves: 0.345062
# Factor: 6. MSE train/test: [0.707664, 0.767873] MSE on plane waves: 1.406982
# Factor: 10. MSE train/test: [0.839327, 0.864276] MSE on plane waves: 0.248193
# Factor: 20. MSE train/test: [0.981995, 1.010213] MSE on plane waves: 0.328968
# Epoch time/Remaining time in seconds: [16/5867]
# ---------- Epoch 123 ------------
#
# Factor: 2. MSE train/test: [0.790857, 0.679264] MSE on plane waves: 0.033769
# Factor: 4. MSE train/test: [0.752281, 0.655115] MSE on plane waves: 0.007690
# Factor: 6. MSE train/test: [0.736255, 0.689384] MSE on plane waves: 0.101664
# Factor: 10. MSE train/test: [0.792012, 0.802386] MSE on plane waves: 1.725329
# Factor: 20. MSE train/test: [0.992135, 0.942589] MSE on plane waves: 0.005078
# Epoch time/Remaining time in seconds: [15/5851]
# ---------- Epoch 124 ------------
#
# Factor: 2. MSE train/test: [0.701537, 0.781207] MSE on plane waves: 0.002761
# Factor: 4. MSE train/test: [0.677132, 0.720538] MSE on plane waves: 0.015940
# Factor: 6. MSE train/test: [0.692556, 0.710334] MSE on plane waves: 0.049098
# Factor: 10. MSE train/test: [0.773024, 0.811429] MSE on plane waves: 0.610608
# Factor: 20. MSE train/test: [0.985838, 0.982314] MSE on plane waves: 0.270743
# Epoch time/Remaining time in seconds: [16/5838]
# ---------- Epoch 125 ------------
#
# Factor: 2. MSE train/test: [0.680816, 0.734905] MSE on plane waves: 0.000326
# Factor: 4. MSE train/test: [0.699693, 0.670843] MSE on plane waves: 0.103619
# Factor: 6. MSE train/test: [0.708592, 0.708467] MSE on plane waves: 0.113009
# Factor: 10. MSE train/test: [0.804066, 0.807384] MSE on plane waves: 0.077298
# Factor: 20. MSE train/test: [0.971681, 0.982197] MSE on plane waves: 0.021030
# Epoch time/Remaining time in seconds: [17/5827]
# ---------- Epoch 126 ------------
#
# Factor: 2. MSE train/test: [0.715016, 0.717363] MSE on plane waves: 0.025146
# Factor: 4. MSE train/test: [0.666540, 0.688947] MSE on plane waves: 0.158883
# Factor: 6. MSE train/test: [0.701484, 0.695073] MSE on plane waves: 0.530036
# Factor: 10. MSE train/test: [0.769407, 0.779842] MSE on plane waves: 0.050006
# Factor: 20. MSE train/test: [0.949169, 0.947802] MSE on plane waves: 3.188847
# Epoch time/Remaining time in seconds: [16/5815]
# ---------- Epoch 127 ------------
#
# Factor: 2. MSE train/test: [0.590177, 0.699563] MSE on plane waves: 0.001579
# Factor: 4. MSE train/test: [0.576347, 0.654871] MSE on plane waves: 0.251775
# Factor: 6. MSE train/test: [0.645278, 0.690404] MSE on plane waves: 1.095421
# Factor: 10. MSE train/test: [0.765849, 0.788444] MSE on plane waves: 0.116066
# Factor: 20. MSE train/test: [0.954877, 0.949318] MSE on plane waves: 0.433565
# Epoch time/Remaining time in seconds: [15/5801]
# ---------- Epoch 128 ------------
#
# Factor: 2. MSE train/test: [0.593767, 0.711869] MSE on plane waves: 0.015127
# Factor: 4. MSE train/test: [0.572627, 0.626925] MSE on plane waves: 0.354770
# Factor: 6. MSE train/test: [0.629441, 0.654010] MSE on plane waves: 0.064701
# Factor: 10. MSE train/test: [0.759692, 0.746682] MSE on plane waves: 5.340513
# Factor: 20. MSE train/test: [0.921934, 0.966175] MSE on plane waves: 1.258935
# Epoch time/Remaining time in seconds: [16/5789]
# ---------- Epoch 129 ------------
#
# Factor: 2. MSE train/test: [0.693373, 0.647843] MSE on plane waves: 0.027305
# Factor: 4. MSE train/test: [0.577691, 0.616438] MSE on plane waves: 0.331321
# Factor: 6. MSE train/test: [0.654403, 0.650842] MSE on plane waves: 0.275382
# Factor: 10. MSE train/test: [0.775879, 0.786817] MSE on plane waves: 4.007022
# Factor: 20. MSE train/test: [0.935414, 0.977954] MSE on plane waves: 0.883187
# Epoch time/Remaining time in seconds: [18/5782]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[88], line 14
#      11 t_e = time()
#      13 training_dataset = ds.sample_epoch(time=np.random.randint(6950)) # Approximately 19 years for training
# ---> 14 testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035)) # Approximately 3 years for testing
#      15 print(f'---------- Epoch {epoch} ------------\n')
#      17 for factor in [2,4,6,10,20]:
#      18     ############# Training step ################
#
# File ~/MOM6/experiments/ANN-Results/helpers/cm26.py:188, in DatasetCM26.sample_epoch(self, time, cftime, factors)
#     186 for factor in factors:
#     187     ds_coarse = snapshot.coarsen(factor)
# --> 188     coarse_advection = ds_coarse.state.advection()
#     190     ds_coarse.data['SGSx'] = remesh(advx, snapshot, ds_coarse) - coarse_advection[0]
#     191     ds_coarse.data['SGSy'] = remesh(advy, snapshot, ds_coarse) - coarse_advection[1]
#
# File ~/MOM6/experiments/ANN-Results/helpers/computational_tools.py:446, in StateFunctions.advection(self)
#     441 '''
#     442 https://github.com/NOAA-GFDL/MOM6/blob/dev/gfdl/src/core/MOM_CoriolisAdv.F90#L751
#     443 https://github.com/NOAA-GFDL/MOM6/blob/dev/gfdl/src/core/MOM_CoriolisAdv.F90#L875
#     444 '''
#     445 CAu, CAv = self.PV_cross_uv()
# --> 446 KEx, KEy = self.gradKE()
#     447 return (CAu - KEx, CAv - KEy)
#
# File ~/MOM6/experiments/ANN-Results/helpers/computational_tools.py:372, in StateFunctions.gradKE(self)
#     370 KE = self.KE_Arakawa()
#     371 IdxCu = 1. / param.dxCu
# --> 372 IdyCv = 1. / param.dyCv
#     374 KEx = grid.diff(KE, 'X') * IdxCu * param.wet_u
#     375 KEy = grid.diff(KE, 'Y') * IdyCv * param.wet_v
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/_typed_ops.py:288, in DataArrayOpsMixin.__rtruediv__(self, other)
#     287 def __rtruediv__(self, other):
# --> 288     return self._binary_op(other, operator.truediv, reflexive=True)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/dataarray.py:4658, in DataArray._binary_op(self, other, f, reflexive)
#    4652 other_variable = getattr(other, "variable", other)
#    4653 other_coords = getattr(other, "coords", None)
#    4655 variable = (
#    4656     f(self.variable, other_variable)
#    4657     if not reflexive
# -> 4658     else f(other_variable, self.variable)
#    4659 )
#    4660 coords, indexes = self.coords._merge_raw(other_coords, reflexive)
#    4661 name = self._result_name(other)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/_typed_ops.py:494, in VariableOpsMixin.__rtruediv__(self, other)
#     493 def __rtruediv__(self, other):
# --> 494     return self._binary_op(other, operator.truediv, reflexive=True)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/variable.py:2686, in Variable._binary_op(self, other, f, reflexive)
#    2683 attrs = self._attrs if keep_attrs else None
#    2684 with np.errstate(all="ignore"):
#    2685     new_data = (
# -> 2686         f(self_data, other_data) if not reflexive else f(other_data, self_data)
#    2687     )
#    2688 result = Variable(dims, new_data, attrs=attrs)
#    2689 return result
#
# KeyboardInterrupt:

# %% [markdown]
# # Check dissipation pattern for trained ANN

# %%
# ann_Txy = import_ANN('trained_models/ANN_CM26/Txy_epoch_2000.nc')
# ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26/Txx_Tyy_epoch_2000.nc')
ann_Txy = import_ANN('trained_models/ANN_CM26_grid_harmonic/Txy_epoch_500.nc')
ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26_grid_harmonic/Txx_Tyy_epoch_500.nc')

# %%
testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035))

# %%
plt.figure(figsize=(12,4))
import cmocean
for j,grid_harmonic in enumerate(['vorticity', 'divergence']):
    batch = sample_grid_harmonic(testing_dataset[20],grid_harmonic,plain=False)
    zb = batch.state.ANN(ann_Txy, ann_Txx_Tyy)
#    zb = batch.state.Smagorinsky()
    dissipation =  zb['Txx'] * zb['sh_xx'] + batch.grid.interp(zb['Txy'] * zb['sh_xy'],['X','Y'])
    plt.subplot(1,2,1+j)
    (dissipation).plot()
    plt.title(f'Dissipation on \ngrid harmonic: {grid_harmonic}')
plt.tight_layout()

# %%
plt.figure(figsize=(12,4))
batch = sample_two_thirds(testing_dataset[20])
zb = batch.state.ANN(ann_Txy, ann_Txx_Tyy)
dissipation =  zb['Txx'] * zb['sh_xx'] + batch.grid.interp(zb['Txy'] * zb['sh_xy'],['X','Y'])
plt.subplot(1,2,1)
(dissipation).plot()
plt.title(f'Dissipation on plane wave')
plt.subplot(1,2,2)
(dissipation).plot(vmax=0)
plt.title('Only negative values of dissipation')
plt.tight_layout()

# %% [markdown]
# # Check pointwise prediction

# %%
testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035))
for factor in [4,6,10]:
    data = testing_dataset[factor].data
    compare(testing_dataset[factor].state.ANN(ann_Txy, ann_Txx_Tyy)['ZB20u'], data.SGSx, selector=lambda x: x)
# Out:
# Correlation: 0.6102829204633489
# Relative Error: 0.9441413080750909
# R2 =  0.31097169747967557
# R2 max =  0.37244796457396256
# Optinal scaling: 0.7110980706756572
# Nans: 0
# Correlation: 0.5710860175871263
# Relative Error: 0.9439473428033348
# R2 =  0.28960758290662336
# R2 max =  0.32613751376866995
# Optinal scaling: 0.7492457358763267
# Nans: 0
# Correlation: 0.45323684583533885
# Relative Error: 0.9873468161195604
# R2 =  0.1773512884634001
# R2 max =  0.20540977508476987
# Optinal scaling: 0.7301449028220129
# Nans: 0
