# %%
import matplotlib.pyplot as plt
from helpers.cm26 import DatasetCM26, remesh
from helpers.computational_tools import select_NA, select_Pacific, StateFunctions, compare
from helpers.ann_tools import ANN, import_ANN, minibatch, export_ANN
import torch
import torch.optim as optim
import numpy as np
import xarray as xr
from time import time
import json
# %load_ext autoreload
# %autoreload 3

# %%
def sample_grid_harmonic(dataset, key, plain=False):
    '''
    Here for simplicity the dataset is coarsegrained
    snapshot of CM26.
    '''
    data = dataset.data
    ny, nx = data.u.shape
    
    u = np.zeros((ny,nx))
    v = np.zeros((ny,nx))
    
    # assign random phase (1 or -1)
    phase = -1 if np.random.randint(2)==0 else 1
    
    if key == 'vorticity':
        sign = -1
    elif key == 'divergence':
        sign = 1
    else:
        print('Error: key is wrongly specified')
    
    for j in range(ny):
        for i in range(nx):
            if plain:
                idx = i if np.random.randint(2)==0 else j
            else:
                idx = i+j
            u[j,i] = phase *        (-1)**(idx)
            v[j,i] = phase * sign * (-1)**(idx)
            
    data['u'] = xr.DataArray(u, dims=['yh', 'xq']) * dataset.param.wet_u
    data['v'] = xr.DataArray(v, dims=['yq', 'xh']) * dataset.param.wet_v
    return DatasetCM26(data, dataset.param, dataset.grid)

# %%
def sample_plane_wave(ny, nx):
        # Sampling frequency between -pi and pi, i.e. all
        # available frequencies
        freq_x = 0
        freq_y = 0
        while np.abs(freq_x)<2/3*np.pi and np.abs(freq_y)<2/3*np.pi:
            # i.e. if wave is inside the square of 2/3*pi,
            # keep sampling
            freq_x = np.random.rand() * np.pi * 2 - np.pi
            freq_y = np.random.rand() * np.pi * 2 - np.pi

        phase_u = np.random.rand()*2*np.pi
        phase_v = np.random.rand()*2*np.pi

        i = np.ones(ny).reshape(-1,1)@np.arange(nx).reshape(1,-1)
        j = np.arange(ny).reshape(-1,1)@np.ones(nx).reshape(1,-1)

        u = np.sin(freq_x * i + freq_y * j + phase_u)
        v = np.sin(freq_x * i + freq_y * j + phase_v)

        return u, v

# %%
u, v = sample_plane_wave(30,30)
plt.subplot(1,2,1)
plt.imshow(u)
plt.subplot(1,2,2)
plt.imshow(v)

# %%
def sample_two_thirds(dataset):
    '''
    Here for simplicity the dataset is coarsegrained
    snapshot of CM26.
    '''        
    
    data = dataset.data
    ny, nx = data.u.shape
    u,v = sample_plane_wave(ny,nx)

    data['u'] = xr.DataArray(u, dims=['yh', 'xq']) * dataset.param.wet_u
    data['v'] = xr.DataArray(v, dims=['yq', 'xh']) * dataset.param.wet_v
    return DatasetCM26(data, dataset.param, dataset.grid)

# %%
def perturb_velocities(dataset, amp=1e-2):
    data = dataset.data.copy()
    ny, nx = data.u.shape
    u,v = sample_plane_wave(ny,nx)
    
    data['u'] = data['u'] + amp * xr.DataArray(u, dims=['yh', 'xq']) * dataset.param.wet_u
    data['v'] = data['v'] + amp * xr.DataArray(v, dims=['yq', 'xh']) * dataset.param.wet_v
    
    return DatasetCM26(data, dataset.param, dataset.grid)

# %%
ds = DatasetCM26()

# %%
training_dataset = ds.sample_epoch(time=np.random.randint(6950))

# %%
plt.figure(figsize=(12,4))
for j,grid_harmonic in enumerate(['vorticity', 'divergence']):
    batch = sample_grid_harmonic(training_dataset[20],grid_harmonic)
#    batch = sample_two_thirds(training_dataset[20])
    smag = batch.state.Smagorinsky()
    Txx = smag['Txx']
    Tyy = smag['Tyy']
    Txy = smag['Txy']
    sh_xy, sh_xx, vort_xy = batch.state.velocity_gradients()
    dissipation =  Txx * sh_xx + batch.grid.interp(Txy * sh_xy,['X','Y'])
    plt.subplot(1,2,1+j)
    dissipation.plot()
    plt.title(f'Dissipation on \ngrid harmonic: {grid_harmonic}')
plt.tight_layout()

# %%
training_dataset[20]

# %%
plt.figure(figsize=(8,4))
batch = sample_two_thirds(training_dataset[20])
smag = batch.state.Smagorinsky()
Txx = smag['Txx']
Tyy = smag['Tyy']
Txy = smag['Txy']
sh_xy, sh_xx, vort_xy = batch.state.velocity_gradients()
dissipation =  Txx * sh_xx + batch.grid.interp(Txy * sh_xy,['X','Y'])
dissipation.plot()
plt.title(f'Dissipation on plane wave')
plt.tight_layout()

# %%
training_dataset = ds.sample_epoch(time=np.random.randint(6950))
batch = training_dataset[20]
plt.figure(figsize=(12,3))
plt.subplot(1,3,1)
sh_xx0 = batch.state.velocity_gradients()[0]
plt.title('Initial sh_xx shear')
select_NA(sh_xx0).plot()
plt.subplot(1,3,2)
sh_xx = perturb_velocities(batch,amp=1e-2).state.velocity_gradients()[0]
select_NA(sh_xx).plot()
plt.title('Perturbed')
plt.subplot(1,3,3)
sh_xx = perturb_velocities(batch,amp=1e-2).state.velocity_gradients()[0]
select_NA(sh_xx-sh_xx0).plot()
plt.title('Perturbation')
# Out:
# Text(0.5, 1.0, 'Perturbation')

# %%
# ann_Txy = ANN([27, 20, 1])
# ann_Txx_Tyy = ANN([27, 20, 2])
log_dict = {}
ann_Txy = import_ANN('trained_models/ANN_CM26/Txy_epoch_2000.nc')
ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26/Txx_Tyy_epoch_2000.nc')

# %%
num_epochs=1000

all_parameters = list(ann_Txy.parameters()) + list(ann_Txx_Tyy.parameters())
optimizer = optim.Adam(all_parameters, lr=1e-3)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
        milestones=[int(num_epochs/2), int(num_epochs*3/4), int(num_epochs*7/8)], gamma=0.1)  

t_s = time()

for epoch in range(num_epochs):
    t_e = time()
    
    training_dataset = ds.sample_epoch(time=np.random.randint(6950)) # Approximately 19 years for training
    testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035)) # Approximately 3 years for testing
    print(f'---------- Epoch {epoch} ------------\n')
    
    for factor in [2,4,6,10,20]:
        ############# Training step ################
        
        optimizer.zero_grad()
        
        batch = training_dataset[factor]
        prediction = batch.state.Apply_ANN(ann_Txy, ann_Txx_Tyy)
        ANNx = prediction['ZB20u']
        ANNy = prediction['ZB20v']
        SGSx = torch.tensor(batch.data.SGSx.values).type(torch.float32)
        SGSy = torch.tensor(batch.data.SGSy.values).type(torch.float32)
        
        SGS_norm = 1. / torch.sqrt((SGSx**2 + SGSy**2).mean())
        
        MSE_train = ((ANNx*SGS_norm-SGSx*SGS_norm)**2 + (ANNy*SGS_norm-SGSy*SGS_norm)**2).mean()
        
        # Regulatization by perturbing and computing response
        smag = batch.state.Smagorinsky()
        smagx = torch.tensor(smag['smagx'].values).type(torch.float32)
        smagy = torch.tensor(smag['smagy'].values).type(torch.float32)

        batch_perturbed = perturb_velocities(batch)
        smag = batch_perturbed.state.Smagorinsky()
        smagx_perturbed = torch.tensor(smag['smagx'].values).type(torch.float32)
        smagy_perturbed = torch.tensor(smag['smagy'].values).type(torch.float32)
        smagx_response = smagx_perturbed - smagx
        smagy_response = smagy_perturbed - smagy
        
        prediction = batch_perturbed.state.Apply_ANN(ann_Txy, ann_Txx_Tyy)
        ANNx_perturbed = prediction['ZB20u']
        ANNy_perturbed = prediction['ZB20v']
        ANNx_response = ANNx_perturbed - ANNx
        ANNy_response = ANNy_perturbed - ANNy
        
        SGS_norm = 1. / torch.sqrt((smagx_response**2 + smagy_response**2).mean())
        
        MSE_plane_waves = (
            (ANNx_response * SGS_norm - smagx_response * SGS_norm)**2 +
            (ANNy_response * SGS_norm - smagy_response * SGS_norm)**2
        ).mean()
        
        loss = MSE_train + MSE_plane_waves
        
        loss.backward()
        optimizer.step()
        
        del batch_perturbed.data
        
        ############ Testing step ##################
        with torch.no_grad():
            batch = testing_dataset[factor]
            prediction = batch.state.Apply_ANN(ann_Txy, ann_Txx_Tyy)
            ANNx = prediction['ZB20u']
            ANNy = prediction['ZB20v']
            SGSx = torch.tensor(batch.data.SGSx.values).type(torch.float32)
            SGSy = torch.tensor(batch.data.SGSy.values).type(torch.float32)

            SGS_norm = 1. / torch.sqrt((SGSx**2 + SGSy**2).mean())

            MSE_test = ((ANNx*SGS_norm-SGSx*SGS_norm)**2 + (ANNy*SGS_norm-SGSy*SGS_norm)**2).mean()
        
        print(f'Factor: {factor}.' + \
              ' MSE train/test: [%.6f, %.6f]' % (float(MSE_train.data), float(MSE_test.data)) + \
              ' MSE on plane waves: %.6f' % (float(MSE_plane_waves)))
        ########### Saving history of losses ############
        log_dict[f'epoch-{epoch+1}-factor-{factor}'] = \
            dict(MSE_train=float(MSE_train.data),
                 MSE_test=float(MSE_test.data),
                 MSE_plane_waves=float(MSE_plane_waves)
                )
        ######## Freeing memory ############
        del training_dataset[factor].data
        del training_dataset[factor].param
        del testing_dataset[factor].data
        del testing_dataset[factor].param
    t = time()
    print('Epoch time/Remaining time in seconds: [%d/%d]' % (t-t_e, (t-t_s)*(num_epochs/(epoch+1)-1)))
    scheduler.step()    
    
    if (epoch+1) % 50 == 0:
        export_ANN(ann_Txy, input_norms=torch.ones(27), output_norms=torch.ones(1), 
           filename=f'trained_models/ANN_CM26_grid_harmonic_ver3/Txy_epoch_{epoch+1}.nc')
        export_ANN(ann_Txx_Tyy, input_norms=torch.ones(27), output_norms=torch.ones(2), 
           filename=f'trained_models/ANN_CM26_grid_harmonic_ver3/Txx_Tyy_epoch_{epoch+1}.nc')
        with open(f'trained_models/ANN_CM26_grid_harmonic_ver3/log_dict_epoch_{epoch+1}', 'w') as file:
            json.dump(log_dict, file)
# Out:
# ---------- Epoch 0 ------------
#
# Factor: 2. MSE train/test: [0.613465, 0.626957] MSE on plane waves: 1.112745
# Factor: 4. MSE train/test: [0.541300, 0.558200] MSE on plane waves: 1.064974
# Factor: 6. MSE train/test: [0.580507, 0.599920] MSE on plane waves: 1.058999
# Factor: 10. MSE train/test: [0.688538, 0.701487] MSE on plane waves: 0.989176
# Factor: 20. MSE train/test: [0.892305, 0.919077] MSE on plane waves: 0.953884
# Epoch time/Remaining time in seconds: [21/21469]
# ---------- Epoch 1 ------------
#
# Factor: 2. MSE train/test: [0.610532, 0.625302] MSE on plane waves: 0.892761
# Factor: 4. MSE train/test: [0.573668, 0.589493] MSE on plane waves: 1.028998
# Factor: 6. MSE train/test: [0.616896, 0.633833] MSE on plane waves: 0.792512
# Factor: 10. MSE train/test: [0.718306, 0.732814] MSE on plane waves: 0.920112
# Factor: 20. MSE train/test: [0.937685, 0.923940] MSE on plane waves: 1.012636
# Epoch time/Remaining time in seconds: [19/20237]
# ---------- Epoch 2 ------------
#
# Factor: 2. MSE train/test: [0.684668, 0.690547] MSE on plane waves: 0.778418
# Factor: 4. MSE train/test: [0.587660, 0.608301] MSE on plane waves: 0.807474
# Factor: 6. MSE train/test: [0.617434, 0.622203] MSE on plane waves: 0.885109
# Factor: 10. MSE train/test: [0.704284, 0.714635] MSE on plane waves: 0.757912
# Factor: 20. MSE train/test: [0.949302, 0.894903] MSE on plane waves: 0.796795
# Epoch time/Remaining time in seconds: [18/19733]
# ---------- Epoch 3 ------------
#
# Factor: 2. MSE train/test: [0.714369, 0.597562] MSE on plane waves: 0.789535
# Factor: 4. MSE train/test: [0.636736, 0.562136] MSE on plane waves: 0.895237
# Factor: 6. MSE train/test: [0.644355, 0.608014] MSE on plane waves: 0.769042
# Factor: 10. MSE train/test: [0.742367, 0.724357] MSE on plane waves: 0.823203
# Factor: 20. MSE train/test: [0.910346, 0.898674] MSE on plane waves: 0.788081
# Epoch time/Remaining time in seconds: [19/19562]
# ---------- Epoch 4 ------------
#
# Factor: 2. MSE train/test: [0.653416, 0.603379] MSE on plane waves: 0.936766
# Factor: 4. MSE train/test: [0.569402, 0.564882] MSE on plane waves: 0.802887
# Factor: 6. MSE train/test: [0.618899, 0.604642] MSE on plane waves: 0.888574
# Factor: 10. MSE train/test: [0.752640, 0.732987] MSE on plane waves: 0.788261
# Factor: 20. MSE train/test: [0.918181, 0.895800] MSE on plane waves: 0.763029
# Epoch time/Remaining time in seconds: [18/19337]
# ---------- Epoch 5 ------------
#
# Factor: 2. MSE train/test: [0.570403, 0.661023] MSE on plane waves: 0.615400
# Factor: 4. MSE train/test: [0.548448, 0.597365] MSE on plane waves: 0.607396
# Factor: 6. MSE train/test: [0.608160, 0.661364] MSE on plane waves: 0.746537
# Factor: 10. MSE train/test: [0.719524, 0.746526] MSE on plane waves: 0.599782
# Factor: 20. MSE train/test: [0.917622, 0.952037] MSE on plane waves: 0.805473
# Epoch time/Remaining time in seconds: [18/19158]
# ---------- Epoch 6 ------------
#
# Factor: 2. MSE train/test: [0.642474, 0.713246] MSE on plane waves: 0.607909
# Factor: 4. MSE train/test: [0.586966, 0.640221] MSE on plane waves: 0.678092
# Factor: 6. MSE train/test: [0.645351, 0.652816] MSE on plane waves: 0.587309
# Factor: 10. MSE train/test: [0.729711, 0.722826] MSE on plane waves: 0.682675
# Factor: 20. MSE train/test: [0.959672, 0.922883] MSE on plane waves: 0.805423
# Epoch time/Remaining time in seconds: [18/19086]
# ---------- Epoch 7 ------------
#
# Factor: 2. MSE train/test: [0.711985, 0.736166] MSE on plane waves: 0.633520
# Factor: 4. MSE train/test: [0.636446, 0.674023] MSE on plane waves: 0.595503
# Factor: 6. MSE train/test: [0.665404, 0.689375] MSE on plane waves: 0.556512
# Factor: 10. MSE train/test: [0.721844, 0.753675] MSE on plane waves: 0.526432
# Factor: 20. MSE train/test: [0.961882, 0.851762] MSE on plane waves: 0.552998
# Epoch time/Remaining time in seconds: [18/18929]
# ---------- Epoch 8 ------------
#
# Factor: 2. MSE train/test: [0.721435, 0.647550] MSE on plane waves: 0.403180
# Factor: 4. MSE train/test: [0.659351, 0.619184] MSE on plane waves: 0.582227
# Factor: 6. MSE train/test: [0.682588, 0.661142] MSE on plane waves: 0.674398
# Factor: 10. MSE train/test: [0.752909, 0.745317] MSE on plane waves: 0.760164
# Factor: 20. MSE train/test: [0.946395, 0.927856] MSE on plane waves: 0.567965
# Epoch time/Remaining time in seconds: [18/18815]
# ---------- Epoch 9 ------------
#
# Factor: 2. MSE train/test: [0.600801, 0.744944] MSE on plane waves: 0.511346
# Factor: 4. MSE train/test: [0.580411, 0.682109] MSE on plane waves: 0.594347
# Factor: 6. MSE train/test: [0.636539, 0.689712] MSE on plane waves: 0.646814
# Factor: 10. MSE train/test: [0.741831, 0.773345] MSE on plane waves: 0.667257
# Factor: 20. MSE train/test: [0.981884, 0.956228] MSE on plane waves: 0.730867
# Epoch time/Remaining time in seconds: [18/18702]
# ---------- Epoch 10 ------------
#
# Factor: 2. MSE train/test: [0.751554, 0.760935] MSE on plane waves: 0.204215
# Factor: 4. MSE train/test: [0.678927, 0.662463] MSE on plane waves: 0.388285
# Factor: 6. MSE train/test: [0.700954, 0.675964] MSE on plane waves: 0.253020
# Factor: 10. MSE train/test: [0.733604, 0.749727] MSE on plane waves: 0.615077
# Factor: 20. MSE train/test: [0.922593, 0.945831] MSE on plane waves: 0.536822
# Epoch time/Remaining time in seconds: [17/18585]
# ---------- Epoch 11 ------------
#
# Factor: 2. MSE train/test: [0.731805, 0.684718] MSE on plane waves: 0.492815
# Factor: 4. MSE train/test: [0.668734, 0.662734] MSE on plane waves: 0.514474
# Factor: 6. MSE train/test: [0.710069, 0.692967] MSE on plane waves: 0.432145
# Factor: 10. MSE train/test: [0.780997, 0.775185] MSE on plane waves: 0.458652
# Factor: 20. MSE train/test: [0.935403, 0.940721] MSE on plane waves: 0.815195
# Epoch time/Remaining time in seconds: [17/18469]
# ---------- Epoch 12 ------------
#
# Factor: 2. MSE train/test: [0.768216, 0.768510] MSE on plane waves: 0.532488
# Factor: 4. MSE train/test: [0.667107, 0.699030] MSE on plane waves: 0.394643
# Factor: 6. MSE train/test: [0.666303, 0.710935] MSE on plane waves: 0.372815
# Factor: 10. MSE train/test: [0.744887, 0.767698] MSE on plane waves: 0.579839
# Factor: 20. MSE train/test: [0.981799, 0.937226] MSE on plane waves: 0.446930
# Epoch time/Remaining time in seconds: [16/18310]
# ---------- Epoch 13 ------------
#
# Factor: 2. MSE train/test: [0.768364, 0.759474] MSE on plane waves: 0.439954
# Factor: 4. MSE train/test: [0.696844, 0.678920] MSE on plane waves: 0.585137
# Factor: 6. MSE train/test: [0.750036, 0.662673] MSE on plane waves: 0.172981
# Factor: 10. MSE train/test: [0.796893, 0.754614] MSE on plane waves: 0.653859
# Factor: 20. MSE train/test: [0.975440, 0.964951] MSE on plane waves: 0.590775
# Epoch time/Remaining time in seconds: [17/18234]
# ---------- Epoch 14 ------------
#
# Factor: 2. MSE train/test: [0.783041, 0.789615] MSE on plane waves: 0.529543
# Factor: 4. MSE train/test: [0.715876, 0.691293] MSE on plane waves: 0.720791
# Factor: 6. MSE train/test: [0.752692, 0.715523] MSE on plane waves: 0.583853
# Factor: 10. MSE train/test: [0.814722, 0.788946] MSE on plane waves: 0.440119
# Factor: 20. MSE train/test: [0.979628, 0.977851] MSE on plane waves: 0.618163
# Epoch time/Remaining time in seconds: [18/18212]
# ---------- Epoch 15 ------------
#
# Factor: 2. MSE train/test: [0.694679, 0.760903] MSE on plane waves: 0.387715
# Factor: 4. MSE train/test: [0.654033, 0.719411] MSE on plane waves: 0.354211
# Factor: 6. MSE train/test: [0.714737, 0.731071] MSE on plane waves: 0.476606
# Factor: 10. MSE train/test: [0.802323, 0.780737] MSE on plane waves: 0.485347
# Factor: 20. MSE train/test: [0.978620, 1.008566] MSE on plane waves: 0.430738
# Epoch time/Remaining time in seconds: [18/18177]
# ---------- Epoch 16 ------------
#
# Factor: 2. MSE train/test: [0.820814, 0.774391] MSE on plane waves: 0.391327
# Factor: 4. MSE train/test: [0.722527, 0.740536] MSE on plane waves: 0.305901
# Factor: 6. MSE train/test: [0.734242, 0.745498] MSE on plane waves: 0.464758
# Factor: 10. MSE train/test: [0.822959, 0.809016] MSE on plane waves: 0.571651
# Factor: 20. MSE train/test: [1.011334, 0.985602] MSE on plane waves: 0.821430
# Epoch time/Remaining time in seconds: [17/18092]
# ---------- Epoch 17 ------------
#
# Factor: 2. MSE train/test: [0.707345, 0.800954] MSE on plane waves: 0.446978
# Factor: 4. MSE train/test: [0.694736, 0.736079] MSE on plane waves: 0.489873
# Factor: 6. MSE train/test: [0.729338, 0.743369] MSE on plane waves: 0.614933
# Factor: 10. MSE train/test: [0.796604, 0.825181] MSE on plane waves: 0.376064
# Factor: 20. MSE train/test: [0.973450, 0.990449] MSE on plane waves: 0.497254
# Epoch time/Remaining time in seconds: [17/18034]
# ---------- Epoch 18 ------------
#
# Factor: 2. MSE train/test: [0.768663, 0.772648] MSE on plane waves: 0.686395
# Factor: 4. MSE train/test: [0.710536, 0.731604] MSE on plane waves: 0.522261
# Factor: 6. MSE train/test: [0.731472, 0.745221] MSE on plane waves: 0.129289
# Factor: 10. MSE train/test: [0.778141, 0.819181] MSE on plane waves: 0.332713
# Factor: 20. MSE train/test: [0.964735, 0.998525] MSE on plane waves: 0.472215
# Epoch time/Remaining time in seconds: [18/18023]
# ---------- Epoch 19 ------------
#
# Factor: 2. MSE train/test: [0.745557, 0.788165] MSE on plane waves: 0.446427
# Factor: 4. MSE train/test: [0.670590, 0.708359] MSE on plane waves: 0.479718
# Factor: 6. MSE train/test: [0.720834, 0.731225] MSE on plane waves: 0.379582
# Factor: 10. MSE train/test: [0.819362, 0.806510] MSE on plane waves: 0.391746
# Factor: 20. MSE train/test: [1.015580, 0.965216] MSE on plane waves: 0.565263
# Epoch time/Remaining time in seconds: [17/17971]
# ---------- Epoch 20 ------------
#
# Factor: 2. MSE train/test: [0.770087, 0.752702] MSE on plane waves: 0.344123
# Factor: 4. MSE train/test: [0.710313, 0.712835] MSE on plane waves: 0.626845
# Factor: 6. MSE train/test: [0.730105, 0.751038] MSE on plane waves: 0.606673
# Factor: 10. MSE train/test: [0.804032, 0.833670] MSE on plane waves: 0.575275
# Factor: 20. MSE train/test: [1.008017, 1.011806] MSE on plane waves: 0.508039
# Epoch time/Remaining time in seconds: [17/17935]
# ---------- Epoch 21 ------------
#
# Factor: 2. MSE train/test: [0.665723, 0.807573] MSE on plane waves: 0.516813
# Factor: 4. MSE train/test: [0.637546, 0.696294] MSE on plane waves: 0.091428
# Factor: 6. MSE train/test: [0.696772, 0.694823] MSE on plane waves: 0.336395
# Factor: 10. MSE train/test: [0.820625, 0.798381] MSE on plane waves: 0.609138
# Factor: 20. MSE train/test: [0.958723, 0.991844] MSE on plane waves: 0.674403
# Epoch time/Remaining time in seconds: [18/17916]
# ---------- Epoch 22 ------------
#
# Factor: 2. MSE train/test: [0.744389, 0.676802] MSE on plane waves: 0.493725
# Factor: 4. MSE train/test: [0.679373, 0.658758] MSE on plane waves: 0.487075
# Factor: 6. MSE train/test: [0.736958, 0.716789] MSE on plane waves: 0.473179
# Factor: 10. MSE train/test: [0.803214, 0.812565] MSE on plane waves: 0.565224
# Factor: 20. MSE train/test: [0.995189, 1.025078] MSE on plane waves: 0.556352
# Epoch time/Remaining time in seconds: [18/17914]
# ---------- Epoch 23 ------------
#
# Factor: 2. MSE train/test: [0.773440, 0.791206] MSE on plane waves: 0.444034
# Factor: 4. MSE train/test: [0.696513, 0.717698] MSE on plane waves: 0.382421
# Factor: 6. MSE train/test: [0.734893, 0.766521] MSE on plane waves: 0.670043
# Factor: 10. MSE train/test: [0.819548, 0.838041] MSE on plane waves: 0.396934
# Factor: 20. MSE train/test: [1.001330, 1.015792] MSE on plane waves: 0.385476
# Epoch time/Remaining time in seconds: [18/17894]
# ---------- Epoch 24 ------------
#
# Factor: 2. MSE train/test: [0.729120, 0.793623] MSE on plane waves: 0.378661
# Factor: 4. MSE train/test: [0.668493, 0.743075] MSE on plane waves: 0.377496
# Factor: 6. MSE train/test: [0.756159, 0.761196] MSE on plane waves: 0.619933
# Factor: 10. MSE train/test: [0.879009, 0.821121] MSE on plane waves: 0.522296
# Factor: 20. MSE train/test: [1.003302, 1.002599] MSE on plane waves: 0.201998
# Epoch time/Remaining time in seconds: [17/17849]
# ---------- Epoch 25 ------------
#
# Factor: 2. MSE train/test: [0.751080, 0.781417] MSE on plane waves: 0.230797
# Factor: 4. MSE train/test: [0.734935, 0.734451] MSE on plane waves: 0.369285
# Factor: 6. MSE train/test: [0.744570, 0.720566] MSE on plane waves: 0.453427
# Factor: 10. MSE train/test: [0.814252, 0.844787] MSE on plane waves: 0.424983
# Factor: 20. MSE train/test: [0.970682, 0.982190] MSE on plane waves: 0.522627
# Epoch time/Remaining time in seconds: [18/17840]
# ---------- Epoch 26 ------------
#
# Factor: 2. MSE train/test: [0.784140, 0.751346] MSE on plane waves: 0.323006
# Factor: 4. MSE train/test: [0.756199, 0.691248] MSE on plane waves: 0.588590
# Factor: 6. MSE train/test: [0.772185, 0.722995] MSE on plane waves: 0.517530
# Factor: 10. MSE train/test: [0.830731, 0.823030] MSE on plane waves: 0.406561
# Factor: 20. MSE train/test: [0.997944, 0.993770] MSE on plane waves: 0.534912
# Epoch time/Remaining time in seconds: [18/17824]
# ---------- Epoch 27 ------------
#
# Factor: 2. MSE train/test: [0.810124, 0.791310] MSE on plane waves: 0.517283
# Factor: 4. MSE train/test: [0.762940, 0.713458] MSE on plane waves: 0.353790
# Factor: 6. MSE train/test: [0.763005, 0.729411] MSE on plane waves: 0.549746
# Factor: 10. MSE train/test: [0.837875, 0.793500] MSE on plane waves: 0.512076
# Factor: 20. MSE train/test: [1.004636, 1.004121] MSE on plane waves: 0.633640
# Epoch time/Remaining time in seconds: [18/17796]
# ---------- Epoch 28 ------------
#
# Factor: 2. MSE train/test: [0.780817, 0.755625] MSE on plane waves: 0.425240
# Factor: 4. MSE train/test: [0.698032, 0.739061] MSE on plane waves: 0.599871
# Factor: 6. MSE train/test: [0.760578, 0.776082] MSE on plane waves: 0.501859
# Factor: 10. MSE train/test: [0.842227, 0.859510] MSE on plane waves: 0.519591
# Factor: 20. MSE train/test: [0.986352, 1.006475] MSE on plane waves: 0.421846
# Epoch time/Remaining time in seconds: [18/17777]
# ---------- Epoch 29 ------------
#
# Factor: 2. MSE train/test: [0.806488, 0.830736] MSE on plane waves: 0.467515
# Factor: 4. MSE train/test: [0.727720, 0.793304] MSE on plane waves: 0.437086
# Factor: 6. MSE train/test: [0.773487, 0.835242] MSE on plane waves: 0.507867
# Factor: 10. MSE train/test: [0.889354, 0.878403] MSE on plane waves: 0.445905
# Factor: 20. MSE train/test: [1.003440, 1.000992] MSE on plane waves: 0.347631
# Epoch time/Remaining time in seconds: [18/17760]
# ---------- Epoch 30 ------------
#
# Factor: 2. MSE train/test: [0.842066, 0.800809] MSE on plane waves: 0.404437
# Factor: 4. MSE train/test: [0.760525, 0.748356] MSE on plane waves: 0.426404
# Factor: 6. MSE train/test: [0.761324, 0.771505] MSE on plane waves: 0.474483
# Factor: 10. MSE train/test: [0.851464, 0.840056] MSE on plane waves: 0.429467
# Factor: 20. MSE train/test: [0.994742, 0.981768] MSE on plane waves: 0.299198
# Epoch time/Remaining time in seconds: [18/17740]
# ---------- Epoch 31 ------------
#
# Factor: 2. MSE train/test: [0.827855, 0.842438] MSE on plane waves: 0.303034
# Factor: 4. MSE train/test: [0.729313, 0.774781] MSE on plane waves: 0.474966
# Factor: 6. MSE train/test: [0.750486, 0.773960] MSE on plane waves: 0.535293
# Factor: 10. MSE train/test: [0.801148, 0.789769] MSE on plane waves: 0.716084
# Factor: 20. MSE train/test: [1.016476, 0.958229] MSE on plane waves: 0.548249
# Epoch time/Remaining time in seconds: [18/17723]
# ---------- Epoch 32 ------------
#
# Factor: 2. MSE train/test: [0.696875, 0.748774] MSE on plane waves: 0.477947
# Factor: 4. MSE train/test: [0.651120, 0.632750] MSE on plane waves: 0.312976
# Factor: 6. MSE train/test: [0.717985, 0.693233] MSE on plane waves: 0.403645
# Factor: 10. MSE train/test: [0.813870, 0.797261] MSE on plane waves: 0.614125
# Factor: 20. MSE train/test: [0.953272, 1.009215] MSE on plane waves: 0.420709
# Epoch time/Remaining time in seconds: [18/17702]
# ---------- Epoch 33 ------------
#
# Factor: 2. MSE train/test: [0.791462, 0.800923] MSE on plane waves: 0.460609
# Factor: 4. MSE train/test: [0.715065, 0.744933] MSE on plane waves: 0.360400
# Factor: 6. MSE train/test: [0.731635, 0.753211] MSE on plane waves: 0.497083
# Factor: 10. MSE train/test: [0.802614, 0.794379] MSE on plane waves: 0.465346
# Factor: 20. MSE train/test: [0.958741, 0.947477] MSE on plane waves: 0.432294
# Epoch time/Remaining time in seconds: [18/17687]
# ---------- Epoch 34 ------------
#
# Factor: 2. MSE train/test: [0.774960, 0.766736] MSE on plane waves: 0.423850
# Factor: 4. MSE train/test: [0.735314, 0.716146] MSE on plane waves: 0.494066
# Factor: 6. MSE train/test: [0.728786, 0.732092] MSE on plane waves: 0.205877
# Factor: 10. MSE train/test: [0.782869, 0.796270] MSE on plane waves: 0.403102
# Factor: 20. MSE train/test: [0.997664, 0.997611] MSE on plane waves: 0.777336
# Epoch time/Remaining time in seconds: [19/17692]
# ---------- Epoch 35 ------------
#
# Factor: 2. MSE train/test: [0.752551, 0.637079] MSE on plane waves: 0.175484
# Factor: 4. MSE train/test: [0.680620, 0.619598] MSE on plane waves: 0.499685
# Factor: 6. MSE train/test: [0.709896, 0.706545] MSE on plane waves: 0.524300
# Factor: 10. MSE train/test: [0.814331, 0.812208] MSE on plane waves: 0.575249
# Factor: 20. MSE train/test: [1.033395, 0.969672] MSE on plane waves: 0.397561
# Epoch time/Remaining time in seconds: [18/17678]
# ---------- Epoch 36 ------------
#
# Factor: 2. MSE train/test: [0.668095, 0.697119] MSE on plane waves: 0.163409
# Factor: 4. MSE train/test: [0.627810, 0.646219] MSE on plane waves: 0.529692
# Factor: 6. MSE train/test: [0.687838, 0.705436] MSE on plane waves: 0.491643
# Factor: 10. MSE train/test: [0.820486, 0.809109] MSE on plane waves: 0.650351
# Factor: 20. MSE train/test: [0.976808, 0.963412] MSE on plane waves: 0.120887
# Epoch time/Remaining time in seconds: [19/17702]
# ---------- Epoch 37 ------------
#
# Factor: 2. MSE train/test: [0.761030, 0.739530] MSE on plane waves: 0.188174
# Factor: 4. MSE train/test: [0.697425, 0.657050] MSE on plane waves: 0.235113
# Factor: 6. MSE train/test: [0.722059, 0.662615] MSE on plane waves: 0.518881
# Factor: 10. MSE train/test: [0.813861, 0.770375] MSE on plane waves: 0.115093
# Factor: 20. MSE train/test: [1.003867, 0.980659] MSE on plane waves: 0.513361
# Epoch time/Remaining time in seconds: [18/17688]
# ---------- Epoch 38 ------------
#
# Factor: 2. MSE train/test: [0.749436, 0.748573] MSE on plane waves: 0.410318
# Factor: 4. MSE train/test: [0.695810, 0.702579] MSE on plane waves: 0.509767
# Factor: 6. MSE train/test: [0.692416, 0.724787] MSE on plane waves: 0.391779
# Factor: 10. MSE train/test: [0.759482, 0.789970] MSE on plane waves: 0.434553
# Factor: 20. MSE train/test: [0.981471, 0.965634] MSE on plane waves: 0.538111
# Epoch time/Remaining time in seconds: [20/17723]
# ---------- Epoch 39 ------------
#
# Factor: 2. MSE train/test: [0.747454, 0.760220] MSE on plane waves: 0.524668
# Factor: 4. MSE train/test: [0.698361, 0.687257] MSE on plane waves: 0.592057
# Factor: 6. MSE train/test: [0.721239, 0.682025] MSE on plane waves: 0.590880
# Factor: 10. MSE train/test: [0.780206, 0.777954] MSE on plane waves: 0.487562
# Factor: 20. MSE train/test: [0.971949, 1.016247] MSE on plane waves: 0.558189
# Epoch time/Remaining time in seconds: [18/17710]
# ---------- Epoch 40 ------------
#
# Factor: 2. MSE train/test: [0.754380, 0.778613] MSE on plane waves: 0.435333
# Factor: 4. MSE train/test: [0.662873, 0.685051] MSE on plane waves: 0.597821
# Factor: 6. MSE train/test: [0.708231, 0.722940] MSE on plane waves: 0.538139
# Factor: 10. MSE train/test: [0.780835, 0.807028] MSE on plane waves: 0.476509
# Factor: 20. MSE train/test: [0.968674, 0.990442] MSE on plane waves: 0.588792
# Epoch time/Remaining time in seconds: [18/17690]
# ---------- Epoch 41 ------------
#
# Factor: 2. MSE train/test: [0.776182, 0.762202] MSE on plane waves: 0.314688
# Factor: 4. MSE train/test: [0.730551, 0.746510] MSE on plane waves: 0.309207
# Factor: 6. MSE train/test: [0.791108, 0.772485] MSE on plane waves: 0.536124
# Factor: 10. MSE train/test: [0.843007, 0.851722] MSE on plane waves: 0.426070
# Factor: 20. MSE train/test: [1.016757, 0.955051] MSE on plane waves: 0.550579
# Epoch time/Remaining time in seconds: [18/17668]
# ---------- Epoch 42 ------------
#
# Factor: 2. MSE train/test: [0.613987, 0.828539] MSE on plane waves: 0.433903
# Factor: 4. MSE train/test: [0.628200, 0.755686] MSE on plane waves: 0.490635
# Factor: 6. MSE train/test: [0.716422, 0.777979] MSE on plane waves: 0.559291
# Factor: 10. MSE train/test: [0.854875, 0.865758] MSE on plane waves: 0.297537
# Factor: 20. MSE train/test: [1.039207, 1.047945] MSE on plane waves: 0.261112
# Epoch time/Remaining time in seconds: [20/17687]
# ---------- Epoch 43 ------------
#
# Factor: 2. MSE train/test: [0.805051, 0.828751] MSE on plane waves: 0.131789
# Factor: 4. MSE train/test: [0.715010, 0.760507] MSE on plane waves: 0.557708
# Factor: 6. MSE train/test: [0.727459, 0.734305] MSE on plane waves: 0.517281
# Factor: 10. MSE train/test: [0.839370, 0.820512] MSE on plane waves: 0.303896
# Factor: 20. MSE train/test: [1.071832, 0.989283] MSE on plane waves: 0.452280
# Epoch time/Remaining time in seconds: [18/17678]
# ---------- Epoch 44 ------------
#
# Factor: 2. MSE train/test: [0.769569, 0.715430] MSE on plane waves: 0.186521
# Factor: 4. MSE train/test: [0.714297, 0.663825] MSE on plane waves: 0.444918
# Factor: 6. MSE train/test: [0.749575, 0.779852] MSE on plane waves: 0.617754
# Factor: 10. MSE train/test: [0.811948, 0.838196] MSE on plane waves: 0.664191
# Factor: 20. MSE train/test: [1.035879, 0.983737] MSE on plane waves: 0.569087
# Epoch time/Remaining time in seconds: [18/17667]
# ---------- Epoch 45 ------------
#
# Factor: 2. MSE train/test: [0.756339, 0.764823] MSE on plane waves: 0.335898
# Factor: 4. MSE train/test: [0.696728, 0.705282] MSE on plane waves: 0.527941
# Factor: 6. MSE train/test: [0.715325, 0.743028] MSE on plane waves: 0.354531
# Factor: 10. MSE train/test: [0.796567, 0.834841] MSE on plane waves: 0.080922
# Factor: 20. MSE train/test: [0.962858, 1.007801] MSE on plane waves: 0.689807
# Epoch time/Remaining time in seconds: [19/17665]
# ---------- Epoch 46 ------------
#
# Factor: 2. MSE train/test: [0.719589, 0.760510] MSE on plane waves: 0.501199
# Factor: 4. MSE train/test: [0.674053, 0.695255] MSE on plane waves: 0.409043
# Factor: 6. MSE train/test: [0.699124, 0.747108] MSE on plane waves: 0.610896
# Factor: 10. MSE train/test: [0.781448, 0.784196] MSE on plane waves: 0.476749
# Factor: 20. MSE train/test: [1.023358, 0.950425] MSE on plane waves: 0.584655
# Epoch time/Remaining time in seconds: [19/17658]
# ---------- Epoch 47 ------------
#
# Factor: 2. MSE train/test: [0.764628, 0.748779] MSE on plane waves: 0.491073
# Factor: 4. MSE train/test: [0.676581, 0.666877] MSE on plane waves: 0.459653
# Factor: 6. MSE train/test: [0.710270, 0.680246] MSE on plane waves: 0.468472
# Factor: 10. MSE train/test: [0.788789, 0.801790] MSE on plane waves: 0.638479
# Factor: 20. MSE train/test: [1.028040, 1.004999] MSE on plane waves: 0.474955
# Epoch time/Remaining time in seconds: [19/17651]
# ---------- Epoch 48 ------------
#
# Factor: 2. MSE train/test: [0.805713, 0.708368] MSE on plane waves: 0.100065
# Factor: 4. MSE train/test: [0.727573, 0.672321] MSE on plane waves: 0.574440
# Factor: 6. MSE train/test: [0.753789, 0.719257] MSE on plane waves: 0.567073
# Factor: 10. MSE train/test: [0.803365, 0.841292] MSE on plane waves: 0.472004
# Factor: 20. MSE train/test: [0.989456, 1.009385] MSE on plane waves: 0.743541
# Epoch time/Remaining time in seconds: [18/17637]
# ---------- Epoch 49 ------------
#
# Factor: 2. MSE train/test: [0.753622, 0.855257] MSE on plane waves: 0.439388
# Factor: 4. MSE train/test: [0.726589, 0.748075] MSE on plane waves: 0.128129
# Factor: 6. MSE train/test: [0.763351, 0.742545] MSE on plane waves: 0.267684
# Factor: 10. MSE train/test: [0.838323, 0.819570] MSE on plane waves: 0.403491
# Factor: 20. MSE train/test: [1.023122, 1.009270] MSE on plane waves: 0.622065
# Epoch time/Remaining time in seconds: [19/17631]
# ---------- Epoch 50 ------------
#
# Factor: 2. MSE train/test: [0.772102, 0.703451] MSE on plane waves: 0.489818
# Factor: 4. MSE train/test: [0.736050, 0.660238] MSE on plane waves: 0.142623
# Factor: 6. MSE train/test: [0.745936, 0.721743] MSE on plane waves: 0.267816
# Factor: 10. MSE train/test: [0.817903, 0.826115] MSE on plane waves: 0.518599
# Factor: 20. MSE train/test: [0.977460, 0.967748] MSE on plane waves: 0.611617
# Epoch time/Remaining time in seconds: [19/17635]
# ---------- Epoch 51 ------------
#
# Factor: 2. MSE train/test: [0.717286, 0.737609] MSE on plane waves: 0.451702
# Factor: 4. MSE train/test: [0.674332, 0.691175] MSE on plane waves: 0.226257
# Factor: 6. MSE train/test: [0.713172, 0.724183] MSE on plane waves: 0.531814
# Factor: 10. MSE train/test: [0.807858, 0.797566] MSE on plane waves: 0.496838
# Factor: 20. MSE train/test: [0.972998, 0.999936] MSE on plane waves: 0.588710
# Epoch time/Remaining time in seconds: [19/17627]
# ---------- Epoch 52 ------------
#
# Factor: 2. MSE train/test: [0.747661, 0.768946] MSE on plane waves: 0.289752
# Factor: 4. MSE train/test: [0.702037, 0.675663] MSE on plane waves: 0.421234
# Factor: 6. MSE train/test: [0.705559, 0.691145] MSE on plane waves: 0.520089
# Factor: 10. MSE train/test: [0.801038, 0.789748] MSE on plane waves: 0.489933
# Factor: 20. MSE train/test: [1.030081, 0.967333] MSE on plane waves: 0.463106
# Epoch time/Remaining time in seconds: [19/17623]
# ---------- Epoch 53 ------------
#
# Factor: 2. MSE train/test: [0.800082, 0.792836] MSE on plane waves: 0.235942
# Factor: 4. MSE train/test: [0.695998, 0.693712] MSE on plane waves: 0.431014
# Factor: 6. MSE train/test: [0.698789, 0.736844] MSE on plane waves: 0.173022
# Factor: 10. MSE train/test: [0.805628, 0.817706] MSE on plane waves: 0.552148
# Factor: 20. MSE train/test: [0.995554, 0.982604] MSE on plane waves: 0.580108
# Epoch time/Remaining time in seconds: [19/17619]
# ---------- Epoch 54 ------------
#
# Factor: 2. MSE train/test: [0.784937, 0.762680] MSE on plane waves: 0.135073
# Factor: 4. MSE train/test: [0.712214, 0.722196] MSE on plane waves: 0.377615
# Factor: 6. MSE train/test: [0.728026, 0.728012] MSE on plane waves: 0.510596
# Factor: 10. MSE train/test: [0.809781, 0.776990] MSE on plane waves: 0.419518
# Factor: 20. MSE train/test: [0.974552, 1.002560] MSE on plane waves: 0.390023
# Epoch time/Remaining time in seconds: [20/17628]
# ---------- Epoch 55 ------------
#
# Factor: 2. MSE train/test: [0.765085, 0.709415] MSE on plane waves: 0.448054
# Factor: 4. MSE train/test: [0.722925, 0.652905] MSE on plane waves: 0.371026
# Factor: 6. MSE train/test: [0.730740, 0.702479] MSE on plane waves: 0.550276
# Factor: 10. MSE train/test: [0.837563, 0.835070] MSE on plane waves: 0.449309
# Factor: 20. MSE train/test: [0.960717, 0.950018] MSE on plane waves: 0.745229
# Epoch time/Remaining time in seconds: [19/17622]
# ---------- Epoch 56 ------------
#
# Factor: 2. MSE train/test: [0.781792, 0.764091] MSE on plane waves: 0.184816
# Factor: 4. MSE train/test: [0.724309, 0.726119] MSE on plane waves: 0.424805
# Factor: 6. MSE train/test: [0.749001, 0.729636] MSE on plane waves: 0.529279
# Factor: 10. MSE train/test: [0.806848, 0.781021] MSE on plane waves: 0.444001
# Factor: 20. MSE train/test: [1.012575, 0.971759] MSE on plane waves: 0.703386
# Epoch time/Remaining time in seconds: [21/17653]
# ---------- Epoch 57 ------------
#
# Factor: 2. MSE train/test: [0.757965, 0.713094] MSE on plane waves: 0.229852
# Factor: 4. MSE train/test: [0.691705, 0.686966] MSE on plane waves: 0.641235
# Factor: 6. MSE train/test: [0.722889, 0.702779] MSE on plane waves: 0.541741
# Factor: 10. MSE train/test: [0.826959, 0.796574] MSE on plane waves: 0.550537
# Factor: 20. MSE train/test: [1.034432, 1.009284] MSE on plane waves: 0.672086
# Epoch time/Remaining time in seconds: [18/17634]
# ---------- Epoch 58 ------------
#
# Factor: 2. MSE train/test: [0.767552, 0.703937] MSE on plane waves: 0.198008
# Factor: 4. MSE train/test: [0.693620, 0.670327] MSE on plane waves: 0.356325
# Factor: 6. MSE train/test: [0.749902, 0.729428] MSE on plane waves: 0.225620
# Factor: 10. MSE train/test: [0.800799, 0.807885] MSE on plane waves: 0.267685
# Factor: 20. MSE train/test: [1.018029, 0.980555] MSE on plane waves: 0.588737
# Epoch time/Remaining time in seconds: [18/17615]
# ---------- Epoch 59 ------------
#
# Factor: 2. MSE train/test: [0.710117, 0.769767] MSE on plane waves: 0.207746
# Factor: 4. MSE train/test: [0.692225, 0.734711] MSE on plane waves: 0.494956
# Factor: 6. MSE train/test: [0.739564, 0.746239] MSE on plane waves: 0.390315
# Factor: 10. MSE train/test: [0.880148, 0.849411] MSE on plane waves: 0.148345
# Factor: 20. MSE train/test: [1.007860, 1.011772] MSE on plane waves: 0.514452
# Epoch time/Remaining time in seconds: [18/17593]
# ---------- Epoch 60 ------------
#
# Factor: 2. MSE train/test: [0.758523, 0.768108] MSE on plane waves: 0.318210
# Factor: 4. MSE train/test: [0.734381, 0.709816] MSE on plane waves: 0.667767
# Factor: 6. MSE train/test: [0.775336, 0.751117] MSE on plane waves: 0.387894
# Factor: 10. MSE train/test: [0.829320, 0.823502] MSE on plane waves: 0.616120
# Factor: 20. MSE train/test: [0.969672, 0.981880] MSE on plane waves: 0.727389
# Epoch time/Remaining time in seconds: [18/17568]
# ---------- Epoch 61 ------------
#
# Factor: 2. MSE train/test: [0.770694, 0.790758] MSE on plane waves: 0.425224
# Factor: 4. MSE train/test: [0.702865, 0.710137] MSE on plane waves: 0.565098
# Factor: 6. MSE train/test: [0.742955, 0.732568] MSE on plane waves: 0.441078
# Factor: 10. MSE train/test: [0.817897, 0.815344] MSE on plane waves: 0.514142
# Factor: 20. MSE train/test: [0.979782, 0.982923] MSE on plane waves: 0.650904
# Epoch time/Remaining time in seconds: [18/17551]
# ---------- Epoch 62 ------------
#
# Factor: 2. MSE train/test: [0.777195, 0.792090] MSE on plane waves: 0.470996
# Factor: 4. MSE train/test: [0.724060, 0.686223] MSE on plane waves: 0.568455
# Factor: 6. MSE train/test: [0.753749, 0.717019] MSE on plane waves: 0.499265
# Factor: 10. MSE train/test: [0.815938, 0.803190] MSE on plane waves: 0.418918
# Factor: 20. MSE train/test: [1.003355, 1.035011] MSE on plane waves: 0.515558
# Epoch time/Remaining time in seconds: [18/17526]
# ---------- Epoch 63 ------------
#
# Factor: 2. MSE train/test: [0.776358, 0.787893] MSE on plane waves: 0.307721
# Factor: 4. MSE train/test: [0.715602, 0.721350] MSE on plane waves: 0.413826
# Factor: 6. MSE train/test: [0.773562, 0.734930] MSE on plane waves: 0.335458
# Factor: 10. MSE train/test: [0.844747, 0.815964] MSE on plane waves: 0.512270
# Factor: 20. MSE train/test: [1.023450, 0.981855] MSE on plane waves: 0.650721
# Epoch time/Remaining time in seconds: [18/17505]
# ---------- Epoch 64 ------------
#
# Factor: 2. MSE train/test: [0.779344, 0.825713] MSE on plane waves: 0.477954
# Factor: 4. MSE train/test: [0.739285, 0.723210] MSE on plane waves: 0.575323
# Factor: 6. MSE train/test: [0.745959, 0.713268] MSE on plane waves: 0.127049
# Factor: 10. MSE train/test: [0.807056, 0.814062] MSE on plane waves: 0.689865
# Factor: 20. MSE train/test: [1.006877, 0.988047] MSE on plane waves: 0.621490
# Epoch time/Remaining time in seconds: [18/17480]
# ---------- Epoch 65 ------------
#
# Factor: 2. MSE train/test: [0.687424, 0.771870] MSE on plane waves: 0.206744
# Factor: 4. MSE train/test: [0.672560, 0.701144] MSE on plane waves: 0.351606
# Factor: 6. MSE train/test: [0.726179, 0.757679] MSE on plane waves: 0.410282
# Factor: 10. MSE train/test: [0.852553, 0.853425] MSE on plane waves: 0.501374
# Factor: 20. MSE train/test: [0.993730, 1.009893] MSE on plane waves: 0.648376
# Epoch time/Remaining time in seconds: [19/17470]
# ---------- Epoch 66 ------------
#
# Factor: 2. MSE train/test: [0.799878, 0.804065] MSE on plane waves: 0.429399
# Factor: 4. MSE train/test: [0.726945, 0.731932] MSE on plane waves: 0.090490
# Factor: 6. MSE train/test: [0.752012, 0.754793] MSE on plane waves: 0.393102
# Factor: 10. MSE train/test: [0.856719, 0.825027] MSE on plane waves: 0.507709
# Factor: 20. MSE train/test: [1.035007, 0.938949] MSE on plane waves: 0.699257
# Epoch time/Remaining time in seconds: [18/17451]
# ---------- Epoch 67 ------------
#
# Factor: 2. MSE train/test: [0.800310, 0.766744] MSE on plane waves: 0.366571
# Factor: 4. MSE train/test: [0.705685, 0.723959] MSE on plane waves: 0.503069
# Factor: 6. MSE train/test: [0.751847, 0.733018] MSE on plane waves: 0.571049
# Factor: 10. MSE train/test: [0.808930, 0.821157] MSE on plane waves: 0.664903
# Factor: 20. MSE train/test: [1.027082, 1.008299] MSE on plane waves: 0.464229
# Epoch time/Remaining time in seconds: [19/17439]
# ---------- Epoch 68 ------------
#
# Factor: 2. MSE train/test: [0.607143, 0.763037] MSE on plane waves: 0.268148
# Factor: 4. MSE train/test: [0.599643, 0.721802] MSE on plane waves: 0.392780
# Factor: 6. MSE train/test: [0.689252, 0.730510] MSE on plane waves: 0.719750
# Factor: 10. MSE train/test: [0.828481, 0.810120] MSE on plane waves: 0.458455
# Factor: 20. MSE train/test: [0.981612, 1.009764] MSE on plane waves: 0.555261
# Epoch time/Remaining time in seconds: [18/17421]
# ---------- Epoch 69 ------------
#
# Factor: 2. MSE train/test: [0.670755, 0.791607] MSE on plane waves: 0.400134
# Factor: 4. MSE train/test: [0.646796, 0.697915] MSE on plane waves: 0.360546
# Factor: 6. MSE train/test: [0.716127, 0.738739] MSE on plane waves: 0.370355
# Factor: 10. MSE train/test: [0.859581, 0.805802] MSE on plane waves: 0.453937
# Factor: 20. MSE train/test: [1.015033, 0.990166] MSE on plane waves: 0.316817
# Epoch time/Remaining time in seconds: [18/17398]
# ---------- Epoch 70 ------------
#
# Factor: 2. MSE train/test: [0.823121, 0.826682] MSE on plane waves: 0.392334
# Factor: 4. MSE train/test: [0.748265, 0.754783] MSE on plane waves: 0.363294
# Factor: 6. MSE train/test: [0.766997, 0.757196] MSE on plane waves: 0.225933
# Factor: 10. MSE train/test: [0.845561, 0.792891] MSE on plane waves: 0.506648
# Factor: 20. MSE train/test: [0.973853, 0.984438] MSE on plane waves: 0.535442
# Epoch time/Remaining time in seconds: [18/17376]
# ---------- Epoch 71 ------------
#
# Factor: 2. MSE train/test: [0.645978, 0.814210] MSE on plane waves: 0.496501
# Factor: 4. MSE train/test: [0.623624, 0.687241] MSE on plane waves: 0.630167
# Factor: 6. MSE train/test: [0.711283, 0.726859] MSE on plane waves: 0.489436
# Factor: 10. MSE train/test: [0.852640, 0.823779] MSE on plane waves: 0.494879
# Factor: 20. MSE train/test: [1.024121, 1.018510] MSE on plane waves: 0.547495
# Epoch time/Remaining time in seconds: [18/17351]
# ---------- Epoch 72 ------------
#
# Factor: 2. MSE train/test: [0.615211, 0.683819] MSE on plane waves: 0.260657
# Factor: 4. MSE train/test: [0.624075, 0.642552] MSE on plane waves: 0.436691
# Factor: 6. MSE train/test: [0.709900, 0.684107] MSE on plane waves: 0.540180
# Factor: 10. MSE train/test: [0.845442, 0.801725] MSE on plane waves: 0.532982
# Factor: 20. MSE train/test: [0.988331, 1.010798] MSE on plane waves: 0.364040
# Epoch time/Remaining time in seconds: [18/17328]
# ---------- Epoch 73 ------------
#
# Factor: 2. MSE train/test: [0.797012, 0.745929] MSE on plane waves: 0.266392
# Factor: 4. MSE train/test: [0.700481, 0.677304] MSE on plane waves: 0.608213
# Factor: 6. MSE train/test: [0.745597, 0.721666] MSE on plane waves: 0.506682
# Factor: 10. MSE train/test: [0.829668, 0.852798] MSE on plane waves: 0.390977
# Factor: 20. MSE train/test: [0.978239, 0.997299] MSE on plane waves: 0.509648
# Epoch time/Remaining time in seconds: [18/17306]
# ---------- Epoch 74 ------------
#
# Factor: 2. MSE train/test: [0.756030, 0.756279] MSE on plane waves: 0.173559
# Factor: 4. MSE train/test: [0.707762, 0.704716] MSE on plane waves: 0.303090
# Factor: 6. MSE train/test: [0.747135, 0.759260] MSE on plane waves: 0.544458
# Factor: 10. MSE train/test: [0.813079, 0.860146] MSE on plane waves: 0.586915
# Factor: 20. MSE train/test: [0.985003, 0.987550] MSE on plane waves: 0.617801
# Epoch time/Remaining time in seconds: [18/17285]
# ---------- Epoch 75 ------------
#
# Factor: 2. MSE train/test: [0.794560, 0.700087] MSE on plane waves: 0.377407
# Factor: 4. MSE train/test: [0.695059, 0.667491] MSE on plane waves: 0.314812
# Factor: 6. MSE train/test: [0.744931, 0.727602] MSE on plane waves: 0.547280
# Factor: 10. MSE train/test: [0.825827, 0.847404] MSE on plane waves: 0.325467
# Factor: 20. MSE train/test: [0.990757, 0.948848] MSE on plane waves: 0.560828
# Epoch time/Remaining time in seconds: [18/17265]
# ---------- Epoch 76 ------------
#
# Factor: 2. MSE train/test: [0.788738, 0.759915] MSE on plane waves: 0.342434
# Factor: 4. MSE train/test: [0.704383, 0.728389] MSE on plane waves: 0.275945
# Factor: 6. MSE train/test: [0.717529, 0.744488] MSE on plane waves: 0.488754
# Factor: 10. MSE train/test: [0.795276, 0.819907] MSE on plane waves: 0.366675
# Factor: 20. MSE train/test: [1.022450, 1.006861] MSE on plane waves: 0.639431
# Epoch time/Remaining time in seconds: [18/17244]
# ---------- Epoch 77 ------------
#
# Factor: 2. MSE train/test: [0.713803, 0.810008] MSE on plane waves: 0.393085
# Factor: 4. MSE train/test: [0.652781, 0.733394] MSE on plane waves: 0.463318
# Factor: 6. MSE train/test: [0.691757, 0.746801] MSE on plane waves: 0.242514
# Factor: 10. MSE train/test: [0.825872, 0.825050] MSE on plane waves: 0.323442
# Factor: 20. MSE train/test: [1.035890, 0.975470] MSE on plane waves: 0.711285
# Epoch time/Remaining time in seconds: [18/17222]
# ---------- Epoch 78 ------------
#
# Factor: 2. MSE train/test: [0.762844, 0.727343] MSE on plane waves: 0.426888
# Factor: 4. MSE train/test: [0.711653, 0.689015] MSE on plane waves: 0.517882
# Factor: 6. MSE train/test: [0.760249, 0.738218] MSE on plane waves: 0.506186
# Factor: 10. MSE train/test: [0.854848, 0.849380] MSE on plane waves: 0.122393
# Factor: 20. MSE train/test: [1.031019, 0.991896] MSE on plane waves: 0.556690
# Epoch time/Remaining time in seconds: [18/17202]
# ---------- Epoch 79 ------------
#
# Factor: 2. MSE train/test: [0.742368, 0.655932] MSE on plane waves: 0.357518
# Factor: 4. MSE train/test: [0.705979, 0.617064] MSE on plane waves: 0.496727
# Factor: 6. MSE train/test: [0.756071, 0.688620] MSE on plane waves: 0.307098
# Factor: 10. MSE train/test: [0.831057, 0.796954] MSE on plane waves: 0.338709
# Factor: 20. MSE train/test: [1.022398, 1.026759] MSE on plane waves: 0.637621
# Epoch time/Remaining time in seconds: [18/17183]
# ---------- Epoch 80 ------------
#
# Factor: 2. MSE train/test: [0.772096, 0.746017] MSE on plane waves: 0.268610
# Factor: 4. MSE train/test: [0.698763, 0.690298] MSE on plane waves: 0.359284
# Factor: 6. MSE train/test: [0.717844, 0.698174] MSE on plane waves: 0.532488
# Factor: 10. MSE train/test: [0.812802, 0.815026] MSE on plane waves: 0.621149
# Factor: 20. MSE train/test: [0.978913, 1.014455] MSE on plane waves: 0.718157
# Epoch time/Remaining time in seconds: [18/17161]
# ---------- Epoch 81 ------------
#
# Factor: 2. MSE train/test: [0.803659, 0.784126] MSE on plane waves: 0.432992
# Factor: 4. MSE train/test: [0.692038, 0.702767] MSE on plane waves: 0.155378
# Factor: 6. MSE train/test: [0.702547, 0.725742] MSE on plane waves: 0.427159
# Factor: 10. MSE train/test: [0.783547, 0.799242] MSE on plane waves: 0.487674
# Factor: 20. MSE train/test: [1.013772, 0.976333] MSE on plane waves: 0.523018
# Epoch time/Remaining time in seconds: [19/17146]
# ---------- Epoch 82 ------------
#
# Factor: 2. MSE train/test: [0.744041, 0.800573] MSE on plane waves: 0.377759
# Factor: 4. MSE train/test: [0.712338, 0.717874] MSE on plane waves: 0.130184
# Factor: 6. MSE train/test: [0.745442, 0.727510] MSE on plane waves: 0.634617
# Factor: 10. MSE train/test: [0.811364, 0.837197] MSE on plane waves: 0.560451
# Factor: 20. MSE train/test: [1.001343, 1.007551] MSE on plane waves: 0.519027
# Epoch time/Remaining time in seconds: [18/17123]
# ---------- Epoch 83 ------------
#
# Factor: 2. MSE train/test: [0.664036, 0.825626] MSE on plane waves: 0.394782
# Factor: 4. MSE train/test: [0.609219, 0.729287] MSE on plane waves: 0.163502
# Factor: 6. MSE train/test: [0.690043, 0.733853] MSE on plane waves: 0.210337
# Factor: 10. MSE train/test: [0.779443, 0.810149] MSE on plane waves: 0.441670
# Factor: 20. MSE train/test: [1.018350, 0.978837] MSE on plane waves: 0.486222
# Epoch time/Remaining time in seconds: [18/17102]
# ---------- Epoch 84 ------------
#
# Factor: 2. MSE train/test: [0.729161, 0.766241] MSE on plane waves: 0.178647
# Factor: 4. MSE train/test: [0.671793, 0.685923] MSE on plane waves: 0.543805
# Factor: 6. MSE train/test: [0.698060, 0.694649] MSE on plane waves: 0.523444
# Factor: 10. MSE train/test: [0.804542, 0.802364] MSE on plane waves: 0.376045
# Factor: 20. MSE train/test: [0.990710, 0.991905] MSE on plane waves: 0.331976
# Epoch time/Remaining time in seconds: [18/17078]
# ---------- Epoch 85 ------------
#
# Factor: 2. MSE train/test: [0.648367, 0.785521] MSE on plane waves: 0.555807
# Factor: 4. MSE train/test: [0.620692, 0.685211] MSE on plane waves: 0.464477
# Factor: 6. MSE train/test: [0.677921, 0.698764] MSE on plane waves: 0.503923
# Factor: 10. MSE train/test: [0.787438, 0.788771] MSE on plane waves: 0.252553
# Factor: 20. MSE train/test: [0.974827, 1.017441] MSE on plane waves: 0.550924
# Epoch time/Remaining time in seconds: [18/17057]
# ---------- Epoch 86 ------------
#
# Factor: 2. MSE train/test: [0.744877, 0.808353] MSE on plane waves: 0.402542
# Factor: 4. MSE train/test: [0.703082, 0.704039] MSE on plane waves: 0.535081
# Factor: 6. MSE train/test: [0.730564, 0.747775] MSE on plane waves: 0.380854
# Factor: 10. MSE train/test: [0.823368, 0.823958] MSE on plane waves: 0.496113
# Factor: 20. MSE train/test: [1.042557, 0.977201] MSE on plane waves: 0.477474
# Epoch time/Remaining time in seconds: [18/17041]
# ---------- Epoch 87 ------------
#
# Factor: 2. MSE train/test: [0.810944, 0.807138] MSE on plane waves: 0.527378
# Factor: 4. MSE train/test: [0.720051, 0.716528] MSE on plane waves: 0.604780
# Factor: 6. MSE train/test: [0.728833, 0.712099] MSE on plane waves: 0.465053
# Factor: 10. MSE train/test: [0.818369, 0.812883] MSE on plane waves: 0.123436
# Factor: 20. MSE train/test: [0.966880, 0.995416] MSE on plane waves: 0.612892
# Epoch time/Remaining time in seconds: [19/17028]
# ---------- Epoch 88 ------------
#
# Factor: 2. MSE train/test: [0.769134, 0.835759] MSE on plane waves: 0.267303
# Factor: 4. MSE train/test: [0.692656, 0.744219] MSE on plane waves: 0.151534
# Factor: 6. MSE train/test: [0.716627, 0.758564] MSE on plane waves: 0.559784
# Factor: 10. MSE train/test: [0.796377, 0.818041] MSE on plane waves: 0.404417
# Factor: 20. MSE train/test: [1.011037, 0.952087] MSE on plane waves: 0.473085
# Epoch time/Remaining time in seconds: [18/17004]
# ---------- Epoch 89 ------------
#
# Factor: 2. MSE train/test: [0.752750, 0.804954] MSE on plane waves: 0.309159
# Factor: 4. MSE train/test: [0.713412, 0.740788] MSE on plane waves: 0.399934
# Factor: 6. MSE train/test: [0.728694, 0.767704] MSE on plane waves: 0.381309
# Factor: 10. MSE train/test: [0.846892, 0.835672] MSE on plane waves: 0.375739
# Factor: 20. MSE train/test: [0.998585, 1.006947] MSE on plane waves: 0.334945
# Epoch time/Remaining time in seconds: [18/16983]
# ---------- Epoch 90 ------------
#
# Factor: 2. MSE train/test: [0.640806, 0.842980] MSE on plane waves: 0.317338
# Factor: 4. MSE train/test: [0.643999, 0.760981] MSE on plane waves: 0.421277
# Factor: 6. MSE train/test: [0.734123, 0.761517] MSE on plane waves: 0.553760
# Factor: 10. MSE train/test: [0.846235, 0.826575] MSE on plane waves: 0.503334
# Factor: 20. MSE train/test: [0.978348, 0.914921] MSE on plane waves: 0.574142
# Epoch time/Remaining time in seconds: [18/16961]
# ---------- Epoch 91 ------------
#
# Factor: 2. MSE train/test: [0.757306, 0.813991] MSE on plane waves: 0.609340
# Factor: 4. MSE train/test: [0.688648, 0.707887] MSE on plane waves: 0.474667
# Factor: 6. MSE train/test: [0.740810, 0.762388] MSE on plane waves: 0.243154
# Factor: 10. MSE train/test: [0.832087, 0.835948] MSE on plane waves: 0.593081
# Factor: 20. MSE train/test: [0.976514, 1.005900] MSE on plane waves: 0.418260
# Epoch time/Remaining time in seconds: [19/16948]
# ---------- Epoch 92 ------------
#
# Factor: 2. MSE train/test: [0.828629, 0.728447] MSE on plane waves: 0.208301
# Factor: 4. MSE train/test: [0.768074, 0.668237] MSE on plane waves: 0.481396
# Factor: 6. MSE train/test: [0.781854, 0.715663] MSE on plane waves: 0.372047
# Factor: 10. MSE train/test: [0.856880, 0.841317] MSE on plane waves: 0.306667
# Factor: 20. MSE train/test: [0.996876, 0.956206] MSE on plane waves: 0.520028
# Epoch time/Remaining time in seconds: [18/16931]
# ---------- Epoch 93 ------------
#
# Factor: 2. MSE train/test: [0.823774, 0.590003] MSE on plane waves: 0.173861
# Factor: 4. MSE train/test: [0.745646, 0.570026] MSE on plane waves: 0.095994
# Factor: 6. MSE train/test: [0.737791, 0.661777] MSE on plane waves: 0.331489
# Factor: 10. MSE train/test: [0.828146, 0.810723] MSE on plane waves: 0.288447
# Factor: 20. MSE train/test: [1.030915, 1.042703] MSE on plane waves: 0.431424
# Epoch time/Remaining time in seconds: [18/16914]
# ---------- Epoch 94 ------------
#
# Factor: 2. MSE train/test: [0.787323, 0.775417] MSE on plane waves: 0.471012
# Factor: 4. MSE train/test: [0.743055, 0.741124] MSE on plane waves: 0.324736
# Factor: 6. MSE train/test: [0.763237, 0.749271] MSE on plane waves: 0.477712
# Factor: 10. MSE train/test: [0.823656, 0.815324] MSE on plane waves: 0.524909
# Factor: 20. MSE train/test: [0.960744, 0.999695] MSE on plane waves: 0.193805
# Epoch time/Remaining time in seconds: [18/16895]
# ---------- Epoch 95 ------------
#
# Factor: 2. MSE train/test: [0.768748, 0.766285] MSE on plane waves: 0.519590
# Factor: 4. MSE train/test: [0.708995, 0.722265] MSE on plane waves: 0.609415
# Factor: 6. MSE train/test: [0.750156, 0.751285] MSE on plane waves: 0.429744
# Factor: 10. MSE train/test: [0.843103, 0.831446] MSE on plane waves: 0.623436
# Factor: 20. MSE train/test: [0.979904, 0.988141] MSE on plane waves: 0.573968
# Epoch time/Remaining time in seconds: [18/16878]
# ---------- Epoch 96 ------------
#
# Factor: 2. MSE train/test: [0.726609, 0.787231] MSE on plane waves: 0.369205
# Factor: 4. MSE train/test: [0.765140, 0.722373] MSE on plane waves: 0.430388
# Factor: 6. MSE train/test: [0.769248, 0.752976] MSE on plane waves: 0.236196
# Factor: 10. MSE train/test: [0.818796, 0.817541] MSE on plane waves: 0.421607
# Factor: 20. MSE train/test: [1.031149, 0.996185] MSE on plane waves: 0.358423
# Epoch time/Remaining time in seconds: [19/16866]
# ---------- Epoch 97 ------------
#
# Factor: 2. MSE train/test: [0.741862, 0.788388] MSE on plane waves: 0.518463
# Factor: 4. MSE train/test: [0.700780, 0.714473] MSE on plane waves: 0.390247
# Factor: 6. MSE train/test: [0.742511, 0.722826] MSE on plane waves: 0.401534
# Factor: 10. MSE train/test: [0.860355, 0.797891] MSE on plane waves: 0.696262
# Factor: 20. MSE train/test: [1.041297, 1.051435] MSE on plane waves: 0.559777
# Epoch time/Remaining time in seconds: [18/16844]
# ---------- Epoch 98 ------------
#
# Factor: 2. MSE train/test: [0.859373, 0.803074] MSE on plane waves: 0.504602
# Factor: 4. MSE train/test: [0.748816, 0.723408] MSE on plane waves: 0.313778
# Factor: 6. MSE train/test: [0.790975, 0.744390] MSE on plane waves: 0.511607
# Factor: 10. MSE train/test: [0.854967, 0.837711] MSE on plane waves: 0.773956
# Factor: 20. MSE train/test: [0.965542, 1.015739] MSE on plane waves: 0.395773
# Epoch time/Remaining time in seconds: [19/16830]
# ---------- Epoch 99 ------------
#
# Factor: 2. MSE train/test: [0.805115, 0.664363] MSE on plane waves: 0.358834
# Factor: 4. MSE train/test: [0.736168, 0.621797] MSE on plane waves: 0.444979
# Factor: 6. MSE train/test: [0.788986, 0.696390] MSE on plane waves: 0.601647
# Factor: 10. MSE train/test: [0.821055, 0.843600] MSE on plane waves: 0.248822
# Factor: 20. MSE train/test: [0.978625, 0.996240] MSE on plane waves: 0.770238
# Epoch time/Remaining time in seconds: [19/16815]
# ---------- Epoch 100 ------------
#
# Factor: 2. MSE train/test: [0.742999, 0.747897] MSE on plane waves: 0.428362
# Factor: 4. MSE train/test: [0.707659, 0.737825] MSE on plane waves: 0.458983
# Factor: 6. MSE train/test: [0.762005, 0.753125] MSE on plane waves: 0.390439
# Factor: 10. MSE train/test: [0.822865, 0.843662] MSE on plane waves: 0.176071
# Factor: 20. MSE train/test: [1.002583, 1.053994] MSE on plane waves: 0.530799
# Epoch time/Remaining time in seconds: [18/16796]
# ---------- Epoch 101 ------------
#
# Factor: 2. MSE train/test: [0.762990, 0.770404] MSE on plane waves: 0.232376
# Factor: 4. MSE train/test: [0.702502, 0.714539] MSE on plane waves: 0.550976
# Factor: 6. MSE train/test: [0.740589, 0.751986] MSE on plane waves: 0.233150
# Factor: 10. MSE train/test: [0.806354, 0.771951] MSE on plane waves: 0.470092
# Factor: 20. MSE train/test: [0.973030, 0.963158] MSE on plane waves: 0.527926
# Epoch time/Remaining time in seconds: [18/16775]
# ---------- Epoch 102 ------------
#
# ...
# Epoch time/Remaining time in seconds: [17/602]
# ---------- Epoch 966 ------------
#
# Factor: 2. MSE train/test: [0.764191, 0.773244] MSE on plane waves: 0.426258
# Factor: 4. MSE train/test: [0.677446, 0.689733] MSE on plane waves: 0.392358
# Factor: 6. MSE train/test: [0.698812, 0.726784] MSE on plane waves: 0.336164
# Factor: 10. MSE train/test: [0.810194, 0.843564] MSE on plane waves: 0.590159
# Factor: 20. MSE train/test: [0.989930, 1.008878] MSE on plane waves: 0.426712
# Epoch time/Remaining time in seconds: [17/585]
# ---------- Epoch 967 ------------
#
# Factor: 2. MSE train/test: [0.674286, 0.737434] MSE on plane waves: 0.425918
# Factor: 4. MSE train/test: [0.605808, 0.684770] MSE on plane waves: 0.403294
# Factor: 6. MSE train/test: [0.668617, 0.712664] MSE on plane waves: 0.401912
# Factor: 10. MSE train/test: [0.819790, 0.824239] MSE on plane waves: 0.545624
# Factor: 20. MSE train/test: [1.021018, 0.990438] MSE on plane waves: 0.215274
# Epoch time/Remaining time in seconds: [17/567]
# ---------- Epoch 968 ------------
#
# Factor: 2. MSE train/test: [0.656980, 0.705848] MSE on plane waves: 0.390020
# Factor: 4. MSE train/test: [0.615108, 0.662173] MSE on plane waves: 0.502999
# Factor: 6. MSE train/test: [0.672810, 0.702361] MSE on plane waves: 0.419929
# Factor: 10. MSE train/test: [0.824475, 0.806419] MSE on plane waves: 0.539760
# Factor: 20. MSE train/test: [1.003645, 1.016423] MSE on plane waves: 0.602006
# Epoch time/Remaining time in seconds: [17/549]
# ---------- Epoch 969 ------------
#
# Factor: 2. MSE train/test: [0.746697, 0.752506] MSE on plane waves: 0.413938
# Factor: 4. MSE train/test: [0.678953, 0.686790] MSE on plane waves: 0.163955
# Factor: 6. MSE train/test: [0.725202, 0.745568] MSE on plane waves: 0.656812
# Factor: 10. MSE train/test: [0.829777, 0.830134] MSE on plane waves: 0.458156
# Factor: 20. MSE train/test: [0.985132, 1.013927] MSE on plane waves: 0.398487
# Epoch time/Remaining time in seconds: [17/531]
# ---------- Epoch 970 ------------
#
# Factor: 2. MSE train/test: [0.614213, 0.757362] MSE on plane waves: 0.309022
# Factor: 4. MSE train/test: [0.611530, 0.704146] MSE on plane waves: 0.464424
# Factor: 6. MSE train/test: [0.681583, 0.727352] MSE on plane waves: 0.240157
# Factor: 10. MSE train/test: [0.833914, 0.838987] MSE on plane waves: 0.234019
# Factor: 20. MSE train/test: [0.978677, 1.006750] MSE on plane waves: 0.504162
# Epoch time/Remaining time in seconds: [17/514]
# ---------- Epoch 971 ------------
#
# Factor: 2. MSE train/test: [0.690679, 0.743400] MSE on plane waves: 0.391309
# Factor: 4. MSE train/test: [0.641358, 0.663398] MSE on plane waves: 0.542389
# Factor: 6. MSE train/test: [0.681457, 0.714056] MSE on plane waves: 0.598309
# Factor: 10. MSE train/test: [0.836200, 0.840089] MSE on plane waves: 0.468885
# Factor: 20. MSE train/test: [1.012440, 1.033066] MSE on plane waves: 0.366132
# Epoch time/Remaining time in seconds: [17/496]
# ---------- Epoch 972 ------------
#
# Factor: 2. MSE train/test: [0.725407, 0.742412] MSE on plane waves: 0.371116
# Factor: 4. MSE train/test: [0.694144, 0.683701] MSE on plane waves: 0.189356
# Factor: 6. MSE train/test: [0.734731, 0.728382] MSE on plane waves: 0.368459
# Factor: 10. MSE train/test: [0.811558, 0.833271] MSE on plane waves: 0.348077
# Factor: 20. MSE train/test: [0.999809, 1.002725] MSE on plane waves: 0.078445
# Epoch time/Remaining time in seconds: [17/478]
# ---------- Epoch 973 ------------
#
# Factor: 2. MSE train/test: [0.757262, 0.744673] MSE on plane waves: 0.223920
# Factor: 4. MSE train/test: [0.679194, 0.711214] MSE on plane waves: 0.390280
# Factor: 6. MSE train/test: [0.713087, 0.733195] MSE on plane waves: 0.344628
# Factor: 10. MSE train/test: [0.833897, 0.838826] MSE on plane waves: 0.678774
# Factor: 20. MSE train/test: [1.016092, 1.014004] MSE on plane waves: 0.391836
# Epoch time/Remaining time in seconds: [17/460]
# ---------- Epoch 974 ------------
#
# Factor: 2. MSE train/test: [0.754831, 0.734557] MSE on plane waves: 0.355894
# Factor: 4. MSE train/test: [0.689738, 0.670215] MSE on plane waves: 0.143544
# Factor: 6. MSE train/test: [0.724360, 0.709028] MSE on plane waves: 0.650740
# Factor: 10. MSE train/test: [0.855322, 0.853967] MSE on plane waves: 0.480263
# Factor: 20. MSE train/test: [1.004897, 1.009021] MSE on plane waves: 0.540695
# Epoch time/Remaining time in seconds: [17/443]
# ---------- Epoch 975 ------------
#
# Factor: 2. MSE train/test: [0.716002, 0.634942] MSE on plane waves: 0.310044
# Factor: 4. MSE train/test: [0.685805, 0.585603] MSE on plane waves: 0.435068
# Factor: 6. MSE train/test: [0.705572, 0.659581] MSE on plane waves: 0.420337
# Factor: 10. MSE train/test: [0.830256, 0.828209] MSE on plane waves: 0.531564
# Factor: 20. MSE train/test: [0.966860, 1.001227] MSE on plane waves: 0.483218
# Epoch time/Remaining time in seconds: [17/425]
# ---------- Epoch 976 ------------
#
# Factor: 2. MSE train/test: [0.735262, 0.749155] MSE on plane waves: 0.322486
# Factor: 4. MSE train/test: [0.697245, 0.701052] MSE on plane waves: 0.458777
# Factor: 6. MSE train/test: [0.740682, 0.714718] MSE on plane waves: 0.491525
# Factor: 10. MSE train/test: [0.831951, 0.817715] MSE on plane waves: 0.156181
# Factor: 20. MSE train/test: [1.008829, 1.011200] MSE on plane waves: 0.586467
# Epoch time/Remaining time in seconds: [17/407]
# ---------- Epoch 977 ------------
#
# Factor: 2. MSE train/test: [0.636907, 0.622202] MSE on plane waves: 0.386044
# Factor: 4. MSE train/test: [0.620964, 0.575570] MSE on plane waves: 0.264779
# Factor: 6. MSE train/test: [0.685269, 0.677759] MSE on plane waves: 0.288699
# Factor: 10. MSE train/test: [0.830652, 0.817698] MSE on plane waves: 0.195323
# Factor: 20. MSE train/test: [0.992140, 1.021306] MSE on plane waves: 0.695301
# Epoch time/Remaining time in seconds: [19/390]
# ---------- Epoch 978 ------------
#
# Factor: 2. MSE train/test: [0.681042, 0.717820] MSE on plane waves: 0.452731
# Factor: 4. MSE train/test: [0.655461, 0.654722] MSE on plane waves: 0.164786
# Factor: 6. MSE train/test: [0.710130, 0.713208] MSE on plane waves: 0.436631
# Factor: 10. MSE train/test: [0.853105, 0.814993] MSE on plane waves: 0.308637
# Factor: 20. MSE train/test: [1.007149, 1.025232] MSE on plane waves: 0.212867
# Epoch time/Remaining time in seconds: [17/372]
# ---------- Epoch 979 ------------
#
# Factor: 2. MSE train/test: [0.655404, 0.772940] MSE on plane waves: 0.482387
# Factor: 4. MSE train/test: [0.605651, 0.687523] MSE on plane waves: 0.494935
# Factor: 6. MSE train/test: [0.657227, 0.727938] MSE on plane waves: 0.613207
# Factor: 10. MSE train/test: [0.814045, 0.815945] MSE on plane waves: 0.519624
# Factor: 20. MSE train/test: [1.001405, 0.995911] MSE on plane waves: 0.315179
# Epoch time/Remaining time in seconds: [17/354]
# ---------- Epoch 980 ------------
#
# Factor: 2. MSE train/test: [0.697481, 0.781101] MSE on plane waves: 0.167368
# Factor: 4. MSE train/test: [0.624553, 0.708722] MSE on plane waves: 0.437676
# Factor: 6. MSE train/test: [0.678713, 0.730182] MSE on plane waves: 0.421405
# Factor: 10. MSE train/test: [0.807444, 0.827820] MSE on plane waves: 0.466087
# Factor: 20. MSE train/test: [1.020172, 1.012788] MSE on plane waves: 0.392019
# Epoch time/Remaining time in seconds: [17/336]
# ---------- Epoch 981 ------------
#
# Factor: 2. MSE train/test: [0.657846, 0.732018] MSE on plane waves: 0.351596
# Factor: 4. MSE train/test: [0.648332, 0.712417] MSE on plane waves: 0.327724
# Factor: 6. MSE train/test: [0.733960, 0.755071] MSE on plane waves: 0.311999
# Factor: 10. MSE train/test: [0.848952, 0.843882] MSE on plane waves: 0.500717
# Factor: 20. MSE train/test: [0.991053, 0.961560] MSE on plane waves: 0.334455
# Epoch time/Remaining time in seconds: [17/319]
# ---------- Epoch 982 ------------
#
# Factor: 2. MSE train/test: [0.734836, 0.763767] MSE on plane waves: 0.112807
# Factor: 4. MSE train/test: [0.701456, 0.680562] MSE on plane waves: 0.388687
# Factor: 6. MSE train/test: [0.760201, 0.719833] MSE on plane waves: 0.222546
# Factor: 10. MSE train/test: [0.816425, 0.842329] MSE on plane waves: 0.405884
# Factor: 20. MSE train/test: [1.013532, 0.951024] MSE on plane waves: 0.476310
# Epoch time/Remaining time in seconds: [18/301]
# ---------- Epoch 983 ------------
#
# Factor: 2. MSE train/test: [0.643700, 0.800395] MSE on plane waves: 0.141837
# Factor: 4. MSE train/test: [0.621457, 0.698866] MSE on plane waves: 0.446637
# Factor: 6. MSE train/test: [0.678467, 0.712167] MSE on plane waves: 0.432776
# Factor: 10. MSE train/test: [0.825451, 0.846232] MSE on plane waves: 0.193788
# Factor: 20. MSE train/test: [0.983651, 0.998815] MSE on plane waves: 0.454104
# Epoch time/Remaining time in seconds: [17/283]
# ---------- Epoch 984 ------------
#
# Factor: 2. MSE train/test: [0.660706, 0.771507] MSE on plane waves: 0.416396
# Factor: 4. MSE train/test: [0.598508, 0.689211] MSE on plane waves: 0.477867
# Factor: 6. MSE train/test: [0.677543, 0.714794] MSE on plane waves: 0.444565
# Factor: 10. MSE train/test: [0.815079, 0.847025] MSE on plane waves: 0.299866
# Factor: 20. MSE train/test: [0.965418, 1.016913] MSE on plane waves: 0.205757
# Epoch time/Remaining time in seconds: [17/265]
# ---------- Epoch 985 ------------
#
# Factor: 2. MSE train/test: [0.740548, 0.702065] MSE on plane waves: 0.378589
# Factor: 4. MSE train/test: [0.686306, 0.678888] MSE on plane waves: 0.455138
# Factor: 6. MSE train/test: [0.716049, 0.763449] MSE on plane waves: 0.159943
# Factor: 10. MSE train/test: [0.793280, 0.850131] MSE on plane waves: 0.493557
# Factor: 20. MSE train/test: [0.979866, 0.997473] MSE on plane waves: 0.452763
# Epoch time/Remaining time in seconds: [16/248]
# ---------- Epoch 986 ------------
#
# Factor: 2. MSE train/test: [0.759577, 0.737137] MSE on plane waves: 0.389166
# Factor: 4. MSE train/test: [0.672754, 0.659942] MSE on plane waves: 0.571604
# Factor: 6. MSE train/test: [0.726020, 0.718030] MSE on plane waves: 0.694173
# Factor: 10. MSE train/test: [0.825363, 0.850943] MSE on plane waves: 0.623458
# Factor: 20. MSE train/test: [1.010537, 1.039484] MSE on plane waves: 0.565074
# Epoch time/Remaining time in seconds: [16/230]
# ---------- Epoch 987 ------------
#
# Factor: 2. MSE train/test: [0.730571, 0.764829] MSE on plane waves: 0.233539
# Factor: 4. MSE train/test: [0.712580, 0.673906] MSE on plane waves: 0.331739
# Factor: 6. MSE train/test: [0.742378, 0.712327] MSE on plane waves: 0.283988
# Factor: 10. MSE train/test: [0.833607, 0.827454] MSE on plane waves: 0.465818
# Factor: 20. MSE train/test: [1.027135, 0.991652] MSE on plane waves: 0.481320
# Epoch time/Remaining time in seconds: [16/212]
# ---------- Epoch 988 ------------
#
# Factor: 2. MSE train/test: [0.733022, 0.787724] MSE on plane waves: 0.347271
# Factor: 4. MSE train/test: [0.681805, 0.691486] MSE on plane waves: 0.440240
# Factor: 6. MSE train/test: [0.738243, 0.707605] MSE on plane waves: 0.427156
# Factor: 10. MSE train/test: [0.816919, 0.824408] MSE on plane waves: 0.340691
# Factor: 20. MSE train/test: [1.000716, 1.009101] MSE on plane waves: 0.549218
# Epoch time/Remaining time in seconds: [16/194]
# ---------- Epoch 989 ------------
#
# Factor: 2. MSE train/test: [0.748910, 0.634257] MSE on plane waves: 0.429885
# Factor: 4. MSE train/test: [0.685967, 0.592123] MSE on plane waves: 0.519331
# Factor: 6. MSE train/test: [0.736993, 0.694044] MSE on plane waves: 0.498930
# Factor: 10. MSE train/test: [0.834113, 0.822849] MSE on plane waves: 0.225655
# Factor: 20. MSE train/test: [0.991165, 0.989947] MSE on plane waves: 0.343546
# Epoch time/Remaining time in seconds: [17/177]
# ---------- Epoch 990 ------------
#
# Factor: 2. MSE train/test: [0.780841, 0.766089] MSE on plane waves: 0.438930
# Factor: 4. MSE train/test: [0.696545, 0.702468] MSE on plane waves: 0.357367
# Factor: 6. MSE train/test: [0.737379, 0.698043] MSE on plane waves: 0.414583
# Factor: 10. MSE train/test: [0.859214, 0.793028] MSE on plane waves: 0.459672
# Factor: 20. MSE train/test: [1.005425, 1.001313] MSE on plane waves: 0.309392
# Epoch time/Remaining time in seconds: [18/159]
# ---------- Epoch 991 ------------
#
# Factor: 2. MSE train/test: [0.749017, 0.702497] MSE on plane waves: 0.264923
# Factor: 4. MSE train/test: [0.698995, 0.639818] MSE on plane waves: 0.161484
# Factor: 6. MSE train/test: [0.718620, 0.681607] MSE on plane waves: 0.262612
# Factor: 10. MSE train/test: [0.826465, 0.793173] MSE on plane waves: 0.324437
# Factor: 20. MSE train/test: [1.015929, 0.994319] MSE on plane waves: 0.089211
# Epoch time/Remaining time in seconds: [18/141]
# ---------- Epoch 992 ------------
#
# Factor: 2. MSE train/test: [0.735916, 0.734027] MSE on plane waves: 0.256639
# Factor: 4. MSE train/test: [0.671520, 0.654741] MSE on plane waves: 0.193980
# Factor: 6. MSE train/test: [0.713373, 0.686751] MSE on plane waves: 0.408800
# Factor: 10. MSE train/test: [0.804285, 0.813301] MSE on plane waves: 0.383055
# Factor: 20. MSE train/test: [1.021978, 1.006710] MSE on plane waves: 0.475915
# Epoch time/Remaining time in seconds: [18/124]
# ---------- Epoch 993 ------------
#
# Factor: 2. MSE train/test: [0.727785, 0.778731] MSE on plane waves: 0.357097
# Factor: 4. MSE train/test: [0.678955, 0.686666] MSE on plane waves: 0.499932
# Factor: 6. MSE train/test: [0.695548, 0.712172] MSE on plane waves: 0.292513
# Factor: 10. MSE train/test: [0.803862, 0.780698] MSE on plane waves: 0.545811
# Factor: 20. MSE train/test: [0.997756, 1.076756] MSE on plane waves: 0.358554
# Epoch time/Remaining time in seconds: [18/106]
# ---------- Epoch 994 ------------
#
# Factor: 2. MSE train/test: [0.694921, 0.780478] MSE on plane waves: 0.463468
# Factor: 4. MSE train/test: [0.627628, 0.707654] MSE on plane waves: 0.444663
# Factor: 6. MSE train/test: [0.688498, 0.715572] MSE on plane waves: 0.268659
# Factor: 10. MSE train/test: [0.807943, 0.817901] MSE on plane waves: 0.415281
# Factor: 20. MSE train/test: [1.026919, 1.007507] MSE on plane waves: 0.402540
# Epoch time/Remaining time in seconds: [18/88]
# ---------- Epoch 995 ------------
#
# Factor: 2. MSE train/test: [0.730749, 0.584183] MSE on plane waves: 0.073747
# Factor: 4. MSE train/test: [0.706625, 0.585569] MSE on plane waves: 0.453551
# Factor: 6. MSE train/test: [0.737771, 0.652678] MSE on plane waves: 0.213619
# Factor: 10. MSE train/test: [0.791334, 0.757089] MSE on plane waves: 0.372033
# Factor: 20. MSE train/test: [0.973264, 0.985998] MSE on plane waves: 0.531630
# Epoch time/Remaining time in seconds: [18/70]
# ---------- Epoch 996 ------------
#
# Factor: 2. MSE train/test: [0.685801, 0.778618] MSE on plane waves: 0.218564
# Factor: 4. MSE train/test: [0.639200, 0.707939] MSE on plane waves: 0.282544
# Factor: 6. MSE train/test: [0.693538, 0.744697] MSE on plane waves: 0.073579
# Factor: 10. MSE train/test: [0.818062, 0.832123] MSE on plane waves: 0.376286
# Factor: 20. MSE train/test: [0.981508, 1.004277] MSE on plane waves: 0.336210
# Epoch time/Remaining time in seconds: [18/53]
# ---------- Epoch 997 ------------
#
# Factor: 2. MSE train/test: [0.750227, 0.767848] MSE on plane waves: 0.341569
# Factor: 4. MSE train/test: [0.735049, 0.687799] MSE on plane waves: 0.396289
# Factor: 6. MSE train/test: [0.732926, 0.741734] MSE on plane waves: 0.414763
# Factor: 10. MSE train/test: [0.821079, 0.843907] MSE on plane waves: 0.206238
# Factor: 20. MSE train/test: [1.000290, 1.015468] MSE on plane waves: 0.151102
# Epoch time/Remaining time in seconds: [18/35]
# ---------- Epoch 998 ------------
#
# Factor: 2. MSE train/test: [0.624005, 0.735907] MSE on plane waves: 0.341427
# Factor: 4. MSE train/test: [0.576975, 0.690527] MSE on plane waves: 0.647132
# Factor: 6. MSE train/test: [0.670789, 0.720893] MSE on plane waves: 0.465299
# Factor: 10. MSE train/test: [0.829099, 0.844334] MSE on plane waves: 0.495997
# Factor: 20. MSE train/test: [1.008138, 0.997488] MSE on plane waves: 0.229533
# Epoch time/Remaining time in seconds: [18/17]
# ---------- Epoch 999 ------------
#
# Factor: 2. MSE train/test: [0.700622, 0.689413] MSE on plane waves: 0.305408
# Factor: 4. MSE train/test: [0.645226, 0.660118] MSE on plane waves: 0.316843
# Factor: 6. MSE train/test: [0.693248, 0.709634] MSE on plane waves: 0.435298
# Factor: 10. MSE train/test: [0.825797, 0.821831] MSE on plane waves: 0.506956
# Factor: 20. MSE train/test: [0.986167, 0.980828] MSE on plane waves: 0.392647
# Epoch time/Remaining time in seconds: [17/0]

# %% [markdown]
# # Check dissipation pattern for trained ANN

# %%
# ann_Txy = import_ANN('trained_models/ANN_CM26/Txy_epoch_2000.nc')
# ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26/Txx_Tyy_epoch_2000.nc')
ann_Txy = import_ANN('trained_models/ANN_CM26_grid_harmonic_ver3/Txy_epoch_1000.nc')
ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26_grid_harmonic_ver3/Txx_Tyy_epoch_1000.nc')

# %%
testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035))

# %%
plt.figure(figsize=(12,4))
import cmocean
for j,grid_harmonic in enumerate(['vorticity', 'divergence']):
    batch = sample_grid_harmonic(testing_dataset[20],grid_harmonic,plain=False)
    zb = batch.state.ANN(ann_Txy, ann_Txx_Tyy)
#    zb = batch.state.Smagorinsky()
    dissipation =  zb['Txx'] * zb['sh_xx'] + batch.grid.interp(zb['Txy'] * zb['sh_xy'],['X','Y'])
    plt.subplot(1,2,1+j)
    select_NA(dissipation).plot()
    plt.title(f'Dissipation on \ngrid harmonic: {grid_harmonic}')
plt.tight_layout()

# %%
plt.figure(figsize=(12,4))
batch = sample_two_thirds(testing_dataset[20])
zb = batch.state.ANN(ann_Txy, ann_Txx_Tyy)
dissipation =  zb['Txx'] * zb['sh_xx'] + batch.grid.interp(zb['Txy'] * zb['sh_xy'],['X','Y'])
plt.subplot(1,2,1)
(dissipation).plot()
plt.title(f'Dissipation on plane wave')
plt.subplot(1,2,2)
(dissipation).plot(vmax=0)
plt.title('Only negative values of dissipation')
plt.tight_layout()

# %% [markdown]
# # Check pointwise prediction

# %%
testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035))
for factor in [4,6,10]:
    data = testing_dataset[factor].data
    compare(testing_dataset[factor].state.ANN(ann_Txy, ann_Txx_Tyy)['ZB20u'], data.SGSx)
# Out:
# Correlation: 0.5617098947560792
# Relative Error: 0.9277958477431285
# R2 =  0.3141243476715062
# R2 max =  0.3154947579223323
# Optinal scaling: 0.9381684612625195
# Nans: 0
# Correlation: 0.3950713605801982
# Relative Error: 0.9642467935835142
# R2 =  0.15246623693335815
# R2 max =  0.15602715996260796
# Optinal scaling: 0.8687561180612663
# Nans: 0
# Correlation: 0.19410760291029083
# Relative Error: 1.0289280206496325
# R2 =  -0.030007217518437823
# R2 max =  0.03756493565274843
# Optinal scaling: 0.42713194365949175
# Nans: 0

# %%
testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035))
for factor in [4,6,10]:
    data = testing_dataset[factor].data
    compare(testing_dataset[factor].state.ANN(ann_Txy, ann_Txx_Tyy)['ZB20v'], data.SGSy)
# Out:
# Correlation: 0.491248601054708
# Relative Error: 0.925628311481033
# R2 =  0.2188089212151515
# R2 max =  0.2413216264595035
# Optinal scaling: 0.7660294536336756
# Nans: 0
# Correlation: 0.5010089082541015
# Relative Error: 0.9327700231245204
# R2 =  0.23544851614416806
# R2 max =  0.2509884482633099
# Optinal scaling: 0.8007513559104452
# Nans: 0
# Correlation: 0.30347127177525146
# Relative Error: 1.0064085750682215
# R2 =  0.022193260652622615
# R2 max =  0.09209088481690664
# Optinal scaling: 0.5344135426483816
# Nans: 0
