# %%
import matplotlib.pyplot as plt
from helpers.cm26 import DatasetCM26, remesh
from helpers.computational_tools import select_NA, select_Pacific, StateFunctions, compare
from helpers.ann_tools import ANN, import_ANN, minibatch, export_ANN
import torch
import torch.optim as optim
import numpy as np
import xarray as xr
from time import time
import json
# %load_ext autoreload
# %autoreload 3

# %%
def sample_grid_harmonic(dataset, key, plain=False):
    '''
    Here for simplicity the dataset is coarsegrained
    snapshot of CM26.
    '''
    data = dataset.data
    ny, nx = data.u.shape
    
    u = np.zeros((ny,nx))
    v = np.zeros((ny,nx))
    
    # assign random phase (1 or -1)
    phase = -1 if np.random.randint(2)==0 else 1
    
    if key == 'vorticity':
        sign = -1
    elif key == 'divergence':
        sign = 1
    else:
        print('Error: key is wrongly specified')
    
    for j in range(ny):
        for i in range(nx):
            if plain:
                idx = i if np.random.randint(2)==0 else j
            else:
                idx = i+j
            u[j,i] = phase *        (-1)**(idx)
            v[j,i] = phase * sign * (-1)**(idx)
            
    data['u'] = xr.DataArray(u, dims=['yh', 'xq']) * dataset.param.wet_u
    data['v'] = xr.DataArray(v, dims=['yq', 'xh']) * dataset.param.wet_v
    return DatasetCM26(data, dataset.param, dataset.grid)

# %%
def sample_plane_wave(ny, nx):
        # Sampling frequency between -pi and pi, i.e. all
        # available frequencies
        freq_x = 0
        freq_y = 0
        while np.abs(freq_x)<2/3*np.pi and np.abs(freq_y)<2/3*np.pi:
            # i.e. if wave is inside the square of 2/3*pi,
            # keep sampling
            freq_x = np.random.rand() * np.pi * 2 - np.pi
            freq_y = np.random.rand() * np.pi * 2 - np.pi

        phase_u = np.random.rand()*2*np.pi
        phase_v = np.random.rand()*2*np.pi

        i = np.ones(ny).reshape(-1,1)@np.arange(nx).reshape(1,-1)
        j = np.arange(ny).reshape(-1,1)@np.ones(nx).reshape(1,-1)

        u = np.sin(freq_x * i + freq_y * j + phase_u)
        v = np.sin(freq_x * i + freq_y * j + phase_v)

        return u, v

# %%
u, v = sample_plane_wave(30,30)
plt.subplot(1,2,1)
plt.imshow(u)
plt.subplot(1,2,2)
plt.imshow(v)

# %%
def sample_two_thirds(dataset):
    '''
    Here for simplicity the dataset is coarsegrained
    snapshot of CM26.
    '''        
    
    data = dataset.data
    ny, nx = data.u.shape
    u,v = sample_plane_wave(ny,nx)

    data['u'] = xr.DataArray(u, dims=['yh', 'xq']) * dataset.param.wet_u
    data['v'] = xr.DataArray(v, dims=['yq', 'xh']) * dataset.param.wet_v
    return DatasetCM26(data, dataset.param, dataset.grid)

# %%
ds = DatasetCM26()

# %%
training_dataset = ds.sample_epoch(time=np.random.randint(6950))

# %%
plt.figure(figsize=(12,4))
for j,grid_harmonic in enumerate(['vorticity', 'divergence']):
    batch = sample_grid_harmonic(training_dataset[20],grid_harmonic)
#    batch = sample_two_thirds(training_dataset[20])
    smag = batch.state.Smagorinsky()
    Txx = smag['Txx']
    Tyy = smag['Tyy']
    Txy = smag['Txy']
    sh_xy, sh_xx, vort_xy = batch.state.velocity_gradients()
    dissipation =  Txx * sh_xx + batch.grid.interp(Txy * sh_xy,['X','Y'])
    plt.subplot(1,2,1+j)
    dissipation.plot()
    plt.title(f'Dissipation on \ngrid harmonic: {grid_harmonic}')
plt.tight_layout()

# %%
plt.figure(figsize=(8,4))
batch = sample_two_thirds(training_dataset[20])
smag = batch.state.Smagorinsky()
Txx = smag['Txx']
Tyy = smag['Tyy']
Txy = smag['Txy']
sh_xy, sh_xx, vort_xy = batch.state.velocity_gradients()
dissipation =  Txx * sh_xx + batch.grid.interp(Txy * sh_xy,['X','Y'])
dissipation.plot()
plt.title(f'Dissipation on plane wave')
plt.tight_layout()

# %%
ann_Txy = ANN([27, 20, 1])
ann_Txx_Tyy = ANN([27, 20, 2])
log_dict = {}
# ann_Txy = import_ANN('trained_models/ANN_CM26/Txy_epoch_2000.nc')
# ann_Txx_Tyy = import_ANN('trained_models/ANN_CM26/Txx_Tyy_epoch_2000.nc')

# %%
training_dataset = ds.sample_epoch(time=np.random.randint(6950)) # Approximately 19 years for training
batch = training_dataset[20]

# %%
num_epochs=500

all_parameters = list(ann_Txy.parameters()) + list(ann_Txx_Tyy.parameters())
optimizer = optim.Adam(all_parameters, lr=1e-3)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
        milestones=[int(num_epochs/2), int(num_epochs*3/4), int(num_epochs*7/8)], gamma=0.1)  

t_s = time()

for epoch in range(num_epochs):
    for ibatch in range(5):
        t_e = time()

        optimizer.zero_grad()
        ds_regularization = sample_two_thirds(batch)
        prediction = ds_regularization.state.Apply_ANN(ann_Txy, ann_Txx_Tyy)
        ANNxx = prediction['Txx']
        ANNyy = prediction['Tyy']
        ANNxy = prediction['Txy']
        smag = ds_regularization.state.Smagorinsky()
        Txx = torch.tensor(smag['Txx'].values).type(torch.float32)
        Tyy = torch.tensor(smag['Tyy'].values).type(torch.float32)
        Txy = torch.tensor(smag['Txy'].values).type(torch.float32)

        SGS_norm = 1. / torch.sqrt((Txx**2 + Tyy**2 + Txy**2).mean())

        MSE_plane_waves = (
            (ANNxx * SGS_norm - Txx * SGS_norm)**2 + \
            (ANNyy * SGS_norm - Tyy * SGS_norm)**2 + \
            (ANNxy * SGS_norm - Txy * SGS_norm)**2
        ).mean()
        del ds_regularization.data
        del ds_regularization.param

        loss = MSE_plane_waves

        loss.backward()
        optimizer.step()

    scheduler.step()    
    print(f'Epoch: {epoch}, MSE_plane_waves: {MSE_plane_waves}')
# Out:
# Epoch: 0, MSE_plane_waves: 9.098087310791016
# Epoch: 1, MSE_plane_waves: 5.9653754234313965
# Epoch: 2, MSE_plane_waves: 6.912248611450195
# Epoch: 3, MSE_plane_waves: 3.5443975925445557
# Epoch: 4, MSE_plane_waves: 3.936497926712036
# Epoch: 5, MSE_plane_waves: 2.9889633655548096
# Epoch: 6, MSE_plane_waves: 3.174353837966919
# Epoch: 7, MSE_plane_waves: 3.0023508071899414
# Epoch: 8, MSE_plane_waves: 0.4966614544391632
# Epoch: 9, MSE_plane_waves: 1.426505446434021
# Epoch: 10, MSE_plane_waves: 4.077734470367432
# Epoch: 11, MSE_plane_waves: 1.9323662519454956
# Epoch: 12, MSE_plane_waves: 1.2500211000442505
# Epoch: 13, MSE_plane_waves: 0.7230972051620483
# Epoch: 14, MSE_plane_waves: 1.981961965560913
# Epoch: 15, MSE_plane_waves: 0.6943548321723938
# Epoch: 16, MSE_plane_waves: 0.2666451632976532
# Epoch: 17, MSE_plane_waves: 0.09740614145994186
# Epoch: 18, MSE_plane_waves: 1.6717761754989624
# Epoch: 19, MSE_plane_waves: 0.24136611819267273
# Epoch: 20, MSE_plane_waves: 0.5863447189331055
# Epoch: 21, MSE_plane_waves: 0.5913938879966736
# Epoch: 22, MSE_plane_waves: 0.5335364937782288
# Epoch: 23, MSE_plane_waves: 0.18164300918579102
# Epoch: 24, MSE_plane_waves: 0.27016541361808777
# Epoch: 25, MSE_plane_waves: 0.15384888648986816
# Epoch: 26, MSE_plane_waves: 0.9252880811691284
# Epoch: 27, MSE_plane_waves: 0.2978321313858032
# Epoch: 28, MSE_plane_waves: 0.27629005908966064
# Epoch: 29, MSE_plane_waves: 0.13611875474452972
# Epoch: 30, MSE_plane_waves: 0.07696971297264099
# Epoch: 31, MSE_plane_waves: 0.08779849112033844
# Epoch: 32, MSE_plane_waves: 0.07271832227706909
# Epoch: 33, MSE_plane_waves: 0.4750767946243286
# Epoch: 34, MSE_plane_waves: 0.04376961290836334
# Epoch: 35, MSE_plane_waves: 0.28543251752853394
# Epoch: 36, MSE_plane_waves: 0.3217349350452423
# Epoch: 37, MSE_plane_waves: 0.19699186086654663
# Epoch: 38, MSE_plane_waves: 0.06846386194229126
# Epoch: 39, MSE_plane_waves: 0.16230371594429016
# Epoch: 40, MSE_plane_waves: 0.10866403579711914
# Epoch: 41, MSE_plane_waves: 0.2502169907093048
# Epoch: 42, MSE_plane_waves: 0.3221108317375183
# Epoch: 43, MSE_plane_waves: 0.2678644061088562
# Epoch: 44, MSE_plane_waves: 0.12747959792613983
# Epoch: 45, MSE_plane_waves: 0.19591663777828217
# Epoch: 46, MSE_plane_waves: 0.14113572239875793
# Epoch: 47, MSE_plane_waves: 0.1466331034898758
# Epoch: 48, MSE_plane_waves: 0.08260343968868256
# Epoch: 49, MSE_plane_waves: 0.17641130089759827
# Epoch: 50, MSE_plane_waves: 0.11300250887870789
# Epoch: 51, MSE_plane_waves: 0.09350872039794922
# Epoch: 52, MSE_plane_waves: 0.10342247784137726
# Epoch: 53, MSE_plane_waves: 0.054856352508068085
# Epoch: 54, MSE_plane_waves: 0.18184268474578857
# Epoch: 55, MSE_plane_waves: 0.13479439914226532
# Epoch: 56, MSE_plane_waves: 0.14781081676483154
# Epoch: 57, MSE_plane_waves: 0.0633399561047554
# Epoch: 58, MSE_plane_waves: 0.051195576786994934
# Epoch: 59, MSE_plane_waves: 0.06813310831785202
# Epoch: 60, MSE_plane_waves: 0.10071142017841339
# Epoch: 61, MSE_plane_waves: 0.12355372309684753
# Epoch: 62, MSE_plane_waves: 0.045953717082738876
# Epoch: 63, MSE_plane_waves: 0.10934276133775711
# Epoch: 64, MSE_plane_waves: 0.04612794518470764
# Epoch: 65, MSE_plane_waves: 0.13819585740566254
# Epoch: 66, MSE_plane_waves: 0.044857852160930634
# Epoch: 67, MSE_plane_waves: 0.09524637460708618
# Epoch: 68, MSE_plane_waves: 0.13143323361873627
# Epoch: 69, MSE_plane_waves: 0.057712361216545105
# Epoch: 70, MSE_plane_waves: 0.08457452058792114
# Epoch: 71, MSE_plane_waves: 0.11368664354085922
# Epoch: 72, MSE_plane_waves: 0.06580673903226852
# Epoch: 73, MSE_plane_waves: 0.10261799395084381
# Epoch: 74, MSE_plane_waves: 0.12501117587089539
# Epoch: 75, MSE_plane_waves: 0.25463277101516724
# Epoch: 76, MSE_plane_waves: 0.13763220608234406
# Epoch: 77, MSE_plane_waves: 0.07836222648620605
# Epoch: 78, MSE_plane_waves: 0.08918318152427673
# Epoch: 79, MSE_plane_waves: 0.14922168850898743
# Epoch: 80, MSE_plane_waves: 0.07894457876682281
# Epoch: 81, MSE_plane_waves: 0.13721813261508942
# Epoch: 82, MSE_plane_waves: 0.10813942551612854
# Epoch: 83, MSE_plane_waves: 0.04879841208457947
# Epoch: 84, MSE_plane_waves: 0.06683046370744705
# Epoch: 85, MSE_plane_waves: 0.027874313294887543
# Epoch: 86, MSE_plane_waves: 0.13544349372386932
# Epoch: 87, MSE_plane_waves: 0.10914406925439835
# Epoch: 88, MSE_plane_waves: 0.09052101522684097
# Epoch: 89, MSE_plane_waves: 0.12380704283714294
# Epoch: 90, MSE_plane_waves: 0.09009717404842377
# Epoch: 91, MSE_plane_waves: 0.08894713222980499
# Epoch: 92, MSE_plane_waves: 0.04434684291481972
# Epoch: 93, MSE_plane_waves: 0.12049046158790588
# Epoch: 94, MSE_plane_waves: 0.05195329710841179
# Epoch: 95, MSE_plane_waves: 0.056680742651224136
# Epoch: 96, MSE_plane_waves: 0.090800940990448
# Epoch: 97, MSE_plane_waves: 0.12980803847312927
# Epoch: 98, MSE_plane_waves: 0.06491456180810928
# Epoch: 99, MSE_plane_waves: 0.06220538169145584
# Epoch: 100, MSE_plane_waves: 0.11896497756242752
# Epoch: 101, MSE_plane_waves: 0.06020795553922653
# Epoch: 102, MSE_plane_waves: 0.09264276921749115
# Epoch: 103, MSE_plane_waves: 0.09684131294488907
# Epoch: 104, MSE_plane_waves: 0.11705707013607025
# Epoch: 105, MSE_plane_waves: 0.060294680297374725
# Epoch: 106, MSE_plane_waves: 0.09194871783256531
# Epoch: 107, MSE_plane_waves: 0.05480772256851196
# Epoch: 108, MSE_plane_waves: 0.05287542939186096
# Epoch: 109, MSE_plane_waves: 0.08322744071483612
# Epoch: 110, MSE_plane_waves: 0.04514772444963455
# Epoch: 111, MSE_plane_waves: 0.0889604240655899
# Epoch: 112, MSE_plane_waves: 0.09034169465303421
# Epoch: 113, MSE_plane_waves: 0.14337332546710968
# Epoch: 114, MSE_plane_waves: 0.143354132771492
# Epoch: 115, MSE_plane_waves: 0.03453487157821655
# Epoch: 116, MSE_plane_waves: 0.04554734379053116
# Epoch: 117, MSE_plane_waves: 0.026221323758363724
# Epoch: 118, MSE_plane_waves: 0.12756577134132385
# Epoch: 119, MSE_plane_waves: 0.1099095493555069
# Epoch: 120, MSE_plane_waves: 0.052591435611248016
# Epoch: 121, MSE_plane_waves: 0.11708064377307892
# Epoch: 122, MSE_plane_waves: 0.07566073536872864
# Epoch: 123, MSE_plane_waves: 0.05302078276872635
# Epoch: 124, MSE_plane_waves: 0.1076042577624321
# Epoch: 125, MSE_plane_waves: 0.05153262987732887
# Epoch: 126, MSE_plane_waves: 0.06319965422153473
# Epoch: 127, MSE_plane_waves: 0.0593525655567646
# Epoch: 128, MSE_plane_waves: 0.06935474276542664
# Epoch: 129, MSE_plane_waves: 0.0878310352563858
# Epoch: 130, MSE_plane_waves: 0.10338461399078369
# Epoch: 131, MSE_plane_waves: 0.07252885401248932
# Epoch: 132, MSE_plane_waves: 0.07935965806245804
# Epoch: 133, MSE_plane_waves: 0.07157312333583832
# Epoch: 134, MSE_plane_waves: 0.04056106507778168
# Epoch: 135, MSE_plane_waves: 0.029992446303367615
# Epoch: 136, MSE_plane_waves: 0.044440846890211105
# Epoch: 137, MSE_plane_waves: 0.07522184401750565
# Epoch: 138, MSE_plane_waves: 0.0747661143541336
# Epoch: 139, MSE_plane_waves: 0.05881804972887039
# Epoch: 140, MSE_plane_waves: 0.07600928843021393
# Epoch: 141, MSE_plane_waves: 0.07924652099609375
# Epoch: 142, MSE_plane_waves: 0.07630699127912521
# Epoch: 143, MSE_plane_waves: 0.04625910148024559
# Epoch: 144, MSE_plane_waves: 0.03979021683335304
# Epoch: 145, MSE_plane_waves: 0.05555946007370949
# Epoch: 146, MSE_plane_waves: 0.05516591668128967
# Epoch: 147, MSE_plane_waves: 0.06724512577056885
# Epoch: 148, MSE_plane_waves: 0.04617132619023323
# Epoch: 149, MSE_plane_waves: 0.06068140268325806
# Epoch: 150, MSE_plane_waves: 0.0662383884191513
# Epoch: 151, MSE_plane_waves: 0.06724458932876587
# Epoch: 152, MSE_plane_waves: 0.0248003751039505
# Epoch: 153, MSE_plane_waves: 0.04576627165079117
# Epoch: 154, MSE_plane_waves: 0.09047182649374008
# Epoch: 155, MSE_plane_waves: 0.09170892089605331
# Epoch: 156, MSE_plane_waves: 0.02008773200213909
# Epoch: 157, MSE_plane_waves: 0.06622890383005142
# Epoch: 158, MSE_plane_waves: 0.07218524068593979
# Epoch: 159, MSE_plane_waves: 0.055526770651340485
# Epoch: 160, MSE_plane_waves: 0.02425677701830864
# Epoch: 161, MSE_plane_waves: 0.04219891503453255
# Epoch: 162, MSE_plane_waves: 0.06820067763328552
# Epoch: 163, MSE_plane_waves: 0.03922298550605774
# Epoch: 164, MSE_plane_waves: 0.08665962517261505
# Epoch: 165, MSE_plane_waves: 0.050047729164361954
# Epoch: 166, MSE_plane_waves: 0.04297150298953056
# Epoch: 167, MSE_plane_waves: 0.03054475039243698
# Epoch: 168, MSE_plane_waves: 0.04124562069773674
# Epoch: 169, MSE_plane_waves: 0.07759721577167511
# Epoch: 170, MSE_plane_waves: 0.020327938720583916
# Epoch: 171, MSE_plane_waves: 0.02118671126663685
# Epoch: 172, MSE_plane_waves: 0.04085894301533699
# Epoch: 173, MSE_plane_waves: 0.08209025859832764
# Epoch: 174, MSE_plane_waves: 0.07379207760095596
# Epoch: 175, MSE_plane_waves: 0.05956641584634781
# Epoch: 176, MSE_plane_waves: 0.05766253545880318
# Epoch: 177, MSE_plane_waves: 0.11631111800670624
# Epoch: 178, MSE_plane_waves: 0.02455797977745533
# Epoch: 179, MSE_plane_waves: 0.0649920254945755
# Epoch: 180, MSE_plane_waves: 0.04118522256612778
# Epoch: 181, MSE_plane_waves: 0.049760621041059494
# Epoch: 182, MSE_plane_waves: 0.03653152659535408
# Epoch: 183, MSE_plane_waves: 0.0822177529335022
# Epoch: 184, MSE_plane_waves: 0.09070248901844025
# Epoch: 185, MSE_plane_waves: 0.06288410723209381
# Epoch: 186, MSE_plane_waves: 0.035061392933130264
# Epoch: 187, MSE_plane_waves: 0.09171364456415176
# Epoch: 188, MSE_plane_waves: 0.0435808040201664
# Epoch: 189, MSE_plane_waves: 0.04731980711221695
# Epoch: 190, MSE_plane_waves: 0.06507674604654312
# Epoch: 191, MSE_plane_waves: 0.020812388509511948
# Epoch: 192, MSE_plane_waves: 0.051340267062187195
# Epoch: 193, MSE_plane_waves: 0.025960275903344154
# Epoch: 194, MSE_plane_waves: 0.02903285063803196
# Epoch: 195, MSE_plane_waves: 0.10316430032253265
# Epoch: 196, MSE_plane_waves: 0.05212903022766113
# Epoch: 197, MSE_plane_waves: 0.07789287716150284
# Epoch: 198, MSE_plane_waves: 0.022164050489664078
# Epoch: 199, MSE_plane_waves: 0.017475401982665062
# Epoch: 200, MSE_plane_waves: 0.05721519887447357
# Epoch: 201, MSE_plane_waves: 0.045325446873903275
# Epoch: 202, MSE_plane_waves: 0.0610586553812027
# Epoch: 203, MSE_plane_waves: 0.049860283732414246
# Epoch: 204, MSE_plane_waves: 0.06397277861833572
# Epoch: 205, MSE_plane_waves: 0.03970443829894066
# Epoch: 206, MSE_plane_waves: 0.04127536341547966
# Epoch: 207, MSE_plane_waves: 0.06656059622764587
# Epoch: 208, MSE_plane_waves: 0.05075760930776596
# Epoch: 209, MSE_plane_waves: 0.056757789105176926
# Epoch: 210, MSE_plane_waves: 0.052650995552539825
# Epoch: 211, MSE_plane_waves: 0.04396713897585869
# Epoch: 212, MSE_plane_waves: 0.06350649893283844
# Epoch: 213, MSE_plane_waves: 0.05015535652637482
# Epoch: 214, MSE_plane_waves: 0.028002623468637466
# Epoch: 215, MSE_plane_waves: 0.03391339257359505
# Epoch: 216, MSE_plane_waves: 0.054929304867982864
# Epoch: 217, MSE_plane_waves: 0.022497791796922684
# Epoch: 218, MSE_plane_waves: 0.03716922551393509
# Epoch: 219, MSE_plane_waves: 0.045827802270650864
# Epoch: 220, MSE_plane_waves: 0.05688152462244034
# Epoch: 221, MSE_plane_waves: 0.040202293545007706
# Epoch: 222, MSE_plane_waves: 0.06748759746551514
# Epoch: 223, MSE_plane_waves: 0.04322793707251549
# Epoch: 224, MSE_plane_waves: 0.04878669232130051
# Epoch: 225, MSE_plane_waves: 0.033226128667593
# Epoch: 226, MSE_plane_waves: 0.03363887593150139
# Epoch: 227, MSE_plane_waves: 0.0496177040040493
# Epoch: 228, MSE_plane_waves: 0.07041008770465851
# Epoch: 229, MSE_plane_waves: 0.027916615828871727
# Epoch: 230, MSE_plane_waves: 0.03632665053009987
# Epoch: 231, MSE_plane_waves: 0.06913642585277557
# Epoch: 232, MSE_plane_waves: 0.04223603010177612
# Epoch: 233, MSE_plane_waves: 0.03771796077489853
# Epoch: 234, MSE_plane_waves: 0.041657932102680206
# Epoch: 235, MSE_plane_waves: 0.06331935524940491
# Epoch: 236, MSE_plane_waves: 0.0768173560500145
# Epoch: 237, MSE_plane_waves: 0.07619789987802505
# Epoch: 238, MSE_plane_waves: 0.053587790578603745
# Epoch: 239, MSE_plane_waves: 0.0217499490827322
# Epoch: 240, MSE_plane_waves: 0.03362276405096054
# Epoch: 241, MSE_plane_waves: 0.049332793802022934
# Epoch: 242, MSE_plane_waves: 0.028743602335453033
# Epoch: 243, MSE_plane_waves: 0.02707490883767605
# Epoch: 244, MSE_plane_waves: 0.0457870215177536
# Epoch: 245, MSE_plane_waves: 0.04141416400671005
# Epoch: 246, MSE_plane_waves: 0.019019708037376404
# Epoch: 247, MSE_plane_waves: 0.024473022669553757
# Epoch: 248, MSE_plane_waves: 0.04976445809006691
# Epoch: 249, MSE_plane_waves: 0.03932948783040047
# Epoch: 250, MSE_plane_waves: 0.03188558295369148
# Epoch: 251, MSE_plane_waves: 0.028125133365392685
# Epoch: 252, MSE_plane_waves: 0.05397975817322731
# Epoch: 253, MSE_plane_waves: 0.05642662197351456
# Epoch: 254, MSE_plane_waves: 0.03662847727537155
# Epoch: 255, MSE_plane_waves: 0.05115592107176781
# Epoch: 256, MSE_plane_waves: 0.05277290567755699
# Epoch: 257, MSE_plane_waves: 0.05314462631940842
# Epoch: 258, MSE_plane_waves: 0.05506756156682968
# Epoch: 259, MSE_plane_waves: 0.03599635139107704
# Epoch: 260, MSE_plane_waves: 0.0392453707754612
# Epoch: 261, MSE_plane_waves: 0.04231225326657295
# Epoch: 262, MSE_plane_waves: 0.017070982605218887
# Epoch: 263, MSE_plane_waves: 0.023688890039920807
# Epoch: 264, MSE_plane_waves: 0.05964373052120209
# Epoch: 265, MSE_plane_waves: 0.028880976140499115
# Epoch: 266, MSE_plane_waves: 0.03479019179940224
# Epoch: 267, MSE_plane_waves: 0.06914618611335754
# Epoch: 268, MSE_plane_waves: 0.02161129005253315
# Epoch: 269, MSE_plane_waves: 0.08706321567296982
# Epoch: 270, MSE_plane_waves: 0.07708460837602615
# Epoch: 271, MSE_plane_waves: 0.04821338132023811
# Epoch: 272, MSE_plane_waves: 0.050587836652994156
# Epoch: 273, MSE_plane_waves: 0.0607011504471302
# Epoch: 274, MSE_plane_waves: 0.052653878927230835
# Epoch: 275, MSE_plane_waves: 0.06513112783432007
# Epoch: 276, MSE_plane_waves: 0.04909311234951019
# Epoch: 277, MSE_plane_waves: 0.05556095764040947
# Epoch: 278, MSE_plane_waves: 0.0312812402844429
# Epoch: 279, MSE_plane_waves: 0.015299098566174507
# Epoch: 280, MSE_plane_waves: 0.06224599853157997
# Epoch: 281, MSE_plane_waves: 0.050101786851882935
# Epoch: 282, MSE_plane_waves: 0.06777030974626541
# Epoch: 283, MSE_plane_waves: 0.027100108563899994
# Epoch: 284, MSE_plane_waves: 0.05150348320603371
# Epoch: 285, MSE_plane_waves: 0.05774226039648056
# Epoch: 286, MSE_plane_waves: 0.024662937968969345
# Epoch: 287, MSE_plane_waves: 0.049490831792354584
# Epoch: 288, MSE_plane_waves: 0.05151901766657829
# Epoch: 289, MSE_plane_waves: 0.087311290204525
# Epoch: 290, MSE_plane_waves: 0.031594615429639816
# Epoch: 291, MSE_plane_waves: 0.06099528446793556
# Epoch: 292, MSE_plane_waves: 0.02771201729774475
# Epoch: 293, MSE_plane_waves: 0.026864847168326378
# Epoch: 294, MSE_plane_waves: 0.039072442799806595
# Epoch: 295, MSE_plane_waves: 0.0461590513586998
# Epoch: 296, MSE_plane_waves: 0.06776226311922073
# Epoch: 297, MSE_plane_waves: 0.05798424407839775
# Epoch: 298, MSE_plane_waves: 0.033004265278577805
# Epoch: 299, MSE_plane_waves: 0.03617960214614868
# Epoch: 300, MSE_plane_waves: 0.06900355219841003
# Epoch: 301, MSE_plane_waves: 0.05882134661078453
# Epoch: 302, MSE_plane_waves: 0.04203490540385246
# Epoch: 303, MSE_plane_waves: 0.04131940007209778
# Epoch: 304, MSE_plane_waves: 0.07075023651123047
# Epoch: 305, MSE_plane_waves: 0.03513127937912941
# Epoch: 306, MSE_plane_waves: 0.052737534046173096
# Epoch: 307, MSE_plane_waves: 0.030438914895057678
# Epoch: 308, MSE_plane_waves: 0.041400328278541565
# Epoch: 309, MSE_plane_waves: 0.07879969477653503
# Epoch: 310, MSE_plane_waves: 0.03145642578601837
# Epoch: 311, MSE_plane_waves: 0.013453548774123192
# Epoch: 312, MSE_plane_waves: 0.06402745097875595
# Epoch: 313, MSE_plane_waves: 0.025474241003394127
# Epoch: 314, MSE_plane_waves: 0.056816279888153076
# Epoch: 315, MSE_plane_waves: 0.06114673241972923
# Epoch: 316, MSE_plane_waves: 0.07018490135669708
# Epoch: 317, MSE_plane_waves: 0.048870060592889786
# Epoch: 318, MSE_plane_waves: 0.03293571248650551
# Epoch: 319, MSE_plane_waves: 0.04041411727666855
# Epoch: 320, MSE_plane_waves: 0.023158514872193336
# Epoch: 321, MSE_plane_waves: 0.0677698627114296
# Epoch: 322, MSE_plane_waves: 0.03542904928326607
# Epoch: 323, MSE_plane_waves: 0.03346128761768341
# Epoch: 324, MSE_plane_waves: 0.06369409710168839
# Epoch: 325, MSE_plane_waves: 0.05916327238082886
# Epoch: 326, MSE_plane_waves: 0.036449652165174484
# Epoch: 327, MSE_plane_waves: 0.060913894325494766
# Epoch: 328, MSE_plane_waves: 0.03816761076450348
# Epoch: 329, MSE_plane_waves: 0.052143435925245285
# Epoch: 330, MSE_plane_waves: 0.04019347205758095
# Epoch: 331, MSE_plane_waves: 0.03967626020312309
# Epoch: 332, MSE_plane_waves: 0.054992347955703735
# Epoch: 333, MSE_plane_waves: 0.07999904453754425
# Epoch: 334, MSE_plane_waves: 0.04621522128582001
# Epoch: 335, MSE_plane_waves: 0.055771660059690475
# Epoch: 336, MSE_plane_waves: 0.03436509892344475
# Epoch: 337, MSE_plane_waves: 0.03308291360735893
# Epoch: 338, MSE_plane_waves: 0.030517907813191414
# Epoch: 339, MSE_plane_waves: 0.031638309359550476
# Epoch: 340, MSE_plane_waves: 0.0387151837348938
# Epoch: 341, MSE_plane_waves: 0.056161507964134216
# Epoch: 342, MSE_plane_waves: 0.014137081801891327
# Epoch: 343, MSE_plane_waves: 0.06109881028532982
# Epoch: 344, MSE_plane_waves: 0.06656395643949509
# Epoch: 345, MSE_plane_waves: 0.01904156431555748
# Epoch: 346, MSE_plane_waves: 0.03737669438123703
# Epoch: 347, MSE_plane_waves: 0.052094973623752594
# Epoch: 348, MSE_plane_waves: 0.061531998217105865
# Epoch: 349, MSE_plane_waves: 0.03890417143702507
# Epoch: 350, MSE_plane_waves: 0.02968020923435688
# Epoch: 351, MSE_plane_waves: 0.013130057603120804
# Epoch: 352, MSE_plane_waves: 0.049982160329818726
# Epoch: 353, MSE_plane_waves: 0.034712597727775574
# Epoch: 354, MSE_plane_waves: 0.02524007111787796
# Epoch: 355, MSE_plane_waves: 0.03182337060570717
# Epoch: 356, MSE_plane_waves: 0.028184620663523674
# Epoch: 357, MSE_plane_waves: 0.03711443394422531
# Epoch: 358, MSE_plane_waves: 0.06263861060142517
# Epoch: 359, MSE_plane_waves: 0.014274992980062962
# Epoch: 360, MSE_plane_waves: 0.028058132156729698
# Epoch: 361, MSE_plane_waves: 0.042292941361665726
# Epoch: 362, MSE_plane_waves: 0.04698126018047333
# Epoch: 363, MSE_plane_waves: 0.01378449983894825
# Epoch: 364, MSE_plane_waves: 0.053013067692518234
# Epoch: 365, MSE_plane_waves: 0.018553100526332855
# Epoch: 366, MSE_plane_waves: 0.08312010020017624
# Epoch: 367, MSE_plane_waves: 0.016184154897928238
# Epoch: 368, MSE_plane_waves: 0.03686487674713135
# Epoch: 369, MSE_plane_waves: 0.03966289013624191
# Epoch: 370, MSE_plane_waves: 0.055645089596509933
# Epoch: 371, MSE_plane_waves: 0.05338164046406746
# Epoch: 372, MSE_plane_waves: 0.0755370706319809
# Epoch: 373, MSE_plane_waves: 0.07768799364566803
# Epoch: 374, MSE_plane_waves: 0.014540591277182102
# Epoch: 375, MSE_plane_waves: 0.022879932075738907
# Epoch: 376, MSE_plane_waves: 0.03617110848426819
# Epoch: 377, MSE_plane_waves: 0.01854032650589943
# Epoch: 378, MSE_plane_waves: 0.048276402056217194
# Epoch: 379, MSE_plane_waves: 0.024982795119285583
# Epoch: 380, MSE_plane_waves: 0.044637035578489304
# Epoch: 381, MSE_plane_waves: 0.034953773021698
# Epoch: 382, MSE_plane_waves: 0.03616303950548172
# Epoch: 383, MSE_plane_waves: 0.05454027280211449
# Epoch: 384, MSE_plane_waves: 0.029985757544636726
# Epoch: 385, MSE_plane_waves: 0.061888568103313446
# Epoch: 386, MSE_plane_waves: 0.05157991498708725
# Epoch: 387, MSE_plane_waves: 0.022558946162462234
# Epoch: 388, MSE_plane_waves: 0.040930647403001785
# Epoch: 389, MSE_plane_waves: 0.03199093043804169
# Epoch: 390, MSE_plane_waves: 0.05082724988460541
# Epoch: 391, MSE_plane_waves: 0.03359024226665497
# Epoch: 392, MSE_plane_waves: 0.05665325000882149
# Epoch: 393, MSE_plane_waves: 0.03888070210814476
# Epoch: 394, MSE_plane_waves: 0.06633660197257996
# Epoch: 395, MSE_plane_waves: 0.053522415459156036
# Epoch: 396, MSE_plane_waves: 0.030657049268484116
# Epoch: 397, MSE_plane_waves: 0.026270920410752296
# Epoch: 398, MSE_plane_waves: 0.024377411231398582
# Epoch: 399, MSE_plane_waves: 0.051714640110731125
# Epoch: 400, MSE_plane_waves: 0.03961668908596039
# Epoch: 401, MSE_plane_waves: 0.03627735748887062
# Epoch: 402, MSE_plane_waves: 0.03998954966664314
# Epoch: 403, MSE_plane_waves: 0.019752521067857742
# Epoch: 404, MSE_plane_waves: 0.01918119750916958
# Epoch: 405, MSE_plane_waves: 0.04786967113614082
# Epoch: 406, MSE_plane_waves: 0.016800330951809883
# Epoch: 407, MSE_plane_waves: 0.052287403494119644
# Epoch: 408, MSE_plane_waves: 0.05202191695570946
# Epoch: 409, MSE_plane_waves: 0.02886057086288929
# Epoch: 410, MSE_plane_waves: 0.05259507894515991
# Epoch: 411, MSE_plane_waves: 0.014322067610919476
# Epoch: 412, MSE_plane_waves: 0.03361864015460014
# Epoch: 413, MSE_plane_waves: 0.025920752435922623
# Epoch: 414, MSE_plane_waves: 0.055696967989206314
# Epoch: 415, MSE_plane_waves: 0.06854067742824554
# Epoch: 416, MSE_plane_waves: 0.03827397897839546
# Epoch: 417, MSE_plane_waves: 0.07319926470518112
# Epoch: 418, MSE_plane_waves: 0.060933683067560196
# Epoch: 419, MSE_plane_waves: 0.023657571524381638
# Epoch: 420, MSE_plane_waves: 0.048033036291599274
# Epoch: 421, MSE_plane_waves: 0.047731347382068634
# Epoch: 422, MSE_plane_waves: 0.025739293545484543
# Epoch: 423, MSE_plane_waves: 0.040623486042022705
# Epoch: 424, MSE_plane_waves: 0.030368437990546227
# Epoch: 425, MSE_plane_waves: 0.020199261605739594
# Epoch: 426, MSE_plane_waves: 0.045391231775283813
# Epoch: 427, MSE_plane_waves: 0.04668322950601578
# Epoch: 428, MSE_plane_waves: 0.04217018932104111
# Epoch: 429, MSE_plane_waves: 0.03610968589782715
# Epoch: 430, MSE_plane_waves: 0.050321679562330246
# Epoch: 431, MSE_plane_waves: 0.032457366585731506
# Epoch: 432, MSE_plane_waves: 0.05359785258769989
# Epoch: 433, MSE_plane_waves: 0.05527859181165695
# Epoch: 434, MSE_plane_waves: 0.0751272514462471
# Epoch: 435, MSE_plane_waves: 0.059188809245824814
# Epoch: 436, MSE_plane_waves: 0.04142108932137489
# Epoch: 437, MSE_plane_waves: 0.02805066853761673
# Epoch: 438, MSE_plane_waves: 0.04247509688138962
# Epoch: 439, MSE_plane_waves: 0.045018598437309265
# Epoch: 440, MSE_plane_waves: 0.04993395134806633
# Epoch: 441, MSE_plane_waves: 0.03488278016448021
# Epoch: 442, MSE_plane_waves: 0.0689588338136673
# Epoch: 443, MSE_plane_waves: 0.037351109087467194
# Epoch: 444, MSE_plane_waves: 0.03222048282623291
# Epoch: 445, MSE_plane_waves: 0.021577976644039154
# Epoch: 446, MSE_plane_waves: 0.049147527664899826
# Epoch: 447, MSE_plane_waves: 0.04584840312600136
# Epoch: 448, MSE_plane_waves: 0.012307809665799141
# Epoch: 449, MSE_plane_waves: 0.042444031685590744
# Epoch: 450, MSE_plane_waves: 0.035092759877443314
# Epoch: 451, MSE_plane_waves: 0.09308455139398575
# Epoch: 452, MSE_plane_waves: 0.015296359546482563
# Epoch: 453, MSE_plane_waves: 0.04608000069856644
# Epoch: 454, MSE_plane_waves: 0.09617263823747635
# Epoch: 455, MSE_plane_waves: 0.03459116816520691
# Epoch: 456, MSE_plane_waves: 0.03728002309799194
# Epoch: 457, MSE_plane_waves: 0.03739282861351967
# Epoch: 458, MSE_plane_waves: 0.04843050613999367
# Epoch: 459, MSE_plane_waves: 0.02014991082251072
# Epoch: 460, MSE_plane_waves: 0.026656165719032288
# Epoch: 461, MSE_plane_waves: 0.05852840840816498
# Epoch: 462, MSE_plane_waves: 0.026567334309220314
# Epoch: 463, MSE_plane_waves: 0.025895606726408005
# Epoch: 464, MSE_plane_waves: 0.009882860817015171
# Epoch: 465, MSE_plane_waves: 0.04479091241955757
# Epoch: 466, MSE_plane_waves: 0.02524613030254841
# Epoch: 467, MSE_plane_waves: 0.05479515716433525
# Epoch: 468, MSE_plane_waves: 0.021242603659629822
# Epoch: 469, MSE_plane_waves: 0.05796752870082855
# Epoch: 470, MSE_plane_waves: 0.06357523053884506
# Epoch: 471, MSE_plane_waves: 0.04717971011996269
# Epoch: 472, MSE_plane_waves: 0.047859400510787964
# Epoch: 473, MSE_plane_waves: 0.06469821184873581
# Epoch: 474, MSE_plane_waves: 0.058331362903118134
# Epoch: 475, MSE_plane_waves: 0.031418077647686005
# Epoch: 476, MSE_plane_waves: 0.041131068021059036
# Epoch: 477, MSE_plane_waves: 0.03741559386253357
# Epoch: 478, MSE_plane_waves: 0.04543508216738701
# Epoch: 479, MSE_plane_waves: 0.0382312647998333
# Epoch: 480, MSE_plane_waves: 0.041670624166727066
# Epoch: 481, MSE_plane_waves: 0.05644352734088898
# Epoch: 482, MSE_plane_waves: 0.06491304188966751
# Epoch: 483, MSE_plane_waves: 0.029228074476122856
# Epoch: 484, MSE_plane_waves: 0.06126593053340912
# Epoch: 485, MSE_plane_waves: 0.02847493439912796
# Epoch: 486, MSE_plane_waves: 0.08099590986967087
# Epoch: 487, MSE_plane_waves: 0.04501354321837425
# Epoch: 488, MSE_plane_waves: 0.03922578692436218
# Epoch: 489, MSE_plane_waves: 0.021252484992146492
# Epoch: 490, MSE_plane_waves: 0.06707894057035446
# Epoch: 491, MSE_plane_waves: 0.024635450914502144
# Epoch: 492, MSE_plane_waves: 0.045063409954309464
# Epoch: 493, MSE_plane_waves: 0.03525253012776375
# Epoch: 494, MSE_plane_waves: 0.06928211450576782
# Epoch: 495, MSE_plane_waves: 0.07176192104816437
# Epoch: 496, MSE_plane_waves: 0.055306874215602875
# Epoch: 497, MSE_plane_waves: 0.03580665588378906
# Epoch: 498, MSE_plane_waves: 0.054049327969551086
# Epoch: 499, MSE_plane_waves: 0.040992651134729385

# %% [markdown]
# # Check dissipation pattern for trained ANN

# %%
testing_dataset = ds.sample_epoch(time=np.random.randint(6950,8035))

# %%
plt.figure(figsize=(12,8))
import cmocean
for j,grid_harmonic in enumerate(['vorticity', 'divergence']):
    batch = sample_grid_harmonic(testing_dataset[20],grid_harmonic,plain=False)
    zb = batch.state.ANN(ann_Txy, ann_Txx_Tyy)
#    zb = batch.state.Smagorinsky()
    plt.subplot(2,2,1+j)
    dissipation =  zb['Txx'] * zb['sh_xx']# + batch.grid.interp(zb['Txy'] * zb['sh_xy'],['X','Y'])
    select_NA(dissipation).plot()
    plt.title(f'Dissipation (center) on \ngrid harmonic: {grid_harmonic}')
    plt.subplot(2,2,3+j)
    dissipation =  batch.grid.interp(zb['Txy'] * zb['sh_xy'],['X','Y'])
    select_NA(dissipation).plot()
    plt.title(f'Dissipation (corner) on \ngrid harmonic: {grid_harmonic}')

plt.tight_layout()

# %%
plt.figure(figsize=(12,4))
batch = sample_two_thirds(testing_dataset[20])
zb = batch.state.ANN(ann_Txy, ann_Txx_Tyy)
dissipation =  zb['Txx'] * zb['sh_xx'] + batch.grid.interp(zb['Txy'] * zb['sh_xy'],['X','Y'])
plt.subplot(1,2,1)
select_NA(dissipation).plot()
plt.title(f'Dissipation on plane wave')
plt.subplot(1,2,2)
select_NA(dissipation).plot(vmax=0)
plt.title('Only negative values of dissipation')
plt.tight_layout()

# %% [markdown]
# # Slight chess noise pattern is still present. Why?

# %%
for grid_harmonic in ['vorticity', 'divergence']:
    batch = sample_grid_harmonic(testing_dataset[20],grid_harmonic,plain=False)
    sh_xy, sh_xx, vort_xy = batch.state.velocity_gradients()
    plt.figure(figsize=(12,8))
    plt.subplot(2,2,1)
    sh_xy.plot()
    plt.title('sh_xy')
    plt.suptitle(f'Grid harmonic: {grid_harmonic}')
    plt.subplot(2,2,2)
    sh_xx.plot()
    plt.title('sh_xx')
    smag = batch.state.Smagorinsky()
    plt.subplot(2,2,3)
    smag['Txx'].plot()
    plt.title('Smagorinsky: Txx')
    plt.subplot(2,2,4)
    smag['Txy'].plot()
    plt.title('Smagorinsky: Txy')
    plt.tight_layout()

# %% [markdown]
# # Conclusions: there is contribution from not collocated point for both vorticity and divergence harmonics. This contribution likely disappers due to involved interpolation which we use for input feeatures. Lack of this contribution in ANN as compared to Smagorinsky probably results to this effect. While this may be considered as important, we note that this effect is almost negligible after many epochs of training. Note that corner point is effectively less affected by staggering because smagorinsky coefficient is computed in center and only then interpolated.
