# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from helpers.dataset import dataset_experiments, compute_spectrum
# %load_ext autoreload
# %autoreload 2

# %%
common_folder = '/scratch/pp2681/mom6/Feb2022'
exps = ('bare/R2', 'bare/R4', 'bare/R8', 'bare/R16', 'bare/R32', 'bare/R64',
       'ZB2020/R4/FGR1', 'ZB2020/R4/FGR2', 'ZB2020/R4/FGR3', 'ZB2020/R4/FGR4', 
       'ZB2020/R8/FGR1', 'ZB2020/R8/FGR2', 'ZB2020/R8/FGR3', 'ZB2020/R8/FGR4',
       'ZB2020/R4/FGR2_sign', 
       'ZB2020/R4/bilap_003', 'ZB2020/R4/FGR2_bilap_003',
       'ZB2020/R4/bilap_001', 'ZB2020/R4/FGR2_bilap_001',
       'ZB2020/R4/FGR2_AZ2017', 'ZB2020/R8/FGR2_AZ2017')
exps_names = ('R2', 'R4', 'R8', 'R16', 'R32', 'R64',
              'R4, ZB, FGR=1', 'R4, ZB, FGR=2', 'R4, ZB, FGR=3', 'R4, ZB, FGR=4',
              'R8, ZB, FGR=1', 'R8, ZB, FGR=2', 'R8, ZB, FGR=3', 'R8, ZB, FGR=4',
              'R4, ZB, FGR=2, sign', 
              'R4 $C_S=0.03$', 'R4, ZB, $C_S=0.03$',
              'R4 $C_S=0.01$', 'R4, ZB, $C_S=0.01$',
              'R4, AZ2017, FGR=2', 'R8, AZ2017, FGR=2')

# %%
ds = dataset_experiments(common_folder, exps, exps_names)

# %% [markdown]
# # KE spectra for $1/4^o$ coarse model

# %%
ds.plot_KE_spectrum(('bare/R4', 'ZB2020/R4/FGR2', 'ZB2020/R4/FGR3', 'ZB2020/R4/FGR4', 'bare/R32'), nfactor=2, tstart=3650.)

# %% [markdown]
# # KE spectra for $1/8^o$ coarse model

# %%
ds.plot_KE_spectrum(('bare/R8', 'ZB2020/R8/FGR2', 'ZB2020/R8/FGR3', 'ZB2020/R8/FGR4', 'bare/R32'), nfactor=2, tstart=3650.)

# %% [markdown]
# # Relative vorticity for $1/4^o$ coarse model

# %%
ds.plot_relative_vorticity_snapshot(('bare/R4', 'ZB2020/R4/FGR2', 'ZB2020/R4/FGR3', 'bare/R64'))

# %% [markdown]
# # Relative vorticity for $1/8^o$ coarse model

# %%
ds.plot_relative_vorticity_snapshot(('bare/R8', 'ZB2020/R8/FGR2', 'ZB2020/R8/FGR3', 'bare/R64'))

# %% [markdown]
# # KE snapshot $1/4^o$

# %%
ds.plot_KE_snapshot(('bare/R4', 'ZB2020/R4/FGR2', 'ZB2020/R4/FGR3', 'bare/R64'))

# %% [markdown]
# # KE snapshot $1/8^o$

# %%
ds.plot_KE_snapshot(('bare/R8', 'ZB2020/R8/FGR2', 'ZB2020/R8/FGR3', 'bare/R64'))

# %% [markdown]
# # EKE $1/4^o$

# %% [markdown]
# ### Upper layer

# %%
ds.plot_EKE(('bare/R4', 'ZB2020/R4/FGR2', 'ZB2020/R4/FGR3', 'bare/R64'))

# %% [markdown]
# ### Lower layer

# %%
ds.plot_EKE(('bare/R4', 'ZB2020/R4/FGR2', 'ZB2020/R4/FGR3', 'bare/R64'), zl=1, vmax=0.01)

# %% [markdown]
# # EKE $1/8^o$

# %% [markdown]
# ### Upper layer

# %%
ds.plot_EKE(('bare/R8', 'ZB2020/R8/FGR2', 'ZB2020/R8/FGR3', 'bare/R64'))

# %% [markdown]
# ### Lower layer

# %%
ds.plot_EKE(('bare/R8', 'ZB2020/R8/FGR2', 'ZB2020/R8/FGR3', 'bare/R64'), zl=1, vmax=0.01)

# %% [markdown]
# # Sea Surface Height, $1/4^o$

# %%
ds.plot_ssh(('bare/R4', 'ZB2020/R4/FGR2', 'ZB2020/R4/FGR3', 'bare/R64'))

# %% [markdown]
# # Sea Surface Height, $1/8^o$

# %%
ds.plot_ssh(('bare/R8', 'ZB2020/R8/FGR2', 'ZB2020/R8/FGR3', 'bare/R64'))

# %% [markdown]
# # KE series, $1/4^o$

# %%
ds.plot_KE(('bare/R4', 'ZB2020/R4/FGR2', 'ZB2020/R4/FGR3', 'bare/R64'))

# %% [markdown]
# # KE series, $1/8^o$

# %%
ds.plot_KE(('bare/R8', 'ZB2020/R8/FGR2', 'ZB2020/R8/FGR3', 'bare/R64'))

# %% [markdown]
# # Snapshot of ZB2020 tendency

# %%
ds.plot_SGS_snapshot('ZB2020/R4/FGR2')

# %% [markdown]
# # Wrong sign in ZB2020?

# %%
ds.plot_KE_spectrum(('bare/R4', 'ZB2020/R4/FGR2', 'ZB2020/R4/FGR2_sign', 'bare/R32'), nfactor=2, tstart=3650.)

# %%
ds.plot_cospectrum_componentwise(['ZB2020/R4/FGR2_sign'], tstart = 3650., nfactor=2, averaging=False)

# %% [markdown]
# # Too high Smagorinsky constant?

# %%
ds.plot_KE_spectrum(('ZB2020/R4/bilap_003', 'ZB2020/R4/FGR2_bilap_003', 'bare/R32'), nfactor=2, tstart=3650.)

# %%
ds.plot_KE_spectrum(('ZB2020/R4/bilap_001', 'ZB2020/R4/FGR2_bilap_001', 'bare/R32'), nfactor=2, tstart=3650.)

# %% [markdown]
# # Kinetic energy cospectrum with reducing eddy viscosity

# %%
ds.plot_cospectrum_componentwise(['ZB2020/R4/FGR2'], tstart = 3650., nfactor=2, averaging=False)
ds.plot_cospectrum_componentwise(['ZB2020/R4/FGR2_bilap_003'], tstart = 3650., nfactor=2, averaging=False)
ds.plot_cospectrum_componentwise(['ZB2020/R4/FGR2_bilap_001'], tstart = 3650., nfactor=2, averaging=False)

# %% [markdown]
# # Kinetic energy cospectrum with enlarging FGR

# %%
ds.plot_cospectrum_componentwise(['ZB2020/R4/FGR2'], tstart = 3650., nfactor=2, averaging=False)
ds.plot_cospectrum_componentwise(['ZB2020/R4/FGR3'], tstart = 3650., nfactor=2, averaging=False)
ds.plot_cospectrum_componentwise(['ZB2020/R4/FGR4'], tstart = 3650., nfactor=2, averaging=False)

# %% [markdown]
# # Comparison ZB2020 to AZ2017

# %%
ds.plot_KE_spectrum(('bare/R4', 'ZB2020/R4/FGR2', 'ZB2020/R4/FGR2_AZ2017', 'bare/R32'), nfactor=2, tstart=3650.)

# %%
ds.plot_KE_spectrum(('bare/R8', 'ZB2020/R8/FGR2', 'ZB2020/R8/FGR2_AZ2017', 'bare/R32'), nfactor=2, tstart=3650.)
