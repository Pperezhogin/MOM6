# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from helpers.dataset_new import *
# %load_ext autoreload
# %autoreload 2
matplotlib.rcParams['figure.dpi'] = 100
import json
from helpers.dataset import dataset_experiments, compute_spectrum, compute_cospectrum
from IPython.display import Video

# %% [markdown]
# # Compute statistics

# %%
DNS = ['/scratch/pp2681/mom6/Feb2022/bare/R4/output/', '/scratch/pp2681/mom6/Feb2022/bare/R8/output/', '/scratch/pp2681/mom6/Feb2022/bare/R16/output/', '/scratch/pp2681/mom6/Feb2022/bare/R32/output/', '/scratch/pp2681/mom6/Feb2022/bare/R64/output/']
compute_statistics(DNS, coarsegraining=['R4','R8', 'R16', 'R32'])
# Out:
# /scratch/pp2681/mom6/Feb2022/bare/R4/output/statistics.nc
# /scratch/pp2681/mom6/Feb2022/bare/R8/output/statistics.nc
# /scratch/pp2681/mom6/Feb2022/bare/R8/output/statistics_R4.nc
# /scratch/pp2681/mom6/Feb2022/bare/R16/output/statistics.nc
# /scratch/pp2681/mom6/Feb2022/bare/R16/output/statistics_R4.nc
# /scratch/pp2681/mom6/Feb2022/bare/R16/output/statistics_R8.nc
# /scratch/pp2681/mom6/Feb2022/bare/R32/output/statistics.nc
# /scratch/pp2681/mom6/Feb2022/bare/R32/output/statistics_R4.nc
# /scratch/pp2681/mom6/Feb2022/bare/R32/output/statistics_R8.nc
# /scratch/pp2681/mom6/Feb2022/bare/R32/output/statistics_R16.nc
# /scratch/pp2681/mom6/Feb2022/bare/R64/output/statistics.nc
# /scratch/pp2681/mom6/Feb2022/bare/R64/output/statistics_R4.nc
# /scratch/pp2681/mom6/Feb2022/bare/R64/output/statistics_R8.nc
# /scratch/pp2681/mom6/Feb2022/bare/R64/output/statistics_R16.nc
# /scratch/pp2681/mom6/Feb2022/bare/R64/output/statistics_R32.nc

# %%
R4_folders = ['/scratch/pp2681/mom6/Apr2022/R4/EXP'+str(i)+'/output' for i in range(1,211)]
compute_statistics(R4_folders)
# Out:
# /scratch/pp2681/mom6/Apr2022/R4/EXP1/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP2/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP3/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP4/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP5/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP6/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP7/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP8/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP9/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP10/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP11/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP12/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP13/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP14/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP15/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP16/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP17/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP18/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP19/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP20/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP21/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP22/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP23/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP24/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP25/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP26/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP27/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP28/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP29/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP30/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP31/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP32/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP33/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP34/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP35/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP36/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP37/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP38/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP39/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP40/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP41/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP42/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP43/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP44/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP45/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP46/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP47/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP48/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP49/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP50/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP51/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP52/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP53/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP54/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP55/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP56/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP57/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP58/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP59/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP60/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP61/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP62/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP63/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP64/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP65/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP66/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP67/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP68/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP69/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP70/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP71/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP72/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP73/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP74/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP75/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP76/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP77/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP78/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP79/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP80/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP81/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP82/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP83/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP84/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP85/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP86/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP87/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP88/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP89/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP90/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP91/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP92/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP93/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP94/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP95/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP96/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP97/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP98/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP99/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP100/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP101/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP102/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP103/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP104/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP105/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP106/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP107/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP108/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP109/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP110/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP111/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP112/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP113/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP114/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP115/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP116/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP117/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP118/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP119/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP120/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP121/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP122/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP123/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP124/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP125/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP126/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP127/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP128/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP129/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP130/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP131/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP132/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP133/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP134/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP135/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP136/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP137/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP138/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP139/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP140/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP141/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP142/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP143/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP144/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP145/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP146/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP147/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP148/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP149/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP150/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP151/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP152/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP153/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP154/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP155/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP156/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP157/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP158/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP159/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP160/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP161/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP162/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP163/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP164/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP165/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP166/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP167/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP168/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP169/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP170/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP171/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP172/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP173/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP174/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP175/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP176/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP177/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP178/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP179/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP180/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP181/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP182/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP183/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP184/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP185/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP186/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP187/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP188/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP189/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP190/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP191/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP192/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP193/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP194/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP195/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP196/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP197/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP198/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP199/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP200/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP201/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP202/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP203/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP204/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP205/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP206/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP207/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP208/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP209/output/statistics.nc
# /scratch/pp2681/mom6/Apr2022/R4/EXP210/output/statistics.nc

# %% [markdown]
# # Read DNS and coarse models into common file with additional dimension "EXP"

# %%
ds = xr.open_dataset('/scratch/pp2681/mom6/Feb2022/bare/R64/output/statistics_R4.nc')
param = {}
for exp in ['EXP'+str(i) for i in range(1,211)]:
    folder = '/scratch/pp2681/mom6/Apr2022/R4/'+exp
    stat = folder+'/output/statistics.nc'
    ds = xr.concat([ds, xr.open_dataset(stat)], dim='EXP')
    with open(folder+'/args.json', 'r') as f:
        param[exp] = json.load(f)

# %%
ds['ssh_mean_error'] = ds.ssh_mean - ds.ssh_mean.isel(EXP=0)
ds['ssh_var_error'] = ds.ssh_var - ds.ssh_var.isel(EXP=0)
ds['ssh_mean_L1'] = abs(ds.ssh_mean_error).mean(dim=("xh","yh"))
ds['ssh_mean_L2'] = np.sqrt((ds.ssh_mean_error**2).mean(dim=("xh","yh")))
ds['ssh_var_L1'] = abs(ds.ssh_var_error).mean(dim=("xh","yh"))
ds['ssh_var_L2'] = np.sqrt((ds.ssh_var_error**2).mean(dim=("xh","yh")))

# %%
C_S = np.zeros(211)
amp = np.zeros(211)
for key in param.keys():
    EXP = int(key[3:])
    C_S[EXP] = param[key]['SMAG_BI_CONST']
    if param[key]['USE_ZB2020']=='True':
        amp[EXP] = param[key]['amplitude']
amp[1:11] = 0.

# %%
fig, axs = plt.subplots(2,2, constrained_layout=True, figsize=(8,6))
X,Y,Z = plot_error_pcolor(fig,axs[0][0], ds, 'ssh_mean_L2', 0, C_S, amp, cmap_label = '$m$', title='Time-mean SSH, L2 error')
X,Y,Z = plot_error_pcolor(fig,axs[0][1], ds, 'ssh_var_L2', 0, C_S, amp, cmap_label = '$m^2$', title='Variance SSH, L2 error')
X,Y,Z = plot_error_pcolor(fig,axs[1][0], ds, 'ssh_mean_L2', 1, C_S, amp, cmap_label = '$m$', title='Time-mean SSH, L2 error')
X,Y,Z = plot_error_pcolor(fig,axs[1][1], ds, 'ssh_var_L2', 1, C_S, amp, cmap_label = '$m^2$', title='Variance SSH, L2 error')

# %%
ar1 = np.argsort(ds.ssh_mean_L2.isel(zi=0)).values[1:10]
ar2 = np.argsort(ds.ssh_var_L2.isel(zi=0)).values[1:10]
ar3 = np.argsort(ds.ssh_mean_L2.isel(zi=1)).values[1:10]
ar4 = np.argsort(ds.ssh_var_L2.isel(zi=1)).values[1:10]
print(ar1)
print(ar2)
print(ar3)
print(ar4)
print(np.intersect1d(ar1,ar2))
print(np.intersect1d(ar3,ar4))
# Out:
# [205 169 166 159 186 196 170 154 112]
# [  1 186 146 196 201 128  31 193  33]
# [205 169 166 186 159 196 170 157 154]
# [  1 146 135   4  33 128 186  45   5]
# [186 196]
# [186]

# %%
ds.ssh_mean_error.isel(zi=0,EXP=[11,205,186]).plot(col='EXP')

# %%
from functools import reduce
reduce(np.intersect1d, (ar1,ar2,ar3,ar4))
# Out:
# array([  1, 138, 166, 186, 193, 196, 203])

# %% [markdown]
# # Spectra for best experiments

# %%
common_folder = '/scratch/pp2681/mom6'

# %%
exps = ['Apr2022/R4/EXP'+str(i) for i in range(1,211)]
exps.append('Feb2022/bare/R32')
#print(exps)

# %%
DS =  dataset_experiments(common_folder, exps)

# %%
DS.plot_KE_spectrum(['Apr2022/R4/EXP1', 'Apr2022/R4/EXP4', 'Apr2022/R4/EXP8', 'Apr2022/R4/EXP10', 'Feb2022/bare/R32'],
names = ('$1/4^o, C_S=0.01$', '$1/4^o, C_S=0.04$', '$1/4^o, C_S=0.08$', '$1/4^o, C_S=0.1$', '$1/32^o$'), tstart=3650., Lat=(35,45), Lon=(5,15), window='hanning', nfactor=1, nd_wavenumber=False)

# %%
matplotlib.rcParams.update({'font.size': 10})
fig, axs = plt.subplots(3,3, constrained_layout=True, figsize=(10,6))

row = 0
for exp in [1, 4, 10]:
    ax = axs[row,0]
    ds.ssh_mean.isel(zi=0,EXP=0).plot(ax=ax, vmin=-1.7, vmax=1.7, cmap=cm.seismic, cbar_kwargs={'label': ''})
    ax.set_title('$1/64^o$ mean ssh, $m$')
    ax.set_ylabel('')
    ax.set_xlabel('')

    ax = axs[row,1]
    ds.ssh_mean.isel(zi=0,EXP=exp).plot(ax=ax, vmin=-1.7, vmax=1.7, cmap=cm.seismic, cbar_kwargs={'label': ''})
    ax.set_title(f'$1/4^o$, $C_S={exp/100}$,  mean ssh, $m$')
    ax.set_ylabel('')
    ax.set_xlabel('')

    ax = axs[row,2]
    ds.ssh_mean_error.isel(zi=0,EXP=exp).plot(ax=ax, vmin=-1.7, vmax=1.7, cmap=cm.seismic, cbar_kwargs={'label': ''})
    error = float(ds.ssh_mean_L2.isel(zi=0,EXP=exp))
    ax.set_title(f'L2 error = ${error:.5f}  m$')
    ax.set_ylabel('')
    ax.set_xlabel('')
    
    row += 1
fig.savefig('SSH_Smag.png', dpi=150)

# %%
DS.plot_KE_spectrum(['Apr2022/R4/EXP1', 'Apr2022/R4/EXP11', 'Apr2022/R4/EXP14', 'Apr2022/R4/EXP18', 'Feb2022/bare/R32'],
names = ('$1/4^o, \gamma=0$', '$1/4^o, \gamma=1/24$', '$1/4^o, \gamma=4/24$', '$1/4^o, \gamma=8/24$', '$1/32^o$'), tstart=3650., Lat=(35,45), Lon=(5,15), window='hanning', nfactor=1, nd_wavenumber=False)
plt.suptitle('$C_S=0.01$')
# Out:
# Text(0.5, 0.98, '$C_S=0.01$')

# %%
DS.plot_KE_spectrum(['Apr2022/R4/EXP4', 'Apr2022/R4/EXP41', 'Apr2022/R4/EXP44', 'Apr2022/R4/EXP48', 'Feb2022/bare/R32'],
names = ('$1/4^o, \gamma=0$', '$1/4^o, \gamma=1/24$', '$1/4^o, \gamma=4/24$', '$1/4^o, \gamma=8/24$', '$1/32^o$'), tstart=3650., Lat=(35,45), Lon=(5,15), window='hanning', nfactor=1, nd_wavenumber=False)
plt.suptitle('$C_S=0.04$')
# Out:
# Text(0.5, 0.98, '$C_S=0.04$')

# %%
DS.plot_KE_spectrum(['Apr2022/R4/EXP10', 'Apr2022/R4/EXP101', 'Apr2022/R4/EXP104', 'Apr2022/R4/EXP108', 'Feb2022/bare/R32'],
names = ('$1/4^o, \gamma=0$', '$1/4^o, \gamma=1/24$', '$1/4^o, \gamma=4/24$', '$1/4^o, \gamma=8/24$', '$1/32^o$'), tstart=3650., Lat=(35,45), Lon=(5,15), window='hanning', nfactor=1, nd_wavenumber=False)
plt.suptitle('$C_S=0.1$')
# Out:
# Text(0.5, 0.98, '$C_S=0.1$')

# %%
DS.plot_cospectrum_componentwise(['Apr2022/R4/EXP14'], tstart = 3650., Lat=(35,45), Lon=(5,15), window='hanning', ylim1=(-8e-10, 8e-10), ylim2=(-6e-11, 6e-11), averaging=False, nfactor=1, truncate=False, nd_wavenumber=False)
plt.suptitle('$C_S=0.01, \gamma=4/24$')

DS.plot_cospectrum_componentwise(['Apr2022/R4/EXP48'], tstart = 3650., Lat=(35,45), Lon=(5,15), window='hanning', ylim1=(-8e-10, 8e-10), ylim2=(-6e-11, 6e-11), averaging=False, nfactor=1, truncate=False, nd_wavenumber=False)
plt.suptitle('$C_S=0.04, \gamma=8/24$')

DS.plot_cospectrum_componentwise(['Apr2022/R4/EXP108'], tstart = 3650., Lat=(35,45), Lon=(5,15), window='hanning', ylim1=(-8e-10, 8e-10), ylim2=(-6e-11, 6e-11), averaging=False, nfactor=1, truncate=False, nd_wavenumber=False)
plt.suptitle('$C_S=0.1, \gamma=8/24$')
# Out:
# Text(0.5, 0.98, '$C_S=0.1, \\gamma=8/24$')

# %%
out = DS['Apr2022/R4/EXP18'].prog.RV.isel(zl=0,Time=[1,10,50,100]).plot(col='Time', size=4, aspect=0.9)
axs = out.axes
for i in range(axs.shape[1]):
    for j in range(axs.shape[0]):
        axs[j][i].set_xlabel('')
        axs[j][i].set_ylabel('')
plt.suptitle('$C_S=0.01, \gamma=8/24$', y=1)

out = DS['Apr2022/R4/EXP38'].prog.RV.isel(zl=0,Time=[1,10,50,100]).plot(col='Time', size=4, aspect=0.9)
axs = out.axes
for i in range(axs.shape[1]):
    for j in range(axs.shape[0]):
        axs[j][i].set_xlabel('')
        axs[j][i].set_ylabel('')
plt.suptitle('$C_S=0.03, \gamma=8/24$', y=1)
# Out:
# Text(0.5, 1, '$C_S=0.03, \\gamma=8/24$')

# %%
lox.axes[0][0]
# Out:
# <AxesSubplot:title={'center':'Time = 60.0'}, xlabel='q point nominal longitude\n[degrees_east]', ylabel='q point nominal latitude\n[degrees_north]'>

# %% [markdown]
# # Best ADM/Reynolds-like models

# %%
print(ds.ssh_mean_L2.isel(zi=0,EXP=112))
param['EXP112']
# Out:
# <xarray.DataArray 'ssh_mean_L2' ()>
# array(0.13747461, dtype=float32)
# Coordinates:
#     zi       float64 1.034e+03
# {'resolution': 'R4',
#  'DAYMAX': 7300.0,
#  'RESTINT': 1825.0,
#  'LAPLACIAN': 'False',
#  'BIHARMONIC': 'True',
#  'SMAGORINSKY_AH': True,
#  'SMAG_BI_CONST': 0.01,
#  'USE_ZB2020': 'True',
#  'amplitude': 0.125,
#  'ZB_type': 0,
#  'ZB_cons': 1,
#  'LPF_iter': 2,
#  'LPF_order': 4,
#  'HPF_iter': 0,
#  'HPF_order': 1,
#  'Stress_iter': 0,
#  'Stress_order': 1}

# %%
DS.plot_KE_spectrum(['Apr2022/R4/EXP1', 'Apr2022/R4/EXP112', 'Feb2022/bare/R32'],
names = ('$1/4^o, C_S=0.01$', '$1/4^o, C_S=0.01$, ADM-like', '$1/32^o$'), tstart=3650., Lat=(35,45), Lon=(5,15), window='hanning', nfactor=1, nd_wavenumber=False)
DS.plot_cospectrum_componentwise(['Apr2022/R4/EXP112'], tstart = 3650., Lat=(35,45), Lon=(5,15), window='hanning', ylim1=(-8e-10, 8e-10), ylim2=(-6e-11, 6e-11), averaging=False, nfactor=1, truncate=False, nd_wavenumber=False)

# %%
ds.ssh_mean_L2.isel(zi=0,EXP=145)
param['EXP145']
# Out:
# {'resolution': 'R4',
#  'DAYMAX': 7300.0,
#  'RESTINT': 1825.0,
#  'LAPLACIAN': 'False',
#  'BIHARMONIC': 'True',
#  'SMAGORINSKY_AH': True,
#  'SMAG_BI_CONST': 0.04,
#  'USE_ZB2020': 'True',
#  'amplitude': 1.0,
#  'ZB_type': 0,
#  'ZB_cons': 1,
#  'LPF_iter': 4,
#  'LPF_order': 4,
#  'HPF_iter': 0,
#  'HPF_order': 1,
#  'Stress_iter': 2,
#  'Stress_order': 2}

# %%
DS.plot_KE_spectrum(['Apr2022/R4/EXP4', 'Apr2022/R4/EXP145', 'Feb2022/bare/R32'],
names = ('$1/4^o, C_S=0.04$', '$1/4^o, C_S=0.04$, ADM-like filtered', '$1/32^o$'), tstart=3650., Lat=(35,45), Lon=(5,15), window='hanning', nfactor=1, nd_wavenumber=False)
DS.plot_cospectrum_componentwise(['Apr2022/R4/EXP145'], tstart = 3650., Lat=(35,45), Lon=(5,15), window='hanning', ylim1=(-8e-10, 8e-10), ylim2=(-6e-11, 6e-11), averaging=False, nfactor=1, truncate=False, nd_wavenumber=False)

# %%
ds.ssh_mean_L2.isel(zi=0,EXP=169)
param['EXP169']
# Out:
# {'resolution': 'R4',
#  'DAYMAX': 7300.0,
#  'RESTINT': 1825.0,
#  'LAPLACIAN': 'False',
#  'BIHARMONIC': 'True',
#  'SMAGORINSKY_AH': True,
#  'SMAG_BI_CONST': 0.02,
#  'USE_ZB2020': 'True',
#  'amplitude': 0.2916666666666667,
#  'ZB_type': 0,
#  'ZB_cons': 1,
#  'LPF_iter': 0,
#  'LPF_order': 1,
#  'HPF_iter': 0,
#  'HPF_order': 1,
#  'Stress_iter': 3,
#  'Stress_order': 2}

# %%
DS.plot_KE_spectrum(['Apr2022/R4/EXP2', 'Apr2022/R4/EXP169', 'Feb2022/bare/R32'],
names = ('$1/4^o, C_S=0.02$', '$1/4^o, C_S=0.02$, Momentum-filtered', '$1/32^o$'), tstart=3650., Lat=(35,45), Lon=(5,15), window='hanning', nfactor=1, nd_wavenumber=False)
DS.plot_cospectrum_componentwise(['Apr2022/R4/EXP169'], tstart = 3650., Lat=(35,45), Lon=(5,15), window='hanning', ylim1=(-8e-10, 8e-10), ylim2=(-6e-11, 6e-11), averaging=False, nfactor=1, truncate=False, nd_wavenumber=False)

# %%
ds.ssh_mean_L2.isel(zi=0,EXP=186)
param['EXP186']
# Out:
# {'resolution': 'R4',
#  'DAYMAX': 7300.0,
#  'RESTINT': 1825.0,
#  'LAPLACIAN': 'False',
#  'BIHARMONIC': 'True',
#  'SMAGORINSKY_AH': True,
#  'SMAG_BI_CONST': 0.01,
#  'USE_ZB2020': 'True',
#  'amplitude': 4.0,
#  'ZB_type': 0,
#  'ZB_cons': 1,
#  'LPF_iter': 2,
#  'LPF_order': 3,
#  'HPF_iter': 3,
#  'HPF_order': 2,
#  'Stress_iter': 0,
#  'Stress_order': 1}

# %%
DS.plot_KE_spectrum(['Apr2022/R4/EXP1', 'Apr2022/R4/EXP186', 'Feb2022/bare/R32'],
names = ('$1/4^o, C_S=0.01$', '$1/4^o, C_S=0.01$, Reynolds-like', '$1/32^o$'), tstart=3650., Lat=(35,45), Lon=(5,15), window='hanning', nfactor=1, nd_wavenumber=False)
DS.plot_cospectrum_componentwise(['Apr2022/R4/EXP186'], tstart = 3650., Lat=(35,45), Lon=(5,15), window='hanning', ylim1=(-8e-10, 8e-10), ylim2=(-6e-11, 6e-11), averaging=False, nfactor=1, truncate=False, nd_wavenumber=False)

# %%
ds.ssh_mean_L2.isel(zi=0,EXP=205)
param['EXP205']
# Out:
# {'resolution': 'R4',
#  'DAYMAX': 7300.0,
#  'RESTINT': 1825.0,
#  'LAPLACIAN': 'False',
#  'BIHARMONIC': 'True',
#  'SMAGORINSKY_AH': True,
#  'SMAG_BI_CONST': 0.03,
#  'USE_ZB2020': 'True',
#  'amplitude': 7.0,
#  'ZB_type': 0,
#  'ZB_cons': 1,
#  'LPF_iter': 1,
#  'LPF_order': 4,
#  'HPF_iter': 2,
#  'HPF_order': 2,
#  'Stress_iter': 1,
#  'Stress_order': 2}

# %%
DS.plot_KE_spectrum(['Apr2022/R4/EXP3', 'Apr2022/R4/EXP205', 'Feb2022/bare/R32'],
names = ('$1/4^o, C_S=0.03$', '$1/4^o, C_S=0.03$, best overall', '$1/32^o$'), tstart=3650., Lat=(35,45), Lon=(5,15), window='hanning', nfactor=1, nd_wavenumber=False)
DS.plot_cospectrum_componentwise(['Apr2022/R4/EXP205'], tstart = 3650., Lat=(35,45), Lon=(5,15), window='hanning', averaging=False, nfactor=1, truncate=False, nd_wavenumber=False)

# %%
DS.plot_relative_vorticity_snapshot(('Apr2022/R4/EXP3', 'Apr2022/R4/EXP205', 'Feb2022/bare/R32'), 
                                    names=['$1/4^o, C_S=0.03$', '$1/4^o, C_S=0.03$, best overall','$1/32^o$'])

# %%
DS.plot_ssh(('Apr2022/R4/EXP3', 'Apr2022/R4/EXP205', 'Feb2022/bare/R32'), 
                                    names=['$1/4^o, C_S=0.03$', '$1/4^o, C_S=0.03$, best overall','$1/32^o$'])

# %%
DS.plot_KE(('Apr2022/R4/EXP3', 'Apr2022/R4/EXP205', 'Feb2022/bare/R32'), 
                                    names=['$1/4^o, C_S=0.03$', '$1/4^o, C_S=0.03$, best overall','$1/32^o$'])

# %%
DS.plot_EKE(('Apr2022/R4/EXP3', 'Apr2022/R4/EXP205', 'Feb2022/bare/R32'), 
                                    names=['$1/4^o, C_S=0.03$', '$1/4^o, C_S=0.03$, best overall','$1/32^o$'], zl=0, vmax=0.02)
plt.suptitle('Upper Layer')
DS.plot_EKE(('Apr2022/R4/EXP3', 'Apr2022/R4/EXP205', 'Feb2022/bare/R32'), 
                                    names=['$1/4^o, C_S=0.03$', '$1/4^o, C_S=0.03$, best overall','$1/32^o$'], zl=1, vmax=0.01)
plt.suptitle('Lower Layer')
# Out:
# Text(0.5, 0.98, 'Lower Layer')

# %% [markdown]
# # Animation

# %%
exps =  ['Apr2022/R4/EXP3', 'Apr2022/R4/EXP205', 'Apr2022/R4/EXP18', 'Apr2022/R4/EXP38', 'Feb2022/bare/R32']
ds =  dataset_experiments('/scratch/pp2681/mom6/', exps, ['$1/4^o, C_S=0.03$', '$1/4^o, C_S=0.03$, best overall', '$1/4^o, C_S=0.01, \gamma=8/24$', '$1/4^o, C_S=0.03, \gamma=8/24$', '$1/32^o$'])

# %%
video_name, fig = ds.plot_relative_vorticity_animation([exps[i] for i in [0,1,4]], timeover=242,zl=1)
Video(video_name,width=1000)
# Out:
# <video src="vorti_anim_.mp4" controls  width="1000" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
video_name, fig = ds.plot_relative_vorticity_animation([exps[i] for i in [2,3,4]], timeover=242,zl=1)
Video(video_name,width=1000)
# Out:
# <video src="vorti_anim_.mp4" controls  width="1000" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
video_name, fig = ds.plot_KE_animation([exps[i] for i in [0,1,4]], timeover=242,zl=1,vmax=0.01)
Video(video_name,width=1000)
# Out:
# <video src="vorti_anim_.mp4" controls  width="1000" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
matplotlib.rcParams['figure.dpi'] = 200
fig, axs = plt.subplots(2,6, figsize=(10,3.5), gridspec_kw={'wspace': 0, 'hspace': 0.2})
axs = axs.reshape(-1)
for j, key in enumerate(['sh_xx', 'sh_xy', 'vort_xy', 'S_11', 'S_12', 'S_22','sh_xxf', 'sh_xyf', 'vort_xyf', 'S_11f', 'S_12f', 'S_22f']):
    field = ds['Apr2022/R4/EXP205'].mom[key].isel(Time=-1,zl=0)
    vmax = float(np.percentile(np.nan_to_num(field),99.9))
    vmin = float(np.percentile(np.nan_to_num(field),0.1))
    vmax = max(abs(vmin), abs(vmax))
    
    field.plot(ax=axs[j], add_colorbar=False, vmin=-vmax, vmax=vmax, cmap=cm.bwr)
    axs[j].set_xlabel('')
    axs[j].set_ylabel('')
    axs[j].set_title(key)
    axs[j].set_xticks([])
    axs[j].set_yticks([])
fig.savefig('Filtering.png',dpi=200)
# Out:
# vmax= 8.258831913735777e-06
# max(abs)= 1.327779591520084e-05
# vmax= 1.0614643288136003e-05
# max(abs)= 1.57834238052601e-05
# vmax= 1.3951450084277895e-05
# max(abs)= 2.1421305063995533e-05
# vmax= 0.05098448237031698
# max(abs)= 0.07532807439565659
# vmax= 0.012674241349101325
# max(abs)= 0.02986004948616028
# vmax= 0.022535709412768484
# max(abs)= 0.04388823360204697
# vmax= 2.2120059038570615e-06
# max(abs)= 3.6131164051766973e-06
# vmax= 2.554611814048258e-06
# max(abs)= 3.817825927399099e-06
# vmax= 3.1655070088163484e-06
# max(abs)= 5.772584245278267e-06
# vmax= 0.041429233986884355
# max(abs)= 0.0654185563325882
# vmax= 0.009409286662936315
# max(abs)= 0.017276586964726448
# vmax= 0.01647685421258211
# max(abs)= 0.026524323970079422
